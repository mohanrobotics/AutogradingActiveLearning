# %% [markdown]
# # Binary classification - single_model using Naive Bayes

# %% [markdown]
# # Importing and Preprocessing

# %% [markdown]
# ## Importing libraries

# %%
#### import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %% [markdown]
# ## Importing files

# %%
original_data = pd.read_csv('../dataset/mohler2_cleaned.csv' ,dtype = {'question_number':str})
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'question_number':'question_id','question_text':'question','answer_model':'ref_answer','answer_student':'student_answer','score_avg':'grade'})

# %% [markdown]
# ## Preprocessing

# %%
df = original_data.copy()

#converting to lower case
df['ref_modified'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))


#lemmatisation
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))

# %% [markdown]
# # Gathering required features

# %%
short_df = df[['question_id','question','student_answer','student_modified','ref_modified' ,'grade']]
short_df['grades_round']= short_df['grade'].apply(lambda x: round(x))

# %% [markdown]
# # Bag of words

# %%
# short_df['word_count'] = short_df['student_answer'].apply(lambda x: dict(Counter(x.split())))

# counting unique words in every student's answer
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(short_df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = short_df['grades_round'].values

# %% [markdown]
# # Seeding

# %%
#getting the seed index
classes = short_df['grades_round'].unique()
seed_index = []
for i in classes:
    seed_index.append(short_df['grades_round'][short_df['grades_round']==i].index[0])
seed_index
# Out:
# [0, 1, 4, 5, 52, 94]

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
train_idx = seed_index
X_train = X[train_idx]
y_train = Y[train_idx]
 
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
# lr = LogisticRegression()
nb = MultinomialNB()
learner = ActiveLearner(
#     estimator = lr,
    estimator = nb,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = int(len(X)/5)
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
#     print("\nQ: ", act_data.loc[int(query_idx),'question'])
#     print("A: ",act_data.loc[int(query_idx),'student_answer'])
#     print("Actual grade: ",y_pool[query_idx].reshape(1, ))
#     print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
#     human_label = int(input("\nGive me a grade 0 or 1:"))
    
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=y_pool[query_idx].reshape(1, )
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X_pool, y_pool))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X_pool, y_pool)))
print("======================================")
print("By just labelling ",round(n_queries*100.0/len(X),2),"% of total data accuracy of ", round(learner.score(X_pool, y_pool),3), " % is achieved on the unseen data"  )
# Out:
# Accuracy after query no. 1: 0.060370
# Accuracy after query no. 2: 0.054643
# Accuracy after query no. 3: 0.111796
# Accuracy after query no. 4: 0.109375
# Accuracy after query no. 5: 0.133690
# Accuracy after query no. 6: 0.195062
# Accuracy after query no. 7: 0.259366
# Accuracy after query no. 8: 0.241351
# Accuracy after query no. 9: 0.247219
# Accuracy after query no. 10: 0.260099
# Accuracy after query no. 11: 0.277938
# Accuracy after query no. 12: 0.363861
# Accuracy after query no. 13: 0.308296
# Accuracy after query no. 14: 0.298101
# Accuracy after query no. 15: 0.313094
# Accuracy after query no. 16: 0.312397
# Accuracy after query no. 17: 0.377015
# Accuracy after query no. 18: 0.380066
# Accuracy after query no. 19: 0.395532
# Accuracy after query no. 20: 0.371275
# Accuracy after query no. 21: 0.371014
# Accuracy after query no. 22: 0.374482
# Accuracy after query no. 23: 0.346457
# Accuracy after query no. 24: 0.356551
# Accuracy after query no. 25: 0.360846
# Accuracy after query no. 26: 0.360996
# Accuracy after query no. 27: 0.392279
# Accuracy after query no. 28: 0.406146
# Accuracy after query no. 29: 0.412962
# Accuracy after query no. 30: 0.412303
# Accuracy after query no. 31: 0.424116
# Accuracy after query no. 32: 0.425125
# Accuracy after query no. 33: 0.425718
# Accuracy after query no. 34: 0.426311
# Accuracy after query no. 35: 0.426905
# Accuracy after query no. 36: 0.426667
# Accuracy after query no. 37: 0.421842
# Accuracy after query no. 38: 0.428691
# Accuracy after query no. 39: 0.428452
# Accuracy after query no. 40: 0.424875
# Accuracy after query no. 41: 0.428392
# Accuracy after query no. 42: 0.469089
# Accuracy after query no. 43: 0.469703
# Accuracy after query no. 44: 0.461957
# Accuracy after query no. 45: 0.465077
# Accuracy after query no. 46: 0.467782
# Accuracy after query no. 47: 0.465048
# Accuracy after query no. 48: 0.466080
# Accuracy after query no. 49: 0.467951
# Accuracy after query no. 50: 0.474434
# Accuracy after query no. 51: 0.471279
# Accuracy after query no. 52: 0.471896
# Accuracy after query no. 53: 0.470835
# Accuracy after query no. 54: 0.473971
# Accuracy after query no. 55: 0.472071
# Accuracy after query no. 56: 0.468908
# Accuracy after query no. 57: 0.456074
# Accuracy after query no. 58: 0.453322
# Accuracy after query no. 59: 0.453513
# Accuracy after query no. 60: 0.452441
# Accuracy after query no. 61: 0.438316
# Accuracy after query no. 62: 0.433867
# Accuracy after query no. 63: 0.443742
# Accuracy after query no. 64: 0.440135
# Accuracy after query no. 65: 0.440321
# Accuracy after query no. 66: 0.438397
# Accuracy after query no. 67: 0.438582
# Accuracy after query no. 68: 0.438767
# Accuracy after query no. 69: 0.438952
# Accuracy after query no. 70: 0.437447
# Accuracy after query no. 71: 0.442283
# Accuracy after query no. 72: 0.440355
# Accuracy after query no. 73: 0.440542
# Accuracy after query no. 74: 0.440728
# Accuracy after query no. 75: 0.445574
# Accuracy after query no. 76: 0.445339
# Accuracy after query no. 77: 0.443832
# Accuracy after query no. 78: 0.446141
# Accuracy after query no. 79: 0.454815
# Accuracy after query no. 80: 0.452886
# Accuracy after query no. 81: 0.452229
# Accuracy after query no. 82: 0.455395
# Accuracy after query no. 83: 0.456864
# Accuracy after query no. 84: 0.455357
# Accuracy after query no. 85: 0.456402
# Accuracy after query no. 86: 0.456596
# Accuracy after query no. 87: 0.458493
# Accuracy after query no. 88: 0.461670
# Accuracy after query no. 89: 0.462292
# Accuracy after query no. 90: 0.468031
# Accuracy after query no. 91: 0.467804
# Accuracy after query no. 92: 0.467577
# Accuracy after query no. 93: 0.460094
# Accuracy after query no. 94: 0.461144
# Accuracy after query no. 95: 0.466894
# Accuracy after query no. 96: 0.465385
# Accuracy after query no. 97: 0.465156
# Accuracy after query no. 98: 0.464500
# Accuracy after query no. 99: 0.464698
# Accuracy after query no. 100: 0.463613
# Accuracy after query no. 101: 0.466809
# Accuracy after query no. 102: 0.464439
# Accuracy after query no. 103: 0.460780
# Accuracy after query no. 104: 0.454545
# Accuracy after query no. 105: 0.451737
# Accuracy after query no. 106: 0.460944
# Accuracy after query no. 107: 0.460713
# Accuracy after query no. 108: 0.468213
# Accuracy after query no. 109: 0.472282
# Accuracy after query no. 110: 0.474205
# Accuracy after query no. 111: 0.476129
# Accuracy after query no. 112: 0.481497
# Accuracy after query no. 113: 0.485149
# Accuracy after query no. 114: 0.484065
# Accuracy after query no. 115: 0.483843
# Accuracy after query no. 116: 0.482759
# Accuracy after query no. 117: 0.482104
# Accuracy after query no. 118: 0.482312
# Accuracy after query no. 119: 0.471731
# Accuracy after query no. 120: 0.472366
# Accuracy after query no. 121: 0.470410
# Accuracy after query no. 122: 0.474071
# Accuracy after query no. 123: 0.476438
# Accuracy after query no. 124: 0.478806
# Accuracy after query no. 125: 0.475552
# Accuracy after query no. 126: 0.474026
# Accuracy after query no. 127: 0.469467
# Accuracy after query no. 128: 0.469671
# Accuracy after query no. 129: 0.469874
# Accuracy after query no. 130: 0.471813
# Accuracy after query no. 131: 0.471150
# Accuracy after query no. 132: 0.467882
# Accuracy after query no. 133: 0.466782
# Accuracy after query no. 134: 0.468288
# Accuracy after query no. 135: 0.469361
# Accuracy after query no. 136: 0.476522
# Accuracy after query no. 137: 0.478904
# Accuracy after query no. 138: 0.477372
# Accuracy after query no. 139: 0.474097
# Accuracy after query no. 140: 0.471254
# Accuracy after query no. 141: 0.471895
# Accuracy after query no. 142: 0.479948
# Accuracy after query no. 143: 0.481029
# Accuracy after query no. 144: 0.492583
# Accuracy after query no. 145: 0.497599
# Accuracy after query no. 146: 0.497817
# Accuracy after query no. 147: 0.490607
# Accuracy after query no. 148: 0.486014
# Accuracy after query no. 149: 0.485352
# Accuracy after query no. 150: 0.484252
# Accuracy after query no. 151: 0.491028
# Accuracy after query no. 152: 0.488179
# Accuracy after query no. 153: 0.491897
# Accuracy after query no. 154: 0.489921
# Accuracy after query no. 155: 0.496274
# Accuracy after query no. 156: 0.496053
# Accuracy after query no. 157: 0.495832
# Accuracy after query no. 158: 0.495610
# Accuracy after query no. 159: 0.496706
# Accuracy after query no. 160: 0.500879
# Accuracy after query no. 161: 0.500220
# Accuracy after query no. 162: 0.501319
# Accuracy after query no. 163: 0.501100
# Accuracy after query no. 164: 0.500000
# Accuracy after query no. 165: 0.499780
# Accuracy after query no. 166: 0.498678
# Accuracy after query no. 167: 0.497576
# Accuracy after query no. 168: 0.498236
# Accuracy after query no. 169: 0.498456
# Accuracy after query no. 170: 0.498676
# Accuracy after query no. 171: 0.498896
# Accuracy after query no. 172: 0.500000
# Accuracy after query no. 173: 0.488732
# Accuracy after query no. 174: 0.489832
# Accuracy after query no. 175: 0.488280
# Accuracy after query no. 176: 0.485841
# Accuracy after query no. 177: 0.478973
# Accuracy after query no. 178: 0.474314
# Accuracy after query no. 179: 0.472751
# Accuracy after query no. 180: 0.474734
# Accuracy after query no. 181: 0.468736
# Accuracy after query no. 182: 0.468944
# Accuracy after query no. 183: 0.469596
# Accuracy after query no. 184: 0.469361
# Accuracy after query no. 185: 0.469125
# Accuracy after query no. 186: 0.465333
# Accuracy after query no. 187: 0.466874
# Accuracy after query no. 188: 0.465302
# Accuracy after query no. 189: 0.465065
# Accuracy after query no. 190: 0.464826
# Accuracy after query no. 191: 0.478842
# Accuracy after query no. 192: 0.478164
# Accuracy after query no. 193: 0.478377
# Accuracy after query no. 194: 0.481267
# Accuracy after query no. 195: 0.483713
# Accuracy after query no. 196: 0.484375
# Accuracy after query no. 197: 0.484591
# Accuracy after query no. 198: 0.484808
# Accuracy after query no. 199: 0.485025
# Accuracy after query no. 200: 0.484794
# Accuracy after query no. 201: 0.485011
# Accuracy after query no. 202: 0.484781
# Accuracy after query no. 203: 0.482311
# Accuracy after query no. 204: 0.489247
# Accuracy after query no. 205: 0.492604
# Accuracy after query no. 206: 0.492825
# Accuracy after query no. 207: 0.493495
# Accuracy after query no. 208: 0.494165
# Accuracy after query no. 209: 0.494387
# Accuracy after query no. 210: 0.494609
# Accuracy after query no. 211: 0.493034
# Accuracy after query no. 212: 0.493705
# Accuracy after query no. 213: 0.496176
# Accuracy after query no. 214: 0.496400
# Accuracy after query no. 215: 0.498424
# Accuracy after query no. 216: 0.498198
# Accuracy after query no. 217: 0.497972
# Accuracy after query no. 218: 0.491885
# Accuracy after query no. 219: 0.490753
# Accuracy after query no. 220: 0.490523
# Accuracy after query no. 221: 0.488939
# Accuracy after query no. 222: 0.490967
# Accuracy after query no. 223: 0.491188
# Accuracy after query no. 224: 0.492315
# Accuracy after query no. 225: 0.492085
# Accuracy after query no. 226: 0.492760
# Accuracy after query no. 227: 0.492983
# Accuracy after query no. 228: 0.490489
# Accuracy after query no. 229: 0.490711
# Accuracy after query no. 230: 0.490027
# Accuracy after query no. 231: 0.489796
# Accuracy after query no. 232: 0.490018
# Accuracy after query no. 233: 0.490695
# Accuracy after query no. 234: 0.490463
# Accuracy after query no. 235: 0.495684
# Accuracy after query no. 236: 0.495455
# Accuracy after query no. 237: 0.496135
# Accuracy after query no. 238: 0.497270
# Accuracy after query no. 239: 0.497497
# Accuracy after query no. 240: 0.497723
# Accuracy after query no. 241: 0.497494
# Accuracy after query no. 242: 0.499544
# Accuracy after query no. 243: 0.500684
# Accuracy after query no. 244: 0.500456
# Accuracy after query no. 245: 0.500685
# Accuracy after query no. 246: 0.500913
# Accuracy after query no. 247: 0.500228
# Accuracy after query no. 248: 0.500914
# Accuracy after query no. 249: 0.498400
# Accuracy after query no. 250: 0.499085
# Accuracy after query no. 251: 0.498398
# Accuracy after query no. 252: 0.498626
# Accuracy after query no. 253: 0.500229
# Accuracy after query no. 254: 0.498625
# Accuracy after query no. 255: 0.499771
# Accuracy after query no. 256: 0.496330
# Accuracy after query no. 257: 0.496099
# Accuracy after query no. 258: 0.495868
# Accuracy after query no. 259: 0.497933
# Accuracy after query no. 260: 0.497243
# Accuracy after query no. 261: 0.497471
# Accuracy after query no. 262: 0.496780
# Accuracy after query no. 263: 0.495628
# Accuracy after query no. 264: 0.496317
# Accuracy after query no. 265: 0.496545
# Accuracy after query no. 266: 0.499078
# Accuracy after query no. 267: 0.492854
# Accuracy after query no. 268: 0.496771
# Accuracy after query no. 269: 0.496539
# Accuracy after query no. 270: 0.494460
# Accuracy after query no. 271: 0.495150
# Accuracy after query no. 272: 0.495379
# Accuracy after query no. 273: 0.495608
# Accuracy after query no. 274: 0.497687
# Accuracy after query no. 275: 0.492827
# Accuracy after query no. 276: 0.492130
# Accuracy after query no. 277: 0.495137
# Accuracy after query no. 278: 0.494903
# Accuracy after query no. 279: 0.495596
# Accuracy after query no. 280: 0.496289
# Accuracy after query no. 281: 0.495592
# Accuracy after query no. 282: 0.496750
# Accuracy after query no. 283: 0.496981
# Accuracy after query no. 284: 0.496747
# Accuracy after query no. 285: 0.497443
# Accuracy after query no. 286: 0.497209
# Accuracy after query no. 287: 0.497441
# Accuracy after query no. 288: 0.497672
# Accuracy after query no. 289: 0.497904
# Accuracy after query no. 290: 0.498602
# Accuracy after query no. 291: 0.498834
# Accuracy after query no. 292: 0.500000
# Accuracy after query no. 293: 0.497434
# Accuracy after query no. 294: 0.497666
# Accuracy after query no. 295: 0.500701
# Accuracy after query no. 296: 0.499065
# Accuracy after query no. 297: 0.501169
# Accuracy after query no. 298: 0.501403
# Accuracy after query no. 299: 0.500702
# Accuracy after query no. 300: 0.501873
# Accuracy after query no. 301: 0.502108
# Accuracy after query no. 302: 0.502812
# Accuracy after query no. 303: 0.508673
# Accuracy after query no. 304: 0.508443
# Accuracy after query no. 305: 0.513374
# Accuracy after query no. 306: 0.514085
# Accuracy after query no. 307: 0.513856
# Accuracy after query no. 308: 0.515508
# Accuracy after query no. 309: 0.512929
# Accuracy after query no. 310: 0.512230
# Accuracy after query no. 311: 0.511529
# Accuracy after query no. 312: 0.509887
# Accuracy after query no. 313: 0.510127
# Accuracy after query no. 314: 0.512253
# Accuracy after query no. 315: 0.509194
# Accuracy after query no. 316: 0.511321
# Accuracy after query no. 317: 0.509674
# Accuracy after query no. 318: 0.508971
# Accuracy after query no. 319: 0.506377
# Accuracy after query no. 320: 0.505198
# Accuracy after query no. 321: 0.505437
# Accuracy after query no. 322: 0.505676
# Accuracy after query no. 323: 0.505916
# Accuracy after query no. 324: 0.509943
# Accuracy after query no. 325: 0.514448
# Accuracy after query no. 326: 0.513744
# Accuracy after query no. 327: 0.514462
# Accuracy after query no. 328: 0.518027
# Accuracy after query no. 329: 0.517323
# Accuracy after query no. 330: 0.517094
# Accuracy after query no. 331: 0.516865
# Accuracy after query no. 332: 0.516160
# Accuracy after query no. 333: 0.515930
# Accuracy after query no. 334: 0.516175
# Accuracy after query no. 335: 0.516421
# Accuracy after query no. 336: 0.516667
# Accuracy after query no. 337: 0.516436
# Accuracy after query no. 338: 0.522402
# Accuracy after query no. 339: 0.522175
# Accuracy after query no. 340: 0.520038
# Accuracy after query no. 341: 0.517422
# Accuracy after query no. 342: 0.517670
# Accuracy after query no. 343: 0.517439
# Accuracy after query no. 344: 0.517686
# Accuracy after query no. 345: 0.518890
# Accuracy after query no. 346: 0.519617
# Accuracy after query no. 347: 0.517951
# Accuracy after query no. 348: 0.518199
# Accuracy after query no. 349: 0.518927
# Accuracy after query no. 350: 0.523011
# Accuracy after query no. 351: 0.523741
# Accuracy after query no. 352: 0.523512
# Accuracy after query no. 353: 0.521363
# Accuracy after query no. 354: 0.521614
# Accuracy after query no. 355: 0.521864
# Accuracy after query no. 356: 0.519712
# Accuracy after query no. 357: 0.518519
# Accuracy after query no. 358: 0.520693
# Accuracy after query no. 359: 0.520462
# Accuracy after query no. 360: 0.520231
# Accuracy after query no. 361: 0.521446
# Accuracy after query no. 362: 0.521697
# Accuracy after query no. 363: 0.522431
# Accuracy after query no. 364: 0.523649
# Accuracy after query no. 365: 0.523419
# Accuracy after query no. 366: 0.520773
# Accuracy after query no. 367: 0.520058
# Accuracy after query no. 368: 0.523211
# Accuracy after query no. 369: 0.524432
# Accuracy after query no. 370: 0.524685
# Accuracy after query no. 371: 0.522518
# Accuracy after query no. 372: 0.523256
# Accuracy after query no. 373: 0.524479
# Accuracy after query no. 374: 0.524733
# Accuracy after query no. 375: 0.524017
# Accuracy after query no. 376: 0.523786
# Accuracy after query no. 377: 0.522584
# Accuracy after query no. 378: 0.522838
# Accuracy after query no. 379: 0.522120
# Accuracy after query no. 380: 0.520914
# Accuracy after query no. 381: 0.520681
# Accuracy after query no. 382: 0.520448
# Accuracy after query no. 383: 0.519727
# Accuracy after query no. 384: 0.520468
# Accuracy after query no. 385: 0.525110
# Accuracy after query no. 386: 0.523902
# Accuracy after query no. 387: 0.523670
# Accuracy after query no. 388: 0.523438
# Accuracy after query no. 389: 0.523205
# Accuracy after query no. 390: 0.523460
# Accuracy after query no. 391: 0.522738
# Accuracy after query no. 392: 0.518591
# Accuracy after query no. 393: 0.521292
# Accuracy after query no. 394: 0.521548
# Accuracy after query no. 395: 0.525723
# Accuracy after query no. 396: 0.526471
# Accuracy after query no. 397: 0.526729
# Accuracy after query no. 398: 0.525025
# Accuracy after query no. 399: 0.525773
# Accuracy after query no. 400: 0.525540
# Accuracy after query no. 401: 0.527273
# Accuracy after query no. 402: 0.528515
# Accuracy after query no. 403: 0.528283
# Accuracy after query no. 404: 0.531004
# Accuracy after query no. 405: 0.531265
# Accuracy after query no. 406: 0.531034
# Accuracy after query no. 407: 0.529818
# Accuracy after query no. 408: 0.529093
# Accuracy after query no. 409: 0.529354
# Accuracy after query no. 410: 0.530109
# Accuracy after query no. 411: 0.530370
# Accuracy after query no. 412: 0.530632
# Accuracy after query no. 413: 0.530895
# Accuracy after query no. 414: 0.530663
# Accuracy after query no. 415: 0.531420
# Accuracy after query no. 416: 0.532673
# Accuracy after query no. 417: 0.532442
# Accuracy after query no. 418: 0.534192
# Accuracy after query no. 419: 0.532970
# Accuracy after query no. 420: 0.534226
# Accuracy after query no. 421: 0.533499
# Accuracy after query no. 422: 0.533267
# Accuracy after query no. 423: 0.534029
# Accuracy after query no. 424: 0.534294
# Accuracy after query no. 425: 0.534560
# Accuracy after query no. 426: 0.533831
# Accuracy after query no. 427: 0.536088
# Accuracy after query no. 428: 0.534363
# Accuracy after query no. 429: 0.534629
# Accuracy after query no. 430: 0.528415
# Accuracy after query no. 431: 0.530175
# Accuracy after query no. 432: 0.529940
# Accuracy after query no. 433: 0.537194
# Accuracy after query no. 434: 0.532468
# Accuracy after query no. 435: 0.533733
# Accuracy after query no. 436: 0.530000
# Accuracy after query no. 437: 0.532266
# Accuracy after query no. 438: 0.531532
# Accuracy after query no. 439: 0.531798
# Accuracy after query no. 440: 0.532064
# Accuracy after query no. 441: 0.532331
# Accuracy after query no. 442: 0.532598
# Accuracy after query no. 443: 0.532865
# Accuracy after query no. 444: 0.533133
# Accuracy after query no. 445: 0.532396
# Accuracy after query no. 446: 0.532663
# Accuracy after query no. 447: 0.532428
# Accuracy after query no. 448: 0.533702
# Accuracy after query no. 449: 0.533468
# Accuracy after query no. 450: 0.532729
# Accuracy after query no. 451: 0.534509
# Accuracy after query no. 452: 0.533770
# Accuracy after query no. 453: 0.533535
# Accuracy after query no. 454: 0.533804
# Accuracy after query no. 455: 0.536598
# Accuracy after query no. 456: 0.536869
# Accuracy after query no. 457: 0.539161
# Accuracy after query no. 458: 0.539434
# Accuracy after query no. 459: 0.534143
# Accuracy after query no. 460: 0.535931
# Accuracy after query no. 461: 0.536203
# Accuracy after query no. 462: 0.535968
# Accuracy after query no. 463: 0.535226
# Accuracy after query no. 464: 0.535497
# Accuracy after query no. 465: 0.536783
# Accuracy after query no. 466: 0.535533
# Accuracy after query no. 467: 0.537836
# Accuracy after query no. 468: 0.538110
# Accuracy after query no. 469: 0.537875
# Accuracy after query no. 470: 0.538149
# Accuracy after query no. 471: 0.540967
# Accuracy after query no. 472: 0.541242
# Accuracy after query no. 473: 0.541518
# Accuracy after query no. 474: 0.541794
# Accuracy after query no. 475: 0.542070
# Accuracy after query no. 476: 0.538265
# Accuracy after query no. 477: 0.538540
# Accuracy after query no. 478: 0.536772
# Accuracy after query no. 479: 0.539601
# Accuracy after query no. 480: 0.541922
# Accuracy after query no. 481: 0.538107
# Accuracy after query no. 482: 0.542477
# Accuracy after query no. 483: 0.547875
# Accuracy after query no. 484: 0.546619
# Accuracy after query no. 485: 0.540748
# Accuracy after query no. 486: 0.541026
# Accuracy after query no. 487: 0.542842
# Accuracy after query no. 488: 0.545175
# ======================================
# By just labelling  19.98 % of total data accuracy of  0.545  % is achieved on the unseen data

# %% [markdown]
# ## Regular supervised task

# %%
from sklearn.model_selection import train_test_split

# %%
check_X = np.copy(X)
check_Y = np.copy(Y)

X_train,X_test,Y_train,Y_test = train_test_split(check_X,check_Y,test_size = 0.2)

# %%
# logisticRegr = LogisticRegression()
nb.fit(X_train, Y_train)
score = nb.score(X_test, Y_test)

print(score)
# Out:
# 0.5807770961145194

# %%
supervised_accuracy = [score for x in range(0,n_queries)]

plt.figure()
plt.plot(np.linspace(0,n_queries-1,n_queries),supervised_accuracy)
plt.plot(accuracy_list)
plt.title("Accuracy after every query")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.legend(["Supervised", "Active Learning"], loc="lower right")
plt.show()
