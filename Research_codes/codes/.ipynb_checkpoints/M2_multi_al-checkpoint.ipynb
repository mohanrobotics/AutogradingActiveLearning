# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %%
original_data = pd.read_csv('../dataset/mohler2_cleaned.csv')
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'question_number':'question_id','question_text':'question','answer_model':'ref_answer','answer_student':'student_answer','score_avg':'grade'})

# %%
short_df = original_data[['student_answer','grade','question']]
# np.sort(short_df['grade'].unique())
short_df['grades_round']= short_df['grade'].apply(lambda x: round(x))
# short_df['status'] = short_df['grade'] >= 3
# short_df['status'] = short_df['status'].astype(int)
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#getting the seed index
classes = short_df['grades_round'].unique()
seed_index = []
for i in classes:
    seed_index.append(short_df['grades_round'][short_df['grades_round']==i].index[0])
seed_index
# Out:
# [0, 1, 4, 5, 52, 94]

# %%
# short_df['word_count'] = short_df['student_answer'].apply(lambda x: dict(Counter(x.split())))

# counting unique words in every student's answer
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(short_df['student_answer'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = short_df['grades_round'].values

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
# train_idx = [0, 1, 4 ,5,52,605]
train_idx = seed_index
X_train = X[train_idx]
y_train = Y[train_idx]
print(y_train)
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
lr = LogisticRegression()
learner = ActiveLearner(
    estimator = lr,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = 40
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
    print("\nQ: ", act_data.loc[int(query_idx),'question'])
    print("A: ",act_data.loc[int(query_idx),'student_answer'])
    print("Actual grade: ",y_pool[query_idx].reshape(1, ))
    print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
    human_label = int(input("\nGive me a grade:"))
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=[human_label]
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X,Y))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X, Y)))
# Out:
# [4 5 3 2 1 0]
#
# Q:  What is the main advantage of arrays over linked lists?
# A:  You can go up and down an array  but you can only go one direction while traversing a linked list.
# Actual grade:  [3]
# Class probabilities:  [[0.15950206 0.17439805 0.17162072 0.16732109 0.15154103 0.17561705]]
#
# Give me a grade:3
# Accuracy after query no. 1: 0.090909
#
# Q:  What is the difference between an array declared as static  and one that is not?
# A:  All elements are initialized to zero if not explicitly initialized  this does not happen for automatic local arrays
# Actual grade:  [4]
# Class probabilities:  [[0.15923123 0.17398125 0.17429699 0.16187412 0.17046869 0.16014771]]
#
# Give me a grade:4
# Accuracy after query no. 2: 0.112613
#
# Q:  What are the access-specifiers that can be used in a C++ class definition?
# A:  A C plus plus class definition may include access-specifiers public  private  and static.
# Actual grade:  [4]
# Class probabilities:  [[0.16280209 0.17058857 0.17573148 0.17281871 0.15177786 0.16628129]]
#
# Give me a grade:4
# Accuracy after query no. 3: 0.138002
#
# Q:  What are the different ways to pass a pointer to a function?
# A:  pass by value and pass by reference with reference or pointer arguments.
# Actual grade:  [2]
# Class probabilities:  [[0.1588316  0.16360293 0.17078506 0.17023331 0.17377588 0.16277122]]
#
# Give me a grade:2
# Accuracy after query no. 4: 0.143325
#
# Q:  What data structure is more appropriate for scheduling printing jobs at a printer  a stack or a queue?
# A:  Queue of course!
# Actual grade:  [5]
# Class probabilities:  [[0.17802018 0.15515444 0.17165987 0.17565268 0.17062053 0.1488923 ]]
#
# Give me a grade:5
# Accuracy after query no. 5: 0.272727
#
# Q:  What is the scope of global variables?
# A:  Global variables have file scope.
# Actual grade:  [5]
# Class probabilities:  [[0.17418155 0.15016531 0.17077037 0.16013665 0.17070177 0.17404436]]
#
# Give me a grade:5
# Accuracy after query no. 6: 0.324734
#
# Q:  What is the alternative way to solve a problem that could be solved through recursive functions?
# A:  Using an iterative solution.  For  while  or do while loop.
# Actual grade:  [5]
# Class probabilities:  [[0.15045467 0.15175244 0.16661368 0.18358665 0.16738216 0.18021039]]
#
# Give me a grade:5
# Accuracy after query no. 7: 0.374693
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Testing  refining  production  and maintenance.
# Actual grade:  [4]
# Class probabilities:  [[0.19168516 0.16099846 0.17705587 0.14170476 0.14148127 0.18707447]]
#
# Give me a grade:4
# Accuracy after query no. 8: 0.358313
#
# Q:  What is a linked list?
# A:  A data type that contains a pointer to at least the next element in a list.
# Actual grade:  [4]
# Class probabilities:  [[0.19506458 0.16004761 0.14583371 0.12774885 0.18292488 0.18838037]]
#
# Give me a grade:4
# Accuracy after query no. 9: 0.368550
#
# Q:  How many dimensions need to be specified when passing a multi-dimensional array as an argument to a function?
# A:  None  just pass the array name.
# Actual grade:  [2]
# Class probabilities:  [[0.18105615 0.10951712 0.15634059 0.17317978 0.18511304 0.19479332]]
#
# Give me a grade:2
# Accuracy after query no. 10: 0.350123
#
# Q:  What is the difference between a constructor and a function?
# A:  a constructor initializes data members but the functions actually perform tasks.  Constructors cant return values either.
# Actual grade:  [4]
# Class probabilities:  [[0.15714944 0.18054766 0.13793369 0.15788518 0.18908692 0.1773971 ]]
#
# Give me a grade:4
# Accuracy after query no. 11: 0.359132
#
# Q:  What is the stack operation corresponding to the enqueue operation in queues?
# A:  FIFO: First in First out
# Actual grade:  [2]
# Class probabilities:  [[0.19600419 0.1131481  0.18310934 0.12738568 0.19699416 0.18335853]]
#
# Give me a grade:2
# Accuracy after query no. 12: 0.347256
#
# Q:  How many constructors can be created for a class?
# A:  One
# Actual grade:  [0]
# Class probabilities:  [[0.1453589  0.12585749 0.19270702 0.13872557 0.19742425 0.19992677]]
#
# Give me a grade:0
# Accuracy after query no. 13: 0.341114
#
# Q:  What is the main disadvantage of a doubly-linked list over a basic linked list?
# A:  nodes take up more memory
# Actual grade:  [5]
# Class probabilities:  [[0.18700504 0.12062627 0.18270543 0.13289266 0.18723018 0.18954042]]
#
# Give me a grade:5
# Accuracy after query no. 14: 0.361179
#
# Q:  What are the similarities between iteration and recursion?
# A:  both based on a control statement  both involve repitition  both involve a termination test  both gradually approach termination  both can potentially occur infinetly.
# Actual grade:  [5]
# Class probabilities:  [[0.17425177 0.11537939 0.16797961 0.16031329 0.18532938 0.19674656]]
#
# Give me a grade:5
# Accuracy after query no. 15: 0.373464
#
# Q:  Briefly describe in one sentence how does merge sort work?
# A:  It divides the array into two halves  sorts each half  then merges the two halves together.
# Actual grade:  [5]
# Class probabilities:  [[0.19610914 0.06727952 0.19856097 0.16964338 0.16876471 0.19964229]]
#
# Give me a grade:5
# Accuracy after query no. 16: 0.411957
#
# Q:  What are the two main functions defined by a queue?
# A:  enque -LRB- Data -RRB-   Deque -LRB- -RRB-
# Actual grade:  [5]
# Class probabilities:  [[0.15607573 0.18863462 0.15136509 0.09641287 0.20137654 0.20613515]]
#
# Give me a grade:5
# Accuracy after query no. 17: 0.441032
#
# Q:  How can you implement a stack with an array?
# A:  If you use a dynamically allocated array  you must provide a destructor and copy constructor.
# Actual grade:  [3]
# Class probabilities:  [[0.0981056  0.09433103 0.19850596 0.20803607 0.20185715 0.19916419]]
#
# Give me a grade:3
# Accuracy after query no. 18: 0.431204
#
# Q:  What are the two different ways of specifying the length of an array?
# A:  statically and dynamically
# Actual grade:  [2]
# Class probabilities:  [[0.13432676 0.11149389 0.17955249 0.17524017 0.1946495  0.20473719]]
#
# Give me a grade:2
# Accuracy after query no. 19: 0.401720
#
# Q:  What is the main advantage associated with function arguments that are passed by reference?
# A:  The function can change the data stored in a variable passed by reference directly.
# Actual grade:  [4]
# Class probabilities:  [[0.19646936 0.09111558 0.20751252 0.12859579 0.19878368 0.17752307]]
#
# Give me a grade:4
# Accuracy after query no. 20: 0.388616
#
# Q:  What is typically included in a class definition?
# A:  An object and data.
# Actual grade:  [2]
# Class probabilities:  [[0.09217712 0.1676869  0.20223431 0.12324016 0.20568066 0.20898085]]
#
# Give me a grade:2
# Accuracy after query no. 21: 0.377969
#
# Q:  How does the compiler handle inline functions?
# A:  not answered
# Actual grade:  [0]
# Class probabilities:  [[0.16271957 0.10032286 0.20280133 0.09994592 0.21492566 0.21928466]]
#
# Give me a grade:0
# Accuracy after query no. 22: 0.381245
#
# Q:  When does C++ create a default constructor?
# A:  when no user-defined constructor exists
# Actual grade:  [5]
# Class probabilities:  [[0.19526781 0.09783116 0.18677223 0.1209796  0.18534109 0.21380811]]
#
# Give me a grade:5
# Accuracy after query no. 23: 0.391482
#
# Q:  What is the advantage of linked lists over arrays?
# A:  linked list many be dynamically grown.  It has not limit
# Actual grade:  [5]
# Class probabilities:  [[0.21150479 0.07646679 0.21599783 0.11799218 0.17539472 0.20264369]]
#
# Give me a grade:5
# Accuracy after query no. 24: 0.411138
#
# Q:  What is the main advantage of arrays over linked lists?
# A:  link lists only allow sequential access where arrays allow random access
# Actual grade:  [4]
# Class probabilities:  [[0.17302899 0.1176317  0.15093771 0.13450293 0.21431421 0.20958447]]
#
# Give me a grade:4
# Accuracy after query no. 25: 0.407453
#
# Q:  How are infix expressions evaluated by computers?
# A:  Infix expressions are interpreted as postfix expressions by implementing stacks.
# Actual grade:  [5]
# Class probabilities:  [[0.16814808 0.08944132 0.22153354 0.08501468 0.21593641 0.21992597]]
#
# Give me a grade:5
# Accuracy after query no. 26: 0.413186
#
# Q:  What is the base case for a recursive implementation of merge sort?
# A:  where you only must merge sort once
# Actual grade:  [4]
# Class probabilities:  [[0.16231776 0.08384176 0.12753448 0.22184415 0.18090226 0.2235596 ]]
#
# Give me a grade:4
# Accuracy after query no. 27: 0.407043
#
# Q:  Briefly  how does selection sort work?
# A:  selection sort iterates through the array one element a time searching for the right and replacing current value with it.
# Actual grade:  [4]
# Class probabilities:  [[0.13967555 0.0475627  0.21365298 0.1574639  0.2166598  0.22498507]]
# Give me a grade:4
# Accuracy after query no. 28: 0.416871
#
# Q:  How many dimensions need to be specified when passing a multi-dimensional array as an argument to a function?
# A:  Every dimension after the first.
# Actual grade:  [5]
# Class probabilities:  [[0.15848068 0.06736895 0.22685827 0.10762695 0.21956991 0.22009524]]
#
# Give me a grade:5
# Accuracy after query no. 29: 0.436937
#
# Q:  What are the two main functions defined by a stack?
# A:  Adding a new item and removing the item
# Actual grade:  [5]
# Class probabilities:  [[0.12173787 0.08553329 0.22455498 0.12367052 0.2338208  0.21068254]]

# %% [markdown]
# ## Regular supervised task

# %%
from sklearn.model_selection import train_test_split

# %%
check_X = np.copy(X)
check_Y = np.copy(Y)

X_train,X_test,Y_train,Y_test = train_test_split(check_X,check_Y,test_size = 0.2)

# %%
logisticRegr = LogisticRegression()
logisticRegr.fit(X_train, Y_train)
score = logisticRegr.score(X_test, Y_test)

print(score)
# Out:
# 0.6585365853658537

# %%
supervised_accuracy = [score for x in range(0,40)]

plt.figure()
plt.plot(np.linspace(0,39,40),supervised_accuracy)
plt.plot(accuracy_list)
plt.title("Accuracy after every query")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.legend(["Supervised", "Active Learning"], loc="lower right")
plt.show()
