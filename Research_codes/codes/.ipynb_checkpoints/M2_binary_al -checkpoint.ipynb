# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %%
original_data = pd.read_csv('../dataset/mohler2_cleaned.csv')
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'question_number':'question_id','question_text':'question','answer_model':'ref_answer','answer_student':'student_answer','score_avg':'grade'})

# %%
short_df = original_data[['student_answer','grade','question']]
short_df['status'] = short_df['grade'] >= 3
short_df['status'] = short_df['status'].astype(int)
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
short_df
# Out:
#                                          student_answer  grade  \
# 0     High risk problems are address in the prototyp...    3.5
# 1     To simulate portions of the desired final prod...    5.0
# 2     A prototype program simulates the behaviors of...    4.0
# 3     Defined in the Specification phase a prototype...    5.0
# 4     It is used to let the users have a first idea ...    3.0
# 5     To find problem and errors in a program before...    2.0
# 6     To address major issues in the creation of the...    2.5
# 7     you can break the whole program into prototype...    5.0
# 8     To provide an example or model of how the fini...    3.5
# 9     Simulating the behavior of only a portion of t...    5.0
# 10    A program that stimulates the behavior of port...    5.0
# 11    A program that simulates the behavior of porti...    5.0
# 12    To lay out the basics and give you a starting ...    2.0
# 13    To simulate problem solving for parts of the p...    4.5
# 14    A prototype program provides a basic groundwor...    2.0
# 15    A prototype program is a part of the Specifica...    4.5
# 16    Program that simulates the behavior of portion...    5.0
# 17    it provides a limited proof of concept to veri...    2.0
# 18    It tests the main function of the program whil...    2.0
# 19    To get early feedback from users in early stag...    2.5
# 20    it simulates the behavior of portions of the d...    5.0
# 21    It simulates the behavior of portions of the d...    5.0
# 22    A prototype program is used in problem solving...    1.5
# 23    To ease the understanding of problem under dis...    2.5
# 24    it simulates the behavior of portions of the d...    5.0
# 25    The role of a prototype program is to help spo...    2.0
# 26    the prototype program gives a general idea of ...    3.0
# 27    to show that a certain part of the program wor...    3.0
# 28    Prototype programming is an approach to progra...    2.5
# 29    Refining and possibly the design if the testin...    3.5
# ...                                                 ...    ...
# 2412  if it has no children  you just delete it. if ...    4.0
# 2413  pointer to the child and delete it has 2 child...    3.0
# 2414  Log -LRB- n -RRB- where n is the number of nod...    5.0
# 2415                           log -LRB- n -RRB- steps     5.0
# 2416   The number of levels and the height of the tree     5.0
# 2417         It is the same as the height of the tree.     5.0
# 2418  Given n elements  it would take n divided by 2...    1.5
# 2419                                             log n     5.0
# 2420  Depends on the location of the node you are lo...    2.0
# 2421  2 to the power of n where n is the of levels t...    2.0
# 2422  The number of steps to search a node is the fu...    3.5
# 2423   It would take n divided by 2 elements  given n.     1.5
# 2424                                 log -LRB- n -RRB-     5.0
# 2425                               O -LRB- log n -RRB-     5.0
# 2426                   O -LRB- Log -LRB- n -RRB- -RRB-     5.0
# 2427  If the binary search tree is constructed effic...    5.0
# 2428                   N  n being the number of nodes.     4.0
# 2429  depending on the way that the tree is ordered ...    5.0
# 2430                                 log -LRB- n -RRB-     5.0
# 2431  worst case scenario equals the number of level...    5.0
# 2432              3 steps at most.  There are 3 cases.     1.5
# 2433  log -LRB- n -RRB- where n equals the total num...    5.0
# 2434  the same number of steps as the number of leve...    5.0
# 2435  to find a node in a binary search tree takes a...    5.0
# 2436  three steps visit the root node  then go to ri...    2.5
# 2437                                             log n     5.0
# 2438  -LRB- n -LRB- n minus 1 -RRB- -RRB- divided by 2     1.5
# 2439                                              2n-1     2.5
# 2440  it takes at most h steps  where h is the heigh...    5.0
# 2441  it depends on the install search tree then fro...    1.5
#
#                                                question  status
# 0     What is the role of a prototype program in pro...       1
# 1     What is the role of a prototype program in pro...       1
# 2     What is the role of a prototype program in pro...       1
# 3     What is the role of a prototype program in pro...       1
# 4     What is the role of a prototype program in pro...       1
# 5     What is the role of a prototype program in pro...       0
# 6     What is the role of a prototype program in pro...       0
# 7     What is the role of a prototype program in pro...       1
# 8     What is the role of a prototype program in pro...       1
# 9     What is the role of a prototype program in pro...       1
# 10    What is the role of a prototype program in pro...       1
# 11    What is the role of a prototype program in pro...       1
# 12    What is the role of a prototype program in pro...       0
# 13    What is the role of a prototype program in pro...       1
# 14    What is the role of a prototype program in pro...       0
# 15    What is the role of a prototype program in pro...       1
# 16    What is the role of a prototype program in pro...       1
# 17    What is the role of a prototype program in pro...       0
# 18    What is the role of a prototype program in pro...       0
# 19    What is the role of a prototype program in pro...       0
# 20    What is the role of a prototype program in pro...       1
# 21    What is the role of a prototype program in pro...       1
# 22    What is the role of a prototype program in pro...       0
# 23    What is the role of a prototype program in pro...       0
# 24    What is the role of a prototype program in pro...       1
# 25    What is the role of a prototype program in pro...       0
# 26    What is the role of a prototype program in pro...       1
# 27    What is the role of a prototype program in pro...       1
# 28    What is the role of a prototype program in pro...       0
# 29    What stages in the software life cycle are inf...       1
# ...                                                 ...     ...
# 2412  How do you delete a node from a binary search ...       1
# 2413  How do you delete a node from a binary search ...       1
# 2414  How many steps does it take to search a node i...       1
# 2415  How many steps does it take to search a node i...       1
# 2416  How many steps does it take to search a node i...       1
# 2417  How many steps does it take to search a node i...       1
# 2418  How many steps does it take to search a node i...       0
# 2419  How many steps does it take to search a node i...       1
# 2420  How many steps does it take to search a node i...       0
# 2421  How many steps does it take to search a node i...       0
# 2422  How many steps does it take to search a node i...       1
# 2423  How many steps does it take to search a node i...       0
# 2424  How many steps does it take to search a node i...       1
# 2425  How many steps does it take to search a node i...       1
# 2426  How many steps does it take to search a node i...       1
# 2427  How many steps does it take to search a node i...       1
# 2428  How many steps does it take to search a node i...       1
# 2429  How many steps does it take to search a node i...       1
# 2430  How many steps does it take to search a node i...       1
# 2431  How many steps does it take to search a node i...       1
# 2432  How many steps does it take to search a node i...       0
# 2433  How many steps does it take to search a node i...       1
# 2434  How many steps does it take to search a node i...       1
# 2435  How many steps does it take to search a node i...       1
# 2436  How many steps does it take to search a node i...       0
# 2437  How many steps does it take to search a node i...       1
# 2438  How many steps does it take to search a node i...       0
# 2439  How many steps does it take to search a node i...       0
# 2440  How many steps does it take to search a node i...       1
# 2441  How many steps does it take to search a node i...       0
#
# [2442 rows x 4 columns]

# %%
# short_df['word_count'] = short_df['student_answer'].apply(lambda x: dict(Counter(x.split())))

# counting unique words in every student's answer
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(short_df['student_answer'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = short_df['status'].values

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
train_idx = [0, 5, 6 ,100]
X_train = X[train_idx]
y_train = Y[train_idx]
 
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
lr = LogisticRegression()
learner = ActiveLearner(
    estimator = lr,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = 40
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
    print("\nQ: ", act_data.loc[int(query_idx),'question'])
    print("A: ",act_data.loc[int(query_idx),'student_answer'])
    print("Actual grade: ",y_pool[query_idx].reshape(1, ))
    print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
    human_label = int(input("\nGive me a grade 0 or 1:"))
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=[human_label]
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X,Y))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X, Y)))
# Out:
# Q:  How can you implement a queue with a list?
# A:  Have a pointer to the last element in the list and then use enqueue to insert items there.  Link the first and last elements together to dequeue the list.
# Actual grade:  [1]
# Class probabilities:  [[0.50022144 0.49977856]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 1: 0.791155
#
# Q:  What are the different ways to pass a pointer to a function?
# A:  by address address of bPtr or directly bPtr.
# Actual grade:  [0]
# Class probabilities:  [[0.50036059 0.49963941]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 2: 0.663391
#
# Q:  What are the different ways to pass a pointer to a function?
# A:  Four different ways: Nonconstant pointer to nonconstant data  a nonconstant pointer to constant data  a constant pointer to nonconstant data and a constant pointer to constant data.
# Actual grade:  [1]
# Class probabilities:  [[0.49938588 0.50061412]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 3: 0.708436
#
# Q:  What is a binary tree?
# A:  A binary tree is a set of nodes that is either empty or partitioned into a root node and one or two subsets that are binary subtrees of the root.  Each node has at most two children  the left child and the right child.
# Actual grade:  [1]
# Class probabilities:  [[0.50012922 0.49987078]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 4: 0.789517
#
# Q:  What is the experimental approach for measuring the running time of an algorithm?
# A:  For every call into memory  add or multiply it into an equation of type O -LRB- n -RRB-
# Actual grade:  [0]
# Class probabilities:  [[0.50006618 0.49993382]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 5: 0.704341
#
# Q:  When defining a recursive function  what are possible causes for infinite recursion?
# A:  improper handling of cases such that not all possible values are able to be handled.
# Actual grade:  [1]
# Class probabilities:  [[0.49989566 0.50010434]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 6: 0.769042
#
# Q:  What is the experimental approach for measuring the running time of an algorithm?
# A:  running an algorithm on a specific set of data
# Actual grade:  [1]
# Class probabilities:  [[0.4998553 0.5001447]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 7: 0.808763
#
# Q:  Which implementation (array-based vs. list-based) is preferred for a queue  and why?
# A:  List based.  Because it is on the run time order of N  also it does not have a limited size like an array does
# Actual grade:  [1]
# Class probabilities:  [[0.49984913 0.50015087]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 8: 0.840704
#
# Q:  What is a pointer?
# A:  a pointer is a reference to a memory location.
# Actual grade:  [1]
# Class probabilities:  [[0.50008264 0.49991736]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 9: 0.858722
#
# Q:  What does the address (&) operator return?
# A:  ADDRESS returns the memory address of its operand.
# Actual grade:  [1]
# Class probabilities:  [[0.50136005 0.49863995]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 10: 0.860360
#
# Q:  How are infix expressions evaluated by computers?
# A:  Computers cannot evaulate infix expressions  it must first convert infix to postfix expression then it can evaluate.
# Actual grade:  [1]
# Class probabilities:  [[0.49996881 0.50003119]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 11: 0.866093
#
# Q:  What is a recursive function?
# A:  It invoke by itself again ana again  unless it reach bas case
# Actual grade:  [1]
# Class probabilities:  [[0.50144063 0.49855937]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 12: 0.867322
#
# Q:  Briefly describe the divide-and-conquer paradigm.
# A:  it is the separating of large program into smaller classes then until target is reached.
# Actual grade:  [1]
# Class probabilities:  [[0.50043125 0.49956875]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 13: 0.868960
#
# Q:  When defining a recursive function  what are possible causes for infinite recursion?
# A:  badly designed algorithyms. using recursion for a non recursive problem.
# Actual grade:  [0]
# Class probabilities:  [[0.49823759 0.50176241]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 14: 0.866503
#
# Q:  What is the main advantage of a doubly-linked list over a basic linked list?
# A:  a doubly linked list has pointers in both directions. this allows for access from back to front as well as front to back
# Actual grade:  [1]
# Class probabilities:  [[0.5005389 0.4994611]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 15: 0.866912
#
# Q:  What are the main advantages associated with object-oriented programming?
# A:  Using different modules allows for easier debugging
# Actual grade:  [0]
# Class probabilities:  [[0.49926405 0.50073595]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 16: 0.863227
#
# Q:  How can you implement a queue with an array?
# A:  For applications in which a fixed-sized queue does not present a problem  you can use an array to represent a queue.
# Actual grade:  [0]
# Class probabilities:  [[0.5001402 0.4998598]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 17: 0.857084
#
# Q:  What are the two different ways of specifying the length of an array?
# A:  Explicitly int array [10]  or by variable const int size equals 10  int array [size]
# Actual grade:  [1]
# Class probabilities:  [[0.49997694 0.50002306]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 18: 0.861589
#
# Q:  What is the main advantage of a doubly-linked list over a basic linked list?
# A:  Gives faster times for some operations such as insertion and deletion
# Actual grade:  [1]
# Class probabilities:  [[0.50090636 0.49909364]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 19: 0.863636
#
# Q:  How are objects initialized when they are created?
# A:  Objects are initialized by a value given.  When an object is defined for a certain task.
# Actual grade:  [0]
# Class probabilities:  [[0.49996832 0.50003168]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 20: 0.857084
#
# Q:  What is the difference between an array declared as static  and one that is not?
# A:  All elements are initialized to zero if not explicitly initialized  this does not happen for automatic local arrays
# Actual grade:  [1]
# Class probabilities:  [[0.50048422 0.49951578]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 21: 0.859541
#
# Q:  What is the scope of global variables?
# A:  it is accessible by all functions within a program
# Actual grade:  [1]
# Class probabilities:  [[0.50090528 0.49909472]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 22: 0.860770
#
# Q:  When does C++ create a default constructor?
# A:  When no constructor exists when one is needed  a parameterless default constructor is declared.
# Actual grade:  [1]
# Class probabilities:  [[0.50113512 0.49886488]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 23: 0.862817
#
# Q:  How many dimensions need to be specified when passing a multi-dimensional array as an argument to a function?
# A:  Multi dimensional arrays are accessed using more than 1 index  one for each dimension at least.
# Actual grade:  [1]
# Class probabilities:  [[0.49713593 0.50286407]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 24: 0.866093
#
# Q:  How many constructors can be created for a class?
# A:  It depends what type of class is being defined.  Typically you would have a constructor call for each object.
# Actual grade:  [0]
# Class probabilities:  [[0.50040884 0.49959116]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 25: 0.864865
#
# Q:  How can an array be addressed in pointer/offset notation?
# A:  address of b [3] bPtr plus 3
# Actual grade:  [1]
# Class probabilities:  [[0.500881 0.499119]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 26: 0.864865
#
# Q:  What operations would you need to perform to find a given element on a stack?
# A:  You would have to keep using peek or getTop to see what the top element is then popping the top element until peek or getTop provides the element you are looking for.
# Actual grade:  [1]
# Class probabilities:  [[0.49756753 0.50243247]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 27: 0.865684
#
# Q:  What is a variable?
# A:  A variable is a location in the computer 's memory where a value can be stored for use by a program.  Each variable has a name  a value  a type and a size.
# Actual grade:  [1]
# Class probabilities:  [[0.50583077 0.49416923]]
# Give me a grade 0 or 1:1
# Accuracy after query no. 28: 0.869779
#
# Q:  What data structure is more appropriate for scheduling printing jobs at a printer  a stack or a queue?
# A:  A queue is more appropriate for scheduling printing jobs because queues have first in first out behavior.
# Actual grade:  [1]
# Class probabilities:  [[0.49964571 0.50035429]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 29: 0.871007
#
# Q:  What is the alternative way to solve a problem that could be solved through recursive functions?
# A:  itteration  like a for loop  a while loop  or a do while loop
# Actual grade:  [1]
# Class probabilities:  [[0.49218756 0.50781244]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 30: 0.871417
#
# Q:  What is typically included in a class definition?
# A:  For us it is usually a set  get  and displayMessge or other messages that tell you what properties a class has but does not reveal its implementations.  You could have anything you want in your own class definition.
# Actual grade:  [0]
# Class probabilities:  [[0.48533545 0.51466455]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 31: 0.871417
#
# Q:  What is a pointer?
# A:  A pointer is a way to get at another object.  Essentially it is a way to grab an instance of an object and then either pass that instance a message or retreive some data from that object.  A pointer is actually just an address of where an instance is held in memory.
# Actual grade:  [1]
# Class probabilities:  [[0.49277731 0.50722269]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 32: 0.870598
#
# Q:  What is the main difference between strings declared using the type string versus strings declared using an array of characters?
# A:  All strings represented by character arrays end with the null character.  You declare an object of type string just like any other type  for example: string s
# Actual grade:  [1]
# Class probabilities:  [[0.49889752 0.50110248]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 33: 0.872236
#
# Q:  What is the alternative way to solve a problem that could be solved through recursive functions?
# A:  Another alternative way to solve a problem instead of using recursive functions is by using iteration.
# Actual grade:  [1]
# Class probabilities:  [[0.49632777 0.50367223]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 34: 0.873055
#
# Q:  When does C++ create a default constructor?
# A:  When no constructor was specified in the constructor 's class  but the class is instantiated in a program.
# Actual grade:  [1]
# Class probabilities:  [[0.49843416 0.50156584]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 35: 0.873464
#
# Q:  What is the role of a prototype program in problem solving?
# A:  To simulate problem solving for parts of the problem
# Actual grade:  [1]
# Class probabilities:  [[0.48623046 0.51376954]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 36: 0.873464
#
# Q:  What is the scope of global variables?
# A:  global variables have program scope -LRB- accessible anywhere in program -RRB-
# Actual grade:  [1]
# Class probabilities:  [[0.47753379 0.52246621]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 37: 0.873464
#
# Q:  What are the main advantages associated with object-oriented programming?
# A:  They make it easier to reuse and adapt previously written code and they separate complex programs into smaller  easier to understand classes.
# Actual grade:  [1]
# Class probabilities:  [[0.43484341 0.56515659]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 38: 0.873464
#
# Q:  What are the two different ways of specifying the length of an array?
# A:  You can use an initializer list  or simply tell the compiler how many elements you want in the array.  For an Initializer list: int a [] equals 10  2  3  4  5   For an elemental declaration: int b [5]   Both arrays have 5 elements in them  but array a is already initialized.
# Actual grade:  [1]
# Class probabilities:  [[0.47546518 0.52453482]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 39: 0.873464
#
# Q:  Briefly describe the divide-and-conquer paradigm.
# A:  It takes a large problem and splits it into two or more easier or faster solutions  and makes for better readability.
# Actual grade:  [1]
# Class probabilities:  [[0.57582906 0.42417094]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 40: 0.873874

# %% [markdown]
# ## Regular supervised task

# %%
from sklearn.model_selection import train_test_split

# %%
check_X = np.copy(X)
check_Y = np.copy(Y)

X_train,X_test,Y_train,Y_test = train_test_split(check_X,check_Y,test_size = 0.2)

# %%
logisticRegr = LogisticRegression()
logisticRegr.fit(X_train, Y_train)
score = logisticRegr.score(X_test, Y_test)

print(score)
# Out:
# 0.9059304703476483

# %%
supervised_accuracy = [score for x in range(0,40)]

plt.figure()
plt.plot(np.linspace(0,39,40),supervised_accuracy)
plt.plot(accuracy_list)
plt.title("Accuracy after every query")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.legend(["Supervised", "Active Learning"], loc="lower right")
plt.show()
