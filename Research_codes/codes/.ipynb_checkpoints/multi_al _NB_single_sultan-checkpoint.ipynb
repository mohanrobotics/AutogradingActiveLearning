# %% [markdown]
# # Multiclass classification - single_model using Naive Bayes(sultan)

# %% [markdown]
# # Importing and Preprocessing

# %% [markdown]
# ## Importing libraries

# %%
#### import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %% [markdown]
# # Gathering required features

# %%
df = pd.read_pickle("./sultan_features.pkl")
df = df.fillna(0)

# %%
short_df = df[['question_id','question','student_answer','student_modified','ref_modified', \
               'grade','length_ratio','aligned_score','aligned_score_demo','cos_similarity','cos_similarity_demo']]
short_df['grades_round']= short_df['grade'].apply(lambda x: round(x))
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Sultan features

# %%
X = short_df[['length_ratio','aligned_score','aligned_score_demo','cos_similarity','cos_similarity_demo']]
X[X<0] = 0
Y = short_df['grades_round'].values
X = np.array(X)
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/core/frame.py:3163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._where(-key, value, inplace=True)

# %% [markdown]
# # Seeding

# %%
#getting the seed index
classes = short_df['grades_round'].unique()
seed_index = []
for i in classes:
    seed_index.append(short_df['grades_round'][short_df['grades_round']==i].index[0])
seed_index
# Out:
# [0, 1, 4, 5, 52, 94]

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
train_idx = seed_index
X_train = X[train_idx]
y_train = Y[train_idx]
 
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
# lr = LogisticRegression()
nb = MultinomialNB()
learner = ActiveLearner(
#     estimator = lr,
    estimator = nb,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = int(len(X)/6)
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
#     print("\nQ: ", act_data.loc[int(query_idx),'question'])
#     print("A: ",act_data.loc[int(query_idx),'student_answer'])
#     print("Actual grade: ",y_pool[query_idx].reshape(1, ))
#     print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
#     human_label = int(input("\nGive me a grade 0 or 1:"))
    
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=y_pool[query_idx].reshape(1, )
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X,Y))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X_pool, y_pool)))
print("======================================")
print("By just labelling ",round(n_queries*100.0/len(X),2),"% of total data accuracy of ", round(learner.score(X_pool, y_pool),3), " % is achieved on the unseen data"  )
# Out:
# Accuracy after query no. 1: 0.294456
# Accuracy after query no. 2: 0.414133
# Accuracy after query no. 3: 0.445540
# Accuracy after query no. 4: 0.484786
# Accuracy after query no. 5: 0.420814
# Accuracy after query no. 6: 0.451029
# Accuracy after query no. 7: 0.417456
# Accuracy after query no. 8: 0.417628
# Accuracy after query no. 9: 0.417800
# Accuracy after query no. 10: 0.445177
# Accuracy after query no. 11: 0.445361
# Accuracy after query no. 12: 0.464109
# Accuracy after query no. 13: 0.464300
# Accuracy after query no. 14: 0.464905
# Accuracy after query no. 15: 0.476663
# Accuracy after query no. 16: 0.493388
# Accuracy after query no. 17: 0.484084
# Accuracy after query no. 18: 0.487593
# Accuracy after query no. 19: 0.486140
# Accuracy after query no. 20: 0.481374
# Accuracy after query no. 21: 0.481573
# Accuracy after query no. 22: 0.475145
# Accuracy after query no. 23: 0.484045
# Accuracy after query no. 24: 0.485489
# Accuracy after query no. 25: 0.485276
# Accuracy after query no. 26: 0.485892
# Accuracy after query no. 27: 0.489830
# Accuracy after query no. 28: 0.490033
# Accuracy after query no. 29: 0.487329
# Accuracy after query no. 30: 0.487531
# Accuracy after query no. 31: 0.491060
# Accuracy after query no. 32: 0.487521
# Accuracy after query no. 33: 0.487724
# Accuracy after query no. 34: 0.492090
# Accuracy after query no. 35: 0.488546
# Accuracy after query no. 36: 0.492083
# Accuracy after query no. 37: 0.492288
# Accuracy after query no. 38: 0.493745
# Accuracy after query no. 39: 0.491448
# Accuracy after query no. 40: 0.491653
# Accuracy after query no. 41: 0.491023
# Accuracy after query no. 42: 0.491228
# Accuracy after query no. 43: 0.493523
# Accuracy after query no. 44: 0.494565
# Accuracy after query no. 45: 0.493936
# Accuracy after query no. 46: 0.494561
# Accuracy after query no. 47: 0.494768
# Accuracy after query no. 48: 0.496650
# Accuracy after query no. 49: 0.497277
# Accuracy after query no. 50: 0.497485
# Accuracy after query no. 51: 0.498532
# Accuracy after query no. 52: 0.497483
# Accuracy after query no. 53: 0.497692
# Accuracy after query no. 54: 0.494542
# Accuracy after query no. 55: 0.496430
# Accuracy after query no. 56: 0.496639
# Accuracy after query no. 57: 0.497268
# Accuracy after query no. 58: 0.498318
# Accuracy after query no. 59: 0.498107
# Accuracy after query no. 60: 0.499158
# Accuracy after query no. 61: 0.496842
# Accuracy after query no. 62: 0.497051
# Accuracy after query no. 63: 0.495997
# Accuracy after query no. 64: 0.497049
# Accuracy after query no. 65: 0.497259
# Accuracy after query no. 66: 0.497468
# Accuracy after query no. 67: 0.497256
# Accuracy after query no. 68: 0.497466
# Accuracy after query no. 69: 0.497676
# Accuracy after query no. 70: 0.496619
# Accuracy after query no. 71: 0.497252
# Accuracy after query no. 72: 0.497462
# Accuracy after query no. 73: 0.497672
# Accuracy after query no. 74: 0.497883
# Accuracy after query no. 75: 0.498094
# Accuracy after query no. 76: 0.498305
# Accuracy after query no. 77: 0.498516
# Accuracy after query no. 78: 0.497880
# Accuracy after query no. 79: 0.498939
# Accuracy after query no. 80: 0.499151
# Accuracy after query no. 81: 0.498514
# Accuracy after query no. 82: 0.498726
# Accuracy after query no. 83: 0.499363
# Accuracy after query no. 84: 0.498724
# Accuracy after query no. 85: 0.498937
# Accuracy after query no. 86: 0.499149
# Accuracy after query no. 87: 0.480204
# Accuracy after query no. 88: 0.480409
# Accuracy after query no. 89: 0.481040
# Accuracy after query no. 90: 0.480818
# Accuracy after query no. 91: 0.481023
# Accuracy after query no. 92: 0.481229
# Accuracy after query no. 93: 0.481007
# Accuracy after query no. 94: 0.481213
# Accuracy after query no. 95: 0.480991
# Accuracy after query no. 96: 0.481197
# Accuracy after query no. 97: 0.480975
# Accuracy after query no. 98: 0.481180
# Accuracy after query no. 99: 0.481386
# Accuracy after query no. 100: 0.481164
# Accuracy after query no. 101: 0.478373
# Accuracy after query no. 102: 0.475150
# Accuracy after query no. 103: 0.472782
# Accuracy after query no. 104: 0.472556
# Accuracy after query no. 105: 0.472329
# Accuracy after query no. 106: 0.470386
# Accuracy after query no. 107: 0.469300
# Accuracy after query no. 108: 0.469502
# Accuracy after query no. 109: 0.469274
# Accuracy after query no. 110: 0.469475
# Accuracy after query no. 111: 0.469677
# Accuracy after query no. 112: 0.469880
# Accuracy after query no. 113: 0.469221
# Accuracy after query no. 114: 0.469423
# Accuracy after query no. 115: 0.468763
# Accuracy after query no. 116: 0.468966
# Accuracy after query no. 117: 0.468737
# Accuracy after query no. 118: 0.461605
# Accuracy after query no. 119: 0.461372
# Accuracy after query no. 120: 0.460276
# Accuracy after query no. 121: 0.460043
# Accuracy after query no. 122: 0.460242
# Accuracy after query no. 123: 0.460441
# Accuracy after query no. 124: 0.460640
# Accuracy after query no. 125: 0.460407
# Accuracy after query no. 126: 0.454545
# Accuracy after query no. 127: 0.453010
# Accuracy after query no. 128: 0.451906
# Accuracy after query no. 129: 0.451235
# Accuracy after query no. 130: 0.448395
# Accuracy after query no. 131: 0.448156
# Accuracy after query no. 132: 0.448351
# Accuracy after query no. 133: 0.448545
# Accuracy after query no. 134: 0.448306
# Accuracy after query no. 135: 0.445893
# Accuracy after query no. 136: 0.445217
# Accuracy after query no. 137: 0.445846
# Accuracy after query no. 138: 0.444735
# Accuracy after query no. 139: 0.444493
# Accuracy after query no. 140: 0.442073
# Accuracy after query no. 141: 0.440087
# Accuracy after query no. 142: 0.438535
# Accuracy after query no. 143: 0.435674
# Accuracy after query no. 144: 0.432810
# Accuracy after query no. 145: 0.432126
# Accuracy after query no. 146: 0.430568
# Accuracy after query no. 147: 0.427698
# Accuracy after query no. 148: 0.430070
# Accuracy after query no. 149: 0.428072
# Accuracy after query no. 150: 0.433071
# Accuracy after query no. 151: 0.435886
# Accuracy after query no. 152: 0.436077
# Accuracy after query no. 153: 0.436268
# Accuracy after query no. 154: 0.439089
# Accuracy after query no. 155: 0.442350
# Accuracy after query no. 156: 0.444737
# Accuracy after query no. 157: 0.444932
# Accuracy after query no. 158: 0.446005
# Accuracy after query no. 159: 0.449275
# Accuracy after query no. 160: 0.449912
# Accuracy after query no. 161: 0.454066
# Accuracy after query no. 162: 0.455585
# Accuracy after query no. 163: 0.461945
# Accuracy after query no. 164: 0.461708
# Accuracy after query no. 165: 0.463232
# Accuracy after query no. 166: 0.470485
# Accuracy after query no. 167: 0.471133
# Accuracy after query no. 168: 0.471340
# Accuracy after query no. 169: 0.472431
# Accuracy after query no. 170: 0.474404
# Accuracy after query no. 171: 0.477263
# Accuracy after query no. 172: 0.480565
# Accuracy after query no. 173: 0.483429
# Accuracy after query no. 174: 0.483201
# Accuracy after query no. 175: 0.482972
# Accuracy after query no. 176: 0.501770
# Accuracy after query no. 177: 0.501549
# Accuracy after query no. 178: 0.501771
# Accuracy after query no. 179: 0.501994
# Accuracy after query no. 180: 0.501773
# Accuracy after query no. 181: 0.501996
# Accuracy after query no. 182: 0.502218
# Accuracy after query no. 183: 0.502441
# Accuracy after query no. 184: 0.502220
# Accuracy after query no. 185: 0.502443
# Accuracy after query no. 186: 0.502667
# Accuracy after query no. 187: 0.502890
# Accuracy after query no. 188: 0.503114
# Accuracy after query no. 189: 0.502893
# Accuracy after query no. 190: 0.503117
# Accuracy after query no. 191: 0.503341
# Accuracy after query no. 192: 0.503565
# Accuracy after query no. 193: 0.503344
# Accuracy after query no. 194: 0.503568
# Accuracy after query no. 195: 0.503347
# Accuracy after query no. 196: 0.503571
# Accuracy after query no. 197: 0.503796
# Accuracy after query no. 198: 0.504021
# Accuracy after query no. 199: 0.504247
# Accuracy after query no. 200: 0.504025
# Accuracy after query no. 201: 0.504251
# Accuracy after query no. 202: 0.504029
# Accuracy after query no. 203: 0.503807
# Accuracy after query no. 204: 0.504032
# Accuracy after query no. 205: 0.503810
# Accuracy after query no. 206: 0.504036
# Accuracy after query no. 207: 0.503813
# Accuracy after query no. 208: 0.504039
# Accuracy after query no. 209: 0.504266
# Accuracy after query no. 210: 0.504492
# Accuracy after query no. 211: 0.504270
# Accuracy after query no. 212: 0.504496
# Accuracy after query no. 213: 0.504723
# Accuracy after query no. 214: 0.504950
# Accuracy after query no. 215: 0.505178
# Accuracy after query no. 216: 0.505405
# Accuracy after query no. 217: 0.505633
# Accuracy after query no. 218: 0.505861
# Accuracy after query no. 219: 0.506089
# Accuracy after query no. 220: 0.506318
# Accuracy after query no. 221: 0.506095
# Accuracy after query no. 222: 0.505872
# Accuracy after query no. 223: 0.506100
# Accuracy after query no. 224: 0.505877
# Accuracy after query no. 225: 0.506106
# Accuracy after query no. 226: 0.505882
# Accuracy after query no. 227: 0.505659
# Accuracy after query no. 228: 0.505435
# Accuracy after query no. 229: 0.505664
# Accuracy after query no. 230: 0.505893
# Accuracy after query no. 231: 0.506122
# Accuracy after query no. 232: 0.506352
# Accuracy after query no. 233: 0.506582
# Accuracy after query no. 234: 0.506812
# Accuracy after query no. 235: 0.507042
# Accuracy after query no. 236: 0.507273
# Accuracy after query no. 237: 0.507503
# Accuracy after query no. 238: 0.507734
# Accuracy after query no. 239: 0.507965
# Accuracy after query no. 240: 0.507741
# Accuracy after query no. 241: 0.507973
# Accuracy after query no. 242: 0.508204
# Accuracy after query no. 243: 0.508436
# Accuracy after query no. 244: 0.508212
# Accuracy after query no. 245: 0.508444
# Accuracy after query no. 246: 0.508676
# Accuracy after query no. 247: 0.508908
# Accuracy after query no. 248: 0.509141
# Accuracy after query no. 249: 0.508916
# Accuracy after query no. 250: 0.509149
# Accuracy after query no. 251: 0.508924
# Accuracy after query no. 252: 0.509158
# Accuracy after query no. 253: 0.509391
# Accuracy after query no. 254: 0.509624
# Accuracy after query no. 255: 0.509858
# Accuracy after query no. 256: 0.510092
# Accuracy after query no. 257: 0.510326
# Accuracy after query no. 258: 0.510560
# Accuracy after query no. 259: 0.510795
# Accuracy after query no. 260: 0.511029
# Accuracy after query no. 261: 0.511264
# Accuracy after query no. 262: 0.511500
# Accuracy after query no. 263: 0.511735
# Accuracy after query no. 264: 0.511510
# Accuracy after query no. 265: 0.511746
# Accuracy after query no. 266: 0.511521
# Accuracy after query no. 267: 0.511757
# Accuracy after query no. 268: 0.511993
# Accuracy after query no. 269: 0.512229
# Accuracy after query no. 270: 0.512465
# Accuracy after query no. 271: 0.512702
# Accuracy after query no. 272: 0.512939
# Accuracy after query no. 273: 0.513176
# Accuracy after query no. 274: 0.513414
# Accuracy after query no. 275: 0.513651
# Accuracy after query no. 276: 0.513889
# Accuracy after query no. 277: 0.513664
# Accuracy after query no. 278: 0.513902
# Accuracy after query no. 279: 0.513676
# Accuracy after query no. 280: 0.513915
# Accuracy after query no. 281: 0.514153
# Accuracy after query no. 282: 0.514392
# Accuracy after query no. 283: 0.514631
# Accuracy after query no. 284: 0.514870
# Accuracy after query no. 285: 0.515109
# Accuracy after query no. 286: 0.515349
# Accuracy after query no. 287: 0.515589
# Accuracy after query no. 288: 0.515829
# Accuracy after query no. 289: 0.516069
# Accuracy after query no. 290: 0.516309
# Accuracy after query no. 291: 0.516550
# Accuracy after query no. 292: 0.516325
# Accuracy after query no. 293: 0.516099
# Accuracy after query no. 294: 0.516340
# Accuracy after query no. 295: 0.516581
# Accuracy after query no. 296: 0.516822
# Accuracy after query no. 297: 0.517064
# Accuracy after query no. 298: 0.517306
# Accuracy after query no. 299: 0.517548
# Accuracy after query no. 300: 0.517790
# Accuracy after query no. 301: 0.518033
# Accuracy after query no. 302: 0.518276
# Accuracy after query no. 303: 0.518519
# Accuracy after query no. 304: 0.518762
# Accuracy after query no. 305: 0.519005
# Accuracy after query no. 306: 0.519249
# Accuracy after query no. 307: 0.519493
# Accuracy after query no. 308: 0.519737
# Accuracy after query no. 309: 0.519981
# Accuracy after query no. 310: 0.520226
# Accuracy after query no. 311: 0.520000
# Accuracy after query no. 312: 0.520245
# Accuracy after query no. 313: 0.520490
# Accuracy after query no. 314: 0.520735
# Accuracy after query no. 315: 0.520981
# Accuracy after query no. 316: 0.521226
# Accuracy after query no. 317: 0.521472
# Accuracy after query no. 318: 0.521719
# Accuracy after query no. 319: 0.521965
# Accuracy after query no. 320: 0.521739
# Accuracy after query no. 321: 0.521986
# Accuracy after query no. 322: 0.521760
# Accuracy after query no. 323: 0.522007
# Accuracy after query no. 324: 0.522254
# Accuracy after query no. 325: 0.522501
# Accuracy after query no. 326: 0.522749
# Accuracy after query no. 327: 0.522997
# Accuracy after query no. 328: 0.522770
# Accuracy after query no. 329: 0.523019
# Accuracy after query no. 330: 0.523267
# Accuracy after query no. 331: 0.523040
# Accuracy after query no. 332: 0.523289
# Accuracy after query no. 333: 0.523538
# Accuracy after query no. 334: 0.523787
# Accuracy after query no. 335: 0.524036
# Accuracy after query no. 336: 0.524286
# Accuracy after query no. 337: 0.524535
# Accuracy after query no. 338: 0.524786
# Accuracy after query no. 339: 0.525036
# Accuracy after query no. 340: 0.525286
# Accuracy after query no. 341: 0.525537
# Accuracy after query no. 342: 0.525788
# Accuracy after query no. 343: 0.526039
# Accuracy after query no. 344: 0.525813
# Accuracy after query no. 345: 0.526064
# Accuracy after query no. 346: 0.526316
# Accuracy after query no. 347: 0.526089
# Accuracy after query no. 348: 0.526341
# Accuracy after query no. 349: 0.526593
# Accuracy after query no. 350: 0.526846
# Accuracy after query no. 351: 0.527098
# Accuracy after query no. 352: 0.527351
# Accuracy after query no. 353: 0.527604
# Accuracy after query no. 354: 0.527858
# Accuracy after query no. 355: 0.528111
# Accuracy after query no. 356: 0.528365
# Accuracy after query no. 357: 0.528620
# Accuracy after query no. 358: 0.528874
# Accuracy after query no. 359: 0.529129
# Accuracy after query no. 360: 0.529383
# Accuracy after query no. 361: 0.529639
# Accuracy after query no. 362: 0.529894
# Accuracy after query no. 363: 0.530150
# Accuracy after query no. 364: 0.530405
# Accuracy after query no. 365: 0.530662
# Accuracy after query no. 366: 0.530918
# Accuracy after query no. 367: 0.531174
# Accuracy after query no. 368: 0.531431
# Accuracy after query no. 369: 0.531205
# Accuracy after query no. 370: 0.531462
# Accuracy after query no. 371: 0.531719
# Accuracy after query no. 372: 0.531977
# Accuracy after query no. 373: 0.532235
# Accuracy after query no. 374: 0.532008
# Accuracy after query no. 375: 0.532266
# Accuracy after query no. 376: 0.532524
# Accuracy after query no. 377: 0.532783
# Accuracy after query no. 378: 0.531584
# Accuracy after query no. 379: 0.529898
# Accuracy after query no. 380: 0.532588
# Accuracy after query no. 381: 0.531873
# Accuracy after query no. 382: 0.532132
# Accuracy after query no. 383: 0.532392
# Accuracy after query no. 384: 0.532651
# Accuracy after query no. 385: 0.535349
# Accuracy after query no. 386: 0.535610
# Accuracy after query no. 387: 0.539287
# Accuracy after query no. 388: 0.539551
# Accuracy after query no. 389: 0.544211
# Accuracy after query no. 390: 0.541544
# Accuracy after query no. 391: 0.538386
# Accuracy after query no. 392: 0.542074
# Accuracy after query no. 393: 0.538424
# Accuracy after query no. 394: 0.543095
# Accuracy after query no. 395: 0.551200
# Accuracy after query no. 396: 0.561275
# Accuracy after query no. 397: 0.567925
# Accuracy after query no. 398: 0.570167
# Accuracy after query no. 399: 0.570447
# Accuracy after query no. 400: 0.568762
# Accuracy after query no. 401: 0.570025
# Accuracy after query no. 402: 0.566863
# Accuracy after query no. 403: 0.567142
# Accuracy after query no. 404: 0.576280
# Accuracy after query no. 405: 0.573609
# Accuracy after query no. 406: 0.570443
# Accuracy after query no. 407: 0.570724
# ======================================
# By just labelling  16.67 % of total data accuracy of  0.571  % is achieved on the unseen data

# %% [markdown]
# ## Regular supervised task

# %%
from sklearn.model_selection import train_test_split

# %%
check_X = np.copy(X)
check_Y = np.copy(Y)

X_train,X_test,Y_train,Y_test = train_test_split(check_X,check_Y,test_size = 0.2)

# %%
# logisticRegr = LogisticRegression()
nb.fit(X_train, Y_train)
score = nb.score(X_test, Y_test)

print(score)
# Out:
# 0.5132924335378323

# %%
supervised_accuracy = [score for x in range(0,n_queries)]

plt.figure()
plt.plot(np.linspace(0,n_queries-1,n_queries),supervised_accuracy)
plt.plot(accuracy_list)
plt.title("Accuracy after every query")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.legend(["Supervised", "Active Learning"], loc="lower right")
plt.show()
