# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %%
original_data = pd.read_csv('../dataset/mohler1_cleaned.csv')

# %%
original_data = original_data.drop(labels='Unnamed: 6', axis=1)

# %%
original_data
# Out:
#      question_id  grade stud_id  \
# 0            1.1    3.5     [6]
# 1            1.1    5.0     [5]
# 2            1.1    4.0     [8]
# 3            1.1    5.0     [3]
# 4            1.1    3.0     [4]
# 5            1.1    2.0    [24]
# 6            1.1    2.5     [9]
# 7            1.1    5.0    [22]
# 8            1.1    3.5    [23]
# 9            1.1    5.0     [2]
# 10           1.1    5.0    [29]
# 11           1.1    5.0    [31]
# 12           1.1    2.0    [12]
# 13           1.1    4.5    [21]
# 14           1.1    2.0    [13]
# 15           1.1    4.5    [11]
# 16           1.1    5.0    [17]
# 17           1.1    2.0     [7]
# 18           1.1    2.0    [10]
# 19           1.1    2.5    [27]
# 20           1.1    5.0    [20]
# 21           1.1    5.0    [18]
# 22           1.1    1.5    [19]
# 23           1.1    2.5    [16]
# 24           1.1    5.0    [26]
# 25           1.1    2.0     [1]
# 26           1.1    3.0    [28]
# 27           1.1    3.0    [15]
# 28           1.1    2.5    [14]
# 29           1.2    3.5     [6]
# ..           ...    ...     ...
# 581          3.6    3.5    [27]
# 582          3.6    5.0    [25]
# 583          3.6    5.0    [20]
# 584          3.6    5.0    [18]
# 585          3.6    4.5    [19]
# 586          3.6    5.0    [30]
# 587          3.6    5.0    [16]
# 588          3.6    5.0    [26]
# 589          3.6    5.0     [1]
# 590          3.6    5.0    [28]
# 591          3.6    5.0    [15]
# 592          3.6    3.0    [14]
# 593          3.7    5.0     [6]
# 594          3.7    2.0     [5]
# 595          3.7    5.0     [8]
# 596          3.7    5.0     [3]
# 597          3.7    5.0     [4]
# 598          3.7    5.0    [24]
# 599          3.7    4.0     [9]
# 600          3.7    3.0    [22]
# 601          3.7    4.5    [23]
# 602          3.7    3.5     [2]
# 603          3.7    5.0    [29]
# 604          3.7    5.0    [31]
# 605          3.7    0.0    [12]
# 606          3.7    3.0    [21]
# 607          3.7    3.5    [13]
# 608          3.7    5.0    [11]
# 609          3.7    5.0    [17]
# 610          3.7    2.0     [7]
#
#                                               question  \
# 0    What is the role of a prototype program in pro...
# 1    What is the role of a prototype program in pro...
# 2    What is the role of a prototype program in pro...
# 3    What is the role of a prototype program in pro...
# 4    What is the role of a prototype program in pro...
# 5    What is the role of a prototype program in pro...
# 6    What is the role of a prototype program in pro...
# 7    What is the role of a prototype program in pro...
# 8    What is the role of a prototype program in pro...
# 9    What is the role of a prototype program in pro...
# 10   What is the role of a prototype program in pro...
# 11   What is the role of a prototype program in pro...
# 12   What is the role of a prototype program in pro...
# 13   What is the role of a prototype program in pro...
# 14   What is the role of a prototype program in pro...
# 15   What is the role of a prototype program in pro...
# 16   What is the role of a prototype program in pro...
# 17   What is the role of a prototype program in pro...
# 18   What is the role of a prototype program in pro...
# 19   What is the role of a prototype program in pro...
# 20   What is the role of a prototype program in pro...
# 21   What is the role of a prototype program in pro...
# 22   What is the role of a prototype program in pro...
# 23   What is the role of a prototype program in pro...
# 24   What is the role of a prototype program in pro...
# 25   What is the role of a prototype program in pro...
# 26   What is the role of a prototype program in pro...
# 27   What is the role of a prototype program in pro...
# 28   What is the role of a prototype program in pro...
# 29   What stages in the software life cycle are inf...
# ..                                                 ...
# 581  When defining a recursive function, what are p...
# 582  When defining a recursive function, what are p...
# 583  When defining a recursive function, what are p...
# 584  When defining a recursive function, what are p...
# 585  When defining a recursive function, what are p...
# 586  When defining a recursive function, what are p...
# 587  When defining a recursive function, what are p...
# 588  When defining a recursive function, what are p...
# 589  When defining a recursive function, what are p...
# 590  When defining a recursive function, what are p...
# 591  When defining a recursive function, what are p...
# 592  When defining a recursive function, what are p...
# 593  What are the similarities between iteration an...
# 594  What are the similarities between iteration an...
# 595  What are the similarities between iteration an...
# 596  What are the similarities between iteration an...
# 597  What are the similarities between iteration an...
# 598  What are the similarities between iteration an...
# 599  What are the similarities between iteration an...
# 600  What are the similarities between iteration an...
# 601  What are the similarities between iteration an...
# 602  What are the similarities between iteration an...
# 603  What are the similarities between iteration an...
# 604  What are the similarities between iteration an...
# 605  What are the similarities between iteration an...
# 606  What are the similarities between iteration an...
# 607  What are the similarities between iteration an...
# 608  What are the similarities between iteration an...
# 609  What are the similarities between iteration an...
# 610  What are the similarities between iteration an...
#
#                                             ref_answer  \
# 0    To simulate the behaviour of portions of the d...
# 1    To simulate the behaviour of portions of the d...
# 2    To simulate the behaviour of portions of the d...
# 3    To simulate the behaviour of portions of the d...
# 4    To simulate the behaviour of portions of the d...
# 5    To simulate the behaviour of portions of the d...
# 6    To simulate the behaviour of portions of the d...
# 7    To simulate the behaviour of portions of the d...
# 8    To simulate the behaviour of portions of the d...
# 9    To simulate the behaviour of portions of the d...
# 10   To simulate the behaviour of portions of the d...
# 11   To simulate the behaviour of portions of the d...
# 12   To simulate the behaviour of portions of the d...
# 13   To simulate the behaviour of portions of the d...
# 14   To simulate the behaviour of portions of the d...
# 15   To simulate the behaviour of portions of the d...
# 16   To simulate the behaviour of portions of the d...
# 17   To simulate the behaviour of portions of the d...
# 18   To simulate the behaviour of portions of the d...
# 19   To simulate the behaviour of portions of the d...
# 20   To simulate the behaviour of portions of the d...
# 21   To simulate the behaviour of portions of the d...
# 22   To simulate the behaviour of portions of the d...
# 23   To simulate the behaviour of portions of the d...
# 24   To simulate the behaviour of portions of the d...
# 25   To simulate the behaviour of portions of the d...
# 26   To simulate the behaviour of portions of the d...
# 27   To simulate the behaviour of portions of the d...
# 28   To simulate the behaviour of portions of the d...
# 29   The testing stage can influence both the codin...
# ..                                                 ...
# 581  If the recursion step is defined incorrectly, ...
# 582  If the recursion step is defined incorrectly, ...
# 583  If the recursion step is defined incorrectly, ...
# 584  If the recursion step is defined incorrectly, ...
# 585  If the recursion step is defined incorrectly, ...
# 586  If the recursion step is defined incorrectly, ...
# 587  If the recursion step is defined incorrectly, ...
# 588  If the recursion step is defined incorrectly, ...
# 589  If the recursion step is defined incorrectly, ...
# 590  If the recursion step is defined incorrectly, ...
# 591  If the recursion step is defined incorrectly, ...
# 592  If the recursion step is defined incorrectly, ...
# 593                       They both involve repetition
# 594                       They both involve repetition
# 595                       They both involve repetition
# 596                       They both involve repetition
# 597                       They both involve repetition
# 598                       They both involve repetition
# 599                       They both involve repetition
# 600                       They both involve repetition
# 601                       They both involve repetition
# 602                       They both involve repetition
# 603                       They both involve repetition
# 604                       They both involve repetition
# 605                       They both involve repetition
# 606                       They both involve repetition
# 607                       They both involve repetition
# 608                       They both involve repetition
# 609                       They both involve repetition
# 610                       They both involve repetition
#
#                                         student_answer
# 0    High risk problems are address in the prototyp...
# 1    To simulate portions of the desired final prod...
# 2    A prototype program simulates the behaviors of...
# 3    Defined in the Specification phase a prototype...
# 4    It is used to let the users have a first idea ...
# 5    To find problem and errors in a program before...
# 6    To address major issues in the creation of the...
# 7    you can break the whole program into prototype...
# 8    -To provide an example or model of how the fin...
# 9    Simulating the behavior of only a portion of t...
# 10     A program that stimulates the behavior of po...
# 11   A program that simulates the behavior of porti...
# 12   To lay out the basics and give you a starting ...
# 13   To simulate problem solving for parts of the p...
# 14   A prototype program provides a basic groundwor...
# 15   A prototype program is a part of the Specifica...
# 16   Program that simulates the behavior of portion...
# 17   it provides a limited proof of concept to veri...
# 18   It tests the main function of the program whil...
# 19   To get early feedback from users in early stag...
# 20   it simulates the behavior of portions of the d...
# 21   It simulates the behavior of portions of the d...
# 22   A prototype program is used in problem solving...
# 23   To ease the understanding of problem under dis...
# 24   it simulates the behavior of portions of the d...
# 25   The role of a prototype program is to help spo...
# 26   the prototype program gives a general idea of ...
# 27   to show that a certain part of the program wor...
# 28   Prototype programming is an approach to progra...
# 29   Refining and possibly the design if the testin...
# ..                                                 ...
# 581  no base case, as in a single return that does ...
# 582  Either omitting the base case, or writing the ...
# 583  omitting the base case or writing the recursiv...
# 584  Either omitting the base case, or writing the ...
# 585  Infinite recursion may occur if no base case i...
# 586  Not having a base case, or building a recursio...
# 587  Either omitting the base case, or writing the ...
# 588  no base case<br>or if the programmar does not ...
# 589  No easily reached base case and no base case a...
# 590  function is never allowed to reach the 'base c...
# 591  it has no base case, or the base case is never...
# 592  recursion refers to situations in which functi...
# 593  Both involve a controlled repetition structure...
# 594  As discussed earlier, recursion may be used to...
# 595  Both iteration and recursion are based on cont...
# 596  Both are based on a control statement<br>     ...
# 597  Iteration and recursion have many similarities...
# 598  Both rely on repetition, both have a base case...
# 599  Both will repeat (loop) until a condition is m...
# 600  anything you can do iterativly you can do recu...
# 601      Both are repetative and both have a end test.
# 602  Incorrectly writing either can result in infin...
# 603  Both are based on a control statement.<br>Both...
# 604  Both are based on a control statement, Both in...
# 605                                       not answered
# 606  anything you can do recursively you can do ite...
# 607  Many problems can be solved by both iteration ...
# 608  Iteration and recursion both use repetition an...
# 609  both based on control statement, involve repet...
# 610       they are methods of repeating the same task.
#
# [611 rows x 6 columns]

# %%
short_df = original_data[['student_answer','grade','question']]
short_df['status'] = short_df['grade'] >= 3
short_df['status'] = short_df['status'].astype(int)
# Out:
# /home/black-book/anaconda3/envs/rnd/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/black-book/anaconda3/envs/rnd/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
short_df
# Out:
#                                         student_answer  grade  \
# 0    High risk problems are address in the prototyp...    3.5
# 1    To simulate portions of the desired final prod...    5.0
# 2    A prototype program simulates the behaviors of...    4.0
# 3    Defined in the Specification phase a prototype...    5.0
# 4    It is used to let the users have a first idea ...    3.0
# 5    To find problem and errors in a program before...    2.0
# 6    To address major issues in the creation of the...    2.5
# 7    you can break the whole program into prototype...    5.0
# 8    -To provide an example or model of how the fin...    3.5
# 9    Simulating the behavior of only a portion of t...    5.0
# 10     A program that stimulates the behavior of po...    5.0
# 11   A program that simulates the behavior of porti...    5.0
# 12   To lay out the basics and give you a starting ...    2.0
# 13   To simulate problem solving for parts of the p...    4.5
# 14   A prototype program provides a basic groundwor...    2.0
# 15   A prototype program is a part of the Specifica...    4.5
# 16   Program that simulates the behavior of portion...    5.0
# 17   it provides a limited proof of concept to veri...    2.0
# 18   It tests the main function of the program whil...    2.0
# 19   To get early feedback from users in early stag...    2.5
# 20   it simulates the behavior of portions of the d...    5.0
# 21   It simulates the behavior of portions of the d...    5.0
# 22   A prototype program is used in problem solving...    1.5
# 23   To ease the understanding of problem under dis...    2.5
# 24   it simulates the behavior of portions of the d...    5.0
# 25   The role of a prototype program is to help spo...    2.0
# 26   the prototype program gives a general idea of ...    3.0
# 27   to show that a certain part of the program wor...    3.0
# 28   Prototype programming is an approach to progra...    2.5
# 29   Refining and possibly the design if the testin...    3.5
# ..                                                 ...    ...
# 581  no base case, as in a single return that does ...    3.5
# 582  Either omitting the base case, or writing the ...    5.0
# 583  omitting the base case or writing the recursiv...    5.0
# 584  Either omitting the base case, or writing the ...    5.0
# 585  Infinite recursion may occur if no base case i...    4.5
# 586  Not having a base case, or building a recursio...    5.0
# 587  Either omitting the base case, or writing the ...    5.0
# 588  no base case<br>or if the programmar does not ...    5.0
# 589  No easily reached base case and no base case a...    5.0
# 590  function is never allowed to reach the 'base c...    5.0
# 591  it has no base case, or the base case is never...    5.0
# 592  recursion refers to situations in which functi...    3.0
# 593  Both involve a controlled repetition structure...    5.0
# 594  As discussed earlier, recursion may be used to...    2.0
# 595  Both iteration and recursion are based on cont...    5.0
# 596  Both are based on a control statement<br>     ...    5.0
# 597  Iteration and recursion have many similarities...    5.0
# 598  Both rely on repetition, both have a base case...    5.0
# 599  Both will repeat (loop) until a condition is m...    4.0
# 600  anything you can do iterativly you can do recu...    3.0
# 601      Both are repetative and both have a end test.    4.5
# 602  Incorrectly writing either can result in infin...    3.5
# 603  Both are based on a control statement.<br>Both...    5.0
# 604  Both are based on a control statement, Both in...    5.0
# 605                                       not answered    0.0
# 606  anything you can do recursively you can do ite...    3.0
# 607  Many problems can be solved by both iteration ...    3.5
# 608  Iteration and recursion both use repetition an...    5.0
# 609  both based on control statement, involve repet...    5.0
# 610       they are methods of repeating the same task.    2.0
#
#                                               question  status
# 0    What is the role of a prototype program in pro...       1
# 1    What is the role of a prototype program in pro...       1
# 2    What is the role of a prototype program in pro...       1
# 3    What is the role of a prototype program in pro...       1
# 4    What is the role of a prototype program in pro...       1
# 5    What is the role of a prototype program in pro...       0
# 6    What is the role of a prototype program in pro...       0
# 7    What is the role of a prototype program in pro...       1
# 8    What is the role of a prototype program in pro...       1
# 9    What is the role of a prototype program in pro...       1
# 10   What is the role of a prototype program in pro...       1
# 11   What is the role of a prototype program in pro...       1
# 12   What is the role of a prototype program in pro...       0
# 13   What is the role of a prototype program in pro...       1
# 14   What is the role of a prototype program in pro...       0
# 15   What is the role of a prototype program in pro...       1
# 16   What is the role of a prototype program in pro...       1
# 17   What is the role of a prototype program in pro...       0
# 18   What is the role of a prototype program in pro...       0
# 19   What is the role of a prototype program in pro...       0
# 20   What is the role of a prototype program in pro...       1
# 21   What is the role of a prototype program in pro...       1
# 22   What is the role of a prototype program in pro...       0
# 23   What is the role of a prototype program in pro...       0
# 24   What is the role of a prototype program in pro...       1
# 25   What is the role of a prototype program in pro...       0
# 26   What is the role of a prototype program in pro...       1
# 27   What is the role of a prototype program in pro...       1
# 28   What is the role of a prototype program in pro...       0
# 29   What stages in the software life cycle are inf...       1
# ..                                                 ...     ...
# 581  When defining a recursive function, what are p...       1
# 582  When defining a recursive function, what are p...       1
# 583  When defining a recursive function, what are p...       1
# 584  When defining a recursive function, what are p...       1
# 585  When defining a recursive function, what are p...       1
# 586  When defining a recursive function, what are p...       1
# 587  When defining a recursive function, what are p...       1
# 588  When defining a recursive function, what are p...       1
# 589  When defining a recursive function, what are p...       1
# 590  When defining a recursive function, what are p...       1
# 591  When defining a recursive function, what are p...       1
# 592  When defining a recursive function, what are p...       1
# 593  What are the similarities between iteration an...       1
# 594  What are the similarities between iteration an...       0
# 595  What are the similarities between iteration an...       1
# 596  What are the similarities between iteration an...       1
# 597  What are the similarities between iteration an...       1
# 598  What are the similarities between iteration an...       1
# 599  What are the similarities between iteration an...       1
# 600  What are the similarities between iteration an...       1
# 601  What are the similarities between iteration an...       1
# 602  What are the similarities between iteration an...       1
# 603  What are the similarities between iteration an...       1
# 604  What are the similarities between iteration an...       1
# 605  What are the similarities between iteration an...       0
# 606  What are the similarities between iteration an...       1
# 607  What are the similarities between iteration an...       1
# 608  What are the similarities between iteration an...       1
# 609  What are the similarities between iteration an...       1
# 610  What are the similarities between iteration an...       0
#
# [611 rows x 4 columns]

# %%
# short_df['word_count'] = short_df['student_answer'].apply(lambda x: dict(Counter(x.split())))

# counting unique words in every student's answer
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(short_df['student_answer'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = short_df['status'].values

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
train_idx = [0, 5, 6 ,100]
X_train = X[train_idx]
y_train = Y[train_idx]
 
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
lr = LogisticRegression()
learner = ActiveLearner(
    estimator = lr,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = 40
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
    print("\nQ: ", act_data.loc[int(query_idx),'question'])
    print("A: ",act_data.loc[int(query_idx),'student_answer'])
    print("Actual grade: ",y_pool[query_idx].reshape(1, ))
    print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
    human_label = int(input("\nGive me a grade 0 or 1:"))
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=[human_label]
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X,Y))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X, Y)))
# Out:
# Q:  What is the main difference between a while and a do...while statement?
# A:  a while statement will only process if the statement is met, while a do...while will always process once, then only continue if the statement is met.
# Actual grade:  [1]
# Class probabilities:  [[0.49957 0.50043]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 1: 0.780687
#
# Q:  Where are variables declared in a C++ program?
# A:  anywhere, but where you declare them depends on where you want them to be accessible (their scope)
# Actual grade:  [1]
# Class probabilities:  [[0.50011406 0.49988594]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 2: 0.801964
#
# Q:  What is the scope of global variables?
# A:  global variables have program scope (accessible anywhere in program)
# Actual grade:  [1]
# Class probabilities:  [[0.49967804 0.50032196]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 3: 0.798691
#
# Q:  When defining a recursive function, what are possible causes for infinite recursion?
# A:  it has no base case, or the base case is never met
# Actual grade:  [1]
# Class probabilities:  [[0.5012287 0.4987713]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 4: 0.834697
#
# Q:  When does C++ create a default constructor?
# A:  when there is not one already for a specific class
# Actual grade:  [1]
# Class probabilities:  [[0.50174237 0.49825763]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 5: 0.842881
#
# Q:   What are the main advantages associated with object-oriented programming?
# A:  Modularability, the ability to reuse parts of the program later in another program sometimes with completely different goals for the program. Also it makes it easier to debug code by dividing up the code into classes that each do a specific job and when the program fails at one job you only have one class to debug. Good for security purposes because it allows you to let someone use a program which sorts lists without having to give them access to the source code. ALso allows you to use inheritance and polymorphism.
# Actual grade:  [1]
# Class probabilities:  [[0.50640727 0.49359273]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 6: 0.855974
#
# Q:   What are the main advantages associated with object-oriented programming?
# A:  Information can be hidden. It is easier to debug. Programming is easier and more manageable.
# Actual grade:  [1]
# Class probabilities:  [[0.49945121 0.50054879]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 7: 0.862520
#
# Q:  What is the role of a prototype program in problem solving?
# A:  To simulate problem solving for parts of the problem
# Actual grade:  [1]
# Class probabilities:  [[0.48579584 0.51420416]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 8: 0.860884
#
# Q:  What is the role of a prototype program in problem solving?
# A:  A prototype program provides a basic groundwork from which to further enhance and improve a solution to a problem.
# Actual grade:  [0]
# Class probabilities:  [[0.41621675 0.58378325]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 9: 0.860884
#
# Q:   What are the main advantages associated with object-oriented programming?
# A:  Data Abstraction and control... it is possible to isolate elements<br>from other elements a lot easier and prevent tampering of data.<br>
# Actual grade:  [1]
# Class probabilities:  [[0.50964801 0.49035199]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 10: 0.862520
#
# Q:  What is the role of a prototype program in problem solving?
# A:  To get early feedback from users in early stages of development.  To show users a first idea of what the program will do/look like.  To make sure the program will meet requirements before intense programming begins.
# Actual grade:  [0]
# Class probabilities:  [[0.43503968 0.56496032]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 11: 0.864157
#
# Q:  What is the role of a prototype program in problem solving?
# A:  to show that a certain part of the program works as it is supposed to
# Actual grade:  [1]
# Class probabilities:  [[0.46958548 0.53041452]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 12: 0.864157
#
# Q:  What is a variable?
# A:  A pointer to a location in memory.
# Actual grade:  [1]
# Class probabilities:  [[0.43039424 0.56960576]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 13: 0.864157
#
# Q:  What is the main difference between a while and a do...while statement?
# A:  While tests for true first before running, do...while runs once first before checking.
# Actual grade:  [1]
# Class probabilities:  [[0.40029132 0.59970868]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 14: 0.864157
#
# Q:  What is the role of a header-file?
# A:  A header file is a cross communication method between source files, to help limit the size of each individual program. Without header files a program will be 1 large lump of code and thus fairly hard to debug and traverse.
# Actual grade:  [1]
# Class probabilities:  [[0.4146348 0.5853652]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 15: 0.864157
#
# Q:  What is a variable?
# A:  A way to store different values into the program, such as numbers, words, letters, etc.
# Actual grade:  [1]
# Class probabilities:  [[0.35350546 0.64649454]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 16: 0.864157
#
# Q:  What is the scope of global variables?
# A:  it is accessible by all functions within a program
# Actual grade:  [1]
# Class probabilities:  [[0.32220545 0.67779455]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 17: 0.864157
#
# Q:  What is the role of a prototype program in problem solving?
# A:  Prototype programming is an approach to programming that enables one to take an organized approach to developing an effective program with minimal errors and a strategic pattern when solving a problem. i.e. book gave an example of a costumer withdrawing money from a bank, the approach that was taking on a pseudo code level during the OOA/Design lvl before proceeding into creating a solution.
# Actual grade:  [0]
# Class probabilities:  [[0.32906042 0.67093958]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 18: 0.865794
#
# Q:  What is the role of a prototype program in problem solving?
# A:  To ease the understanding of problem under discussion and to ease the understanding of the program itself
# Actual grade:  [0]
# Class probabilities:  [[0.31941662 0.68058338]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 19: 0.867430
#
# Q:  What is the role of a prototype program in problem solving?
# A:  It is used to let the users have a first idea of the completed program and allow the clients to evaluate the program. This can generate much feedback including software specifications and project estimations of the total project.
# Actual grade:  [1]
# Class probabilities:  [[0.49455176 0.50544824]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 20: 0.867430
#
# Q:   What are the main advantages associated with object-oriented programming?
# A:  Re-usability  and ease of maintenance
# Actual grade:  [1]
# Class probabilities:  [[0.35838066 0.64161934]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 21: 0.867430
#
# Q:  What is the role of a prototype program in problem solving?
# A:  A prototype program is used in problem solving to collect data for the problem.
# Actual grade:  [0]
# Class probabilities:  [[0.32667769 0.67332231]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 22: 0.869067
#
# Q:  What is the role of a prototype program in problem solving?
# A:  Defined in the Specification phase a prototype stimulates the behavior of portions of the desired software product.  Meaning, the role of a prototype is a temporary solution until the program itself is refined to be used extensively in problem solving.
# Actual grade:  [1]
# Class probabilities:  [[0.49451433 0.50548567]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 23: 0.869067
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Removing logical errors, testing for valid data, random data and actual data.
# Actual grade:  [0]
# Class probabilities:  [[0.35447333 0.64552667]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 24: 0.870704
#
# Q:  What is typically included in a class definition?
# A:  a constructor and several data members, and at least one public data member or method
# Actual grade:  [1]
# Class probabilities:  [[0.4275981 0.5724019]]
# Give me a grade 0 or 1:1
# Accuracy after query no. 25: 0.870704
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Refining and possibly the design if the testing phase reveals problems in the design. Production can be affected if the program is unworkable in its current form which will lead to a later production time than originally estimated. Also affects coding because after testing you may need to rewrite the code for the program to remove errors.
# Actual grade:  [1]
# Class probabilities:  [[0.42457685 0.57542315]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 26: 0.870704
#
# Q:  When defining a recursive function, what are possible causes for infinite recursion?
# A:  badly designed algorithyms. using recursion for a non recursive problem.
# Actual grade:  [0]
# Class probabilities:  [[0.36335601 0.63664399]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 27: 0.872340
#
# Q:  Where are variables declared in a C++ program?
# A:  Globally for an entire program, and locally for individual functions (including FOR statements)
# Actual grade:  [1]
# Class probabilities:  [[0.391877 0.608123]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 28: 0.872340
#
# Q:  What is the role of a prototype program in problem solving?
# A:  To lay out the basics and give you a starting point in the actual problem solving.
# Actual grade:  [0]
# Class probabilities:  [[0.34897969 0.65102031]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 29: 0.873977
#
# Q:  What is the role of a header-file?
# A:  To allow the compiler to recognize the classes when used elsewhere.
# Actual grade:  [1]
# Class probabilities:  [[0.37594058 0.62405942]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 30: 0.873977
#
# Q:  What is typically included in a class definition?
# A:  An object and data.
# Actual grade:  [0]
# Class probabilities:  [[0.36098263 0.63901737]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 31: 0.873977
#
# Q:  What is a variable?
# A:  a variable is an object where data is stored.
# Actual grade:  [1]
# Class probabilities:  [[0.51907805 0.48092195]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 32: 0.875614
#
# Q:  What is typically included in a class definition?
# A:  the data and methods
# Actual grade:  [1]
# Class probabilities:  [[0.38901911 0.61098089]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 33: 0.875614
#
# Q:  What is the role of a prototype program in problem solving?
# A:  A prototype program is a part of the Specification phase of Software Problem Solvin.  It's employed to illustrate how the key problem or problems will be solved in a program, and sometimes serves as a base program to expand upon.
# Actual grade:  [1]
# Class probabilities:  [[0.35366307 0.64633693]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 34: 0.875614
#
# Q:  What is the main advantage associated with function arguments that are passed by reference?
# A:  gives function ability to access and modify the caller's argument data directly
# Actual grade:  [1]
# Class probabilities:  [[0.33178551 0.66821449]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 35: 0.873977
#
# Q:  What is the main difference between a while and a do...while statement?
# A:  NO ANSWER
# Actual grade:  [0]
# Class probabilities:  [[0.30746735 0.69253265]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 36: 0.877250
#
# Q:  What is the role of a header-file?
# A:  No
# Actual grade:  [0]
# Class probabilities:  [[0.45686145 0.54313855]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 37: 0.877250
#
# Q:  When defining a recursive function, what are possible causes for infinite recursion?
# A:  No easily reached base case and no base case at all
# Actual grade:  [1]
# Class probabilities:  [[0.51425004 0.48574996]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 38: 0.878887
#
# Q:  When does C++ create a default constructor?
# A:  When there are no arguments passed.
# Actual grade:  [0]
# Class probabilities:  [[0.48288688 0.51711312]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 39: 0.878887
#
# Q:  When defining a recursive function, what are possible causes for infinite recursion?
# A:  no base case<br>no change in values.
# Actual grade:  [1]
# Class probabilities:  [[0.48339543 0.51660457]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 40: 0.880524

# %% [markdown]
# ## Regular supervised task

# %%
from sklearn.model_selection import train_test_split

# %%
check_X = np.copy(X)
check_Y = np.copy(Y)

X_train,X_test,Y_train,Y_test = train_test_split(check_X,check_Y,test_size = 0.2)

# %%
logisticRegr = LogisticRegression()
logisticRegr.fit(X_train, Y_train)
score = logisticRegr.score(X_test, Y_test)

print(score)
# Out:
# 0.8617886178861789

# %%
supervised_accuracy = [score for x in range(0,40)]

plt.figure()
plt.plot(np.linspace(0,39,40),supervised_accuracy)
plt.plot(accuracy_list)
plt.title("Accuracy after every query")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.legend(["Supervised", "Active Learning"], loc="lower right")
plt.show()
