# %%
import pandas as pd
from nltk.corpus import stopwords
from textblob import Word
from nltk.stem import PorterStemmer
from textblob import TextBlob
from nltk.tokenize import word_tokenize
# import spacy
# spacy.load("en")
# import en_core_web_sm
# nlp = en_core_web_sm.load()

# %%
original_data = pd.read_csv('/home/mohandass/Documents/R&D/dataset/mohler1_cleaned.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-69ba501382a7> in <module>()
# ----> 1 original_data = pd.read_csv('/home/mohandass/Documents/R&D/dataset/mohler1_cleaned.csv')
#
# ~/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'/home/mohandass/Documents/R&D/dataset/mohler1_cleaned.csv' does not exist

# %%
original_data = original_data.drop(labels='Unnamed: 6', axis=1)

# %%
df = original_data
#converting to lower case
df['ref_answer'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_answer'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['ref_answer'] = df['ref_answer'].str.replace('[^\w\s]','')
df['student_answer'] = df['student_answer'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['ref_answer'] = df['ref_answer'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_answer'] = df['student_answer'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))


# #lemmatisation
df['ref_answer'] = df['ref_answer'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_answer'] = df['student_answer'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))

# #stemming
# st = PorterStemmer()
# df['ref_answer'] = df['ref_answer'].apply(lambda x: " ".join([st.stem(word) for word in word_tokenize(x)]))
# df['student_answer'] = df['student_answer'].apply(lambda x: " ".join([st.stem(word) for word in word_tokenize(x)]))
df
# Out:
#      question_id  grade stud_id  \
# 0            1.1    3.5     [6]
# 1            1.1    5.0     [5]
# 2            1.1    4.0     [8]
# 3            1.1    5.0     [3]
# 4            1.1    3.0     [4]
# 5            1.1    2.0    [24]
# 6            1.1    2.5     [9]
# 7            1.1    5.0    [22]
# 8            1.1    3.5    [23]
# 9            1.1    5.0     [2]
# 10           1.1    5.0    [29]
# 11           1.1    5.0    [31]
# 12           1.1    2.0    [12]
# 13           1.1    4.5    [21]
# 14           1.1    2.0    [13]
# 15           1.1    4.5    [11]
# 16           1.1    5.0    [17]
# 17           1.1    2.0     [7]
# 18           1.1    2.0    [10]
# 19           1.1    2.5    [27]
# 20           1.1    5.0    [20]
# 21           1.1    5.0    [18]
# 22           1.1    1.5    [19]
# 23           1.1    2.5    [16]
# 24           1.1    5.0    [26]
# 25           1.1    2.0     [1]
# 26           1.1    3.0    [28]
# 27           1.1    3.0    [15]
# 28           1.1    2.5    [14]
# 29           1.2    3.5     [6]
# ..           ...    ...     ...
# 581          3.6    3.5    [27]
# 582          3.6    5.0    [25]
# 583          3.6    5.0    [20]
# 584          3.6    5.0    [18]
# 585          3.6    4.5    [19]
# 586          3.6    5.0    [30]
# 587          3.6    5.0    [16]
# 588          3.6    5.0    [26]
# 589          3.6    5.0     [1]
# 590          3.6    5.0    [28]
# 591          3.6    5.0    [15]
# 592          3.6    3.0    [14]
# 593          3.7    5.0     [6]
# 594          3.7    2.0     [5]
# 595          3.7    5.0     [8]
# 596          3.7    5.0     [3]
# 597          3.7    5.0     [4]
# 598          3.7    5.0    [24]
# 599          3.7    4.0     [9]
# 600          3.7    3.0    [22]
# 601          3.7    4.5    [23]
# 602          3.7    3.5     [2]
# 603          3.7    5.0    [29]
# 604          3.7    5.0    [31]
# 605          3.7    0.0    [12]
# 606          3.7    3.0    [21]
# 607          3.7    3.5    [13]
# 608          3.7    5.0    [11]
# 609          3.7    5.0    [17]
# 610          3.7    2.0     [7]
#
#                                               question  \
# 0    What is the role of a prototype program in pro...
# 1    What is the role of a prototype program in pro...
# 2    What is the role of a prototype program in pro...
# 3    What is the role of a prototype program in pro...
# 4    What is the role of a prototype program in pro...
# 5    What is the role of a prototype program in pro...
# 6    What is the role of a prototype program in pro...
# 7    What is the role of a prototype program in pro...
# 8    What is the role of a prototype program in pro...
# 9    What is the role of a prototype program in pro...
# 10   What is the role of a prototype program in pro...
# 11   What is the role of a prototype program in pro...
# 12   What is the role of a prototype program in pro...
# 13   What is the role of a prototype program in pro...
# 14   What is the role of a prototype program in pro...
# 15   What is the role of a prototype program in pro...
# 16   What is the role of a prototype program in pro...
# 17   What is the role of a prototype program in pro...
# 18   What is the role of a prototype program in pro...
# 19   What is the role of a prototype program in pro...
# 20   What is the role of a prototype program in pro...
# 21   What is the role of a prototype program in pro...
# 22   What is the role of a prototype program in pro...
# 23   What is the role of a prototype program in pro...
# 24   What is the role of a prototype program in pro...
# 25   What is the role of a prototype program in pro...
# 26   What is the role of a prototype program in pro...
# 27   What is the role of a prototype program in pro...
# 28   What is the role of a prototype program in pro...
# 29   What stages in the software life cycle are inf...
# ..                                                 ...
# 581  When defining a recursive function, what are p...
# 582  When defining a recursive function, what are p...
# 583  When defining a recursive function, what are p...
# 584  When defining a recursive function, what are p...
# 585  When defining a recursive function, what are p...
# 586  When defining a recursive function, what are p...
# 587  When defining a recursive function, what are p...
# 588  When defining a recursive function, what are p...
# 589  When defining a recursive function, what are p...
# 590  When defining a recursive function, what are p...
# 591  When defining a recursive function, what are p...
# 592  When defining a recursive function, what are p...
# 593  What are the similarities between iteration an...
# 594  What are the similarities between iteration an...
# 595  What are the similarities between iteration an...
# 596  What are the similarities between iteration an...
# 597  What are the similarities between iteration an...
# 598  What are the similarities between iteration an...
# 599  What are the similarities between iteration an...
# 600  What are the similarities between iteration an...
# 601  What are the similarities between iteration an...
# 602  What are the similarities between iteration an...
# 603  What are the similarities between iteration an...
# 604  What are the similarities between iteration an...
# 605  What are the similarities between iteration an...
# 606  What are the similarities between iteration an...
# 607  What are the similarities between iteration an...
# 608  What are the similarities between iteration an...
# 609  What are the similarities between iteration an...
# 610  What are the similarities between iteration an...
#
#                                             ref_answer  \
# 0        simul behaviour portion desir softwar product
# 1        simul behaviour portion desir softwar product
# 2        simul behaviour portion desir softwar product
# 3        simul behaviour portion desir softwar product
# 4        simul behaviour portion desir softwar product
# 5        simul behaviour portion desir softwar product
# 6        simul behaviour portion desir softwar product
# 7        simul behaviour portion desir softwar product
# 8        simul behaviour portion desir softwar product
# 9        simul behaviour portion desir softwar product
# 10       simul behaviour portion desir softwar product
# 11       simul behaviour portion desir softwar product
# 12       simul behaviour portion desir softwar product
# 13       simul behaviour portion desir softwar product
# 14       simul behaviour portion desir softwar product
# 15       simul behaviour portion desir softwar product
# 16       simul behaviour portion desir softwar product
# 17       simul behaviour portion desir softwar product
# 18       simul behaviour portion desir softwar product
# 19       simul behaviour portion desir softwar product
# 20       simul behaviour portion desir softwar product
# 21       simul behaviour portion desir softwar product
# 22       simul behaviour portion desir softwar product
# 23       simul behaviour portion desir softwar product
# 24       simul behaviour portion desir softwar product
# 25       simul behaviour portion desir softwar product
# 26       simul behaviour portion desir softwar product
# 27       simul behaviour portion desir softwar product
# 28       simul behaviour portion desir softwar product
# 29   test stage influenc code stage phase 5 solut r...
# ..                                                 ...
# 581     recurs step defin incorrectli base case includ
# 582     recurs step defin incorrectli base case includ
# 583     recurs step defin incorrectli base case includ
# 584     recurs step defin incorrectli base case includ
# 585     recurs step defin incorrectli base case includ
# 586     recurs step defin incorrectli base case includ
# 587     recurs step defin incorrectli base case includ
# 588     recurs step defin incorrectli base case includ
# 589     recurs step defin incorrectli base case includ
# 590     recurs step defin incorrectli base case includ
# 591     recurs step defin incorrectli base case includ
# 592     recurs step defin incorrectli base case includ
# 593                                     involv repetit
# 594                                     involv repetit
# 595                                     involv repetit
# 596                                     involv repetit
# 597                                     involv repetit
# 598                                     involv repetit
# 599                                     involv repetit
# 600                                     involv repetit
# 601                                     involv repetit
# 602                                     involv repetit
# 603                                     involv repetit
# 604                                     involv repetit
# 605                                     involv repetit
# 606                                     involv repetit
# 607                                     involv repetit
# 608                                     involv repetit
# 609                                     involv repetit
# 610                                     involv repetit
#
#                                         student_answer
# 0    high risk problem address prototyp program mak...
# 1    simul portion desir final product quick easi p...
# 2    prototyp program simul behavior portion desir ...
# 3    defin specif phase prototyp stimul behavior po...
# 4    use let user first idea complet program allow ...
# 5                     find problem error program final
# 6    address major issu creation program way accoun...
# 7    break whole program prototyp program simul par...
# 8    provid exampl model finish program perfombr pr...
# 9         simul behavior portion desir softwar product
# 10   program stimul behavior portion desir softwar ...
# 11   program simul behavior portion desir softwar p...
# 12      lay basic give start point actual problem solv
# 13                     simul problem solv part problem
# 14   prototyp program provid basic groundwork enhan...
# 15   prototyp program part specif phase softwar pro...
# 16   program simul behavior portion desir softwar p...
# 17   provid limit proof concept verifi client actua...
# 18     test main function program leav finer detailsbr
# 19   get earli feedback user earli stage develop sh...
# 20        simul behavior portion desir softwar product
# 21        simul behavior portion desir softwar product
# 22   prototyp program use problem solv collect data...
# 23   ea understand problem discus ea understand pro...
# 24        simul behavior portion desir softwar product
# 25   role prototyp program help spot key problem ma...
# 26   prototyp program give gener idea end product b...
# 27               show certain part program work suppos
# 28   prototyp program approach program enabl one ta...
# 29   refin possibl design test phase reveal problem...
# ..                                                 ...
# 581  base case singl return includ call function st...
# 582  either omit base case write recurs step incorr...
# 583  omit base case write recurs call converg upon ...
# 584  either omit base case write recurs step incorr...
# 585  infinit recurs may occur base case defin call ...
# 586  base case build recurs process doesnt converg ...
# 587  either omit base case write recurs step incore...
# 588  base casebror programmar defin base case simpl...
# 589                   easili reach base case base case
# 590               function never allow reach base case
# 591                      base case base case never met
# 592  recurs refer situat function call type functio...
# 593  involv control repetit structur termin test al...
# 594  discus earlier recurs may use process iter act...
# 595  iter recurs base control statement involv repe...
# 596  base control statementbr iterationrepetit stru...
# 597  iter recurs mani similar base control statemen...
# 598  reli repetit base case becom infinit loop anyt...
# 599  repeat loop condit met exit loop capabl enter ...
# 600                            anyth iterativli recurs
# 601                                     repet end test
# 602  incorrectli write either result infinit loop p...
# 603  base control statementbrboth involv repetition...
# 604  base control statement involv repetit involv t...
# 605                                             answer
# 606                                  anyth recurs iter
# 607  mani problem solv iter recurs either may go co...
# 608  iter recurs use repetit perform sever simpl op...
# 609  base control statement involv repetit involv t...
# 610                                 method repeat task
#
# [611 rows x 6 columns]

# %%
df['ref_answer'] = df['ref_answer'].apply(lambda x: nlp(x))
df['student_answer'] = df['student_answer'].apply(lambda x: nlp(x))

def compute_similarity(row):
    return row['ref_answer'].similarity(row['student_answer'])

df['similarity_cos'] = df.apply(compute_similarity,axis=1)
# df

# "fgh".similarity("jkki")

# %%
df
# Out:
#      question_id  grade stud_id  \
# 0            1.1    3.5     [6]
# 1            1.1    5.0     [5]
# 2            1.1    4.0     [8]
# 3            1.1    5.0     [3]
# 4            1.1    3.0     [4]
# 5            1.1    2.0    [24]
# 6            1.1    2.5     [9]
# 7            1.1    5.0    [22]
# 8            1.1    3.5    [23]
# 9            1.1    5.0     [2]
# 10           1.1    5.0    [29]
# 11           1.1    5.0    [31]
# 12           1.1    2.0    [12]
# 13           1.1    4.5    [21]
# 14           1.1    2.0    [13]
# 15           1.1    4.5    [11]
# 16           1.1    5.0    [17]
# 17           1.1    2.0     [7]
# 18           1.1    2.0    [10]
# 19           1.1    2.5    [27]
# 20           1.1    5.0    [20]
# 21           1.1    5.0    [18]
# 22           1.1    1.5    [19]
# 23           1.1    2.5    [16]
# 24           1.1    5.0    [26]
# 25           1.1    2.0     [1]
# 26           1.1    3.0    [28]
# 27           1.1    3.0    [15]
# 28           1.1    2.5    [14]
# 29           1.2    3.5     [6]
# ..           ...    ...     ...
# 581          3.6    3.5    [27]
# 582          3.6    5.0    [25]
# 583          3.6    5.0    [20]
# 584          3.6    5.0    [18]
# 585          3.6    4.5    [19]
# 586          3.6    5.0    [30]
# 587          3.6    5.0    [16]
# 588          3.6    5.0    [26]
# 589          3.6    5.0     [1]
# 590          3.6    5.0    [28]
# 591          3.6    5.0    [15]
# 592          3.6    3.0    [14]
# 593          3.7    5.0     [6]
# 594          3.7    2.0     [5]
# 595          3.7    5.0     [8]
# 596          3.7    5.0     [3]
# 597          3.7    5.0     [4]
# 598          3.7    5.0    [24]
# 599          3.7    4.0     [9]
# 600          3.7    3.0    [22]
# 601          3.7    4.5    [23]
# 602          3.7    3.5     [2]
# 603          3.7    5.0    [29]
# 604          3.7    5.0    [31]
# 605          3.7    0.0    [12]
# 606          3.7    3.0    [21]
# 607          3.7    3.5    [13]
# 608          3.7    5.0    [11]
# 609          3.7    5.0    [17]
# 610          3.7    2.0     [7]
#
#                                               question  \
# 0    What is the role of a prototype program in pro...
# 1    What is the role of a prototype program in pro...
# 2    What is the role of a prototype program in pro...
# 3    What is the role of a prototype program in pro...
# 4    What is the role of a prototype program in pro...
# 5    What is the role of a prototype program in pro...
# 6    What is the role of a prototype program in pro...
# 7    What is the role of a prototype program in pro...
# 8    What is the role of a prototype program in pro...
# 9    What is the role of a prototype program in pro...
# 10   What is the role of a prototype program in pro...
# 11   What is the role of a prototype program in pro...
# 12   What is the role of a prototype program in pro...
# 13   What is the role of a prototype program in pro...
# 14   What is the role of a prototype program in pro...
# 15   What is the role of a prototype program in pro...
# 16   What is the role of a prototype program in pro...
# 17   What is the role of a prototype program in pro...
# 18   What is the role of a prototype program in pro...
# 19   What is the role of a prototype program in pro...
# 20   What is the role of a prototype program in pro...
# 21   What is the role of a prototype program in pro...
# 22   What is the role of a prototype program in pro...
# 23   What is the role of a prototype program in pro...
# 24   What is the role of a prototype program in pro...
# 25   What is the role of a prototype program in pro...
# 26   What is the role of a prototype program in pro...
# 27   What is the role of a prototype program in pro...
# 28   What is the role of a prototype program in pro...
# 29   What stages in the software life cycle are inf...
# ..                                                 ...
# 581  When defining a recursive function, what are p...
# 582  When defining a recursive function, what are p...
# 583  When defining a recursive function, what are p...
# 584  When defining a recursive function, what are p...
# 585  When defining a recursive function, what are p...
# 586  When defining a recursive function, what are p...
# 587  When defining a recursive function, what are p...
# 588  When defining a recursive function, what are p...
# 589  When defining a recursive function, what are p...
# 590  When defining a recursive function, what are p...
# 591  When defining a recursive function, what are p...
# 592  When defining a recursive function, what are p...
# 593  What are the similarities between iteration an...
# 594  What are the similarities between iteration an...
# 595  What are the similarities between iteration an...
# 596  What are the similarities between iteration an...
# 597  What are the similarities between iteration an...
# 598  What are the similarities between iteration an...
# 599  What are the similarities between iteration an...
# 600  What are the similarities between iteration an...
# 601  What are the similarities between iteration an...
# 602  What are the similarities between iteration an...
# 603  What are the similarities between iteration an...
# 604  What are the similarities between iteration an...
# 605  What are the similarities between iteration an...
# 606  What are the similarities between iteration an...
# 607  What are the similarities between iteration an...
# 608  What are the similarities between iteration an...
# 609  What are the similarities between iteration an...
# 610  What are the similarities between iteration an...
#
#                                             ref_answer  \
# 0    (simulate, behaviour, portions, desired, softw...
# 1    (simulate, behaviour, portions, desired, softw...
# 2    (simulate, behaviour, portions, desired, softw...
# 3    (simulate, behaviour, portions, desired, softw...
# 4    (simulate, behaviour, portions, desired, softw...
# 5    (simulate, behaviour, portions, desired, softw...
# 6    (simulate, behaviour, portions, desired, softw...
# 7    (simulate, behaviour, portions, desired, softw...
# 8    (simulate, behaviour, portions, desired, softw...
# 9    (simulate, behaviour, portions, desired, softw...
# 10   (simulate, behaviour, portions, desired, softw...
# 11   (simulate, behaviour, portions, desired, softw...
# 12   (simulate, behaviour, portions, desired, softw...
# 13   (simulate, behaviour, portions, desired, softw...
# 14   (simulate, behaviour, portions, desired, softw...
# 15   (simulate, behaviour, portions, desired, softw...
# 16   (simulate, behaviour, portions, desired, softw...
# 17   (simulate, behaviour, portions, desired, softw...
# 18   (simulate, behaviour, portions, desired, softw...
# 19   (simulate, behaviour, portions, desired, softw...
# 20   (simulate, behaviour, portions, desired, softw...
# 21   (simulate, behaviour, portions, desired, softw...
# 22   (simulate, behaviour, portions, desired, softw...
# 23   (simulate, behaviour, portions, desired, softw...
# 24   (simulate, behaviour, portions, desired, softw...
# 25   (simulate, behaviour, portions, desired, softw...
# 26   (simulate, behaviour, portions, desired, softw...
# 27   (simulate, behaviour, portions, desired, softw...
# 28   (simulate, behaviour, portions, desired, softw...
# 29   (testing, stage, influence, coding, stage, pha...
# ..                                                 ...
# 581  (recursion, step, defined, incorrectly, base, ...
# 582  (recursion, step, defined, incorrectly, base, ...
# 583  (recursion, step, defined, incorrectly, base, ...
# 584  (recursion, step, defined, incorrectly, base, ...
# 585  (recursion, step, defined, incorrectly, base, ...
# 586  (recursion, step, defined, incorrectly, base, ...
# 587  (recursion, step, defined, incorrectly, base, ...
# 588  (recursion, step, defined, incorrectly, base, ...
# 589  (recursion, step, defined, incorrectly, base, ...
# 590  (recursion, step, defined, incorrectly, base, ...
# 591  (recursion, step, defined, incorrectly, base, ...
# 592  (recursion, step, defined, incorrectly, base, ...
# 593                              (involve, repetition)
# 594                              (involve, repetition)
# 595                              (involve, repetition)
# 596                              (involve, repetition)
# 597                              (involve, repetition)
# 598                              (involve, repetition)
# 599                              (involve, repetition)
# 600                              (involve, repetition)
# 601                              (involve, repetition)
# 602                              (involve, repetition)
# 603                              (involve, repetition)
# 604                              (involve, repetition)
# 605                              (involve, repetition)
# 606                              (involve, repetition)
# 607                              (involve, repetition)
# 608                              (involve, repetition)
# 609                              (involve, repetition)
# 610                              (involve, repetition)
#
#                                         student_answer  similarity_cos
# 0    (high, risk, problems, address, prototype, pro...        0.861395
# 1    (simulate, portions, desired, final, product, ...        0.803366
# 2    (prototype, program, simulates, behaviors, por...        0.937918
# 3    (defined, specification, phase, prototype, sti...        0.913920
# 4    (used, let, users, first, idea, completed, pro...        0.877587
# 5          (find, problem, errors, program, finalized)        0.818970
# 6    (address, major, issues, creation, program, wa...        0.856758
# 7    (break, whole, program, prototype, programs, s...        0.879279
# 8    (provide, example, model, finished, program, p...        0.838259
# 9    (simulating, behavior, portion, desired, softw...        0.920440
# 10   (program, stimulates, behavior, portions, desi...        0.934104
# 11   (program, simulates, behavior, portions, desir...        0.944150
# 12   (lay, basics, give, starting, point, actual, p...        0.817599
# 13        (simulate, problem, solving, parts, problem)        0.823181
# 14   (prototype, program, provides, basic, groundwo...        0.854207
# 15   (prototype, program, part, specification, phas...        0.887454
# 16   (program, simulates, behavior, portions, desir...        0.944150
# 17   (provides, limited, proof, concept, verify, cl...        0.727306
# 18   (tests, main, function, program, leaving, fine...        0.831792
# 19   (get, early, feedback, users, early, stages, d...        0.833095
# 20   (simulates, behavior, portions, desired, softw...        0.937793
# 21   (simulates, behavior, portions, desired, softw...        0.937793
# 22   (prototype, program, used, problem, solving, c...        0.894680
# 23   (ease, understanding, problem, discussion, eas...        0.770719
# 24   (simulates, behavior, portions, desired, softw...        0.937793
# 25   (role, prototype, program, help, spot, key, pr...        0.812309
# 26   (prototype, program, gives, general, idea, end...        0.850444
# 27     (show, certain, part, program, works, supposed)        0.801054
# 28   (prototype, programming, approach, programming...        0.867161
# 29   (refining, possibly, design, testing, phase, r...        0.828856
# ..                                                 ...             ...
# 581  (base, case, single, return, include, calling,...        0.802086
# 582  (either, omitting, base, case, writing, recurs...        0.850552
# 583  (omitting, base, case, writing, recursive, cal...        0.821999
# 584  (either, omitting, base, case, writing, recurs...        0.860427
# 585  (infinite, recursion, may, occur, base, case, ...        0.875084
# 586  (base, case, building, recursion, process, doe...        0.811357
# 587  (either, omitting, base, case, writing, recurs...        0.803652
# 588  (base, casebror, programmar, define, base, cas...        0.866764
# 589          (easily, reached, base, case, base, case)        0.832810
# 590      (function, never, allowed, reach, base, case)        0.828688
# 591               (base, case, base, case, never, met)        0.864214
# 592  (recursion, refers, situations, functions, cal...        0.788657
# 593  (involve, controlled, repetition, structures, ...        0.581050
# 594  (discussed, earlier, recursion, may, used, pro...        0.567665
# 595  (iteration, recursion, based, control, stateme...        0.638468
# 596  (based, control, statementbr, iterationrepetit...        0.640501
# 597  (iteration, recursion, many, similarities, bas...        0.672045
# 598  (rely, repetition, base, case, become, infinit...        0.655304
# 599  (repeat, loop, condition, met, exit, loop, cap...        0.608195
# 600                (anything, iterativly, recursively)        0.453370
# 601                            (repetative, end, test)        0.651034
# 602  (incorrectly, writing, either, result, infinit...        0.674962
# 603  (based, control, statementbrboth, involve, rep...        0.665424
# 604  (based, control, statement, involve, repetitio...        0.704613
# 605                                         (answered)        0.156505
# 606               (anything, recursively, iteratively)        0.256604
# 607  (many, problems, solved, iteration, recursion,...        0.606096
# 608  (iteration, recursion, use, repetition, perfor...        0.645086
# 609  (based, control, statement, involve, repetitio...        0.729878
# 610                         (methods, repeating, task)        0.466870
#
# [611 rows x 7 columns]
