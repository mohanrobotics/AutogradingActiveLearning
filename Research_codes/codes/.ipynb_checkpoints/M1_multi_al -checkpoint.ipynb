# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %%
original_data = pd.read_csv('../dataset/mohler1_cleaned.csv')
original_data = original_data.drop(labels='Unnamed: 6', axis=1)
original_data = original_data.rename(columns={'question_number':'question_id','question_text':'question','answer_model':'ref_answer','answer_student':'student_answer','score_avg':'grade'})

# %%
df = original_data.copy()

#converting to lower case
df['ref_modified'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))


#lemmatisation
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))

df
# Out:
#      question_id  grade stud_id  \
# 0            1.1    3.5     [6]
# 1            1.1    5.0     [5]
# 2            1.1    4.0     [8]
# 3            1.1    5.0     [3]
# 4            1.1    3.0     [4]
# 5            1.1    2.0    [24]
# 6            1.1    2.5     [9]
# 7            1.1    5.0    [22]
# 8            1.1    3.5    [23]
# 9            1.1    5.0     [2]
# 10           1.1    5.0    [29]
# 11           1.1    5.0    [31]
# 12           1.1    2.0    [12]
# 13           1.1    4.5    [21]
# 14           1.1    2.0    [13]
# 15           1.1    4.5    [11]
# 16           1.1    5.0    [17]
# 17           1.1    2.0     [7]
# 18           1.1    2.0    [10]
# 19           1.1    2.5    [27]
# 20           1.1    5.0    [20]
# 21           1.1    5.0    [18]
# 22           1.1    1.5    [19]
# 23           1.1    2.5    [16]
# 24           1.1    5.0    [26]
# 25           1.1    2.0     [1]
# 26           1.1    3.0    [28]
# 27           1.1    3.0    [15]
# 28           1.1    2.5    [14]
# 29           1.2    3.5     [6]
# ..           ...    ...     ...
# 581          3.6    3.5    [27]
# 582          3.6    5.0    [25]
# 583          3.6    5.0    [20]
# 584          3.6    5.0    [18]
# 585          3.6    4.5    [19]
# 586          3.6    5.0    [30]
# 587          3.6    5.0    [16]
# 588          3.6    5.0    [26]
# 589          3.6    5.0     [1]
# 590          3.6    5.0    [28]
# 591          3.6    5.0    [15]
# 592          3.6    3.0    [14]
# 593          3.7    5.0     [6]
# 594          3.7    2.0     [5]
# 595          3.7    5.0     [8]
# 596          3.7    5.0     [3]
# 597          3.7    5.0     [4]
# 598          3.7    5.0    [24]
# 599          3.7    4.0     [9]
# 600          3.7    3.0    [22]
# 601          3.7    4.5    [23]
# 602          3.7    3.5     [2]
# 603          3.7    5.0    [29]
# 604          3.7    5.0    [31]
# 605          3.7    0.0    [12]
# 606          3.7    3.0    [21]
# 607          3.7    3.5    [13]
# 608          3.7    5.0    [11]
# 609          3.7    5.0    [17]
# 610          3.7    2.0     [7]
#
#                                               question  \
# 0    What is the role of a prototype program in pro...
# 1    What is the role of a prototype program in pro...
# 2    What is the role of a prototype program in pro...
# 3    What is the role of a prototype program in pro...
# 4    What is the role of a prototype program in pro...
# 5    What is the role of a prototype program in pro...
# 6    What is the role of a prototype program in pro...
# 7    What is the role of a prototype program in pro...
# 8    What is the role of a prototype program in pro...
# 9    What is the role of a prototype program in pro...
# 10   What is the role of a prototype program in pro...
# 11   What is the role of a prototype program in pro...
# 12   What is the role of a prototype program in pro...
# 13   What is the role of a prototype program in pro...
# 14   What is the role of a prototype program in pro...
# 15   What is the role of a prototype program in pro...
# 16   What is the role of a prototype program in pro...
# 17   What is the role of a prototype program in pro...
# 18   What is the role of a prototype program in pro...
# 19   What is the role of a prototype program in pro...
# 20   What is the role of a prototype program in pro...
# 21   What is the role of a prototype program in pro...
# 22   What is the role of a prototype program in pro...
# 23   What is the role of a prototype program in pro...
# 24   What is the role of a prototype program in pro...
# 25   What is the role of a prototype program in pro...
# 26   What is the role of a prototype program in pro...
# 27   What is the role of a prototype program in pro...
# 28   What is the role of a prototype program in pro...
# 29   What stages in the software life cycle are inf...
# ..                                                 ...
# 581  When defining a recursive function, what are p...
# 582  When defining a recursive function, what are p...
# 583  When defining a recursive function, what are p...
# 584  When defining a recursive function, what are p...
# 585  When defining a recursive function, what are p...
# 586  When defining a recursive function, what are p...
# 587  When defining a recursive function, what are p...
# 588  When defining a recursive function, what are p...
# 589  When defining a recursive function, what are p...
# 590  When defining a recursive function, what are p...
# 591  When defining a recursive function, what are p...
# 592  When defining a recursive function, what are p...
# 593  What are the similarities between iteration an...
# 594  What are the similarities between iteration an...
# 595  What are the similarities between iteration an...
# 596  What are the similarities between iteration an...
# 597  What are the similarities between iteration an...
# 598  What are the similarities between iteration an...
# 599  What are the similarities between iteration an...
# 600  What are the similarities between iteration an...
# 601  What are the similarities between iteration an...
# 602  What are the similarities between iteration an...
# 603  What are the similarities between iteration an...
# 604  What are the similarities between iteration an...
# 605  What are the similarities between iteration an...
# 606  What are the similarities between iteration an...
# 607  What are the similarities between iteration an...
# 608  What are the similarities between iteration an...
# 609  What are the similarities between iteration an...
# 610  What are the similarities between iteration an...
#
#                                             ref_answer  \
# 0    To simulate the behaviour of portions of the d...
# 1    To simulate the behaviour of portions of the d...
# 2    To simulate the behaviour of portions of the d...
# 3    To simulate the behaviour of portions of the d...
# 4    To simulate the behaviour of portions of the d...
# 5    To simulate the behaviour of portions of the d...
# 6    To simulate the behaviour of portions of the d...
# 7    To simulate the behaviour of portions of the d...
# 8    To simulate the behaviour of portions of the d...
# 9    To simulate the behaviour of portions of the d...
# 10   To simulate the behaviour of portions of the d...
# 11   To simulate the behaviour of portions of the d...
# 12   To simulate the behaviour of portions of the d...
# 13   To simulate the behaviour of portions of the d...
# 14   To simulate the behaviour of portions of the d...
# 15   To simulate the behaviour of portions of the d...
# 16   To simulate the behaviour of portions of the d...
# 17   To simulate the behaviour of portions of the d...
# 18   To simulate the behaviour of portions of the d...
# 19   To simulate the behaviour of portions of the d...
# 20   To simulate the behaviour of portions of the d...
# 21   To simulate the behaviour of portions of the d...
# 22   To simulate the behaviour of portions of the d...
# 23   To simulate the behaviour of portions of the d...
# 24   To simulate the behaviour of portions of the d...
# 25   To simulate the behaviour of portions of the d...
# 26   To simulate the behaviour of portions of the d...
# 27   To simulate the behaviour of portions of the d...
# 28   To simulate the behaviour of portions of the d...
# 29   The testing stage can influence both the codin...
# ..                                                 ...
# 581  If the recursion step is defined incorrectly, ...
# 582  If the recursion step is defined incorrectly, ...
# 583  If the recursion step is defined incorrectly, ...
# 584  If the recursion step is defined incorrectly, ...
# 585  If the recursion step is defined incorrectly, ...
# 586  If the recursion step is defined incorrectly, ...
# 587  If the recursion step is defined incorrectly, ...
# 588  If the recursion step is defined incorrectly, ...
# 589  If the recursion step is defined incorrectly, ...
# 590  If the recursion step is defined incorrectly, ...
# 591  If the recursion step is defined incorrectly, ...
# 592  If the recursion step is defined incorrectly, ...
# 593                       They both involve repetition
# 594                       They both involve repetition
# 595                       They both involve repetition
# 596                       They both involve repetition
# 597                       They both involve repetition
# 598                       They both involve repetition
# 599                       They both involve repetition
# 600                       They both involve repetition
# 601                       They both involve repetition
# 602                       They both involve repetition
# 603                       They both involve repetition
# 604                       They both involve repetition
# 605                       They both involve repetition
# 606                       They both involve repetition
# 607                       They both involve repetition
# 608                       They both involve repetition
# 609                       They both involve repetition
# 610                       They both involve repetition
#
#                                         student_answer  \
# 0    High risk problems are address in the prototyp...
# 1    To simulate portions of the desired final prod...
# 2    A prototype program simulates the behaviors of...
# 3    Defined in the Specification phase a prototype...
# 4    It is used to let the users have a first idea ...
# 5    To find problem and errors in a program before...
# 6    To address major issues in the creation of the...
# 7    you can break the whole program into prototype...
# 8    -To provide an example or model of how the fin...
# 9    Simulating the behavior of only a portion of t...
# 10     A program that stimulates the behavior of po...
# 11   A program that simulates the behavior of porti...
# 12   To lay out the basics and give you a starting ...
# 13   To simulate problem solving for parts of the p...
# 14   A prototype program provides a basic groundwor...
# 15   A prototype program is a part of the Specifica...
# 16   Program that simulates the behavior of portion...
# 17   it provides a limited proof of concept to veri...
# 18   It tests the main function of the program whil...
# 19   To get early feedback from users in early stag...
# 20   it simulates the behavior of portions of the d...
# 21   It simulates the behavior of portions of the d...
# 22   A prototype program is used in problem solving...
# 23   To ease the understanding of problem under dis...
# 24   it simulates the behavior of portions of the d...
# 25   The role of a prototype program is to help spo...
# 26   the prototype program gives a general idea of ...
# 27   to show that a certain part of the program wor...
# 28   Prototype programming is an approach to progra...
# 29   Refining and possibly the design if the testin...
# ..                                                 ...
# 581  no base case, as in a single return that does ...
# 582  Either omitting the base case, or writing the ...
# 583  omitting the base case or writing the recursiv...
# 584  Either omitting the base case, or writing the ...
# 585  Infinite recursion may occur if no base case i...
# 586  Not having a base case, or building a recursio...
# 587  Either omitting the base case, or writing the ...
# 588  no base case<br>or if the programmar does not ...
# 589  No easily reached base case and no base case a...
# 590  function is never allowed to reach the 'base c...
# 591  it has no base case, or the base case is never...
# 592  recursion refers to situations in which functi...
# 593  Both involve a controlled repetition structure...
# 594  As discussed earlier, recursion may be used to...
# 595  Both iteration and recursion are based on cont...
# 596  Both are based on a control statement<br>     ...
# 597  Iteration and recursion have many similarities...
# 598  Both rely on repetition, both have a base case...
# 599  Both will repeat (loop) until a condition is m...
# 600  anything you can do iterativly you can do recu...
# 601      Both are repetative and both have a end test.
# 602  Incorrectly writing either can result in infin...
# 603  Both are based on a control statement.<br>Both...
# 604  Both are based on a control statement, Both in...
# 605                                       not answered
# 606  anything you can do recursively you can do ite...
# 607  Many problems can be solved by both iteration ...
# 608  Iteration and recursion both use repetition an...
# 609  both based on control statement, involve repet...
# 610       they are methods of repeating the same task.
#
#                                           ref_modified  \
# 0    simulate behaviour portion desired software pr...
# 1    simulate behaviour portion desired software pr...
# 2    simulate behaviour portion desired software pr...
# 3    simulate behaviour portion desired software pr...
# 4    simulate behaviour portion desired software pr...
# 5    simulate behaviour portion desired software pr...
# 6    simulate behaviour portion desired software pr...
# 7    simulate behaviour portion desired software pr...
# 8    simulate behaviour portion desired software pr...
# 9    simulate behaviour portion desired software pr...
# 10   simulate behaviour portion desired software pr...
# 11   simulate behaviour portion desired software pr...
# 12   simulate behaviour portion desired software pr...
# 13   simulate behaviour portion desired software pr...
# 14   simulate behaviour portion desired software pr...
# 15   simulate behaviour portion desired software pr...
# 16   simulate behaviour portion desired software pr...
# 17   simulate behaviour portion desired software pr...
# 18   simulate behaviour portion desired software pr...
# 19   simulate behaviour portion desired software pr...
# 20   simulate behaviour portion desired software pr...
# 21   simulate behaviour portion desired software pr...
# 22   simulate behaviour portion desired software pr...
# 23   simulate behaviour portion desired software pr...
# 24   simulate behaviour portion desired software pr...
# 25   simulate behaviour portion desired software pr...
# 26   simulate behaviour portion desired software pr...
# 27   simulate behaviour portion desired software pr...
# 28   simulate behaviour portion desired software pr...
# 29   testing stage influence coding stage phase 5 s...
# ..                                                 ...
# 581  recursion step defined incorrectly base case i...
# 582  recursion step defined incorrectly base case i...
# 583  recursion step defined incorrectly base case i...
# 584  recursion step defined incorrectly base case i...
# 585  recursion step defined incorrectly base case i...
# 586  recursion step defined incorrectly base case i...
# 587  recursion step defined incorrectly base case i...
# 588  recursion step defined incorrectly base case i...
# 589  recursion step defined incorrectly base case i...
# 590  recursion step defined incorrectly base case i...
# 591  recursion step defined incorrectly base case i...
# 592  recursion step defined incorrectly base case i...
# 593                                 involve repetition
# 594                                 involve repetition
# 595                                 involve repetition
# 596                                 involve repetition
# 597                                 involve repetition
# 598                                 involve repetition
# 599                                 involve repetition
# 600                                 involve repetition
# 601                                 involve repetition
# 602                                 involve repetition
# 603                                 involve repetition
# 604                                 involve repetition
# 605                                 involve repetition
# 606                                 involve repetition
# 607                                 involve repetition
# 608                                 involve repetition
# 609                                 involve repetition
# 610                                 involve repetition
#
#                                       student_modified
# 0    high risk problem address prototype program ma...
# 1    simulate portion desired final product quick e...
# 2    prototype program simulates behavior portion d...
# 3    defined specification phase prototype stimulat...
# 4    used let user first idea completed program all...
# 5                 find problem error program finalized
# 6    address major issue creation program way accou...
# 7    break whole program prototype program simulate...
# 8    provide example model finished program perfomb...
# 9    simulating behavior portion desired software p...
# 10   program stimulates behavior portion desired so...
# 11   program simulates behavior portion desired sof...
# 12   lay basic give starting point actual problem s...
# 13               simulate problem solving part problem
# 14   prototype program provides basic groundwork en...
# 15   prototype program part specification phase sof...
# 16   program simulates behavior portion desired sof...
# 17   provides limited proof concept verify client a...
# 18   test main function program leaving finer detai...
# 19   get early feedback user early stage developmen...
# 20   simulates behavior portion desired software pr...
# 21   simulates behavior portion desired software pr...
# 22   prototype program used problem solving collect...
# 23   ease understanding problem discussion ease und...
# 24   simulates behavior portion desired software pr...
# 25   role prototype program help spot key problem m...
# 26   prototype program give general idea end produc...
# 27             show certain part program work supposed
# 28   prototype programming approach programming ena...
# 29   refining possibly design testing phase reveals...
# ..                                                 ...
# 581  base case single return include calling functi...
# 582  either omitting base case writing recursion st...
# 583  omitting base case writing recursive call conv...
# 584  either omitting base case writing recursion st...
# 585  infinite recursion may occur base case defined...
# 586  base case building recursion process doesnt co...
# 587  either omitting base case writing recursion st...
# 588  base casebror programmar define base case simp...
# 589                 easily reached base case base case
# 590             function never allowed reach base case
# 591                      base case base case never met
# 592  recursion refers situation function call type ...
# 593  involve controlled repetition structure termin...
# 594  discussed earlier recursion may used process i...
# 595  iteration recursion based control statement in...
# 596  based control statementbr iterationrepetition ...
# 597  iteration recursion many similarity based cont...
# 598  rely repetition base case become infinite loop...
# 599  repeat loop condition met exit loop capable en...
# 600                    anything iterativly recursively
# 601                                repetative end test
# 602  incorrectly writing either result infinite loo...
# 603  based control statementbrboth involve repetiti...
# 604  based control statement involve repetition inv...
# 605                                           answered
# 606                   anything recursively iteratively
# 607  many problem solved iteration recursion either...
# 608  iteration recursion use repetition perform sev...
# 609  based control statement involve repetition inv...
# 610                              method repeating task
#
# [611 rows x 8 columns]

# %%
short_df = df[['student_answer','student_modified', 'grade','question']]
# np.sort(short_df['grade'].unique())
short_df['grades_round']= short_df['grade'].apply(lambda x: round(x))
# short_df['status'] = short_df['grade'] >= 3
# short_df['status'] = short_df['status'].astype(int)
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#getting the seed index
classes = short_df['grades_round'].unique()
seed_index = []
for i in classes:
    seed_index.append(short_df['grades_round'][short_df['grades_round']==i].index[0])
seed_index
# Out:
# [0, 1, 4, 5, 52, 94]

# %%
# short_df['word_count'] = short_df['student_answer'].apply(lambda x: dict(Counter(x.split())))

# counting unique words in every student's answer
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(short_df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = short_df['grades_round'].values

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
# train_idx = [0, 1, 4 ,5,52,605]
train_idx = seed_index
X_train = X[train_idx]
y_train = Y[train_idx]
print(y_train)
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
lr = LogisticRegression()
learner = ActiveLearner(
    estimator = lr,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = 40
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
    print("\nQ: ", act_data.loc[int(query_idx),'question'])
    print("A: ",act_data.loc[int(query_idx),'student_answer'])
    print("Actual grade: ",y_pool[query_idx].reshape(1, ))
    print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
    human_label = int(input("\nGive me a grade:"))
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=[human_label]
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X,Y))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X, Y)))
# Out:
# [4 5 3 2 1 0]
#
# Q:  Where are variables declared in a C++ program?
# A:  It depends if itÃ¢?¬â„¢s a global then they have to be declared out side the source code to be used in every scope however a local variable is one declared in a local function etc. which obviously doesnÃ¢?¬â„¢t need to be declared outside the variable seeing how it is used for the function or block its being called for.
# Actual grade:  [4]
# Class probabilities:  [[0.18610517 0.15125103 0.15607074 0.18136366 0.18420749 0.14100191]]
#
# Give me a grade:4
# Accuracy after query no. 1: 0.186579
#
# Q:  What is the main difference between a while and a do...while statement?
# A:  -WHILE statement --The condition is checked for validity, then is repeated until the conditon is false.<br><br>  -Do...WHILE statement--The code is performed at least once then checked for valid condition.  Will continue to <br>
# Actual grade:  [5]
# Class probabilities:  [[0.18598294 0.17955086 0.16788304 0.14749987 0.16863099 0.1504523 ]]
#
# Give me a grade:5
# Accuracy after query no. 2: 0.224223
#
# Q:  What is the role of a header-file?
# A:  A header file consists of "reusable" source code such as a class in a file that by convention has a .h filename extension. This differs from .cpp files that contain "source-code."
# Actual grade:  [4]
# Class probabilities:  [[0.18412295 0.14793624 0.16563938 0.14288772 0.17677352 0.18264018]]
#
# Give me a grade:4
# Accuracy after query no. 3: 0.291326
#
# Q:   What are the main advantages associated with object-oriented programming?
# A:  Existing classes can be reused<br>Program maintenance and verifications are easy
# Actual grade:  [4]
# Class probabilities:  [[0.18302385 0.14797755 0.16187921 0.14139451 0.18343653 0.18228834]]
#
# Give me a grade:4
# Accuracy after query no. 4: 0.332242
#
# Q:  What is the main difference between a while and a do...while statement?
# A:  While tests for true first before running, do...while runs once first before checking.
# Actual grade:  [5]
# Class probabilities:  [[0.17550714 0.14122174 0.15409516 0.18004774 0.17836789 0.17076035]]
#
# Give me a grade:5
# Accuracy after query no. 5: 0.342062
#
# Q:  What is the role of a prototype program in problem solving?
# A:  it provides a limited proof of concept to verify with the client before actually programming the whole application.<br>
# Actual grade:  [2]
# Class probabilities:  [[0.17839075 0.1442852  0.15876008 0.15924785 0.18661125 0.17270487]]
#
# Give me a grade:2
# Accuracy after query no. 6: 0.335516
#
# Q:  How many constructors can be created for a class?
# A:  as many as the user decides to use.
# Actual grade:  [5]
# Class probabilities:  [[0.17432809 0.14102068 0.17762349 0.15567624 0.18248227 0.16886923]]
#
# Give me a grade:5
# Accuracy after query no. 7: 0.414075
#
# Q:  Where do C++ programs begin to execute?
# A:  c++ programs begin to execute in the main method.
# Actual grade:  [5]
# Class probabilities:  [[0.14879098 0.12015017 0.19963286 0.14845017 0.1933334  0.18964242]]
#
# Give me a grade:5
# Accuracy after query no. 8: 0.456628
#
# Q:  What is the difference between a constructor and a function?
# A:  a constructor initializes data members but the functions actually perform tasks. Constructors cant return values either.
# Actual grade:  [4]
# Class probabilities:  [[0.13363802 0.20656798 0.17862301 0.10832574 0.17790365 0.1949416 ]]
#
# Give me a grade:4
# Accuracy after query no. 9: 0.435352
#
# Q:  What is the main advantage associated with function arguments that are passed by reference?
# A:  It elimitates the need to copy large amonts of data
# Actual grade:  [5]
# Class probabilities:  [[0.137487   0.20579346 0.14184807 0.11150355 0.20264708 0.20072085]]
#
# Give me a grade:5
# Accuracy after query no. 10: 0.459902
#
# Q:  What is the main advantage associated with function arguments that are passed by reference?
# A:  Actual arguments are associated with dummy arguments when a function or subroutine is referenced. In a procedure reference, the actual argument list identifies the correspondence between the actual arguments provided in the list and the dummy arguments of the subprogram
# Actual grade:  [3]
# Class probabilities:  [[0.13447678 0.20490574 0.13884324 0.1080831  0.21374257 0.19994857]]
#
# Give me a grade:3
# Accuracy after query no. 11: 0.463175
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Depending on how the work is done, Testing is spread throughout the <br>process as to prevent errors from showing up later on due to lack of<br>foresight.<br>
# Actual grade:  [2]
# Class probabilities:  [[0.21477546 0.16092152 0.19551951 0.1060889  0.14086364 0.18183097]]
#
# Give me a grade:2
# Accuracy after query no. 12: 0.466448
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Refining the solution, Production and Maintenance are all influenced by the Testing stage.
# Actual grade:  [3]
# Class probabilities:  [[0.21205816 0.12776269 0.1653423  0.10694302 0.19795171 0.18994213]]
#
# Give me a grade:3
# Accuracy after query no. 13: 0.468085
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Elaboration, Construction, and Transition are all affected by testing
# Actual grade:  [2]
# Class probabilities:  [[0.2078188  0.1265111  0.16520091 0.16136368 0.14254439 0.19656113]]
#
# Give me a grade:2
# Accuracy after query no. 14: 0.476268
#
# Q:  What does a function signature include?
# A:  It includes the name of the function and the types of its arguments.
# Actual grade:  [5]
# Class probabilities:  [[0.12801849 0.09525502 0.1655915  0.19984259 0.20456494 0.20672746]]
#
# Give me a grade:5
# Accuracy after query no. 15: 0.523732
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Testing could affect all parts of the life cycle
# Actual grade:  [2]
# Class probabilities:  [[0.18896775 0.11646726 0.22164722 0.14534402 0.12836894 0.19920481]]
#
# Give me a grade:2
# Accuracy after query no. 16: 0.523732
#
# Q:  Where are variables declared in a C++ program?
# A:  Anywhere in the same scope before they are used
# Actual grade:  [4]
# Class probabilities:  [[0.13013646 0.10562588 0.18302884 0.1392591  0.21820811 0.2237416 ]]
#
# Give me a grade:4
# Accuracy after query no. 17: 0.522095
#
# Q:   What are the main advantages associated with object-oriented programming?
# A:  Re-usability  and ease of maintenance
# Actual grade:  [4]
# Class probabilities:  [[0.12024352 0.1001573  0.16909459 0.16109076 0.22489997 0.22451387]]
#
# Give me a grade:4
# Accuracy after query no. 18: 0.520458
#
# Q:  What is the role of a prototype program in problem solving?
# A:  To lay out the basics and give you a starting point in the actual problem solving.
# Actual grade:  [2]
# Class probabilities:  [[0.11491712 0.1175026  0.22148076 0.13626615 0.20081234 0.20902102]]
#
# Give me a grade:2
# Accuracy after query no. 19: 0.523732
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Refining the solution
# Actual grade:  [4]
# Class probabilities:  [[0.113188   0.09557859 0.17341569 0.2202597  0.17577019 0.22178783]]
#
# Give me a grade:4
# Accuracy after query no. 20: 0.507365
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  The testing stage has a direct influence on the final version of a program, being as it is the debugging and finalization of a software revision.
# Actual grade:  [2]
# Class probabilities:  [[0.12736186 0.07955746 0.23230625 0.22438162 0.12225727 0.21413554]]
#
# Give me a grade:2
# Accuracy after query no. 21: 0.510638
#
# Q:  When defining a recursive function, what are possible causes for infinite recursion?
# A:  Lack of defining a base case, or writing the recursion step incorrectly so that it does not converge on the base case
# Actual grade:  [5]
# Class probabilities:  [[0.11773098 0.09582511 0.22777443 0.10504072 0.23228728 0.22134149]]
#
# Give me a grade:5
# Accuracy after query no. 22: 0.527005
#
# Q:  When does C++ create a default constructor?
# A:  When non are provided
# Actual grade:  [5]
# Class probabilities:  [[0.12074012 0.09698612 0.19677247 0.11818688 0.23418685 0.23312755]]
#
# Give me a grade:5
# Accuracy after query no. 23: 0.522095
#
# Q:  What is the main advantage associated with function arguments that are passed by reference?
# A:  You are able to modify the variable that is referenced directly.
# Actual grade:  [4]
# Class probabilities:  [[0.11423298 0.09248842 0.18548053 0.11103836 0.24566101 0.2510987 ]]
# Give me a grade:4
# Accuracy after query no. 24: 0.522095
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  -Verification<br> -Debugging
# Actual grade:  [2]
# Class probabilities:  [[0.10914215 0.09028802 0.22128657 0.09402613 0.23634763 0.2489095 ]]
#
# Give me a grade:2
# Accuracy after query no. 25: 0.527005
#
# Q:  When does C++ create a default constructor?
# A:  The Compiler creates this automatically for you, unless you specifically create one.
# Actual grade:  [5]
# Class probabilities:  [[0.11003494 0.09014145 0.21014103 0.09746323 0.24443818 0.24778117]]
#
# Give me a grade:5
# Accuracy after query no. 26: 0.525368
#
# Q:   What are the main advantages associated with object-oriented programming?
# A:  Information can be hidden. It is easier to debug. Programming is easier and more manageable.
# Actual grade:  [4]
# Class probabilities:  [[0.10464047 0.08630939 0.24629847 0.09294546 0.21519786 0.25460834]]
#
# Give me a grade:4
# Accuracy after query no. 27: 0.533552
#
# Q:  What is the main advantage associated with function arguments that are passed by reference?
# A:  because you can't change the original and passing by reference limits memory needed for the program.
# Actual grade:  [4]
# Class probabilities:  [[0.08543078 0.06942682 0.21580049 0.11442632 0.26028801 0.2546276 ]]
#
# Give me a grade:4
# Accuracy after query no. 28: 0.540098
#
# Q:  What is the scope of global variables?
# A:  throughout the execution of the program
# Actual grade:  [4]
# Class probabilities:  [[0.08068104 0.06837327 0.2431765  0.09739632 0.25719829 0.25317458]]
#
# Give me a grade:4
# Accuracy after query no. 29: 0.540098
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Testing, refining, production, and maintenance.
# Actual grade:  [4]
# Class probabilities:  [[0.10800061 0.06998854 0.18815047 0.26465287 0.26629038 0.10291714]]
#
# Give me a grade:4
# Accuracy after query no. 30: 0.543372
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  All stages are influenced except setting the program requirements.  If a test fails, it can change the whole design, implementation, etc of a program as well as the final outcome.
# Actual grade:  [2]
# Class probabilities:  [[0.04343146 0.04184038 0.23570544 0.18503296 0.2340976  0.25989218]]
#
# Give me a grade:2
# Accuracy after query no. 31: 0.546645
#
# Q:  What is typically included in a class definition?
# A:  An object and data.
# Actual grade:  [2]
# Class probabilities:  [[0.08839932 0.15535972 0.14316713 0.07760623 0.26836681 0.26710079]]
#
# Give me a grade:2
# Accuracy after query no. 32: 0.548282
#
# Q:  What is the main advantage associated with function arguments that are passed by reference?
# A:  Gives access to the caller data directly, also it allows for modifying the data.
# Actual grade:  [4]
# Class probabilities:  [[0.0599816  0.22437558 0.22201456 0.05266182 0.25744806 0.18351839]]
#
# Give me a grade:4
# Accuracy after query no. 33: 0.549918
#
# Q:  What is the main difference between a while and a do...while statement?
# A:  the loop body always executes at least once<br>
# Actual grade:  [4]
# Class probabilities:  [[0.09673748 0.07661199 0.21137479 0.0849377  0.26535784 0.2649802 ]]
#
# Give me a grade:4
# Accuracy after query no. 34: 0.540098
#
# Q:  When does C++ create a default constructor?
# A:  When there are no arguments passed.
# Actual grade:  [2]
# Class probabilities:  [[0.09150253 0.07043598 0.19004598 0.13330374 0.25388351 0.26082826]]
#
# Give me a grade:2
# Accuracy after query no. 35: 0.538462
#
# Q:  What are the similarities between iteration and recursion?
# A:  Both are repetative and both have a end test.
# Actual grade:  [4]
# Class probabilities:  [[0.08993284 0.07245581 0.25269983 0.07453503 0.25612143 0.25425507]]
#
# Give me a grade:4
# Accuracy after query no. 36: 0.540098
#
# Q:  How are overloaded functions differentiated by the compiler?
# A:  By the type they are initilized with (int, char, etc.)
# Actual grade:  [3]
# Class probabilities:  [[0.08597237 0.06983807 0.23530627 0.06977508 0.26914952 0.2699587 ]]
#
# Give me a grade:3
# Accuracy after query no. 37: 0.538462
#
# Q:  How are overloaded functions differentiated by the compiler?
# A:  by their signature (return type, argument list)
# Actual grade:  [4]
# Class probabilities:  [[0.07289495 0.05643592 0.19209287 0.2192563  0.21260481 0.24671515]]
#
# Give me a grade:4
# Accuracy after query no. 38: 0.522095
#
# Q:  Where do C++ programs begin to execute?
# A:  Int main()
# Actual grade:  [5]
# Class probabilities:  [[0.0857965  0.07008587 0.18884569 0.13879168 0.25253286 0.26394739]]
#
# Give me a grade:5
# Accuracy after query no. 39: 0.528642
#
# Q:  What is the role of a prototype program in problem solving?
# A:  A prototype program simulates the behaviors of portions of the desired software product to allow for error checking.
# Actual grade:  [4]
# Class probabilities:  [[0.0529313  0.06389468 0.24756469 0.09170565 0.27476623 0.26913745]]
#
# Give me a grade:4
# Accuracy after query no. 40: 0.522095

# %% [markdown]
# ## Regular supervised task

# %%
from sklearn.model_selection import train_test_split

# %%
check_X = np.copy(X)
check_Y = np.copy(Y)

X_train,X_test,Y_train,Y_test = train_test_split(check_X,check_Y,test_size = 0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-251156164671> in <module>()
# ----> 1 check_X = np.copy(X)
#       2 check_Y = np.copy(Y)
#       3
#       4 X_train,X_test,Y_train,Y_test = train_test_split(check_X,check_Y,test_size = 0.2)
#
# NameError: name 'X' is not defined

# %%
logisticRegr = LogisticRegression()
logisticRegr.fit(X_train, Y_train)
score = logisticRegr.score(X_test, Y_test)

print(score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-53f6d4977bab> in <module>()
#       1 logisticRegr = LogisticRegression()
# ----> 2 logisticRegr.fit(X_train, Y_train)
#       3 score = logisticRegr.score(X_test, Y_test)
#       4
#       5 print(score)
#
# NameError: name 'X_train' is not defined

# %%
supervised_accuracy = [score for x in range(0,40)]

plt.figure()
plt.plot(np.linspace(0,39,40),supervised_accuracy)
plt.plot(accuracy_list)
plt.title("Accuracy after every query")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.legend(["Supervised", "Active Learning"], loc="lower right")
plt.show()
