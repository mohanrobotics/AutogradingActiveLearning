# %% [markdown]
# # Binary classification - single_model using Naive Bayes(semeval)

# %% [markdown]
# # Importing and Preprocessing

# %% [markdown]
# ## Importing libraries

# %%
#### import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %% [markdown]
# ## Importing files

# %%
original_data = pd.read_csv('../dataset/Semeval_dataset/train_semeval.csv')
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'reference_answer':'ref_answer'})

# %% [markdown]
# ## Preprocessing

# %%
df = original_data.copy()
#converting to lower case
df['ref_modified'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))


#lemmatisation
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))

# %% [markdown]
# # Gathering required features

# %%
short_df = df[['question','student_answer','student_modified','ref_modified' ,'grade']]
short_df['status'] = short_df['grade'] >= 3
short_df['status'] = short_df['status'].astype(int)

# FOR ONE BY ONE QUESTION
# short_df = short_df[short_df['question_id'] == ques_id_list[0]]
# ques_id_list.pop(0)
# ques_id_list
# ======================
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Bag of words

# %%
# short_df['word_count'] = short_df['student_answer'].apply(lambda x: dict(Counter(x.split())))

# counting unique words in every student's answer
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(short_df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = short_df['status'].values

# %% [markdown]
# # Seeding

# %%
#getting the seed index
classes = short_df['status'].unique()
seed_index = []
for i in classes:
    seed_index.append(short_df['status'][short_df['status']==i].index[0])
seed_index
# Out:
# [0, 1]

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
train_idx = seed_index
X_train = X[train_idx]
y_train = Y[train_idx]
 
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
# lr = LogisticRegression()
nb = MultinomialNB()
learner = ActiveLearner(
#     estimator = lr,
    estimator = nb,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = int(len(X)/10)
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
#     print("\nQ: ", act_data.loc[int(query_idx),'question'])
#     print("A: ",act_data.loc[int(query_idx),'student_answer'])
#     print("Actual grade: ",y_pool[query_idx].reshape(1, ))
#     print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
#     human_label = int(input("\nGive me a grade 0 or 1:"))
    
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=y_pool[query_idx].reshape(1, )
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X,Y))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X_pool, y_pool)))
print("======================================")
print("By just labelling ",round(n_queries*100.0/len(X),2),"% of total data accuracy of ", round(learner.score(X_pool, y_pool),3), " % is achieved on the unseen data"  )
# Out:
# Accuracy after query no. 1: 0.764398
# Accuracy after query no. 2: 0.288016
# Accuracy after query no. 3: 0.277196
# Accuracy after query no. 4: 0.300625
# Accuracy after query no. 5: 0.700322
# Accuracy after query no. 6: 0.700464
# Accuracy after query no. 7: 0.298589
# Accuracy after query no. 8: 0.299456
# Accuracy after query no. 9: 0.299314
# Accuracy after query no. 10: 0.328424
# Accuracy after query no. 11: 0.327885
# Accuracy after query no. 12: 0.321292
# Accuracy after query no. 13: 0.318732
# Accuracy after query no. 14: 0.342015
# Accuracy after query no. 15: 0.333401
# Accuracy after query no. 16: 0.330034
# Accuracy after query no. 17: 0.303838
# Accuracy after query no. 18: 0.344716
# Accuracy after query no. 19: 0.338116
# Accuracy after query no. 20: 0.369517
# Accuracy after query no. 21: 0.422766
# Accuracy after query no. 22: 0.429929
# Accuracy after query no. 23: 0.454693
# Accuracy after query no. 24: 0.474408
# Accuracy after query no. 25: 0.474100
# Accuracy after query no. 26: 0.468731
# Accuracy after query no. 27: 0.512146
# Accuracy after query no. 28: 0.516704
# Accuracy after query no. 29: 0.516201
# Accuracy after query no. 30: 0.517318
# Accuracy after query no. 31: 0.517018
# Accuracy after query no. 32: 0.533131
# Accuracy after query no. 33: 0.542562
# Accuracy after query no. 34: 0.532739
# Accuracy after query no. 35: 0.532238
# Accuracy after query no. 36: 0.535794
# Accuracy after query no. 37: 0.535294
# Accuracy after query no. 38: 0.533983
# Accuracy after query no. 39: 0.530235
# Accuracy after query no. 40: 0.534402
# Accuracy after query no. 41: 0.538571
# Accuracy after query no. 42: 0.542944
# Accuracy after query no. 43: 0.541836
# Accuracy after query no. 44: 0.547430
# Accuracy after query no. 45: 0.548557
# Accuracy after query no. 46: 0.565332
# Accuracy after query no. 47: 0.550813
# Accuracy after query no. 48: 0.568815
# Accuracy after query no. 49: 0.585807
# Accuracy after query no. 50: 0.618873
# Accuracy after query no. 51: 0.621440
# Accuracy after query no. 52: 0.663886
# Accuracy after query no. 53: 0.638991
# Accuracy after query no. 54: 0.647669
# Accuracy after query no. 55: 0.679357
# Accuracy after query no. 56: 0.704948
# Accuracy after query no. 57: 0.680652
# Accuracy after query no. 58: 0.687309
# Accuracy after query no. 59: 0.711491
# Accuracy after query no. 60: 0.715101
# Accuracy after query no. 61: 0.715247
# Accuracy after query no. 62: 0.723955
# Accuracy after query no. 63: 0.728589
# Accuracy after query no. 64: 0.735876
# Accuracy after query no. 65: 0.726642
# Accuracy after query no. 66: 0.725566
# Accuracy after query no. 67: 0.730000
# Accuracy after query no. 68: 0.733211
# Accuracy after query no. 69: 0.727644
# Accuracy after query no. 70: 0.728609
# Accuracy after query no. 71: 0.731822
# Accuracy after query no. 72: 0.734831
# Accuracy after query no. 73: 0.733551
# Accuracy after query no. 74: 0.734314
# Accuracy after query no. 75: 0.730581
# Accuracy after query no. 76: 0.724596
# Accuracy after query no. 77: 0.727198
# Accuracy after query no. 78: 0.731233
# Accuracy after query no. 79: 0.735065
# Accuracy after query no. 80: 0.739718
# Accuracy after query no. 81: 0.737618
# Accuracy after query no. 82: 0.737155
# Accuracy after query no. 83: 0.737920
# Accuracy after query no. 84: 0.739709
# Accuracy after query no. 85: 0.740270
# Accuracy after query no. 86: 0.741037
# Accuracy after query no. 87: 0.744877
# Accuracy after query no. 88: 0.747694
# Accuracy after query no. 89: 0.748667
# Accuracy after query no. 90: 0.751282
# Accuracy after query no. 91: 0.752051
# Accuracy after query no. 92: 0.757333
# Accuracy after query no. 93: 0.758309
# Accuracy after query no. 94: 0.752719
# Accuracy after query no. 95: 0.753900
# Accuracy after query no. 96: 0.755286
# Accuracy after query no. 97: 0.758522
# Accuracy after query no. 98: 0.759704
# Accuracy after query no. 99: 0.760477
# Accuracy after query no. 100: 0.760633
# Accuracy after query no. 101: 0.760378
# Accuracy after query no. 102: 0.760740
# Accuracy after query no. 103: 0.761102
# Accuracy after query no. 104: 0.761464
# Accuracy after query no. 105: 0.757713
# Accuracy after query no. 106: 0.758074
# Accuracy after query no. 107: 0.759053
# Accuracy after query no. 108: 0.759210
# Accuracy after query no. 109: 0.759160
# Accuracy after query no. 110: 0.760552
# Accuracy after query no. 111: 0.763386
# Accuracy after query no. 112: 0.763543
# Accuracy after query no. 113: 0.763700
# Accuracy after query no. 114: 0.765094
# Accuracy after query no. 115: 0.764839
# Accuracy after query no. 116: 0.765203
# Accuracy after query no. 117: 0.764330
# Accuracy after query no. 118: 0.765519
# Accuracy after query no. 119: 0.765677
# Accuracy after query no. 120: 0.765628
# Accuracy after query no. 121: 0.765786
# Accuracy after query no. 122: 0.766770
# Accuracy after query no. 123: 0.765070
# Accuracy after query no. 124: 0.764402
# Accuracy after query no. 125: 0.762908
# Accuracy after query no. 126: 0.764925
# Accuracy after query no. 127: 0.764669
# Accuracy after query no. 128: 0.765241
# Accuracy after query no. 129: 0.766846
# Accuracy after query no. 130: 0.767004
# Accuracy after query no. 131: 0.767163
# Accuracy after query no. 132: 0.767322
# Accuracy after query no. 133: 0.767687
# Accuracy after query no. 134: 0.768260
# Accuracy after query no. 135: 0.768419
# Accuracy after query no. 136: 0.768785
# Accuracy after query no. 137: 0.768530
# Accuracy after query no. 138: 0.768275
# Accuracy after query no. 139: 0.768641
# Accuracy after query no. 140: 0.768800
# Accuracy after query no. 141: 0.769581
# Accuracy after query no. 142: 0.770570
# Accuracy after query no. 143: 0.770522
# Accuracy after query no. 144: 0.770682
# Accuracy after query no. 145: 0.770635
# Accuracy after query no. 146: 0.770794
# Accuracy after query no. 147: 0.770747
# Accuracy after query no. 148: 0.770492
# Accuracy after query no. 149: 0.770859
# Accuracy after query no. 150: 0.770604
# Accuracy after query no. 151: 0.770972
# Accuracy after query no. 152: 0.770717
# Accuracy after query no. 153: 0.768384
# Accuracy after query no. 154: 0.768336
# Accuracy after query no. 155: 0.768495
# Accuracy after query no. 156: 0.765329
# Accuracy after query no. 157: 0.765281
# Accuracy after query no. 158: 0.766687
# Accuracy after query no. 159: 0.766847
# Accuracy after query no. 160: 0.766174
# Accuracy after query no. 161: 0.766334
# Accuracy after query no. 162: 0.766285
# Accuracy after query no. 163: 0.766028
# Accuracy after query no. 164: 0.765147
# Accuracy after query no. 165: 0.766347
# Accuracy after query no. 166: 0.766299
# Accuracy after query no. 167: 0.766875
# Accuracy after query no. 168: 0.766410
# Accuracy after query no. 169: 0.769904
# Accuracy after query no. 170: 0.770065
# Accuracy after query no. 171: 0.769808
# Accuracy after query no. 172: 0.770177
# Accuracy after query no. 173: 0.770547
# Accuracy after query no. 174: 0.770499
# Accuracy after query no. 175: 0.769825
# Accuracy after query no. 176: 0.769777
# Accuracy after query no. 177: 0.769102
# Accuracy after query no. 178: 0.769889
# Accuracy after query no. 179: 0.770050
# Accuracy after query no. 180: 0.770629
# Accuracy after query no. 181: 0.771208
# Accuracy after query no. 182: 0.770115
# Accuracy after query no. 183: 0.769440
# Accuracy after query no. 184: 0.770228
# Accuracy after query no. 185: 0.770389
# Accuracy after query no. 186: 0.770550
# Accuracy after query no. 187: 0.770502
# Accuracy after query no. 188: 0.770036
# Accuracy after query no. 189: 0.770197
# Accuracy after query no. 190: 0.770149
# Accuracy after query no. 191: 0.770310
# Accuracy after query no. 192: 0.769005
# Accuracy after query no. 193: 0.768538
# Accuracy after query no. 194: 0.767023
# Accuracy after query no. 195: 0.767393
# Accuracy after query no. 196: 0.769021
# Accuracy after query no. 197: 0.768763
# Accuracy after query no. 198: 0.770392
# Accuracy after query no. 199: 0.769924
# Accuracy after query no. 200: 0.770296
# Accuracy after query no. 201: 0.769618
# Accuracy after query no. 202: 0.769780
# Accuracy after query no. 203: 0.770361
# Accuracy after query no. 204: 0.770943
# Accuracy after query no. 205: 0.771105
# Accuracy after query no. 206: 0.768326
# Accuracy after query no. 207: 0.768067
# Accuracy after query no. 208: 0.769279
# Accuracy after query no. 209: 0.768180
# Accuracy after query no. 210: 0.768552
# Accuracy after query no. 211: 0.768923
# Accuracy after query no. 212: 0.769085
# Accuracy after query no. 213: 0.769247
# Accuracy after query no. 214: 0.769409
# Accuracy after query no. 215: 0.769360
# Accuracy after query no. 216: 0.771417
# Accuracy after query no. 217: 0.771158
# Accuracy after query no. 218: 0.766477
# Accuracy after query no. 219: 0.766639
# Accuracy after query no. 220: 0.765957
# Accuracy after query no. 221: 0.766330
# Accuracy after query no. 222: 0.766702
# Accuracy after query no. 223: 0.764966
# Accuracy after query no. 224: 0.766182
# Accuracy after query no. 225: 0.765711
# Accuracy after query no. 226: 0.766294
# Accuracy after query no. 227: 0.766456
# Accuracy after query no. 228: 0.766406
# Accuracy after query no. 229: 0.766779
# Accuracy after query no. 230: 0.767152
# Accuracy after query no. 231: 0.768159
# Accuracy after query no. 232: 0.767476
# Accuracy after query no. 233: 0.767638
# Accuracy after query no. 234: 0.767801
# Accuracy after query no. 235: 0.767963
# Accuracy after query no. 236: 0.768125
# Accuracy after query no. 237: 0.768288
# Accuracy after query no. 238: 0.768027
# Accuracy after query no. 239: 0.768824
# Accuracy after query no. 240: 0.769198
# Accuracy after query no. 241: 0.768938
# Accuracy after query no. 242: 0.768889
# Accuracy after query no. 243: 0.768205
# Accuracy after query no. 244: 0.767521
# Accuracy after query no. 245: 0.767683
# Accuracy after query no. 246: 0.766363
# Accuracy after query no. 247: 0.766737
# Accuracy after query no. 248: 0.766476
# Accuracy after query no. 249: 0.766850
# Accuracy after query no. 250: 0.768073
# Accuracy after query no. 251: 0.768236
# Accuracy after query no. 252: 0.769035
# Accuracy after query no. 253: 0.768137
# Accuracy after query no. 254: 0.769786
# Accuracy after query no. 255: 0.769525
# Accuracy after query no. 256: 0.768627
# Accuracy after query no. 257: 0.769851
# Accuracy after query no. 258: 0.770440
# Accuracy after query no. 259: 0.771240
# Accuracy after query no. 260: 0.770979
# Accuracy after query no. 261: 0.771568
# Accuracy after query no. 262: 0.771520
# Accuracy after query no. 263: 0.771684
# Accuracy after query no. 264: 0.771848
# Accuracy after query no. 265: 0.772437
# Accuracy after query no. 266: 0.773027
# Accuracy after query no. 267: 0.774468
# Accuracy after query no. 268: 0.775910
# Accuracy after query no. 269: 0.776075
# Accuracy after query no. 270: 0.775814
# Accuracy after query no. 271: 0.775980
# Accuracy after query no. 272: 0.775719
# Accuracy after query no. 273: 0.775671
# Accuracy after query no. 274: 0.776263
# Accuracy after query no. 275: 0.775789
# Accuracy after query no. 276: 0.775741
# Accuracy after query no. 277: 0.775906
# Accuracy after query no. 278: 0.775858
# Accuracy after query no. 279: 0.776237
# Accuracy after query no. 280: 0.776403
# Accuracy after query no. 281: 0.776142
# Accuracy after query no. 282: 0.776307
# Accuracy after query no. 283: 0.775833
# Accuracy after query no. 284: 0.774931
# Accuracy after query no. 285: 0.775950
# Accuracy after query no. 286: 0.776116
# Accuracy after query no. 287: 0.776068
# Accuracy after query no. 288: 0.776875
# Accuracy after query no. 289: 0.776614
# Accuracy after query no. 290: 0.775711
# Accuracy after query no. 291: 0.775449
# Accuracy after query no. 292: 0.775401
# Accuracy after query no. 293: 0.774925
# Accuracy after query no. 294: 0.774663
# Accuracy after query no. 295: 0.774829
# Accuracy after query no. 296: 0.773924
# Accuracy after query no. 297: 0.773876
# Accuracy after query no. 298: 0.774256
# Accuracy after query no. 299: 0.773779
# Accuracy after query no. 300: 0.773730
# Accuracy after query no. 301: 0.774539
# Accuracy after query no. 302: 0.774062
# Accuracy after query no. 303: 0.774657
# Accuracy after query no. 304: 0.775681
# Accuracy after query no. 305: 0.775204
# Accuracy after query no. 306: 0.775370
# Accuracy after query no. 307: 0.776180
# Accuracy after query no. 308: 0.776347
# Accuracy after query no. 309: 0.776728
# Accuracy after query no. 310: 0.776680
# Accuracy after query no. 311: 0.776847
# Accuracy after query no. 312: 0.776799
# Accuracy after query no. 313: 0.777611
# Accuracy after query no. 314: 0.778208
# Accuracy after query no. 315: 0.777085
# Accuracy after query no. 316: 0.778112
# Accuracy after query no. 317: 0.778495
# Accuracy after query no. 318: 0.778447
# Accuracy after query no. 319: 0.778830
# Accuracy after query no. 320: 0.778997
# Accuracy after query no. 321: 0.778519
# Accuracy after query no. 322: 0.779117
# Accuracy after query no. 323: 0.779285
# Accuracy after query no. 324: 0.779238
# Accuracy after query no. 325: 0.779190
# Accuracy after query no. 326: 0.779358
# Accuracy after query no. 327: 0.779526
# Accuracy after query no. 328: 0.779478
# Accuracy after query no. 329: 0.779646
# Accuracy after query no. 330: 0.779815
# Accuracy after query no. 331: 0.780198
# Accuracy after query no. 332: 0.779935
# Accuracy after query no. 333: 0.780104
# Accuracy after query no. 334: 0.780919
# Accuracy after query no. 335: 0.780656
# Accuracy after query no. 336: 0.780609
# Accuracy after query no. 337: 0.780994
# Accuracy after query no. 338: 0.780946
# Accuracy after query no. 339: 0.780899
# Accuracy after query no. 340: 0.780635
# Accuracy after query no. 341: 0.780804
# Accuracy after query no. 342: 0.780973
# Accuracy after query no. 343: 0.780926
# Accuracy after query no. 344: 0.781527
# Accuracy after query no. 345: 0.781264
# Accuracy after query no. 346: 0.782731
# Accuracy after query no. 347: 0.783117
# Accuracy after query no. 348: 0.783070
# Accuracy after query no. 349: 0.782806
# Accuracy after query no. 350: 0.782759
# Accuracy after query no. 351: 0.782929
# Accuracy after query no. 352: 0.782882
# Accuracy after query no. 353: 0.782835
# Accuracy after query no. 354: 0.782788
# Accuracy after query no. 355: 0.783391
# Accuracy after query no. 356: 0.783344
# Accuracy after query no. 357: 0.783948
# Accuracy after query no. 358: 0.781948
# Accuracy after query no. 359: 0.782552
# Accuracy after query no. 360: 0.781854
# Accuracy after query no. 361: 0.782023
# Accuracy after query no. 362: 0.781976
# Accuracy after query no. 363: 0.781929
# Accuracy after query no. 364: 0.781881
# Accuracy after query no. 365: 0.781834
# Accuracy after query no. 366: 0.781787
# Accuracy after query no. 367: 0.781957
# Accuracy after query no. 368: 0.782779
# Accuracy after query no. 369: 0.782514
# Accuracy after query no. 370: 0.782902
# Accuracy after query no. 371: 0.783290
# Accuracy after query no. 372: 0.783025
# Accuracy after query no. 373: 0.783195
# Accuracy after query no. 374: 0.783148
# Accuracy after query no. 375: 0.782666
# Accuracy after query no. 376: 0.782836
# Accuracy after query no. 377: 0.782353
# Accuracy after query no. 378: 0.782741
# Accuracy after query no. 379: 0.783348
# Accuracy after query no. 380: 0.782865
# Accuracy after query no. 381: 0.783035
# Accuracy after query no. 382: 0.783424
# Accuracy after query no. 383: 0.785777
# Accuracy after query no. 384: 0.785293
# Accuracy after query no. 385: 0.785465
# Accuracy after query no. 386: 0.785636
# Accuracy after query no. 387: 0.785808
# Accuracy after query no. 388: 0.785979
# Accuracy after query no. 389: 0.786370
# Accuracy after query no. 390: 0.786323
# Accuracy after query no. 391: 0.786495
# Accuracy after query no. 392: 0.786230
# Accuracy after query no. 393: 0.786401
# Accuracy after query no. 394: 0.786355
# Accuracy after query no. 395: 0.786527
# Accuracy after query no. 396: 0.785824
# Accuracy after query no. 397: 0.785777
# Accuracy after query no. 398: 0.785730
# Accuracy after query no. 399: 0.785683
# Accuracy after query no. 400: 0.786074
# Accuracy after query no. 401: 0.786465
# Accuracy after query no. 402: 0.786857
# Accuracy after query no. 403: 0.786810
# Accuracy after query no. 404: 0.786106
# Accuracy after query no. 405: 0.786059
# Accuracy after query no. 406: 0.786231
# Accuracy after query no. 407: 0.786623
# Accuracy after query no. 408: 0.787234
# Accuracy after query no. 409: 0.787187
# Accuracy after query no. 410: 0.787360
# Accuracy after query no. 411: 0.787533
# Accuracy after query no. 412: 0.787486
# Accuracy after query no. 413: 0.788318
# Accuracy after query no. 414: 0.788271
# Accuracy after query no. 415: 0.788225
# Accuracy after query no. 416: 0.788178
# Accuracy after query no. 417: 0.787912
# Accuracy after query no. 418: 0.788085
# Accuracy after query no. 419: 0.788478
# Accuracy after query no. 420: 0.788432
# Accuracy after query no. 421: 0.787945
# Accuracy after query no. 422: 0.787679
# Accuracy after query no. 423: 0.788072
# Accuracy after query no. 424: 0.788246
# Accuracy after query no. 425: 0.788199
# Accuracy after query no. 426: 0.788152
# Accuracy after query no. 427: 0.788326
# Accuracy after query no. 428: 0.788500
# Accuracy after query no. 429: 0.788233
# Accuracy after query no. 430: 0.788406
# Accuracy after query no. 431: 0.789021
# Accuracy after query no. 432: 0.788754
# Accuracy after query no. 433: 0.789369
# Accuracy after query no. 434: 0.789102
# Accuracy after query no. 435: 0.789276
# Accuracy after query no. 436: 0.790113
# Accuracy after query no. 437: 0.790066
# Accuracy after query no. 438: 0.790241
# Accuracy after query no. 439: 0.789973
# Accuracy after query no. 440: 0.790148
# Accuracy after query no. 441: 0.788113
# Accuracy after query no. 442: 0.788066
# Accuracy after query no. 443: 0.788019
# Accuracy after query no. 444: 0.788415
# Accuracy after query no. 445: 0.788368
# Accuracy after query no. 446: 0.788100
# Accuracy after query no. 447: 0.787832
# Accuracy after query no. 448: 0.788006
# Accuracy after query no. 449: 0.788181
# Accuracy after query no. 450: 0.788576
# Accuracy after query no. 451: 0.788530
# Accuracy after query no. 452: 0.788704
# Accuracy after query no. 453: 0.788879
# Accuracy after query no. 454: 0.788611
# Accuracy after query no. 455: 0.788785
# Accuracy after query no. 456: 0.788739
# Accuracy after query no. 457: 0.788692
# Accuracy after query no. 458: 0.788867
# Accuracy after query no. 459: 0.788820
# Accuracy after query no. 460: 0.788773
# Accuracy after query no. 461: 0.788726
# Accuracy after query no. 462: 0.788901
# Accuracy after query no. 463: 0.789520
# Accuracy after query no. 464: 0.789474
# Accuracy after query no. 465: 0.790093
# Accuracy after query no. 466: 0.789602
# Accuracy after query no. 467: 0.789778
# Accuracy after query no. 468: 0.789731
# Accuracy after query no. 469: 0.789907
# Accuracy after query no. 470: 0.789860
# Accuracy after query no. 471: 0.790036
# Accuracy after query no. 472: 0.789989
# Accuracy after query no. 473: 0.789942
# Accuracy after query no. 474: 0.790118
# Accuracy after query no. 475: 0.790294
# Accuracy after query no. 476: 0.790247
# Accuracy after query no. 477: 0.790200
# Accuracy after query no. 478: 0.790154
# Accuracy after query no. 479: 0.790330
# Accuracy after query no. 480: 0.790729
# Accuracy after query no. 481: 0.790682
# Accuracy after query no. 482: 0.790635
# Accuracy after query no. 483: 0.790812
# Accuracy after query no. 484: 0.790988
# Accuracy after query no. 485: 0.790942
# Accuracy after query no. 486: 0.791118
# Accuracy after query no. 487: 0.791295
# Accuracy after query no. 488: 0.791695
# Accuracy after query no. 489: 0.791648
# Accuracy after query no. 490: 0.792048
# Accuracy after query no. 491: 0.791778
# Accuracy after query no. 492: 0.791955
# Accuracy after query no. 493: 0.792132
# Accuracy after query no. 494: 0.792309
# Accuracy after query no. 495: 0.792263
# Accuracy after query no. 496: 0.792217
# ======================================
# By just labelling  9.98 % of total data accuracy of  0.792  % is achieved on the unseen data

# %% [markdown]
# ## Regular supervised task

# %% [markdown]
# ## Importing test data

# %%
original_data = pd.read_csv('../dataset/Semeval_dataset/test1_semeval.csv')
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'reference_answer':'ref_answer'})
df = original_data.copy()
#converting to lower case
df['ref_modified'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))


#lemmatisation
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
short_df = df[['question','student_answer','student_modified','ref_modified' ,'grade']]
short_df['status'] = short_df['grade'] >= 3
short_df['status'] = short_df['status'].astype(int)
# counting unique words in every student's answer
student_answer_count_vector = CV.transform(short_df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X_test = student_answer_count_vector
Y_test = short_df['status'].values 
# Y_test = np.reshape(Y_test, (-1, 1))
X_train = np.copy(X)
Y_train = np.copy(Y)
X_test.shape
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (540, 1908)

# %%
# logisticRegr = LogisticRegression()
naive_bayes = MultinomialNB()
naive_bayes.fit(X_train, Y_train)
score = nb.score(X_test, Y_test)

print(score)
# Out:
# 0.7592592592592593

# %%
supervised_accuracy = [score for x in range(0,n_queries)]

plt.figure()
plt.plot(np.linspace(0,n_queries-1,n_queries),supervised_accuracy)
plt.plot(accuracy_list)
plt.title("Accuracy after every query")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.legend(["Supervised", "Active Learning"], loc="lower right")
plt.show()

# %%
score = learner.score(X_test, Y_test)
score
# Out:
# 0.7777777777777778
