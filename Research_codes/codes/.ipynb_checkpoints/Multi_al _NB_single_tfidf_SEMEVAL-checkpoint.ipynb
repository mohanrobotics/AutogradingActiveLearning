# %% [markdown]
# # Multiclass classification - single_model using Naive Bayes(semeval)

# %% [markdown]
# # Importing and Preprocessing

# %% [markdown]
# ## Importing libraries

# %%
#### import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %% [markdown]
# ## Importing files

# %%
original_data = pd.read_csv('../dataset/Semeval_dataset/train_semeval.csv')
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'reference_answer':'ref_answer'})

# %% [markdown]
# ## Preprocessing

# %%
df = original_data.copy()
#converting to lower case
df['ref_modified'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))


#lemmatisation
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))

# %% [markdown]
# # Gathering required features

# %%
short_df = df[['question','student_answer','student_modified','ref_modified' ,'grade']]
short_df['status'] = short_df['grade']
short_df['status'].unique()
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# array([2, 5, 4, 0, 3])

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
df.groupby('grade').student_modified.count().plot.bar(ylim=0)
plt.show()

# %% [markdown]
# # Bag of words

# %%
# short_df['word_count'] = short_df['student_answer'].apply(lambda x: dict(Counter(x.split())))

# counting unique words in every student's answer
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(short_df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = short_df['status'].values

# %% [markdown]
# # Seeding

# %%
#getting the seed index
classes = short_df['status'].unique()
seed_index = []
for i in classes:
    seed_index.append(short_df['status'][short_df['status']==i].index[0])
seed_index
# Out:
# [0, 1, 16, 30, 79]

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
train_idx = seed_index
X_train = X[train_idx]
y_train = Y[train_idx]
 
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
# lr = LogisticRegression()
nb = MultinomialNB()
learner = ActiveLearner(
#     estimator = lr,
    estimator = nb,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = int(len(X)/5)
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
#     print("\nQ: ", act_data.loc[int(query_idx),'question'])
#     print("A: ",act_data.loc[int(query_idx),'student_answer'])
#     print("Actual grade: ",y_pool[query_idx].reshape(1, ))
#     print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
#     human_label = int(input("\nGive me a grade 0 or 1:"))
    
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=y_pool[query_idx].reshape(1, )
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X_pool,y_pool))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X_pool, y_pool)))
print("======================================")
print("By just labelling ",round(n_queries*100.0/len(X),2),"% of total data accuracy of ", round(learner.score(X_pool, y_pool),3), " % is achieved on the unseen data"  )
# Out:
# Accuracy after query no. 1: 0.253476
# Accuracy after query no. 2: 0.277711
# Accuracy after query no. 3: 0.282806
# Accuracy after query no. 4: 0.272782
# Accuracy after query no. 5: 0.264166
# Accuracy after query no. 6: 0.274708
# Accuracy after query no. 7: 0.284850
# Accuracy after query no. 8: 0.283293
# Accuracy after query no. 9: 0.278708
# Accuracy after query no. 10: 0.278563
# Accuracy after query no. 11: 0.284070
# Accuracy after query no. 12: 0.286349
# Accuracy after query no. 13: 0.284387
# Accuracy after query no. 14: 0.280606
# Accuracy after query no. 15: 0.285108
# Accuracy after query no. 16: 0.286176
# Accuracy after query no. 17: 0.284617
# Accuracy after query no. 18: 0.285483
# Accuracy after query no. 19: 0.277452
# Accuracy after query no. 20: 0.286408
# Accuracy after query no. 21: 0.268865
# Accuracy after query no. 22: 0.279239
# Accuracy after query no. 23: 0.275450
# Accuracy after query no. 24: 0.277935
# Accuracy after query no. 25: 0.274347
# Accuracy after query no. 26: 0.288376
# Accuracy after query no. 27: 0.293701
# Accuracy after query no. 28: 0.293355
# Accuracy after query no. 29: 0.300912
# Accuracy after query no. 30: 0.292258
# Accuracy after query no. 31: 0.294750
# Accuracy after query no. 32: 0.293593
# Accuracy after query no. 33: 0.325289
# Accuracy after query no. 34: 0.369980
# Accuracy after query no. 35: 0.332116
# Accuracy after query no. 36: 0.375406
# Accuracy after query no. 37: 0.373452
# Accuracy after query no. 38: 0.374340
# Accuracy after query no. 39: 0.366701
# Accuracy after query no. 40: 0.367790
# Accuracy after query no. 41: 0.335568
# Accuracy after query no. 42: 0.372410
# Accuracy after query no. 43: 0.373501
# Accuracy after query no. 44: 0.363211
# Accuracy after query no. 45: 0.360642
# Accuracy after query no. 46: 0.336112
# Accuracy after query no. 47: 0.334757
# Accuracy after query no. 48: 0.359845
# Accuracy after query no. 49: 0.336928
# Accuracy after query no. 50: 0.336793
# Accuracy after query no. 51: 0.332791
# Accuracy after query no. 52: 0.328583
# Accuracy after query no. 53: 0.354103
# Accuracy after query no. 54: 0.354175
# Accuracy after query no. 55: 0.331636
# Accuracy after query no. 56: 0.335371
# Accuracy after query no. 57: 0.334420
# Accuracy after query no. 58: 0.359967
# Accuracy after query no. 59: 0.341896
# Accuracy after query no. 60: 0.341150
# Accuracy after query no. 61: 0.338160
# Accuracy after query no. 62: 0.358425
# Accuracy after query no. 63: 0.359927
# Accuracy after query no. 64: 0.365102
# Accuracy after query no. 65: 0.366401
# Accuracy after query no. 66: 0.364230
# Accuracy after query no. 67: 0.368389
# Accuracy after query no. 68: 0.370302
# Accuracy after query no. 69: 0.366905
# Accuracy after query no. 70: 0.363098
# Accuracy after query no. 71: 0.366646
# Accuracy after query no. 72: 0.368152
# Accuracy after query no. 73: 0.367410
# Accuracy after query no. 74: 0.366462
# Accuracy after query no. 75: 0.370628
# Accuracy after query no. 76: 0.372136
# Accuracy after query no. 77: 0.372007
# Accuracy after query no. 78: 0.373107
# Accuracy after query no. 79: 0.374411
# Accuracy after query no. 80: 0.371622
# Accuracy after query no. 81: 0.374974
# Accuracy after query no. 82: 0.377509
# Accuracy after query no. 83: 0.378406
# Accuracy after query no. 84: 0.379918
# Accuracy after query no. 85: 0.376102
# Accuracy after query no. 86: 0.378229
# Accuracy after query no. 87: 0.376666
# Accuracy after query no. 88: 0.376128
# Accuracy after query no. 89: 0.374974
# Accuracy after query no. 90: 0.375256
# Accuracy after query no. 91: 0.372255
# Accuracy after query no. 92: 0.371511
# Accuracy after query no. 93: 0.370971
# Accuracy after query no. 94: 0.371253
# Accuracy after query no. 95: 0.368248
# Accuracy after query no. 96: 0.364421
# Accuracy after query no. 97: 0.364907
# Accuracy after query no. 98: 0.365393
# Accuracy after query no. 99: 0.366084
# Accuracy after query no. 100: 0.365543
# Accuracy after query no. 101: 0.365207
# Accuracy after query no. 102: 0.364048
# Accuracy after query no. 103: 0.363300
# Accuracy after query no. 104: 0.367078
# Accuracy after query no. 105: 0.367565
# Accuracy after query no. 106: 0.364759
# Accuracy after query no. 107: 0.367717
# Accuracy after query no. 108: 0.367175
# Accuracy after query no. 109: 0.370546
# Accuracy after query no. 110: 0.372064
# Accuracy after query no. 111: 0.370905
# Accuracy after query no. 112: 0.371187
# Accuracy after query no. 113: 0.372088
# Accuracy after query no. 114: 0.371753
# Accuracy after query no. 115: 0.372654
# Accuracy after query no. 116: 0.372112
# Accuracy after query no. 117: 0.370745
# Accuracy after query no. 118: 0.371647
# Accuracy after query no. 119: 0.374407
# Accuracy after query no. 120: 0.374277
# Accuracy after query no. 121: 0.376833
# Accuracy after query no. 122: 0.376910
# Accuracy after query no. 123: 0.376369
# Accuracy after query no. 124: 0.376446
# Accuracy after query no. 125: 0.376524
# Accuracy after query no. 126: 0.376395
# Accuracy after query no. 127: 0.376473
# Accuracy after query no. 128: 0.373242
# Accuracy after query no. 129: 0.373526
# Accuracy after query no. 130: 0.372776
# Accuracy after query no. 131: 0.374095
# Accuracy after query no. 132: 0.374793
# Accuracy after query no. 133: 0.376320
# Accuracy after query no. 134: 0.378054
# Accuracy after query no. 135: 0.377304
# Accuracy after query no. 136: 0.376761
# Accuracy after query no. 137: 0.377460
# Accuracy after query no. 138: 0.377746
# Accuracy after query no. 139: 0.377202
# Accuracy after query no. 140: 0.376451
# Accuracy after query no. 141: 0.375492
# Accuracy after query no. 142: 0.375570
# Accuracy after query no. 143: 0.375026
# Accuracy after query no. 144: 0.374481
# Accuracy after query no. 145: 0.372691
# Accuracy after query no. 146: 0.371731
# Accuracy after query no. 147: 0.372431
# Accuracy after query no. 148: 0.371262
# Accuracy after query no. 149: 0.371132
# Accuracy after query no. 150: 0.371417
# Accuracy after query no. 151: 0.371286
# Accuracy after query no. 152: 0.371987
# Accuracy after query no. 153: 0.372480
# Accuracy after query no. 154: 0.372557
# Accuracy after query no. 155: 0.372427
# Accuracy after query no. 156: 0.372712
# Accuracy after query no. 157: 0.372582
# Accuracy after query no. 158: 0.373491
# Accuracy after query no. 159: 0.373569
# Accuracy after query no. 160: 0.376145
# Accuracy after query no. 161: 0.373725
# Accuracy after query no. 162: 0.376093
# Accuracy after query no. 163: 0.382004
# Accuracy after query no. 164: 0.382917
# Accuracy after query no. 165: 0.382788
# Accuracy after query no. 166: 0.381826
# Accuracy after query no. 167: 0.380238
# Accuracy after query no. 168: 0.379483
# Accuracy after query no. 169: 0.379562
# Accuracy after query no. 170: 0.379433
# Accuracy after query no. 171: 0.382641
# Accuracy after query no. 172: 0.382721
# Accuracy after query no. 173: 0.383219
# Accuracy after query no. 174: 0.382463
# Accuracy after query no. 175: 0.382126
# Accuracy after query no. 176: 0.379908
# Accuracy after query no. 177: 0.383330
# Accuracy after query no. 178: 0.383410
# Accuracy after query no. 179: 0.384117
# Accuracy after query no. 180: 0.384197
# Accuracy after query no. 181: 0.384278
# Accuracy after query no. 182: 0.382894
# Accuracy after query no. 183: 0.382974
# Accuracy after query no. 184: 0.383054
# Accuracy after query no. 185: 0.383135
# Accuracy after query no. 186: 0.383005
# Accuracy after query no. 187: 0.382248
# Accuracy after query no. 188: 0.382747
# Accuracy after query no. 189: 0.382618
# Accuracy after query no. 190: 0.382488
# Accuracy after query no. 191: 0.380683
# Accuracy after query no. 192: 0.380553
# Accuracy after query no. 193: 0.380004
# Accuracy after query no. 194: 0.380294
# Accuracy after query no. 195: 0.381212
# Accuracy after query no. 196: 0.385696
# Accuracy after query no. 197: 0.385987
# Accuracy after query no. 198: 0.385648
# Accuracy after query no. 199: 0.386779
# Accuracy after query no. 200: 0.387490
# Accuracy after query no. 201: 0.389250
# Accuracy after query no. 202: 0.388912
# Accuracy after query no. 203: 0.388994
# Accuracy after query no. 204: 0.389496
# Accuracy after query no. 205: 0.388947
# Accuracy after query no. 206: 0.390921
# Accuracy after query no. 207: 0.390582
# Accuracy after query no. 208: 0.389823
# Accuracy after query no. 209: 0.390116
# Accuracy after query no. 210: 0.391039
# Accuracy after query no. 211: 0.390911
# Accuracy after query no. 212: 0.390993
# Accuracy after query no. 213: 0.390655
# Accuracy after query no. 214: 0.390316
# Accuracy after query no. 215: 0.391240
# Accuracy after query no. 216: 0.390480
# Accuracy after query no. 217: 0.391194
# Accuracy after query no. 218: 0.392120
# Accuracy after query no. 219: 0.393045
# Accuracy after query no. 220: 0.392285
# Accuracy after query no. 221: 0.393844
# Accuracy after query no. 222: 0.393505
# Accuracy after query no. 223: 0.391479
# Accuracy after query no. 224: 0.392194
# Accuracy after query no. 225: 0.392699
# Accuracy after query no. 226: 0.392782
# Accuracy after query no. 227: 0.392865
# Accuracy after query no. 228: 0.394003
# Accuracy after query no. 229: 0.394298
# Accuracy after query no. 230: 0.395015
# Accuracy after query no. 231: 0.397000
# Accuracy after query no. 232: 0.398352
# Accuracy after query no. 233: 0.397802
# Accuracy after query no. 234: 0.398520
# Accuracy after query no. 235: 0.397759
# Accuracy after query no. 236: 0.397843
# Accuracy after query no. 237: 0.397504
# Accuracy after query no. 238: 0.397376
# Accuracy after query no. 239: 0.397460
# Accuracy after query no. 240: 0.397756
# Accuracy after query no. 241: 0.398264
# Accuracy after query no. 242: 0.397078
# Accuracy after query no. 243: 0.397162
# Accuracy after query no. 244: 0.398517
# Accuracy after query no. 245: 0.399449
# Accuracy after query no. 246: 0.399534
# Accuracy after query no. 247: 0.399406
# Accuracy after query no. 248: 0.399491
# Accuracy after query no. 249: 0.399152
# Accuracy after query no. 250: 0.397964
# Accuracy after query no. 251: 0.398048
# Accuracy after query no. 252: 0.399618
# Accuracy after query no. 253: 0.399491
# Accuracy after query no. 254: 0.399363
# Accuracy after query no. 255: 0.400297
# Accuracy after query no. 256: 0.399745
# Accuracy after query no. 257: 0.400892
# Accuracy after query no. 258: 0.400765
# Accuracy after query no. 259: 0.401275
# Accuracy after query no. 260: 0.400935
# Accuracy after query no. 261: 0.401659
# Accuracy after query no. 262: 0.400468
# Accuracy after query no. 263: 0.400128
# Accuracy after query no. 264: 0.401702
# Accuracy after query no. 265: 0.401788
# Accuracy after query no. 266: 0.401447
# Accuracy after query no. 267: 0.401533
# Accuracy after query no. 268: 0.401618
# Accuracy after query no. 269: 0.400639
# Accuracy after query no. 270: 0.400724
# Accuracy after query no. 271: 0.399957
# Accuracy after query no. 272: 0.400682
# Accuracy after query no. 273: 0.401833
# Accuracy after query no. 274: 0.401066
# Accuracy after query no. 275: 0.401791
# Accuracy after query no. 276: 0.402090
# Accuracy after query no. 277: 0.402390
# Accuracy after query no. 278: 0.403542
# Accuracy after query no. 279: 0.406403
# Accuracy after query no. 280: 0.406063
# Accuracy after query no. 281: 0.405723
# Accuracy after query no. 282: 0.405809
# Accuracy after query no. 283: 0.406751
# Accuracy after query no. 284: 0.408547
# Accuracy after query no. 285: 0.406925
# Accuracy after query no. 286: 0.407225
# Accuracy after query no. 287: 0.406671
# Accuracy after query no. 288: 0.406758
# Accuracy after query no. 289: 0.408770
# Accuracy after query no. 290: 0.407788
# Accuracy after query no. 291: 0.408517
# Accuracy after query no. 292: 0.409033
# Accuracy after query no. 293: 0.409120
# Accuracy after query no. 294: 0.409422
# Accuracy after query no. 295: 0.408867
# Accuracy after query no. 296: 0.408955
# Accuracy after query no. 297: 0.409256
# Accuracy after query no. 298: 0.409344
# Accuracy after query no. 299: 0.409218
# Accuracy after query no. 300: 0.409305
# Accuracy after query no. 301: 0.409179
# Accuracy after query no. 302: 0.409266
# Accuracy after query no. 303: 0.409140
# Accuracy after query no. 304: 0.408798
# Accuracy after query no. 305: 0.409530
# Accuracy after query no. 306: 0.409618
# Accuracy after query no. 307: 0.409062
# Accuracy after query no. 308: 0.409149
# Accuracy after query no. 309: 0.410097
# Accuracy after query no. 310: 0.413408
# Accuracy after query no. 311: 0.412852
# Accuracy after query no. 312: 0.412726
# Accuracy after query no. 313: 0.411739
# Accuracy after query no. 314: 0.411828
# Accuracy after query no. 315: 0.411271
# Accuracy after query no. 316: 0.411145
# Accuracy after query no. 317: 0.412309
# Accuracy after query no. 318: 0.411967
# Accuracy after query no. 319: 0.412271
# Accuracy after query no. 320: 0.413437
# Accuracy after query no. 321: 0.413741
# Accuracy after query no. 322: 0.414477
# Accuracy after query no. 323: 0.416936
# Accuracy after query no. 324: 0.418319
# Accuracy after query no. 325: 0.418840
# Accuracy after query no. 326: 0.418499
# Accuracy after query no. 327: 0.419237
# Accuracy after query no. 328: 0.418896
# Accuracy after query no. 329: 0.418339
# Accuracy after query no. 330: 0.418861
# Accuracy after query no. 331: 0.418735
# Accuracy after query no. 332: 0.418826
# Accuracy after query no. 333: 0.417620
# Accuracy after query no. 334: 0.420302
# Accuracy after query no. 335: 0.422769
# Accuracy after query no. 336: 0.422861
# Accuracy after query no. 337: 0.423384
# Accuracy after query no. 338: 0.422395
# Accuracy after query no. 339: 0.424649
# Accuracy after query no. 340: 0.424308
# Accuracy after query no. 341: 0.424400
# Accuracy after query no. 342: 0.424275
# Accuracy after query no. 343: 0.424367
# Accuracy after query no. 344: 0.423810
# Accuracy after query no. 345: 0.423901
# Accuracy after query no. 346: 0.420745
# Accuracy after query no. 347: 0.420619
# Accuracy after query no. 348: 0.419844
# Accuracy after query no. 349: 0.419718
# Accuracy after query no. 350: 0.420459
# Accuracy after query no. 351: 0.420334
# Accuracy after query no. 352: 0.420208
# Accuracy after query no. 353: 0.418347
# Accuracy after query no. 354: 0.418438
# Accuracy after query no. 355: 0.418746
# Accuracy after query no. 356: 0.418837
# Accuracy after query no. 357: 0.418494
# Accuracy after query no. 358: 0.418584
# Accuracy after query no. 359: 0.418893
# Accuracy after query no. 360: 0.419635
# Accuracy after query no. 361: 0.419075
# Accuracy after query no. 362: 0.420687
# Accuracy after query no. 363: 0.420995
# Accuracy after query no. 364: 0.421087
# Accuracy after query no. 365: 0.420961
# Accuracy after query no. 366: 0.420183
# Accuracy after query no. 367: 0.420274
# Accuracy after query no. 368: 0.420583
# Accuracy after query no. 369: 0.420675
# Accuracy after query no. 370: 0.422725
# Accuracy after query no. 371: 0.423035
# Accuracy after query no. 372: 0.423127
# Accuracy after query no. 373: 0.422348
# Accuracy after query no. 374: 0.422440
# Accuracy after query no. 375: 0.422750
# Accuracy after query no. 376: 0.422842
# Accuracy after query no. 377: 0.423152
# Accuracy after query no. 378: 0.423245
# Accuracy after query no. 379: 0.422683
# Accuracy after query no. 380: 0.421902
# Accuracy after query no. 381: 0.421994
# Accuracy after query no. 382: 0.421213
# Accuracy after query no. 383: 0.422615
# Accuracy after query no. 384: 0.422489
# Accuracy after query no. 385: 0.423892
# Accuracy after query no. 386: 0.423547
# Accuracy after query no. 387: 0.423858
# Accuracy after query no. 388: 0.423951
# Accuracy after query no. 389: 0.424481
# Accuracy after query no. 390: 0.424136
# Accuracy after query no. 391: 0.424667
# Accuracy after query no. 392: 0.425197
# Accuracy after query no. 393: 0.425290
# Accuracy after query no. 394: 0.424726
# Accuracy after query no. 395: 0.424382
# Accuracy after query no. 396: 0.423161
# Accuracy after query no. 397: 0.423911
# Accuracy after query no. 398: 0.424223
# Accuracy after query no. 399: 0.423658
# Accuracy after query no. 400: 0.423313
# Accuracy after query no. 401: 0.423406
# Accuracy after query no. 402: 0.420210
# Accuracy after query no. 403: 0.420083
# Accuracy after query no. 404: 0.419298
# Accuracy after query no. 405: 0.419829
# Accuracy after query no. 406: 0.419043
# Accuracy after query no. 407: 0.419355
# Accuracy after query no. 408: 0.419227
# Accuracy after query no. 409: 0.419759
# Accuracy after query no. 410: 0.419851
# Accuracy after query no. 411: 0.420382
# Accuracy after query no. 412: 0.420255
# Accuracy after query no. 413: 0.419249
# Accuracy after query no. 414: 0.418462
# Accuracy after query no. 415: 0.418773
# Accuracy after query no. 416: 0.418865
# Accuracy after query no. 417: 0.419837
# Accuracy after query no. 418: 0.421469
# Accuracy after query no. 419: 0.421562
# Accuracy after query no. 420: 0.421435
# Accuracy after query no. 421: 0.422188
# Accuracy after query no. 422: 0.422501
# Accuracy after query no. 423: 0.423035
# Accuracy after query no. 424: 0.422467
# Accuracy after query no. 425: 0.423001
# Accuracy after query no. 426: 0.425077
# Accuracy after query no. 427: 0.424510
# Accuracy after query no. 428: 0.425485
# Accuracy after query no. 429: 0.422051
# Accuracy after query no. 430: 0.423026
# Accuracy after query no. 431: 0.424222
# Accuracy after query no. 432: 0.424095
# Accuracy after query no. 433: 0.425292
# Accuracy after query no. 434: 0.426490
# Accuracy after query no. 435: 0.426584
# Accuracy after query no. 436: 0.427783
# Accuracy after query no. 437: 0.427877
# Accuracy after query no. 438: 0.429518
# Accuracy after query no. 439: 0.429613
# Accuracy after query no. 440: 0.430592
# Accuracy after query no. 441: 0.430467
# Accuracy after query no. 442: 0.430562
# Accuracy after query no. 443: 0.430657
# Accuracy after query no. 444: 0.430310
# Accuracy after query no. 445: 0.430405
# Accuracy after query no. 446: 0.430058
# Accuracy after query no. 447: 0.429046
# Accuracy after query no. 448: 0.427812
# Accuracy after query no. 449: 0.427464
# Accuracy after query no. 450: 0.428445
# Accuracy after query no. 451: 0.430534
# Accuracy after query no. 452: 0.429743
# Accuracy after query no. 453: 0.434937
# Accuracy after query no. 454: 0.434812
# Accuracy after query no. 455: 0.432912
# Accuracy after query no. 456: 0.433452
# Accuracy after query no. 457: 0.432217
# Accuracy after query no. 458: 0.432312
# Accuracy after query no. 459: 0.433740
# Accuracy after query no. 460: 0.431394
# Accuracy after query no. 461: 0.431934
# Accuracy after query no. 462: 0.432252
# Accuracy after query no. 463: 0.432126
# Accuracy after query no. 464: 0.431556
# Accuracy after query no. 465: 0.431874
# Accuracy after query no. 466: 0.431970
# Accuracy after query no. 467: 0.433178
# Accuracy after query no. 468: 0.433274
# Accuracy after query no. 469: 0.436263
# Accuracy after query no. 470: 0.435247
# Accuracy after query no. 471: 0.436234
# Accuracy after query no. 472: 0.435663
# Accuracy after query no. 473: 0.435760
# Accuracy after query no. 474: 0.436303
# Accuracy after query no. 475: 0.436400
# Accuracy after query no. 476: 0.436497
# Accuracy after query no. 477: 0.436595
# Accuracy after query no. 478: 0.437138
# Accuracy after query no. 479: 0.435674
# Accuracy after query no. 480: 0.435549
# Accuracy after query no. 481: 0.435646
# Accuracy after query no. 482: 0.435743
# Accuracy after query no. 483: 0.435840
# Accuracy after query no. 484: 0.435268
# Accuracy after query no. 485: 0.434025
# Accuracy after query no. 486: 0.435016
# Accuracy after query no. 487: 0.435783
# Accuracy after query no. 488: 0.435880
# Accuracy after query no. 489: 0.436872
# Accuracy after query no. 490: 0.438310
# Accuracy after query no. 491: 0.439079
# Accuracy after query no. 492: 0.440295
# Accuracy after query no. 493: 0.444867
# Accuracy after query no. 494: 0.444966
# Accuracy after query no. 495: 0.444842
# Accuracy after query no. 496: 0.445166
# Accuracy after query no. 497: 0.446608
# Accuracy after query no. 498: 0.447380
# Accuracy after query no. 499: 0.446361
# Accuracy after query no. 500: 0.446909
# Accuracy after query no. 501: 0.447233
# Accuracy after query no. 502: 0.447781
# Accuracy after query no. 503: 0.448330
# Accuracy after query no. 504: 0.453363
# Accuracy after query no. 505: 0.453913
# Accuracy after query no. 506: 0.453342
# Accuracy after query no. 507: 0.452322
# Accuracy after query no. 508: 0.453321
# Accuracy after query no. 509: 0.453872
# Accuracy after query no. 510: 0.453525
# Accuracy after query no. 511: 0.452728
# Accuracy after query no. 512: 0.453953
# Accuracy after query no. 513: 0.453381
# Accuracy after query no. 514: 0.454157
# Accuracy after query no. 515: 0.454484
# Accuracy after query no. 516: 0.454586
# Accuracy after query no. 517: 0.455588
# Accuracy after query no. 518: 0.459064
# Accuracy after query no. 519: 0.460517
# Accuracy after query no. 520: 0.461746
# Accuracy after query no. 521: 0.461175
# Accuracy after query no. 522: 0.460828
# Accuracy after query no. 523: 0.461383
# Accuracy after query no. 524: 0.459459
# Accuracy after query no. 525: 0.458887
# Accuracy after query no. 526: 0.458540
# Accuracy after query no. 527: 0.458418
# Accuracy after query no. 528: 0.457845
# Accuracy after query no. 529: 0.457723
# Accuracy after query no. 530: 0.458051
# Accuracy after query no. 531: 0.456125
# Accuracy after query no. 532: 0.455551
# Accuracy after query no. 533: 0.455428
# Accuracy after query no. 534: 0.454628
# Accuracy after query no. 535: 0.457214
# Accuracy after query no. 536: 0.457317
# Accuracy after query no. 537: 0.454484
# Accuracy after query no. 538: 0.455490
# Accuracy after query no. 539: 0.456497
# Accuracy after query no. 540: 0.456148
# Accuracy after query no. 541: 0.455121
# Accuracy after query no. 542: 0.454093
# Accuracy after query no. 543: 0.453065
# Accuracy after query no. 544: 0.452715
# Accuracy after query no. 545: 0.453044
# Accuracy after query no. 546: 0.452920
# Accuracy after query no. 547: 0.453702
# Accuracy after query no. 548: 0.455163
# Accuracy after query no. 549: 0.456399
# Accuracy after query no. 550: 0.456275
# Accuracy after query no. 551: 0.456152
# Accuracy after query no. 552: 0.457616
# Accuracy after query no. 553: 0.456586
# Accuracy after query no. 554: 0.457143
# Accuracy after query no. 555: 0.457473
# Accuracy after query no. 556: 0.457804
# Accuracy after query no. 557: 0.454277
# Accuracy after query no. 558: 0.453700
# Accuracy after query no. 559: 0.456073
# Accuracy after query no. 560: 0.455722
# Accuracy after query no. 561: 0.456053
# Accuracy after query no. 562: 0.457065
# Accuracy after query no. 563: 0.457623
# Accuracy after query no. 564: 0.457500
# Accuracy after query no. 565: 0.457377
# Accuracy after query no. 566: 0.459982
# Accuracy after query no. 567: 0.458494
# Accuracy after query no. 568: 0.458371
# Accuracy after query no. 569: 0.459841
# Accuracy after query no. 570: 0.459945
# Accuracy after query no. 571: 0.460050
# Accuracy after query no. 572: 0.460155
# Accuracy after query no. 573: 0.460260
# Accuracy after query no. 574: 0.459909
# Accuracy after query no. 575: 0.460014
# Accuracy after query no. 576: 0.459663
# Accuracy after query no. 577: 0.458856
# Accuracy after query no. 578: 0.459188
# Accuracy after query no. 579: 0.459521
# Accuracy after query no. 580: 0.460082
# Accuracy after query no. 581: 0.463381
# Accuracy after query no. 582: 0.463259
# Accuracy after query no. 583: 0.463136
# Accuracy after query no. 584: 0.463014
# Accuracy after query no. 585: 0.463119
# Accuracy after query no. 586: 0.464139
# Accuracy after query no. 587: 0.464016
# Accuracy after query no. 588: 0.463208
# Accuracy after query no. 589: 0.466514
# Accuracy after query no. 590: 0.467078
# Accuracy after query no. 591: 0.466728
# Accuracy after query no. 592: 0.467978
# Accuracy after query no. 593: 0.467170
# Accuracy after query no. 594: 0.467506
# Accuracy after query no. 595: 0.467384
# Accuracy after query no. 596: 0.467033
# Accuracy after query no. 597: 0.466682
# Accuracy after query no. 598: 0.466331
# Accuracy after query no. 599: 0.466667
# Accuracy after query no. 600: 0.465170
# Accuracy after query no. 601: 0.465505
# Accuracy after query no. 602: 0.466071
# Accuracy after query no. 603: 0.466407
# Accuracy after query no. 604: 0.466972
# Accuracy after query no. 605: 0.466850
# Accuracy after query no. 606: 0.466957
# Accuracy after query no. 607: 0.466835
# Accuracy after query no. 608: 0.466942
# Accuracy after query no. 609: 0.467279
# Accuracy after query no. 610: 0.466008
# Accuracy after query no. 611: 0.466575
# Accuracy after query no. 612: 0.465993
# Accuracy after query no. 613: 0.467249
# Accuracy after query no. 614: 0.467126
# Accuracy after query no. 615: 0.466774
# Accuracy after query no. 616: 0.467111
# Accuracy after query no. 617: 0.466759
# Accuracy after query no. 618: 0.464565
# Accuracy after query no. 619: 0.463982
# Accuracy after query no. 620: 0.462247
# Accuracy after query no. 621: 0.462583
# Accuracy after query no. 622: 0.463381
# Accuracy after query no. 623: 0.463718
# Accuracy after query no. 624: 0.463134
# Accuracy after query no. 625: 0.463010
# Accuracy after query no. 626: 0.461734
# Accuracy after query no. 627: 0.461148
# Accuracy after query no. 628: 0.461946
# Accuracy after query no. 629: 0.459977
# Accuracy after query no. 630: 0.460083
# Accuracy after query no. 631: 0.460189
# Accuracy after query no. 632: 0.459603
# Accuracy after query no. 633: 0.460171
# Accuracy after query no. 634: 0.459584
# Accuracy after query no. 635: 0.459690
# Accuracy after query no. 636: 0.460721
# Accuracy after query no. 637: 0.460365
# Accuracy after query no. 638: 0.460009
# Accuracy after query no. 639: 0.460116
# Accuracy after query no. 640: 0.461841
# Accuracy after query no. 641: 0.461716
# Accuracy after query no. 642: 0.459972
# Accuracy after query no. 643: 0.461699
# Accuracy after query no. 644: 0.461574
# Accuracy after query no. 645: 0.460755
# Accuracy after query no. 646: 0.460630
# Accuracy after query no. 647: 0.460042
# Accuracy after query no. 648: 0.460612
# Accuracy after query no. 649: 0.461182
# Accuracy after query no. 650: 0.463375
# Accuracy after query no. 651: 0.463251
# Accuracy after query no. 652: 0.462199
# Accuracy after query no. 653: 0.463234
# Accuracy after query no. 654: 0.463805
# Accuracy after query no. 655: 0.465073
# Accuracy after query no. 656: 0.465181
# Accuracy after query no. 657: 0.465521
# Accuracy after query no. 658: 0.464004
# Accuracy after query no. 659: 0.464344
# Accuracy after query no. 660: 0.464684
# Accuracy after query no. 661: 0.463398
# Accuracy after query no. 662: 0.463505
# Accuracy after query no. 663: 0.463381
# Accuracy after query no. 664: 0.463488
# Accuracy after query no. 665: 0.462201
# Accuracy after query no. 666: 0.460214
# Accuracy after query no. 667: 0.460787
# Accuracy after query no. 668: 0.460894
# Accuracy after query no. 669: 0.463562
# Accuracy after query no. 670: 0.462739
# Accuracy after query no. 671: 0.462846
# Accuracy after query no. 672: 0.462721
# Accuracy after query no. 673: 0.462829
# Accuracy after query no. 674: 0.462937
# Accuracy after query no. 675: 0.463045
# Accuracy after query no. 676: 0.463386
# Accuracy after query no. 677: 0.462794
# Accuracy after query no. 678: 0.461969
# Accuracy after query no. 679: 0.461144
# Accuracy after query no. 680: 0.462185
# Accuracy after query no. 681: 0.463460
# Accuracy after query no. 682: 0.463335
# Accuracy after query no. 683: 0.464611
# Accuracy after query no. 684: 0.464486
# Accuracy after query no. 685: 0.465529
# Accuracy after query no. 686: 0.465171
# Accuracy after query no. 687: 0.465279
# Accuracy after query no. 688: 0.465388
# Accuracy after query no. 689: 0.465731
# Accuracy after query no. 690: 0.465372
# Accuracy after query no. 691: 0.464311
# Accuracy after query no. 692: 0.464185
# Accuracy after query no. 693: 0.464294
# Accuracy after query no. 694: 0.464637
# Accuracy after query no. 695: 0.464043
# Accuracy after query no. 696: 0.464386
# Accuracy after query no. 697: 0.462386
# Accuracy after query no. 698: 0.461322
# Accuracy after query no. 699: 0.464478
# Accuracy after query no. 700: 0.466229
# Accuracy after query no. 701: 0.465869
# Accuracy after query no. 702: 0.465978
# Accuracy after query no. 703: 0.466088
# Accuracy after query no. 704: 0.465728
# Accuracy after query no. 705: 0.466072
# Accuracy after query no. 706: 0.465712
# Accuracy after query no. 707: 0.466056
# Accuracy after query no. 708: 0.466165
# Accuracy after query no. 709: 0.464395
# Accuracy after query no. 710: 0.463799
# Accuracy after query no. 711: 0.462262
# Accuracy after query no. 712: 0.463782
# Accuracy after query no. 713: 0.463420
# Accuracy after query no. 714: 0.461647
# Accuracy after query no. 715: 0.462462
# Accuracy after query no. 716: 0.462806
# Accuracy after query no. 717: 0.462915
# Accuracy after query no. 718: 0.463024
# Accuracy after query no. 719: 0.462662
# Accuracy after query no. 720: 0.462771
# Accuracy after query no. 721: 0.463116
# Accuracy after query no. 722: 0.462753
# Accuracy after query no. 723: 0.463806
# Accuracy after query no. 724: 0.462500
# Accuracy after query no. 725: 0.461901
# Accuracy after query no. 726: 0.462010
# Accuracy after query no. 727: 0.461883
# Accuracy after query no. 728: 0.462701
# Accuracy after query no. 729: 0.462810
# Accuracy after query no. 730: 0.463392
# Accuracy after query no. 731: 0.464918
# Accuracy after query no. 732: 0.465974
# Accuracy after query no. 733: 0.466556
# Accuracy after query no. 734: 0.465721
# Accuracy after query no. 735: 0.465595
# Accuracy after query no. 736: 0.465941
# Accuracy after query no. 737: 0.466525
# Accuracy after query no. 738: 0.466872
# Accuracy after query no. 739: 0.467929
# Accuracy after query no. 740: 0.468277
# Accuracy after query no. 741: 0.469098
# Accuracy after query no. 742: 0.468735
# Accuracy after query no. 743: 0.467662
# Accuracy after query no. 744: 0.468009
# Accuracy after query no. 745: 0.467883
# Accuracy after query no. 746: 0.468943
# Accuracy after query no. 747: 0.468817
# Accuracy after query no. 748: 0.470588
# Accuracy after query no. 749: 0.468327
# Accuracy after query no. 750: 0.467727
# Accuracy after query no. 751: 0.469262
# Accuracy after query no. 752: 0.470798
# Accuracy after query no. 753: 0.470672
# Accuracy after query no. 754: 0.471496
# Accuracy after query no. 755: 0.471608
# Accuracy after query no. 756: 0.471483
# Accuracy after query no. 757: 0.473021
# Accuracy after query no. 758: 0.473371
# Accuracy after query no. 759: 0.472295
# Accuracy after query no. 760: 0.472645
# Accuracy after query no. 761: 0.474185
# Accuracy after query no. 762: 0.472870
# Accuracy after query no. 763: 0.472983
# Accuracy after query no. 764: 0.472619
# Accuracy after query no. 765: 0.474399
# Accuracy after query no. 766: 0.473797
# Accuracy after query no. 767: 0.474148
# Accuracy after query no. 768: 0.472355
# Accuracy after query no. 769: 0.472944
# Accuracy after query no. 770: 0.472103
# Accuracy after query no. 771: 0.472454
# Accuracy after query no. 772: 0.473282
# Accuracy after query no. 773: 0.473157
# Accuracy after query no. 774: 0.474224
# Accuracy after query no. 775: 0.473860
# Accuracy after query no. 776: 0.473734
# Accuracy after query no. 777: 0.471698
# Accuracy after query no. 778: 0.472527
# Accuracy after query no. 779: 0.472162
# Accuracy after query no. 780: 0.472275
# Accuracy after query no. 781: 0.472866
# Accuracy after query no. 782: 0.472740
# Accuracy after query no. 783: 0.473093
# Accuracy after query no. 784: 0.473684
# Accuracy after query no. 785: 0.474276
# Accuracy after query no. 786: 0.474150
# Accuracy after query no. 787: 0.473306
# Accuracy after query no. 788: 0.473420
# Accuracy after query no. 789: 0.474970
# Accuracy after query no. 790: 0.473407
# Accuracy after query no. 791: 0.471843
# Accuracy after query no. 792: 0.472435
# Accuracy after query no. 793: 0.472549
# Accuracy after query no. 794: 0.472662
# Accuracy after query no. 795: 0.472296
# Accuracy after query no. 796: 0.472169
# Accuracy after query no. 797: 0.472042
# Accuracy after query no. 798: 0.474796
# Accuracy after query no. 799: 0.474430
# Accuracy after query no. 800: 0.474544
# Accuracy after query no. 801: 0.474417
# Accuracy after query no. 802: 0.473811
# Accuracy after query no. 803: 0.473444
# Accuracy after query no. 804: 0.473317
# Accuracy after query no. 805: 0.473672
# Accuracy after query no. 806: 0.473785
# Accuracy after query no. 807: 0.473659
# Accuracy after query no. 808: 0.473773
# Accuracy after query no. 809: 0.474850
# Accuracy after query no. 810: 0.474964
# Accuracy after query no. 811: 0.476041
# Accuracy after query no. 812: 0.475674
# Accuracy after query no. 813: 0.474825
# Accuracy after query no. 814: 0.475181
# Accuracy after query no. 815: 0.475536
# Accuracy after query no. 816: 0.476133
# Accuracy after query no. 817: 0.477212
# Accuracy after query no. 818: 0.475639
# Accuracy after query no. 819: 0.475995
# Accuracy after query no. 820: 0.478523
# Accuracy after query no. 821: 0.477432
# Accuracy after query no. 822: 0.479720
# Accuracy after query no. 823: 0.480077
# Accuracy after query no. 824: 0.480193
# Accuracy after query no. 825: 0.480068
# Accuracy after query no. 826: 0.482117
# Accuracy after query no. 827: 0.482234
# Accuracy after query no. 828: 0.482108
# Accuracy after query no. 829: 0.481499
# Accuracy after query no. 830: 0.480648
# Accuracy after query no. 831: 0.481490
# Accuracy after query no. 832: 0.481123
# Accuracy after query no. 833: 0.480513
# Accuracy after query no. 834: 0.480872
# Accuracy after query no. 835: 0.480988
# Accuracy after query no. 836: 0.481105
# Accuracy after query no. 837: 0.482190
# Accuracy after query no. 838: 0.481580
# Accuracy after query no. 839: 0.481455
# Accuracy after query no. 840: 0.482299
# Accuracy after query no. 841: 0.482416
# Accuracy after query no. 842: 0.482048
# Accuracy after query no. 843: 0.481437
# Accuracy after query no. 844: 0.480825
# Accuracy after query no. 845: 0.480456
# Accuracy after query no. 846: 0.481302
# Accuracy after query no. 847: 0.480933
# Accuracy after query no. 848: 0.480807
# Accuracy after query no. 849: 0.480680
# Accuracy after query no. 850: 0.480797
# Accuracy after query no. 851: 0.480914
# Accuracy after query no. 852: 0.481518
# Accuracy after query no. 853: 0.481635
# Accuracy after query no. 854: 0.481509
# Accuracy after query no. 855: 0.480896
# Accuracy after query no. 856: 0.480526
# Accuracy after query no. 857: 0.479912
# Accuracy after query no. 858: 0.480760
# Accuracy after query no. 859: 0.481121
# Accuracy after query no. 860: 0.481481
# Accuracy after query no. 861: 0.481111
# Accuracy after query no. 862: 0.481472
# Accuracy after query no. 863: 0.481590
# Accuracy after query no. 864: 0.481220
# Accuracy after query no. 865: 0.481337
# Accuracy after query no. 866: 0.481210
# Accuracy after query no. 867: 0.481084
# Accuracy after query no. 868: 0.481201
# Accuracy after query no. 869: 0.481074
# Accuracy after query no. 870: 0.480948
# Accuracy after query no. 871: 0.481065
# Accuracy after query no. 872: 0.481183
# Accuracy after query no. 873: 0.484723
# Accuracy after query no. 874: 0.484352
# Accuracy after query no. 875: 0.484471
# Accuracy after query no. 876: 0.484589
# Accuracy after query no. 877: 0.484218
# Accuracy after query no. 878: 0.484581
# Accuracy after query no. 879: 0.484700
# Accuracy after query no. 880: 0.484819
# Accuracy after query no. 881: 0.485427
# Accuracy after query no. 882: 0.485546
# Accuracy after query no. 883: 0.485665
# Accuracy after query no. 884: 0.484804
# Accuracy after query no. 885: 0.486639
# Accuracy after query no. 886: 0.485287
# Accuracy after query no. 887: 0.486632
# Accuracy after query no. 888: 0.486506
# Accuracy after query no. 889: 0.486871
# Accuracy after query no. 890: 0.487482
# Accuracy after query no. 891: 0.487110
# Accuracy after query no. 892: 0.486739
# Accuracy after query no. 893: 0.487841
# Accuracy after query no. 894: 0.487961
# Accuracy after query no. 895: 0.486360
# Accuracy after query no. 896: 0.487217
# Accuracy after query no. 897: 0.487337
# Accuracy after query no. 898: 0.488933
# Accuracy after query no. 899: 0.489299
# Accuracy after query no. 900: 0.488435
# Accuracy after query no. 901: 0.488063
# Accuracy after query no. 902: 0.488922
# Accuracy after query no. 903: 0.488796
# Accuracy after query no. 904: 0.488916
# Accuracy after query no. 905: 0.489037
# Accuracy after query no. 906: 0.488911
# Accuracy after query no. 907: 0.489278
# Accuracy after query no. 908: 0.489398
# Accuracy after query no. 909: 0.489273
# Accuracy after query no. 910: 0.489147
# Accuracy after query no. 911: 0.489267
# Accuracy after query no. 912: 0.489388
# Accuracy after query no. 913: 0.490002
# Accuracy after query no. 914: 0.490123
# Accuracy after query no. 915: 0.490738
# Accuracy after query no. 916: 0.490613
# Accuracy after query no. 917: 0.492216
# Accuracy after query no. 918: 0.492338
# Accuracy after query no. 919: 0.491965
# Accuracy after query no. 920: 0.491592
# Accuracy after query no. 921: 0.491219
# Accuracy after query no. 922: 0.493073
# Accuracy after query no. 923: 0.493195
# Accuracy after query no. 924: 0.490347
# Accuracy after query no. 925: 0.490963
# Accuracy after query no. 926: 0.489599
# Accuracy after query no. 927: 0.489225
# Accuracy after query no. 928: 0.487611
# Accuracy after query no. 929: 0.490954
# Accuracy after query no. 930: 0.491076
# Accuracy after query no. 931: 0.490206
# Accuracy after query no. 932: 0.490575
# Accuracy after query no. 933: 0.490449
# Accuracy after query no. 934: 0.489082
# Accuracy after query no. 935: 0.489451
# Accuracy after query no. 936: 0.489076
# Accuracy after query no. 937: 0.489198
# Accuracy after query no. 938: 0.488574
# Accuracy after query no. 939: 0.488199
# Accuracy after query no. 940: 0.488817
# Accuracy after query no. 941: 0.488441
# Accuracy after query no. 942: 0.488812
# Accuracy after query no. 943: 0.488684
# Accuracy after query no. 944: 0.489055
# Accuracy after query no. 945: 0.489923
# Accuracy after query no. 946: 0.491289
# Accuracy after query no. 947: 0.491163
# Accuracy after query no. 948: 0.491783
# Accuracy after query no. 949: 0.491158
# Accuracy after query no. 950: 0.491031
# Accuracy after query no. 951: 0.491154
# Accuracy after query no. 952: 0.491525
# Accuracy after query no. 953: 0.490651
# Accuracy after query no. 954: 0.491272
# Accuracy after query no. 955: 0.490397
# Accuracy after query no. 956: 0.490519
# Accuracy after query no. 957: 0.491141
# Accuracy after query no. 958: 0.491263
# Accuracy after query no. 959: 0.491885
# Accuracy after query no. 960: 0.492258
# Accuracy after query no. 961: 0.492381
# Accuracy after query no. 962: 0.494003
# Accuracy after query no. 963: 0.493627
# Accuracy after query no. 964: 0.494000
# Accuracy after query no. 965: 0.497124
# Accuracy after query no. 966: 0.498749
# Accuracy after query no. 967: 0.499375
# Accuracy after query no. 968: 0.499249
# Accuracy after query no. 969: 0.499875
# Accuracy after query no. 970: 0.500250
# Accuracy after query no. 971: 0.500376
# Accuracy after query no. 972: 0.500251
# Accuracy after query no. 973: 0.498622
# Accuracy after query no. 974: 0.497995
# Accuracy after query no. 975: 0.499624
# Accuracy after query no. 976: 0.498997
# Accuracy after query no. 977: 0.496865
# Accuracy after query no. 978: 0.496989
# Accuracy after query no. 979: 0.497114
# Accuracy after query no. 980: 0.496988
# Accuracy after query no. 981: 0.496862
# Accuracy after query no. 982: 0.498995
# Accuracy after query no. 983: 0.499623
# Accuracy after query no. 984: 0.499749
# Accuracy after query no. 985: 0.499120
# Accuracy after query no. 986: 0.499246
# Accuracy after query no. 987: 0.499120
# Accuracy after query no. 988: 0.498491
# Accuracy after query no. 989: 0.500629
# Accuracy after query no. 990: 0.501007
# Accuracy after query no. 991: 0.500881
# Accuracy after query no. 992: 0.501007
# Accuracy after query no. 993: 0.501133
# ======================================
# By just labelling  19.98 % of total data accuracy of  0.501  % is achieved on the unseen data

# %% [markdown]
# ## Regular supervised task

# %% [markdown]
# ## Importing test data

# %%
original_data = pd.read_csv('../dataset/Semeval_dataset/test1_semeval.csv')
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'reference_answer':'ref_answer'})
df = original_data.copy()
#converting to lower case
df['ref_modified'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))


#lemmatisation
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
short_df = df[['question','student_answer','student_modified','ref_modified' ,'grade']]
short_df['status'] = short_df['grade'] 

# counting unique words in every student's answer
student_answer_count_vector = CV.transform(short_df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X_test = student_answer_count_vector
Y_test = short_df['status'].values 
# Y_test = np.reshape(Y_test, (-1, 1))
X_train = np.copy(X)
Y_train = np.copy(Y)
X_test.shape
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (540, 1908)

# %%
# logisticRegr = LogisticRegression()
naive_bayes = MultinomialNB()
naive_bayes.fit(X_train, Y_train)
score = naive_bayes.score(X_test, Y_test)

print(score)
# Out:
# 0.48703703703703705

# %%
supervised_accuracy = [score for x in range(0,n_queries)]

plt.figure()
plt.plot(np.linspace(0,n_queries-1,n_queries),supervised_accuracy)
plt.plot(accuracy_list)
plt.title("Accuracy after every query")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.legend(["Supervised", "Active Learning"], loc="lower right")
plt.show()

# %%
score = learner.score(X_test, Y_test)
score
# Out:
# 0.4685185185185185

# %%
y_pred_ai = learner.predict(X_test)
y_pred_sup = naive_bayes.predict(X_test)

# %%
from sklearn.metrics import f1_score

f1_score(Y_test, y_pred_ai,average='weighted')
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0.4488787849674144

# %%
f1_score(Y_test, y_pred_sup,average='weighted')
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0.47435972417504607
