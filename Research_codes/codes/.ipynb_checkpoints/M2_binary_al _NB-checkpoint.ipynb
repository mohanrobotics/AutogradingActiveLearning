# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %%
original_data = pd.read_csv('../dataset/mohler2_cleaned.csv')
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'question_number':'question_id','question_text':'question','answer_model':'ref_answer','answer_student':'student_answer','score_avg':'grade'})

# %%
df = original_data.copy()

#converting to lower case
df['ref_modified'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))


#lemmatisation
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))

df
# Out:
#       question_id                                           question  \
# 0             1.1  What is the role of a prototype program in pro...
# 1             1.1  What is the role of a prototype program in pro...
# 2             1.1  What is the role of a prototype program in pro...
# 3             1.1  What is the role of a prototype program in pro...
# 4             1.1  What is the role of a prototype program in pro...
# 5             1.1  What is the role of a prototype program in pro...
# 6             1.1  What is the role of a prototype program in pro...
# 7             1.1  What is the role of a prototype program in pro...
# 8             1.1  What is the role of a prototype program in pro...
# 9             1.1  What is the role of a prototype program in pro...
# 10            1.1  What is the role of a prototype program in pro...
# 11            1.1  What is the role of a prototype program in pro...
# 12            1.1  What is the role of a prototype program in pro...
# 13            1.1  What is the role of a prototype program in pro...
# 14            1.1  What is the role of a prototype program in pro...
# 15            1.1  What is the role of a prototype program in pro...
# 16            1.1  What is the role of a prototype program in pro...
# 17            1.1  What is the role of a prototype program in pro...
# 18            1.1  What is the role of a prototype program in pro...
# 19            1.1  What is the role of a prototype program in pro...
# 20            1.1  What is the role of a prototype program in pro...
# 21            1.1  What is the role of a prototype program in pro...
# 22            1.1  What is the role of a prototype program in pro...
# 23            1.1  What is the role of a prototype program in pro...
# 24            1.1  What is the role of a prototype program in pro...
# 25            1.1  What is the role of a prototype program in pro...
# 26            1.1  What is the role of a prototype program in pro...
# 27            1.1  What is the role of a prototype program in pro...
# 28            1.1  What is the role of a prototype program in pro...
# 29            1.2  What stages in the software life cycle are inf...
# ...           ...                                                ...
# 2412         12.9  How do you delete a node from a binary search ...
# 2413         12.9  How do you delete a node from a binary search ...
# 2414         12.1  How many steps does it take to search a node i...
# 2415         12.1  How many steps does it take to search a node i...
# 2416         12.1  How many steps does it take to search a node i...
# 2417         12.1  How many steps does it take to search a node i...
# 2418         12.1  How many steps does it take to search a node i...
# 2419         12.1  How many steps does it take to search a node i...
# 2420         12.1  How many steps does it take to search a node i...
# 2421         12.1  How many steps does it take to search a node i...
# 2422         12.1  How many steps does it take to search a node i...
# 2423         12.1  How many steps does it take to search a node i...
# 2424         12.1  How many steps does it take to search a node i...
# 2425         12.1  How many steps does it take to search a node i...
# 2426         12.1  How many steps does it take to search a node i...
# 2427         12.1  How many steps does it take to search a node i...
# 2428         12.1  How many steps does it take to search a node i...
# 2429         12.1  How many steps does it take to search a node i...
# 2430         12.1  How many steps does it take to search a node i...
# 2431         12.1  How many steps does it take to search a node i...
# 2432         12.1  How many steps does it take to search a node i...
# 2433         12.1  How many steps does it take to search a node i...
# 2434         12.1  How many steps does it take to search a node i...
# 2435         12.1  How many steps does it take to search a node i...
# 2436         12.1  How many steps does it take to search a node i...
# 2437         12.1  How many steps does it take to search a node i...
# 2438         12.1  How many steps does it take to search a node i...
# 2439         12.1  How many steps does it take to search a node i...
# 2440         12.1  How many steps does it take to search a node i...
# 2441         12.1  How many steps does it take to search a node i...
#
#                                              ref_answer  \
# 0     To simulate the behaviour of portions of the d...
# 1     To simulate the behaviour of portions of the d...
# 2     To simulate the behaviour of portions of the d...
# 3     To simulate the behaviour of portions of the d...
# 4     To simulate the behaviour of portions of the d...
# 5     To simulate the behaviour of portions of the d...
# 6     To simulate the behaviour of portions of the d...
# 7     To simulate the behaviour of portions of the d...
# 8     To simulate the behaviour of portions of the d...
# 9     To simulate the behaviour of portions of the d...
# 10    To simulate the behaviour of portions of the d...
# 11    To simulate the behaviour of portions of the d...
# 12    To simulate the behaviour of portions of the d...
# 13    To simulate the behaviour of portions of the d...
# 14    To simulate the behaviour of portions of the d...
# 15    To simulate the behaviour of portions of the d...
# 16    To simulate the behaviour of portions of the d...
# 17    To simulate the behaviour of portions of the d...
# 18    To simulate the behaviour of portions of the d...
# 19    To simulate the behaviour of portions of the d...
# 20    To simulate the behaviour of portions of the d...
# 21    To simulate the behaviour of portions of the d...
# 22    To simulate the behaviour of portions of the d...
# 23    To simulate the behaviour of portions of the d...
# 24    To simulate the behaviour of portions of the d...
# 25    To simulate the behaviour of portions of the d...
# 26    To simulate the behaviour of portions of the d...
# 27    To simulate the behaviour of portions of the d...
# 28    To simulate the behaviour of portions of the d...
# 29    The testing stage can influence both the codin...
# ...                                                 ...
# 2412  Find the node  then replace it with the leftmo...
# 2413  Find the node  then replace it with the leftmo...
# 2414                            The height of the tree.
# 2415                            The height of the tree.
# 2416                            The height of the tree.
# 2417                            The height of the tree.
# 2418                            The height of the tree.
# 2419                            The height of the tree.
# 2420                            The height of the tree.
# 2421                            The height of the tree.
# 2422                            The height of the tree.
# 2423                            The height of the tree.
# 2424                            The height of the tree.
# 2425                            The height of the tree.
# 2426                            The height of the tree.
# 2427                            The height of the tree.
# 2428                            The height of the tree.
# 2429                            The height of the tree.
# 2430                            The height of the tree.
# 2431                            The height of the tree.
# 2432                            The height of the tree.
# 2433                            The height of the tree.
# 2434                            The height of the tree.
# 2435                            The height of the tree.
# 2436                            The height of the tree.
# 2437                            The height of the tree.
# 2438                            The height of the tree.
# 2439                            The height of the tree.
# 2440                            The height of the tree.
# 2441                            The height of the tree.
#
#                                          student_answer  grade  \
# 0     High risk problems are address in the prototyp...    3.5
# 1     To simulate portions of the desired final prod...    5.0
# 2     A prototype program simulates the behaviors of...    4.0
# 3     Defined in the Specification phase a prototype...    5.0
# 4     It is used to let the users have a first idea ...    3.0
# 5     To find problem and errors in a program before...    2.0
# 6     To address major issues in the creation of the...    2.5
# 7     you can break the whole program into prototype...    5.0
# 8     To provide an example or model of how the fini...    3.5
# 9     Simulating the behavior of only a portion of t...    5.0
# 10    A program that stimulates the behavior of port...    5.0
# 11    A program that simulates the behavior of porti...    5.0
# 12    To lay out the basics and give you a starting ...    2.0
# 13    To simulate problem solving for parts of the p...    4.5
# 14    A prototype program provides a basic groundwor...    2.0
# 15    A prototype program is a part of the Specifica...    4.5
# 16    Program that simulates the behavior of portion...    5.0
# 17    it provides a limited proof of concept to veri...    2.0
# 18    It tests the main function of the program whil...    2.0
# 19    To get early feedback from users in early stag...    2.5
# 20    it simulates the behavior of portions of the d...    5.0
# 21    It simulates the behavior of portions of the d...    5.0
# 22    A prototype program is used in problem solving...    1.5
# 23    To ease the understanding of problem under dis...    2.5
# 24    it simulates the behavior of portions of the d...    5.0
# 25    The role of a prototype program is to help spo...    2.0
# 26    the prototype program gives a general idea of ...    3.0
# 27    to show that a certain part of the program wor...    3.0
# 28    Prototype programming is an approach to progra...    2.5
# 29    Refining and possibly the design if the testin...    3.5
# ...                                                 ...    ...
# 2412  if it has no children  you just delete it. if ...    4.0
# 2413  pointer to the child and delete it has 2 child...    3.0
# 2414  Log -LRB- n -RRB- where n is the number of nod...    5.0
# 2415                           log -LRB- n -RRB- steps     5.0
# 2416   The number of levels and the height of the tree     5.0
# 2417         It is the same as the height of the tree.     5.0
# 2418  Given n elements  it would take n divided by 2...    1.5
# 2419                                             log n     5.0
# 2420  Depends on the location of the node you are lo...    2.0
# 2421  2 to the power of n where n is the of levels t...    2.0
# 2422  The number of steps to search a node is the fu...    3.5
# 2423   It would take n divided by 2 elements  given n.     1.5
# 2424                                 log -LRB- n -RRB-     5.0
# 2425                               O -LRB- log n -RRB-     5.0
# 2426                   O -LRB- Log -LRB- n -RRB- -RRB-     5.0
# 2427  If the binary search tree is constructed effic...    5.0
# 2428                   N  n being the number of nodes.     4.0
# 2429  depending on the way that the tree is ordered ...    5.0
# 2430                                 log -LRB- n -RRB-     5.0
# 2431  worst case scenario equals the number of level...    5.0
# 2432              3 steps at most.  There are 3 cases.     1.5
# 2433  log -LRB- n -RRB- where n equals the total num...    5.0
# 2434  the same number of steps as the number of leve...    5.0
# 2435  to find a node in a binary search tree takes a...    5.0
# 2436  three steps visit the root node  then go to ri...    2.5
# 2437                                             log n     5.0
# 2438  -LRB- n -LRB- n minus 1 -RRB- -RRB- divided by 2     1.5
# 2439                                              2n-1     2.5
# 2440  it takes at most h steps  where h is the heigh...    5.0
# 2441  it depends on the install search tree then fro...    1.5
#
#                                            ref_modified  \
# 0     simulate behaviour portion desired software pr...
# 1     simulate behaviour portion desired software pr...
# 2     simulate behaviour portion desired software pr...
# 3     simulate behaviour portion desired software pr...
# 4     simulate behaviour portion desired software pr...
# 5     simulate behaviour portion desired software pr...
# 6     simulate behaviour portion desired software pr...
# 7     simulate behaviour portion desired software pr...
# 8     simulate behaviour portion desired software pr...
# 9     simulate behaviour portion desired software pr...
# 10    simulate behaviour portion desired software pr...
# 11    simulate behaviour portion desired software pr...
# 12    simulate behaviour portion desired software pr...
# 13    simulate behaviour portion desired software pr...
# 14    simulate behaviour portion desired software pr...
# 15    simulate behaviour portion desired software pr...
# 16    simulate behaviour portion desired software pr...
# 17    simulate behaviour portion desired software pr...
# 18    simulate behaviour portion desired software pr...
# 19    simulate behaviour portion desired software pr...
# 20    simulate behaviour portion desired software pr...
# 21    simulate behaviour portion desired software pr...
# 22    simulate behaviour portion desired software pr...
# 23    simulate behaviour portion desired software pr...
# 24    simulate behaviour portion desired software pr...
# 25    simulate behaviour portion desired software pr...
# 26    simulate behaviour portion desired software pr...
# 27    simulate behaviour portion desired software pr...
# 28    simulate behaviour portion desired software pr...
# 29    testing stage influence coding stage phase 5 s...
# ...                                                 ...
# 2412  find node replace leftmost node right subtree ...
# 2413  find node replace leftmost node right subtree ...
# 2414                                        height tree
# 2415                                        height tree
# 2416                                        height tree
# 2417                                        height tree
# 2418                                        height tree
# 2419                                        height tree
# 2420                                        height tree
# 2421                                        height tree
# 2422                                        height tree
# 2423                                        height tree
# 2424                                        height tree
# 2425                                        height tree
# 2426                                        height tree
# 2427                                        height tree
# 2428                                        height tree
# 2429                                        height tree
# 2430                                        height tree
# 2431                                        height tree
# 2432                                        height tree
# 2433                                        height tree
# 2434                                        height tree
# 2435                                        height tree
# 2436                                        height tree
# 2437                                        height tree
# 2438                                        height tree
# 2439                                        height tree
# 2440                                        height tree
# 2441                                        height tree
#
#                                        student_modified
# 0     high risk problem address prototype program ma...
# 1     simulate portion desired final product quick e...
# 2     prototype program simulates behavior portion d...
# 3     defined specification phase prototype stimulat...
# 4     used let user first idea completed program all...
# 5                  find problem error program finalized
# 6     address major issue creation program way accou...
# 7     break whole program prototype program simulate...
# 8     provide example model finished program perfom ...
# 9     simulating behavior portion desired software p...
# 10    program stimulates behavior portion desired so...
# 11    program simulates behavior portion desired sof...
# 12    lay basic give starting point actual problem s...
# 13                simulate problem solving part problem
# 14    prototype program provides basic groundwork en...
# 15    prototype program part specification phase sof...
# 16    program simulates behavior portion desired sof...
# 17    provides limited proof concept verify client a...
# 18      test main function program leaving finer detail
# 19    get early feedback user early stage developmen...
# 20    simulates behavior portion desired software pr...
# 21    simulates behavior portion desired software pr...
# 22    prototype program used problem solving collect...
# 23    ease understanding problem discussion ease und...
# 24    simulates behavior portion desired software pr...
# 25    role prototype program help spot key problem m...
# 26    prototype program give general idea end produc...
# 27              show certain part program work supposed
# 28    prototype programming approach programming ena...
# 29    refining possibly design testing phase reveals...
# ...                                                 ...
# 2412  child delete one child replace node whichever ...
# 2413  pointer child delete 2 child set node child de...
# 2414                        log lrb n rrb n number node
# 2415                                 log lrb n rrb step
# 2416                           number level height tree
# 2417                                        height tree
# 2418  given n element would take n divided 2 step fi...
# 2419                                              log n
# 2420  depends location node looking root one step el...
# 2421                      2 power n n level binary tree
# 2422         number step search node function n minus 1
# 2423             would take n divided 2 element given n
# 2424                                      log lrb n rrb
# 2425                                      lrb log n rrb
# 2426                              lrb log lrb n rrb rrb
# 2427  binary search tree constructed efficiently bes...
# 2428                                    n n number node
# 2429  depending way tree ordered could anywhere log ...
# 2430                                      log lrb n rrb
# 2431  worst case scenario equal number level tree ie...
# 2432                                      3 step 3 case
# 2433       log lrb n rrb n equal total number node tree
# 2434           number step number level generation tree
# 2435  find node binary search tree take number step ...
# 2436  three step visit root node go right subtree vi...
# 2437                                              log n
# 2438              lrb n lrb n minus 1 rrb rrb divided 2
# 2439                                                2n1
# 2440                          take h step h height tree
# 2441  depends install search tree whatever case repe...
#
# [2442 rows x 7 columns]

# %%
short_df = df[['student_answer','student_modified', 'grade','question']]
short_df['status'] = short_df['grade'] >= 3
short_df['status'] = short_df['status'].astype(int)
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
short_df
# Out:
#                                          student_answer  \
# 0     High risk problems are address in the prototyp...
# 1     To simulate portions of the desired final prod...
# 2     A prototype program simulates the behaviors of...
# 3     Defined in the Specification phase a prototype...
# 4     It is used to let the users have a first idea ...
# 5     To find problem and errors in a program before...
# 6     To address major issues in the creation of the...
# 7     you can break the whole program into prototype...
# 8     To provide an example or model of how the fini...
# 9     Simulating the behavior of only a portion of t...
# 10    A program that stimulates the behavior of port...
# 11    A program that simulates the behavior of porti...
# 12    To lay out the basics and give you a starting ...
# 13    To simulate problem solving for parts of the p...
# 14    A prototype program provides a basic groundwor...
# 15    A prototype program is a part of the Specifica...
# 16    Program that simulates the behavior of portion...
# 17    it provides a limited proof of concept to veri...
# 18    It tests the main function of the program whil...
# 19    To get early feedback from users in early stag...
# 20    it simulates the behavior of portions of the d...
# 21    It simulates the behavior of portions of the d...
# 22    A prototype program is used in problem solving...
# 23    To ease the understanding of problem under dis...
# 24    it simulates the behavior of portions of the d...
# 25    The role of a prototype program is to help spo...
# 26    the prototype program gives a general idea of ...
# 27    to show that a certain part of the program wor...
# 28    Prototype programming is an approach to progra...
# 29    Refining and possibly the design if the testin...
# ...                                                 ...
# 2412  if it has no children  you just delete it. if ...
# 2413  pointer to the child and delete it has 2 child...
# 2414  Log -LRB- n -RRB- where n is the number of nod...
# 2415                           log -LRB- n -RRB- steps
# 2416   The number of levels and the height of the tree
# 2417         It is the same as the height of the tree.
# 2418  Given n elements  it would take n divided by 2...
# 2419                                             log n
# 2420  Depends on the location of the node you are lo...
# 2421  2 to the power of n where n is the of levels t...
# 2422  The number of steps to search a node is the fu...
# 2423   It would take n divided by 2 elements  given n.
# 2424                                 log -LRB- n -RRB-
# 2425                               O -LRB- log n -RRB-
# 2426                   O -LRB- Log -LRB- n -RRB- -RRB-
# 2427  If the binary search tree is constructed effic...
# 2428                   N  n being the number of nodes.
# 2429  depending on the way that the tree is ordered ...
# 2430                                 log -LRB- n -RRB-
# 2431  worst case scenario equals the number of level...
# 2432              3 steps at most.  There are 3 cases.
# 2433  log -LRB- n -RRB- where n equals the total num...
# 2434  the same number of steps as the number of leve...
# 2435  to find a node in a binary search tree takes a...
# 2436  three steps visit the root node  then go to ri...
# 2437                                             log n
# 2438  -LRB- n -LRB- n minus 1 -RRB- -RRB- divided by 2
# 2439                                              2n-1
# 2440  it takes at most h steps  where h is the heigh...
# 2441  it depends on the install search tree then fro...
#
#                                        student_modified  grade  \
# 0     high risk problem address prototype program ma...    3.5
# 1     simulate portion desired final product quick e...    5.0
# 2     prototype program simulates behavior portion d...    4.0
# 3     defined specification phase prototype stimulat...    5.0
# 4     used let user first idea completed program all...    3.0
# 5                  find problem error program finalized    2.0
# 6     address major issue creation program way accou...    2.5
# 7     break whole program prototype program simulate...    5.0
# 8     provide example model finished program perfom ...    3.5
# 9     simulating behavior portion desired software p...    5.0
# 10    program stimulates behavior portion desired so...    5.0
# 11    program simulates behavior portion desired sof...    5.0
# 12    lay basic give starting point actual problem s...    2.0
# 13                simulate problem solving part problem    4.5
# 14    prototype program provides basic groundwork en...    2.0
# 15    prototype program part specification phase sof...    4.5
# 16    program simulates behavior portion desired sof...    5.0
# 17    provides limited proof concept verify client a...    2.0
# 18      test main function program leaving finer detail    2.0
# 19    get early feedback user early stage developmen...    2.5
# 20    simulates behavior portion desired software pr...    5.0
# 21    simulates behavior portion desired software pr...    5.0
# 22    prototype program used problem solving collect...    1.5
# 23    ease understanding problem discussion ease und...    2.5
# 24    simulates behavior portion desired software pr...    5.0
# 25    role prototype program help spot key problem m...    2.0
# 26    prototype program give general idea end produc...    3.0
# 27              show certain part program work supposed    3.0
# 28    prototype programming approach programming ena...    2.5
# 29    refining possibly design testing phase reveals...    3.5
# ...                                                 ...    ...
# 2412  child delete one child replace node whichever ...    4.0
# 2413  pointer child delete 2 child set node child de...    3.0
# 2414                        log lrb n rrb n number node    5.0
# 2415                                 log lrb n rrb step    5.0
# 2416                           number level height tree    5.0
# 2417                                        height tree    5.0
# 2418  given n element would take n divided 2 step fi...    1.5
# 2419                                              log n    5.0
# 2420  depends location node looking root one step el...    2.0
# 2421                      2 power n n level binary tree    2.0
# 2422         number step search node function n minus 1    3.5
# 2423             would take n divided 2 element given n    1.5
# 2424                                      log lrb n rrb    5.0
# 2425                                      lrb log n rrb    5.0
# 2426                              lrb log lrb n rrb rrb    5.0
# 2427  binary search tree constructed efficiently bes...    5.0
# 2428                                    n n number node    4.0
# 2429  depending way tree ordered could anywhere log ...    5.0
# 2430                                      log lrb n rrb    5.0
# 2431  worst case scenario equal number level tree ie...    5.0
# 2432                                      3 step 3 case    1.5
# 2433       log lrb n rrb n equal total number node tree    5.0
# 2434           number step number level generation tree    5.0
# 2435  find node binary search tree take number step ...    5.0
# 2436  three step visit root node go right subtree vi...    2.5
# 2437                                              log n    5.0
# 2438              lrb n lrb n minus 1 rrb rrb divided 2    1.5
# 2439                                                2n1    2.5
# 2440                          take h step h height tree    5.0
# 2441  depends install search tree whatever case repe...    1.5
#
#                                                question  status
# 0     What is the role of a prototype program in pro...       1
# 1     What is the role of a prototype program in pro...       1
# 2     What is the role of a prototype program in pro...       1
# 3     What is the role of a prototype program in pro...       1
# 4     What is the role of a prototype program in pro...       1
# 5     What is the role of a prototype program in pro...       0
# 6     What is the role of a prototype program in pro...       0
# 7     What is the role of a prototype program in pro...       1
# 8     What is the role of a prototype program in pro...       1
# 9     What is the role of a prototype program in pro...       1
# 10    What is the role of a prototype program in pro...       1
# 11    What is the role of a prototype program in pro...       1
# 12    What is the role of a prototype program in pro...       0
# 13    What is the role of a prototype program in pro...       1
# 14    What is the role of a prototype program in pro...       0
# 15    What is the role of a prototype program in pro...       1
# 16    What is the role of a prototype program in pro...       1
# 17    What is the role of a prototype program in pro...       0
# 18    What is the role of a prototype program in pro...       0
# 19    What is the role of a prototype program in pro...       0
# 20    What is the role of a prototype program in pro...       1
# 21    What is the role of a prototype program in pro...       1
# 22    What is the role of a prototype program in pro...       0
# 23    What is the role of a prototype program in pro...       0
# 24    What is the role of a prototype program in pro...       1
# 25    What is the role of a prototype program in pro...       0
# 26    What is the role of a prototype program in pro...       1
# 27    What is the role of a prototype program in pro...       1
# 28    What is the role of a prototype program in pro...       0
# 29    What stages in the software life cycle are inf...       1
# ...                                                 ...     ...
# 2412  How do you delete a node from a binary search ...       1
# 2413  How do you delete a node from a binary search ...       1
# 2414  How many steps does it take to search a node i...       1
# 2415  How many steps does it take to search a node i...       1
# 2416  How many steps does it take to search a node i...       1
# 2417  How many steps does it take to search a node i...       1
# 2418  How many steps does it take to search a node i...       0
# 2419  How many steps does it take to search a node i...       1
# 2420  How many steps does it take to search a node i...       0
# 2421  How many steps does it take to search a node i...       0
# 2422  How many steps does it take to search a node i...       1
# 2423  How many steps does it take to search a node i...       0
# 2424  How many steps does it take to search a node i...       1
# 2425  How many steps does it take to search a node i...       1
# 2426  How many steps does it take to search a node i...       1
# 2427  How many steps does it take to search a node i...       1
# 2428  How many steps does it take to search a node i...       1
# 2429  How many steps does it take to search a node i...       1
# 2430  How many steps does it take to search a node i...       1
# 2431  How many steps does it take to search a node i...       1
# 2432  How many steps does it take to search a node i...       0
# 2433  How many steps does it take to search a node i...       1
# 2434  How many steps does it take to search a node i...       1
# 2435  How many steps does it take to search a node i...       1
# 2436  How many steps does it take to search a node i...       0
# 2437  How many steps does it take to search a node i...       1
# 2438  How many steps does it take to search a node i...       0
# 2439  How many steps does it take to search a node i...       0
# 2440  How many steps does it take to search a node i...       1
# 2441  How many steps does it take to search a node i...       0
#
# [2442 rows x 5 columns]

# %%
# short_df['word_count'] = short_df['student_answer'].apply(lambda x: dict(Counter(x.split())))

# counting unique words in every student's answer
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(short_df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = short_df['status'].values

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
train_idx = [0, 5, 6 ,100]
X_train = X[train_idx]
y_train = Y[train_idx]
 
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
# lr = LogisticRegression()
nb = MultinomialNB()
learner = ActiveLearner(
#     estimator = lr,
    estimator = nb,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = 40
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
    print("\nQ: ", act_data.loc[int(query_idx),'question'])
    print("A: ",act_data.loc[int(query_idx),'student_answer'])
    print("Actual grade: ",y_pool[query_idx].reshape(1, ))
#     print(learner.sigma_)
    print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
    human_label = int(input("\nGive me a grade 0 or 1:"))
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=[human_label]
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X,Y))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X, Y)))
# Out:
# Q:  How many constructors can be created for a class?
# A:  1
# Actual grade:  [0]
# Class probabilities:  [[0.5 0.5]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 1: 0.382064
#
# Q:  What is the scope of global variables?
# A:  global variables have program scope -LRB- accessible anywhere in program -RRB-
# Actual grade:  [1]
# Class probabilities:  [[0.51438563 0.48561437]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 2: 0.428747
#
# Q:  What is the role of a header-file?
# A:  No
# Actual grade:  [0]
# Class probabilities:  [[0.5 0.5]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 3: 0.429156
#
# Q:  In one sentence  what is the main idea implemented by selection sort?
# A:  Find the minimum value in the list swap it with the value in the first position  repeat the steps above for remainder of the list -LRB- starting in the second position.
# Actual grade:  [1]
# Class probabilities:  [[0.49467885 0.50532115]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 4: 0.587633
#
# Q:  How many dimensions need to be specified when passing a multi-dimensional array as an argument to a function?
# A:  all of them.
# Actual grade:  [1]
# Class probabilities:  [[0.5 0.5]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 5: 0.841114
#
# Q:  What is the difference between an array that is declared as static and one that is not?
# A:  one declared as static is one that is already defined.  The program knows the length and the array from the start  whereas non-static arrays are declared or assigned later.
# Actual grade:  [1]
# Class probabilities:  [[0.50118284 0.49881716]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 6: 0.860360
#
# Q:  How can you implement a stack with a list?
# A:  Use the head as the top of the stack  only modify the head when you push or pop ... push would add a new item to the head  pop would remove the item from the head.
# Actual grade:  [1]
# Class probabilities:  [[0.49923601 0.50076399]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 7: 0.862408
#
# Q:  What is a binary tree?
# A:  A tree data structure in which each done has at most two children  typical called left and right nodes.  The right node is usually greater than the left node and the parent node.
# Actual grade:  [1]
# Class probabilities:  [[0.50163758 0.49836242]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 8: 0.865274
#
# Q:  Briefly describe the divide-and-conquer paradigm.
# A:  smaller parts are easier to compare than comparing the whole  so it divides the problem down in halves until it can easily compare  then works backwards putting it back together to give the solution.
# Actual grade:  [1]
# Class probabilities:  [[0.4992583 0.5007417]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 9: 0.868960
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  In RUP the stages in the software life cycle are influenced by the testing stage is: Elaboration phase-refined progject vision  iterative devilopment of core system  development of system requirements  more accurate time and cost estimates.  Construction phase-iterative development of remaining system.  Transition phase-testing and deployment of the system.
# Actual grade:  [1]
# Class probabilities:  [[0.49495638 0.50504362]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 10: 0.868550
#
# Q:  What is the main difference between a while and a do...while statement?
# A:  WHILE statement-The condition is checked for validity  then is repeated until the conditon is false.  Do ... WHILE statement --The code is performed at least once then checked for valid condition.  Will continue to
# Actual grade:  [1]
# Class probabilities:  [[0.49775639 0.50224361]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 11: 0.869779
#
# Q:  When does C++ create a default constructor?
# A:  at the very beginning when you run a complier  matter a fact in C plus plus it generates its own default constructor for the class provided if no other constructors have been provided by user
# Actual grade:  [1]
# Class probabilities:  [[0.49848688 0.50151312]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 12: 0.869779
#
# Q:  What does a function signature include?
# A:  The signature can include a result type and thrown errors.
# Actual grade:  [0]
# Class probabilities:  [[0.50894692 0.49105308]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 13: 0.860360
#
# Q:  What is the base case for a recursive implementation of merge sort?
# A:  The base case for a recursive implementation of merge sort is when the sequence being passed to merge sort has less than 2 elements.
# Actual grade:  [1]
# Class probabilities:  [[0.49339718 0.50660282]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 14: 0.860360
#
# Q:  What is a function signature?
# A:  A function signature is the return type and accepted pass value type it takes
# Actual grade:  [1]
# Class probabilities:  [[0.50388354 0.49611646]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 15: 0.866503
#
# Q:  What is the alternative way to solve a problem that could be solved through recursive functions?
# A:  the alternative way to solve a problem that could be solved using recursion is iteration.
# Actual grade:  [1]
# Class probabilities:  [[0.49404977 0.50595023]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 16: 0.867322
#
# Q:  What is a variable?
# A:  a placeholder to hold information used in the program ... for example: int can hold: 1  2  3  4  68  72  256  etc. float can hold: 1.54  55.55  1.24  5.657  8.8123  et. char can hold: A  B  C  D  E  F !  4  5  6  P  etc.
# Actual grade:  [1]
# Class probabilities:  [[0.48742066 0.51257934]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 17: 0.867322
#
# Q:  What are the different ways to pass a pointer to a function?
# A:  nonconst implies nonconst const implies nonconst nonconst implies const const implies const
# Actual grade:  [1]
# Class probabilities:  [[0.48944399 0.51055601]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 18: 0.867322
#
# Q:  Using an index outside the bounds of the array generates an error. Is this a compilation error or a run-time error?
# A:  compilation error
# Actual grade:  [0]
# Class probabilities:  [[0.51793605 0.48206395]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 19: 0.867322
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  1-specification  2-design  3-risk analysis  4-verification  5-coding  6-testing  7-refining  8-production  9-maintenance
# Actual grade:  [0]
# Class probabilities:  [[0.48349611 0.51650389]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 20: 0.867731
#
# Q:  What is the role of a header-file?
# A:  A header file is a cross communication method between source files  to help limit the size of each individual program.  Without header files a program will be 1 large lump of code and thus fairly hard to debug and traverse.
# Actual grade:  [1]
# Class probabilities:  [[0.49414801 0.50585199]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 21: 0.867322
#
# Q:  How are infix expressions evaluated by computers?
# A:  They are converted to post fix expressions.  It still follow the order of precedence for the operators.
# Actual grade:  [1]
# Class probabilities:  [[0.49554022 0.50445978]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 22: 0.867731
#
# Q:  What is a pointer?
# A:  A pointer is a way to get at another object.  Essentially it is a way to grab an instance of an object and then either pass that instance a message or retreive some data from that object.  A pointer is actually just an address of where an instance is held in memory.
# Actual grade:  [1]
# Class probabilities:  [[0.51730008 0.48269992]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 23: 0.868550
#
# Q:  What are the similarities between iteration and recursion?
# A:  both based on a control statement  both involve repitition  both involve a termination test  both gradually approach termination  both can potentially occur infinetly.
# Actual grade:  [1]
# Class probabilities:  [[0.47096333 0.52903667]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 24: 0.868550
#
# Q:  What is typically included in a class definition?
# A:  public section and private section  and there must be a semicolon to set the end
# Actual grade:  [0]
# Class probabilities:  [[0.4692411 0.5307589]]
# Give me a grade 0 or 1:0
# Accuracy after query no. 25: 0.859541
#
# Q:  What are the similarities between iteration and recursion?
# A:  Incorrectly writing either can result in infinite loops  both perform the same task over and over.
# Actual grade:  [1]
# Class probabilities:  [[0.49521532 0.50478468]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 26: 0.859541
#
# Q:  What is the main difference between a string of characters that is read into a variable of type string versus a variable of type char[]?
# A:  The character array has an end of line character at the end of it.
# Actual grade:  [1]
# Class probabilities:  [[0.50127831 0.49872169]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 27: 0.860360
#
# Q:  How many dimensions need to be specified when passing a multi-dimensional array as an argument to a function?
# A:  All of the dimensions must be specified.
# Actual grade:  [1]
# Class probabilities:  [[0.50223263 0.49776737]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 28: 0.860770
#
# Q:  What is the main disadvantage of a doubly-linked list over a basic linked list?
# A:  Insertion and deletion with a doubly linked list are more involved than with a singly linked list leaving more room for error and complex algorithms.
# Actual grade:  [1]
# Class probabilities:  [[0.4607662 0.5392338]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 29: 0.865684
#
# Q:  Using an index outside the bounds of the array generates an error. Is this a compilation error or a run-time error?
# A:  This is a run-time error.  The program will compile AND execute  so these errors can be difficult to debug.
# Actual grade:  [1]
# Class probabilities:  [[0.50313469 0.49686531]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 30: 0.863636
#
# Q:  Using an index outside the bounds of the array generates an error. Is this a compilation error or a run-time error?
# A:  compilation error.
# Actual grade:  [0]
# Class probabilities:  [[0.44586038 0.55413962]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 31: 0.866093
#
# Q:  What is the main disadvantage of a doubly-linked list over a basic linked list?
# A:  You have to keep up with where you are and you have to consider the predecessor and successor connections when inserting or deleting.
# Actual grade:  [1]
# Class probabilities:  [[0.46780304 0.53219696]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 32: 0.866093
#
# Q:  When does C++ create a default constructor?
# A:  during compilation
# Actual grade:  [1]
# Class probabilities:  [[0.53393278 0.46606722]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 33: 0.863636
#
# Q:  What is typically included in a class definition?
# A:  class name  two curly prenthesis  public and private
# Actual grade:  [0]
# Class probabilities:  [[0.45497398 0.54502602]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 34: 0.860360
#
# Q:  How are overloaded functions differentiated by the compiler?
# A:  They have the same name  just different parameters.
# Actual grade:  [1]
# Class probabilities:  [[0.51572476 0.48427524]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 35: 0.861589
#
# Q:  What are the access-specifiers that can be used in a C++ class definition?
# A:  functions and data members can be given access-specifications of public  private  and friend. public access is given to any functions or members not given specific access rights.
# Actual grade:  [1]
# Class probabilities:  [[0.5300455 0.4699545]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 36: 0.871826
#
# Q:  What are the elements typically included in a class definition?
# A:  Class name   semicoln at the end of the defination  private and bublic followed by ":"
# Actual grade:  [1]
# Class probabilities:  [[0.50757584 0.49242416]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 37: 0.872645
#
# Q:  Using an index outside the bounds of the array generates an error. Is this a compilation error or a run-time error?
# A:  compilation error
# Actual grade:  [0]
# Class probabilities:  [[0.44665079 0.55334921]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 38: 0.875512
#
# Q:  What is the role of a header-file?
# A:  Instruct the compiler on how to interface with library and user-written components.
# Actual grade:  [0]
# Class probabilities:  [[0.45615286 0.54384714]]
#
# Give me a grade 0 or 1:0
# Accuracy after query no. 39: 0.876331
#
# Q:  When does C++ create a default constructor?
# A:  The compiler will provide one when class does not explictly include a consructor.
# Actual grade:  [1]
# Class probabilities:  [[0.47940579 0.52059421]]
#
# Give me a grade 0 or 1:1
# Accuracy after query no. 40: 0.875921

# %% [markdown]
# ## Regular supervised task

# %%
from sklearn.model_selection import train_test_split

# %%
check_X = np.copy(X)
check_Y = np.copy(Y)

X_train,X_test,Y_train,Y_test = train_test_split(check_X,check_Y,test_size = 0.2)

# %%
# logisticRegr = LogisticRegression()
nb.fit(X_train, Y_train)
score = nb.score(X_test, Y_test)

print(score)
# Out:
# 0.869120654396728

# %%
supervised_accuracy = [score for x in range(0,40)]

plt.figure()
plt.plot(np.linspace(0,39,40),supervised_accuracy)
plt.plot(accuracy_list)
plt.title("Accuracy after every query")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.legend(["Supervised", "Active Learning"], loc="lower right")
plt.show()
