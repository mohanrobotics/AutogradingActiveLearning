# %% [markdown]
# # Multiclass classification - per_question_model using Naive Bayes(sultan)

# %% [markdown]
# # Importing and Preprocessing

# %% [markdown]
# ## Importing libraries

# %%
#### import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %%
df = pd.read_pickle("./sultan_features.pkl")
df = df.fillna(0)
short_df = df[['question_id','question','student_answer','student_modified','ref_modified', \
               'grade','length_ratio','aligned_score','aligned_score_demo','cos_similarity','cos_similarity_demo']]
short_df['grades_round']= short_df['grade'].apply(lambda x: round(x))
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# # Bag of words per question model

# %%
ques_id_list = list(short_df['question_id'].unique())
Accuracy_dict = {}
accuracy_list = []

n = 0

while  ques_id_list :
    print("question id:",ques_id_list[0])
    # FOR ONE BY ONE QUESTION
    ques_df = short_df[short_df['question_id'] == ques_id_list[0]]
    ques_df.reset_index(drop = True,inplace=True)
    

    # counting unique words in every student's answer
    CV = CountVectorizer()
    student_answer_count_vector = CV.fit_transform(ques_df['student_modified'])
    student_answer_count_vector = student_answer_count_vector.toarray()

    X = student_answer_count_vector
    Y = ques_df['grades_round'].values

    #getting the seed index
    classes = ques_df['grades_round'].unique()
    seed_index = []
    for i in classes:
        seed_index.append(ques_df['grades_round'][ques_df['grades_round']==i].index[0])
    print(seed_index)

    act_data = ques_df.copy()
#     accuracy_list = []

    # initialising
    train_idx = seed_index
    X_train = X[train_idx]
    y_train = Y[train_idx]

    # generating the pool
    X_pool = np.delete(X, train_idx, axis=0)
    y_pool = np.delete(Y, train_idx)

    act_data = act_data.drop(axis=0,index = train_idx)
    act_data.reset_index(drop = True,inplace=True)


    # initializing the active learner
    # lr = LogisticRegression()
    nb = MultinomialNB()
    learner = ActiveLearner(
    #     estimator = lr,
        estimator = nb,
    #     estimator = RandomForestClassifier(n_estimators=5),
    #     estimator=KNeighborsClassifier(n_neighbors=3),
        X_training=X_train, y_training=y_train
    )

    # pool-based sampling
    n_queries = math.ceil(len(ques_df)/10.0)
    print (n_queries)
    for idx in range(n_queries):
        query_idx, query_instance = learner.query(X_pool)
#         print("Question number: ", ques_id_list[0])
#         print("\nQ: ", act_data.loc[int(query_idx),'question'])
#         print("A: ",act_data.loc[int(query_idx),'student_answer'])
#         print("Actual grade: ",y_pool[query_idx].reshape(1, ))
#     #     print(learner.sigma_)
#         print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
#         human_label = int(input("\nGive me a grade 0 or 1:"))
        learner.teach(
            X=X_pool[query_idx].reshape(1, -1),
            y=y_pool[query_idx].reshape(1, )
        )

        # remove queried instance from pool
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx)

        act_data = act_data.drop(axis=0,index = query_idx)
        act_data.reset_index(drop=True, inplace=True)

#         accuracy_list.append(learner.score(X,Y))
#         print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X, Y)))
    accuracy_list.append(learner.score(X_pool, y_pool))
    Accuracy_dict[ques_id_list[0]] = accuracy_list
    print("By just labelling 10 % of total data accuracy of ", round(learner.score(X_pool, y_pool),2), "% is achieved on the unseen data"  )
    ques_id_list.pop(0)
    n += 1
# Out:
# question id: 1.1
# [0, 1, 4, 5]
# 3
# By just labelling 10 % of total data accuracy of  0.27 % is achieved on the unseen data
# question id: 1.2
# [0, 3, 5, 9, 23]
# 3
# By just labelling 10 % of total data accuracy of  0.43 % is achieved on the unseen data
# question id: 1.3
# [0, 1, 3, 5, 8]
# 3
# By just labelling 10 % of total data accuracy of  0.67 % is achieved on the unseen data
# question id: 1.4
# [0, 7, 12]
# 3
# By just labelling 10 % of total data accuracy of  1.0 % is achieved on the unseen data
# question id: 1.5
# [0, 1, 2, 12]
# 3
# By just labelling 10 % of total data accuracy of  0.77 % is achieved on the unseen data
# question id: 1.6
# [0, 1, 2, 3, 18]
# 3
# By just labelling 10 % of total data accuracy of  0.38 % is achieved on the unseen data
# question id: 1.7
# [0, 1, 25]
# 3
# By just labelling 10 % of total data accuracy of  0.83 % is achieved on the unseen data
# question id: 2.1
# [0, 1, 2, 5]
# 3
# By just labelling 10 % of total data accuracy of  0.52 % is achieved on the unseen data
# question id: 2.2
# [0, 1, 2, 4]
# 3
# By just labelling 10 % of total data accuracy of  0.57 % is achieved on the unseen data
# question id: 2.3
# [0, 1, 2, 3]
# 3
# By just labelling 10 % of total data accuracy of  0.57 % is achieved on the unseen data
# question id: 2.4
# [0, 1, 3, 5, 10]
# 3
# By just labelling 10 % of total data accuracy of  0.86 % is achieved on the unseen data
# question id: 2.5
# [0, 1, 3, 19]
# 3
# By just labelling 10 % of total data accuracy of  0.78 % is achieved on the unseen data
# question id: 2.6
# [0, 1, 2, 3]
# 3
# By just labelling 10 % of total data accuracy of  0.61 % is achieved on the unseen data
# question id: 2.7
# [0, 1, 3, 9, 15, 29]
# 3
# By just labelling 10 % of total data accuracy of  0.24 % is achieved on the unseen data
# question id: 3.1
# [0, 1, 2, 16]
# 4
# By just labelling 10 % of total data accuracy of  0.87 % is achieved on the unseen data
# question id: 3.2
# [0, 1, 5, 7]
# 4
# By just labelling 10 % of total data accuracy of  0.78 % is achieved on the unseen data
# question id: 3.3
# [0, 2, 3, 5, 17]
# 4
# By just labelling 10 % of total data accuracy of  0.73 % is achieved on the unseen data
# question id: 3.4
# [0, 1, 5]
# 4
# By just labelling 10 % of total data accuracy of  0.58 % is achieved on the unseen data
# question id: 3.5
# [0, 1, 12, 14]
# 4
# By just labelling 10 % of total data accuracy of  0.7 % is achieved on the unseen data
# question id: 3.6
# [0, 1, 5, 30]
# 4
# By just labelling 10 % of total data accuracy of  0.78 % is achieved on the unseen data
# question id: 3.7
# [0, 1, 6, 7, 12]
# 4
# By just labelling 10 % of total data accuracy of  0.82 % is achieved on the unseen data
# question id: 4.1
# [0, 2, 3, 7]
# 3
# By just labelling 10 % of total data accuracy of  0.52 % is achieved on the unseen data
# question id: 4.2
# [0, 1, 2, 6]
# 3
# By just labelling 10 % of total data accuracy of  0.3 % is achieved on the unseen data
# question id: 4.3
# [0, 1, 12, 16]
# 3
# By just labelling 10 % of total data accuracy of  0.61 % is achieved on the unseen data
# question id: 4.4
# [0, 1, 7, 24]
# 3
# By just labelling 10 % of total data accuracy of  0.52 % is achieved on the unseen data
# question id: 4.5
# [0, 1, 2, 17, 24]
# 3
# By just labelling 10 % of total data accuracy of  0.59 % is achieved on the unseen data
# question id: 4.6
# [0, 2, 24]
# 3
# By just labelling 10 % of total data accuracy of  0.92 % is achieved on the unseen data
# question id: 4.7
# [0, 1, 3, 11]
# 3
# By just labelling 10 % of total data accuracy of  0.0 % is achieved on the unseen data
# question id: 5.1
# [0, 1, 2, 4]
# 3
# By just labelling 10 % of total data accuracy of  0.33 % is achieved on the unseen data
# question id: 5.2
# [0, 1]
# 3
# By just labelling 10 % of total data accuracy of  0.87 % is achieved on the unseen data
# question id: 5.3
# [0, 2, 4, 5]
# 3
# By just labelling 10 % of total data accuracy of  0.43 % is achieved on the unseen data
# question id: 5.4
# [0, 3, 8]
# 3
# By just labelling 10 % of total data accuracy of  0.82 % is achieved on the unseen data
# question id: 6.1
# [0, 4]
# 3
# By just labelling 10 % of total data accuracy of  0.62 % is achieved on the unseen data
# question id: 6.2
# [0, 5, 8]
# 3
# By just labelling 10 % of total data accuracy of  0.8 % is achieved on the unseen data
# question id: 6.3
# [0, 5, 22]
# 3
# By just labelling 10 % of total data accuracy of  0.95 % is achieved on the unseen data
# question id: 6.4
# [0, 1, 5, 10, 25]
# 3
# By just labelling 10 % of total data accuracy of  0.67 % is achieved on the unseen data
# question id: 6.5
# [0, 2, 10, 11]
# 3
# By just labelling 10 % of total data accuracy of  0.58 % is achieved on the unseen data
# question id: 6.6
# [0, 1, 24]
# 3
# By just labelling 10 % of total data accuracy of  0.95 % is achieved on the unseen data
# question id: 6.7
# [0, 5]
# 3
# By just labelling 10 % of total data accuracy of  0.9 % is achieved on the unseen data
# question id: 7.1
# [0, 11, 17]
# 3
# By just labelling 10 % of total data accuracy of  0.95 % is achieved on the unseen data
# question id: 7.2
# [0, 3, 10]
# 3
# By just labelling 10 % of total data accuracy of  0.85 % is achieved on the unseen data
# question id: 7.3
# [0, 1, 6, 10]
# 3
# By just labelling 10 % of total data accuracy of  0.63 % is achieved on the unseen data
# question id: 7.4
# [0, 1, 3, 10, 14]
# 3
# By just labelling 10 % of total data accuracy of  0.33 % is achieved on the unseen data
# question id: 7.5
# [0, 1, 2, 8, 20]
# 3
# By just labelling 10 % of total data accuracy of  0.94 % is achieved on the unseen data
# question id: 7.6
# [0, 14, 24, 25]
# 3
# By just labelling 10 % of total data accuracy of  1.0 % is achieved on the unseen data
# question id: 7.7
# [0, 1, 3, 16, 25]
# 3
# By just labelling 10 % of total data accuracy of  0.5 % is achieved on the unseen data
# question id: 8.1
# [0, 2, 4]
# 3
# By just labelling 10 % of total data accuracy of  0.86 % is achieved on the unseen data
# question id: 8.2
# [0]
# 3
# By just labelling 10 % of total data accuracy of  1.0 % is achieved on the unseen data
# question id: 8.3
# [0, 2, 4, 6]
# 3
# By just labelling 10 % of total data accuracy of  0.05 % is achieved on the unseen data
# question id: 8.4
# [0, 1, 2, 6]
# 3
# By just labelling 10 % of total data accuracy of  0.25 % is achieved on the unseen data
# question id: 8.5
# [0, 3, 8, 21, 26]
# 3
# By just labelling 10 % of total data accuracy of  0.68 % is achieved on the unseen data
# question id: 8.6
# [0, 3, 4, 11]
# 3
# By just labelling 10 % of total data accuracy of  0.75 % is achieved on the unseen data
# question id: 8.7
# [0, 3, 5, 9]
# 3
# By just labelling 10 % of total data accuracy of  0.55 % is achieved on the unseen data
# question id: 9.1
# [0, 1]
# 3
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/naive_bayes.py:461: RuntimeWarning: divide by zero encountered in log
#   self.class_log_prior_ = (np.log(self.class_count_) -
# By just labelling 10 % of total data accuracy of  0.32 % is achieved on the unseen data
# question id: 9.2
# [0, 26]
# 3
# By just labelling 10 % of total data accuracy of  0.95 % is achieved on the unseen data
# question id: 9.3
# [0, 1, 3, 19]
# 3
# By just labelling 10 % of total data accuracy of  0.5 % is achieved on the unseen data
# question id: 9.4
# [0, 1, 4, 13]
# 3
# By just labelling 10 % of total data accuracy of  0.55 % is achieved on the unseen data
# question id: 9.5
# [0, 1, 9]
# 3
# By just labelling 10 % of total data accuracy of  0.76 % is achieved on the unseen data
# question id: 9.6
# [0, 4, 5]
# 3
# By just labelling 10 % of total data accuracy of  0.95 % is achieved on the unseen data
# question id: 9.7
# [0, 1]
# 3
# By just labelling 10 % of total data accuracy of  1.0 % is achieved on the unseen data
# question id: 10.1
# [0, 1, 5, 17]
# 3
# By just labelling 10 % of total data accuracy of  0.29 % is achieved on the unseen data
# question id: 10.2
# [0, 2, 12, 23]
# 3
# By just labelling 10 % of total data accuracy of  0.88 % is achieved on the unseen data
# question id: 10.3
# [0, 6, 7, 8]
# 3
# By just labelling 10 % of total data accuracy of  0.88 % is achieved on the unseen data
# question id: 10.4
# [0, 1, 12]
# 3
# By just labelling 10 % of total data accuracy of  0.44 % is achieved on the unseen data
# question id: 10.5
# [0, 5, 9]
# 3
# By just labelling 10 % of total data accuracy of  0.67 % is achieved on the unseen data
# question id: 10.6
# [0, 1, 2, 3]
# 3
# By just labelling 10 % of total data accuracy of  0.53 % is achieved on the unseen data
# question id: 10.7
# [0, 2, 6, 14, 23]
# 3
# By just labelling 10 % of total data accuracy of  0.69 % is achieved on the unseen data
# question id: 11.1
# [0, 2, 3, 7]
# 6
# By just labelling 10 % of total data accuracy of  0.72 % is achieved on the unseen data
# question id: 11.2
# [0, 12, 14, 15]
# 3
# By just labelling 10 % of total data accuracy of  0.91 % is achieved on the unseen data
# question id: 11.3
# [0, 1, 2, 6, 7, 12]
# 3
# By just labelling 10 % of total data accuracy of  0.52 % is achieved on the unseen data
# question id: 11.4
# [0, 1, 3, 5]
# 3
# By just labelling 10 % of total data accuracy of  0.83 % is achieved on the unseen data
# question id: 11.5
# [0, 2, 3]
# 3
# By just labelling 10 % of total data accuracy of  0.88 % is achieved on the unseen data
# question id: 11.6
# [0, 1, 29]
# 3
# By just labelling 10 % of total data accuracy of  0.92 % is achieved on the unseen data
# question id: 11.7
# [0, 1, 3, 5]
# 3
# By just labelling 10 % of total data accuracy of  0.3 % is achieved on the unseen data
# question id: 11.8
# [0, 1, 6, 8]
# 3
# By just labelling 10 % of total data accuracy of  0.61 % is achieved on the unseen data
# question id: 11.9
# [0, 1, 25]
# 3
# By just labelling 10 % of total data accuracy of  0.71 % is achieved on the unseen data
# question id: 12.1
# [0, 12, 27, 32]
# 6
# By just labelling 10 % of total data accuracy of  0.74 % is achieved on the unseen data
# question id: 12.2
# [0, 1, 2, 4, 8]
# 3
# By just labelling 10 % of total data accuracy of  0.45 % is achieved on the unseen data
# question id: 12.3
# [0, 1, 6, 21]
# 3
# By just labelling 10 % of total data accuracy of  0.48 % is achieved on the unseen data
# question id: 12.4
# [0, 2, 3, 15]
# 3
# By just labelling 10 % of total data accuracy of  0.38 % is achieved on the unseen data
# question id: 12.5
# [0, 11]
# 3
# By just labelling 10 % of total data accuracy of  1.0 % is achieved on the unseen data
# question id: 12.6
# [0, 2, 10]
# 3
# By just labelling 10 % of total data accuracy of  0.86 % is achieved on the unseen data
# question id: 12.7
# [0, 11]
# 3
# By just labelling 10 % of total data accuracy of  0.96 % is achieved on the unseen data
# question id: 12.8
# [0, 1, 2, 3, 22]
# 3
# By just labelling 10 % of total data accuracy of  0.2 % is achieved on the unseen data
# question id: 12.9
# [0, 4, 5, 19, 22]
# 3
# By just labelling 10 % of total data accuracy of  0.25 % is achieved on the unseen data

# %%
# for i in list(short_df['question_id'].unique()):
plt.figure()
plt.bar(np.linspace(0,len(accuracy_list)-1,len(accuracy_list)), accuracy_list)
plt.title("Accuracy for each quesstion")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.show()
