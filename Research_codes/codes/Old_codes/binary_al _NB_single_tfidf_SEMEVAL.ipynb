# %% [markdown]
# # Binary classification - single_model using Naive Bayes - tfidf(semeval)

# %% [markdown]
# # Importing and Preprocessing

# %% [markdown]
# ## Importing libraries

# %%
#### import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

from modAL.models import ActiveLearner
from modAL.models import ActiveLearner

import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %% [markdown]
# ## Importing files

# %%
original_data = pd.read_csv('../dataset/Semeval_dataset/train_semeval.csv')
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'reference_answer':'ref_answer'})

# %% [markdown]
# ## Preprocessing

# %%
df = original_data.copy()
#converting to lower case
df['ref_modified'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))


#lemmatisation
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))

# %% [markdown]
# # Gathering required features

# %%
short_df = df[['question','student_answer','student_modified','ref_modified' ,'grade']]
short_df['status'] = short_df['grade'] >= 3
short_df['status'] = short_df['status'].astype(int)

# FOR ONE BY ONE QUESTION
# short_df = short_df[short_df['question_id'] == ques_id_list[0]]
# ques_id_list.pop(0)
# ques_id_list
# ======================
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Bag of words

# %%
# short_df['word_count'] = short_df['student_answer'].apply(lambda x: dict(Counter(x.split())))

# counting unique words in every student's answer
Tf = TfidfVectorizer()
student_answer_count_vector = Tf.fit_transform(short_df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = short_df['status'].values

# %% [markdown]
# # Seeding

# %%
#getting the seed index
classes = short_df['status'].unique()
seed_index = []
for i in classes:
    seed_index.append(short_df['status'][short_df['status']==i].index[0])
seed_index
# Out:
# [0, 1]

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
train_idx = seed_index
X_train = X[train_idx]
y_train = Y[train_idx]
 
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
# lr = LogisticRegression()
nb = MultinomialNB()
learner = ActiveLearner(
#     estimator = lr,
    estimator = nb,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = int(len(X)/10)
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
#     print("\nQ: ", act_data.loc[int(query_idx),'question'])
#     print("A: ",act_data.loc[int(query_idx),'student_answer'])
#     print("Actual grade: ",y_pool[query_idx].reshape(1, ))
#     print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
#     human_label = int(input("\nGive me a grade 0 or 1:"))
    
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=y_pool[query_idx].reshape(1, )
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X,Y))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X_pool, y_pool)))
print("======================================")
print("By just labelling ",round(n_queries*100.0/len(X),2),"% of total data accuracy of ", round(learner.score(X_pool, y_pool),3), " % is achieved on the unseen data"  )
# Out:
# Accuracy after query no. 1: 0.771043
# Accuracy after query no. 2: 0.770997
# Accuracy after query no. 3: 0.770749
# Accuracy after query no. 4: 0.771106
# Accuracy after query no. 5: 0.770859
# Accuracy after query no. 6: 0.707922
# Accuracy after query no. 7: 0.750403
# Accuracy after query no. 8: 0.649728
# Accuracy after query no. 9: 0.238806
# Accuracy after query no. 10: 0.652612
# Accuracy after query no. 11: 0.249395
# Accuracy after query no. 12: 0.324319
# Accuracy after query no. 13: 0.268066
# Accuracy after query no. 14: 0.239653
# Accuracy after query no. 15: 0.234451
# Accuracy after query no. 16: 0.230862
# Accuracy after query no. 17: 0.237374
# Accuracy after query no. 18: 0.257628
# Accuracy after query no. 19: 0.277890
# Accuracy after query no. 20: 0.266222
# Accuracy after query no. 21: 0.253134
# Accuracy after query no. 22: 0.244692
# Accuracy after query no. 23: 0.254248
# Accuracy after query no. 24: 0.273518
# Accuracy after query no. 25: 0.325981
# Accuracy after query no. 26: 0.295892
# Accuracy after query no. 27: 0.365182
# Accuracy after query no. 28: 0.420328
# Accuracy after query no. 29: 0.383556
# Accuracy after query no. 30: 0.432044
# Accuracy after query no. 31: 0.397488
# Accuracy after query no. 32: 0.435461
# Accuracy after query no. 33: 0.401905
# Accuracy after query no. 34: 0.444962
# Accuracy after query no. 35: 0.655718
# Accuracy after query no. 36: 0.438045
# Accuracy after query no. 37: 0.409533
# Accuracy after query no. 38: 0.442889
# Accuracy after query no. 39: 0.422484
# Accuracy after query no. 40: 0.463162
# Accuracy after query no. 41: 0.443362
# Accuracy after query no. 42: 0.476548
# Accuracy after query no. 43: 0.662266
# Accuracy after query no. 44: 0.691651
# Accuracy after query no. 45: 0.714141
# Accuracy after query no. 46: 0.685633
# Accuracy after query no. 47: 0.710366
# Accuracy after query no. 48: 0.729417
# Accuracy after query no. 49: 0.709231
# Accuracy after query no. 50: 0.688428
# Accuracy after query no. 51: 0.706672
# Accuracy after query no. 52: 0.720651
# Accuracy after query no. 53: 0.700448
# Accuracy after query no. 54: 0.716467
# Accuracy after query no. 55: 0.701547
# Accuracy after query no. 56: 0.720220
# Accuracy after query no. 57: 0.728310
# Accuracy after query no. 58: 0.713791
# Accuracy after query no. 59: 0.723513
# Accuracy after query no. 60: 0.710006
# Accuracy after query no. 61: 0.724011
# Accuracy after query no. 62: 0.733537
# Accuracy after query no. 63: 0.740212
# Accuracy after query no. 64: 0.748929
# Accuracy after query no. 65: 0.754794
# Accuracy after query no. 66: 0.758009
# Accuracy after query no. 67: 0.761429
# Accuracy after query no. 68: 0.756685
# Accuracy after query no. 69: 0.759085
# Accuracy after query no. 70: 0.754952
# Accuracy after query no. 71: 0.756944
# Accuracy after query no. 72: 0.754443
# Accuracy after query no. 73: 0.745403
# Accuracy after query no. 74: 0.749438
# Accuracy after query no. 75: 0.757155
# Accuracy after query no. 76: 0.763648
# Accuracy after query no. 77: 0.762781
# Accuracy after query no. 78: 0.754756
# Accuracy after query no. 79: 0.760843
# Accuracy after query no. 80: 0.751790
# Accuracy after query no. 81: 0.757880
# Accuracy after query no. 82: 0.760696
# Accuracy after query no. 83: 0.754505
# Accuracy after query no. 84: 0.747082
# Accuracy after query no. 85: 0.751741
# Accuracy after query no. 86: 0.755583
# Accuracy after query no. 87: 0.760861
# Accuracy after query no. 88: 0.757122
# Accuracy after query no. 89: 0.759533
# Accuracy after query no. 90: 0.757023
# Accuracy after query no. 91: 0.758819
# Accuracy after query no. 92: 0.762051
# Accuracy after query no. 93: 0.764670
# Accuracy after query no. 94: 0.766058
# Accuracy after query no. 95: 0.768062
# Accuracy after query no. 96: 0.765141
# Accuracy after query no. 97: 0.767762
# Accuracy after query no. 98: 0.769973
# Accuracy after query no. 99: 0.767872
# Accuracy after query no. 100: 0.765359
# Accuracy after query no. 101: 0.765516
# Accuracy after query no. 102: 0.768140
# Accuracy after query no. 103: 0.770148
# Accuracy after query no. 104: 0.767222
# Accuracy after query no. 105: 0.768408
# Accuracy after query no. 106: 0.770212
# Accuracy after query no. 107: 0.768107
# Accuracy after query no. 108: 0.770941
# Accuracy after query no. 109: 0.771717
# Accuracy after query no. 110: 0.772699
# Accuracy after query no. 111: 0.770593
# Accuracy after query no. 112: 0.770340
# Accuracy after query no. 113: 0.768232
# Accuracy after query no. 114: 0.770039
# Accuracy after query no. 115: 0.771434
# Accuracy after query no. 116: 0.768914
# Accuracy after query no. 117: 0.770928
# Accuracy after query no. 118: 0.764488
# Accuracy after query no. 119: 0.763408
# Accuracy after query no. 120: 0.764390
# Accuracy after query no. 121: 0.765374
# Accuracy after query no. 122: 0.763880
# Accuracy after query no. 123: 0.765070
# Accuracy after query no. 124: 0.765022
# Accuracy after query no. 125: 0.765799
# Accuracy after query no. 126: 0.766371
# Accuracy after query no. 127: 0.767355
# Accuracy after query no. 128: 0.765241
# Accuracy after query no. 129: 0.761885
# Accuracy after query no. 130: 0.763697
# Accuracy after query no. 131: 0.758065
# Accuracy after query no. 132: 0.758014
# Accuracy after query no. 133: 0.764377
# Accuracy after query no. 134: 0.765363
# Accuracy after query no. 135: 0.765728
# Accuracy after query no. 136: 0.767543
# Accuracy after query no. 137: 0.768116
# Accuracy after query no. 138: 0.767861
# Accuracy after query no. 139: 0.773405
# Accuracy after query no. 140: 0.773358
# Accuracy after query no. 141: 0.773726
# Accuracy after query no. 142: 0.774093
# Accuracy after query no. 143: 0.773632
# Accuracy after query no. 144: 0.773378
# Accuracy after query no. 145: 0.773331
# Accuracy after query no. 146: 0.773076
# Accuracy after query no. 147: 0.771992
# Accuracy after query no. 148: 0.771737
# Accuracy after query no. 149: 0.772105
# Accuracy after query no. 150: 0.773095
# Accuracy after query no. 151: 0.774709
# Accuracy after query no. 152: 0.773624
# Accuracy after query no. 153: 0.774200
# Accuracy after query no. 154: 0.776023
# Accuracy after query no. 155: 0.775769
# Accuracy after query no. 156: 0.774683
# Accuracy after query no. 157: 0.774844
# Accuracy after query no. 158: 0.773550
# Accuracy after query no. 159: 0.774334
# Accuracy after query no. 160: 0.775120
# Accuracy after query no. 161: 0.775905
# Accuracy after query no. 162: 0.775858
# Accuracy after query no. 163: 0.776228
# Accuracy after query no. 164: 0.775349
# Accuracy after query no. 165: 0.775510
# Accuracy after query no. 166: 0.775463
# Accuracy after query no. 167: 0.775208
# Accuracy after query no. 168: 0.774745
# Accuracy after query no. 169: 0.774281
# Accuracy after query no. 170: 0.774859
# Accuracy after query no. 171: 0.774187
# Accuracy after query no. 172: 0.774140
# Accuracy after query no. 173: 0.774927
# Accuracy after query no. 174: 0.774671
# Accuracy after query no. 175: 0.772538
# Accuracy after query no. 176: 0.773116
# Accuracy after query no. 177: 0.774322
# Accuracy after query no. 178: 0.775318
# Accuracy after query no. 179: 0.775063
# Accuracy after query no. 180: 0.775433
# Accuracy after query no. 181: 0.776222
# Accuracy after query no. 182: 0.776385
# Accuracy after query no. 183: 0.776338
# Accuracy after query no. 184: 0.776291
# Accuracy after query no. 185: 0.776244
# Accuracy after query no. 186: 0.776407
# Accuracy after query no. 187: 0.776360
# Accuracy after query no. 188: 0.776522
# Accuracy after query no. 189: 0.776476
# Accuracy after query no. 190: 0.777057
# Accuracy after query no. 191: 0.776801
# Accuracy after query no. 192: 0.776963
# Accuracy after query no. 193: 0.776917
# Accuracy after query no. 194: 0.776870
# Accuracy after query no. 195: 0.777033
# Accuracy after query no. 196: 0.776986
# Accuracy after query no. 197: 0.777149
# Accuracy after query no. 198: 0.777941
# Accuracy after query no. 199: 0.777685
# Accuracy after query no. 200: 0.777428
# Accuracy after query no. 201: 0.777591
# Accuracy after query no. 202: 0.777754
# Accuracy after query no. 203: 0.778338
# Accuracy after query no. 204: 0.778711
# Accuracy after query no. 205: 0.778244
# Accuracy after query no. 206: 0.777778
# Accuracy after query no. 207: 0.777941
# Accuracy after query no. 208: 0.777895
# Accuracy after query no. 209: 0.777427
# Accuracy after query no. 210: 0.778432
# Accuracy after query no. 211: 0.778595
# Accuracy after query no. 212: 0.779811
# Accuracy after query no. 213: 0.779554
# Accuracy after query no. 214: 0.780349
# Accuracy after query no. 215: 0.779672
# Accuracy after query no. 216: 0.779836
# Accuracy after query no. 217: 0.779368
# Accuracy after query no. 218: 0.777848
# Accuracy after query no. 219: 0.779907
# Accuracy after query no. 220: 0.780072
# Accuracy after query no. 221: 0.780236
# Accuracy after query no. 222: 0.779557
# Accuracy after query no. 223: 0.780143
# Accuracy after query no. 224: 0.780519
# Accuracy after query no. 225: 0.780472
# Accuracy after query no. 226: 0.779371
# Accuracy after query no. 227: 0.780169
# Accuracy after query no. 228: 0.780333
# Accuracy after query no. 229: 0.780709
# Accuracy after query no. 230: 0.776652
# Accuracy after query no. 231: 0.776394
# Accuracy after query no. 232: 0.776769
# Accuracy after query no. 233: 0.777567
# Accuracy after query no. 234: 0.777520
# Accuracy after query no. 235: 0.777684
# Accuracy after query no. 236: 0.778060
# Accuracy after query no. 237: 0.781395
# Accuracy after query no. 238: 0.782406
# Accuracy after query no. 239: 0.782572
# Accuracy after query no. 240: 0.781257
# Accuracy after query no. 241: 0.782480
# Accuracy after query no. 242: 0.782222
# Accuracy after query no. 243: 0.782599
# Accuracy after query no. 244: 0.782130
# Accuracy after query no. 245: 0.782507
# Accuracy after query no. 246: 0.782461
# Accuracy after query no. 247: 0.783263
# Accuracy after query no. 248: 0.783429
# Accuracy after query no. 249: 0.783171
# Accuracy after query no. 250: 0.783549
# Accuracy after query no. 251: 0.783503
# Accuracy after query no. 252: 0.783033
# Accuracy after query no. 253: 0.782563
# Accuracy after query no. 254: 0.783153
# Accuracy after query no. 255: 0.783107
# Accuracy after query no. 256: 0.783273
# Accuracy after query no. 257: 0.783227
# Accuracy after query no. 258: 0.782969
# Accuracy after query no. 259: 0.782710
# Accuracy after query no. 260: 0.782664
# Accuracy after query no. 261: 0.782618
# Accuracy after query no. 262: 0.782784
# Accuracy after query no. 263: 0.783163
# Accuracy after query no. 264: 0.783117
# Accuracy after query no. 265: 0.783284
# Accuracy after query no. 266: 0.783450
# Accuracy after query no. 267: 0.783404
# Accuracy after query no. 268: 0.783784
# Accuracy after query no. 269: 0.783738
# Accuracy after query no. 270: 0.783692
# Accuracy after query no. 271: 0.783220
# Accuracy after query no. 272: 0.783600
# Accuracy after query no. 273: 0.783767
# Accuracy after query no. 274: 0.784360
# Accuracy after query no. 275: 0.783674
# Accuracy after query no. 276: 0.783841
# Accuracy after query no. 277: 0.783582
# Accuracy after query no. 278: 0.784389
# Accuracy after query no. 279: 0.784343
# Accuracy after query no. 280: 0.783870
# Accuracy after query no. 281: 0.783824
# Accuracy after query no. 282: 0.784205
# Accuracy after query no. 283: 0.783945
# Accuracy after query no. 284: 0.784326
# Accuracy after query no. 285: 0.784921
# Accuracy after query no. 286: 0.784661
# Accuracy after query no. 287: 0.784829
# Accuracy after query no. 288: 0.784783
# Accuracy after query no. 289: 0.786020
# Accuracy after query no. 290: 0.785332
# Accuracy after query no. 291: 0.784645
# Accuracy after query no. 292: 0.785241
# Accuracy after query no. 293: 0.785195
# Accuracy after query no. 294: 0.784721
# Accuracy after query no. 295: 0.784675
# Accuracy after query no. 296: 0.783772
# Accuracy after query no. 297: 0.782013
# Accuracy after query no. 298: 0.782180
# Accuracy after query no. 299: 0.785133
# Accuracy after query no. 300: 0.785087
# Accuracy after query no. 301: 0.784826
# Accuracy after query no. 302: 0.784780
# Accuracy after query no. 303: 0.784734
# Accuracy after query no. 304: 0.784474
# Accuracy after query no. 305: 0.784642
# Accuracy after query no. 306: 0.785025
# Accuracy after query no. 307: 0.783691
# Accuracy after query no. 308: 0.783430
# Accuracy after query no. 309: 0.783383
# Accuracy after query no. 310: 0.783122
# Accuracy after query no. 311: 0.783076
# Accuracy after query no. 312: 0.783459
# Accuracy after query no. 313: 0.784701
# Accuracy after query no. 314: 0.784870
# Accuracy after query no. 315: 0.784824
# Accuracy after query no. 316: 0.785637
# Accuracy after query no. 317: 0.785591
# Accuracy after query no. 318: 0.785975
# Accuracy after query no. 319: 0.786145
# Accuracy after query no. 320: 0.785883
# Accuracy after query no. 321: 0.785837
# Accuracy after query no. 322: 0.786006
# Accuracy after query no. 323: 0.786176
# Accuracy after query no. 324: 0.786130
# Accuracy after query no. 325: 0.785868
# Accuracy after query no. 326: 0.786037
# Accuracy after query no. 327: 0.785991
# Accuracy after query no. 328: 0.786161
# Accuracy after query no. 329: 0.785683
# Accuracy after query no. 330: 0.785853
# Accuracy after query no. 331: 0.786022
# Accuracy after query no. 332: 0.785976
# Accuracy after query no. 333: 0.785930
# Accuracy after query no. 334: 0.786316
# Accuracy after query no. 335: 0.786269
# Accuracy after query no. 336: 0.786439
# Accuracy after query no. 337: 0.786609
# Accuracy after query no. 338: 0.785915
# Accuracy after query no. 339: 0.785653
# Accuracy after query no. 340: 0.785606
# Accuracy after query no. 341: 0.785776
# Accuracy after query no. 342: 0.786595
# Accuracy after query no. 343: 0.786765
# Accuracy after query no. 344: 0.786719
# Accuracy after query no. 345: 0.786672
# Accuracy after query no. 346: 0.786193
# Accuracy after query no. 347: 0.786147
# Accuracy after query no. 348: 0.785884
# Accuracy after query no. 349: 0.786055
# Accuracy after query no. 350: 0.786441
# Accuracy after query no. 351: 0.786612
# Accuracy after query no. 352: 0.786782
# Accuracy after query no. 353: 0.786953
# Accuracy after query no. 354: 0.786907
# Accuracy after query no. 355: 0.786860
# Accuracy after query no. 356: 0.787248
# Accuracy after query no. 357: 0.787202
# Accuracy after query no. 358: 0.787373
# Accuracy after query no. 359: 0.787543
# Accuracy after query no. 360: 0.787280
# Accuracy after query no. 361: 0.787451
# Accuracy after query no. 362: 0.787622
# Accuracy after query no. 363: 0.787793
# Accuracy after query no. 364: 0.787964
# Accuracy after query no. 365: 0.786832
# Accuracy after query no. 366: 0.788090
# Accuracy after query no. 367: 0.787826
# Accuracy after query no. 368: 0.788650
# Accuracy after query no. 369: 0.788386
# Accuracy after query no. 370: 0.786600
# Accuracy after query no. 371: 0.787859
# Accuracy after query no. 372: 0.788030
# Accuracy after query no. 373: 0.788420
# Accuracy after query no. 374: 0.788156
# Accuracy after query no. 375: 0.788328
# Accuracy after query no. 376: 0.788499
# Accuracy after query no. 377: 0.788889
# Accuracy after query no. 378: 0.789279
# Accuracy after query no. 379: 0.789233
# Accuracy after query no. 380: 0.789187
# Accuracy after query no. 381: 0.789359
# Accuracy after query no. 382: 0.789313
# Accuracy after query no. 383: 0.789267
# Accuracy after query no. 384: 0.789221
# Accuracy after query no. 385: 0.789393
# Accuracy after query no. 386: 0.789347
# Accuracy after query no. 387: 0.789083
# Accuracy after query no. 388: 0.789037
# Accuracy after query no. 389: 0.789646
# Accuracy after query no. 390: 0.789600
# Accuracy after query no. 391: 0.788899
# Accuracy after query no. 392: 0.789071
# Accuracy after query no. 393: 0.789025
# Accuracy after query no. 394: 0.788979
# Accuracy after query no. 395: 0.788933
# Accuracy after query no. 396: 0.789105
# Accuracy after query no. 397: 0.789497
# Accuracy after query no. 398: 0.789888
# Accuracy after query no. 399: 0.790061
# Accuracy after query no. 400: 0.790015
# Accuracy after query no. 401: 0.790188
# Accuracy after query no. 402: 0.790142
# Accuracy after query no. 403: 0.790096
# Accuracy after query no. 404: 0.790050
# Accuracy after query no. 405: 0.790004
# Accuracy after query no. 406: 0.789958
# Accuracy after query no. 407: 0.790132
# Accuracy after query no. 408: 0.790524
# Accuracy after query no. 409: 0.790698
# Accuracy after query no. 410: 0.790432
# Accuracy after query no. 411: 0.790386
# Accuracy after query no. 412: 0.790340
# Accuracy after query no. 413: 0.790514
# Accuracy after query no. 414: 0.790468
# Accuracy after query no. 415: 0.790422
# Accuracy after query no. 416: 0.791035
# Accuracy after query no. 417: 0.790989
# Accuracy after query no. 418: 0.791163
# Accuracy after query no. 419: 0.791117
# Accuracy after query no. 420: 0.791071
# Accuracy after query no. 421: 0.791245
# Accuracy after query no. 422: 0.791419
# Accuracy after query no. 423: 0.791373
# Accuracy after query no. 424: 0.791327
# Accuracy after query no. 425: 0.791281
# Accuracy after query no. 426: 0.791456
# Accuracy after query no. 427: 0.791189
# Accuracy after query no. 428: 0.791143
# Accuracy after query no. 429: 0.791318
# Accuracy after query no. 430: 0.791492
# Accuracy after query no. 431: 0.791446
# Accuracy after query no. 432: 0.791400
# Accuracy after query no. 433: 0.791354
# Accuracy after query no. 434: 0.791529
# Accuracy after query no. 435: 0.791483
# Accuracy after query no. 436: 0.791437
# Accuracy after query no. 437: 0.791611
# Accuracy after query no. 438: 0.791565
# Accuracy after query no. 439: 0.791740
# Accuracy after query no. 440: 0.791694
# Accuracy after query no. 441: 0.791427
# Accuracy after query no. 442: 0.791602
# Accuracy after query no. 443: 0.791556
# Accuracy after query no. 444: 0.791731
# Accuracy after query no. 445: 0.791243
# Accuracy after query no. 446: 0.791197
# Accuracy after query no. 447: 0.791593
# Accuracy after query no. 448: 0.791768
# Accuracy after query no. 449: 0.791943
# Accuracy after query no. 450: 0.791897
# Accuracy after query no. 451: 0.791851
# Accuracy after query no. 452: 0.791805
# Accuracy after query no. 453: 0.791759
# Accuracy after query no. 454: 0.791934
# Accuracy after query no. 455: 0.791888
# Accuracy after query no. 456: 0.792064
# Accuracy after query no. 457: 0.792018
# Accuracy after query no. 458: 0.791972
# Accuracy after query no. 459: 0.792147
# Accuracy after query no. 460: 0.792101
# Accuracy after query no. 461: 0.792499
# Accuracy after query no. 462: 0.792675
# Accuracy after query no. 463: 0.792629
# Accuracy after query no. 464: 0.792583
# Accuracy after query no. 465: 0.792537
# Accuracy after query no. 466: 0.792491
# Accuracy after query no. 467: 0.792444
# Accuracy after query no. 468: 0.792398
# Accuracy after query no. 469: 0.792352
# Accuracy after query no. 470: 0.792306
# Accuracy after query no. 471: 0.792260
# Accuracy after query no. 472: 0.792436
# Accuracy after query no. 473: 0.792612
# Accuracy after query no. 474: 0.792789
# Accuracy after query no. 475: 0.792965
# Accuracy after query no. 476: 0.792919
# Accuracy after query no. 477: 0.793096
# Accuracy after query no. 478: 0.794386
# Accuracy after query no. 479: 0.794563
# Accuracy after query no. 480: 0.794740
# Accuracy after query no. 481: 0.795363
# Accuracy after query no. 482: 0.794649
# Accuracy after query no. 483: 0.794826
# Accuracy after query no. 484: 0.794780
# Accuracy after query no. 485: 0.794511
# Accuracy after query no. 486: 0.795135
# Accuracy after query no. 487: 0.794866
# Accuracy after query no. 488: 0.794597
# Accuracy after query no. 489: 0.794551
# Accuracy after query no. 490: 0.794505
# Accuracy after query no. 491: 0.795800
# Accuracy after query no. 492: 0.795084
# Accuracy after query no. 493: 0.795485
# Accuracy after query no. 494: 0.794992
# Accuracy after query no. 495: 0.795170
# Accuracy after query no. 496: 0.795124
# ======================================
# By just labelling  9.98 % of total data accuracy of  0.795  % is achieved on the unseen data

# %% [markdown]
# ## Regular supervised task

# %% [markdown]
# ## Importing test data

# %%
original_data = pd.read_csv('../dataset/Semeval_dataset/test1_semeval.csv')
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'reference_answer':'ref_answer'})
df = original_data.copy()
#converting to lower case
df['ref_modified'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))


#lemmatisation
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
short_df = df[['question','student_answer','student_modified','ref_modified' ,'grade']]
short_df['status'] = short_df['grade'] >= 3
short_df['status'] = short_df['status'].astype(int)
# counting unique words in every student's answer
student_answer_count_vector = Tf.transform(short_df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X_test = student_answer_count_vector
Y_test = short_df['status'].values 
# Y_test = np.reshape(Y_test, (-1, 1))
X_train = np.copy(X)
Y_train = np.copy(Y)
X_test.shape
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (540, 1908)

# %%
# logisticRegr = LogisticRegression()
naive_bayes = MultinomialNB()
naive_bayes.fit(X_train, Y_train)
score = naive_bayes.score(X_test, Y_test)

print(score)
# Out:
# 0.7685185185185185

# %%
supervised_accuracy = [score for x in range(0,n_queries)]

plt.figure()
plt.plot(np.linspace(0,n_queries-1,n_queries),supervised_accuracy)
plt.plot(accuracy_list)
plt.title("Accuracy after every query")
plt.xlabel("Query number")
plt.ylabel("Accuracy")
plt.legend(["Supervised", "Active Learning"], loc="lower right")
plt.show()

# %%
score = learner.score(X_test, Y_test)
score
# Out:
# 0.7685185185185185
