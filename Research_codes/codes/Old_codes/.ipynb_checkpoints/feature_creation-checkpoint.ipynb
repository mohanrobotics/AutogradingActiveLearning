# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from modAL.models import ActiveLearner
from modAL.models import ActiveLearner
import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline
from scipy import spatial

# %%
model("water")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fc36fa174411> in <module>()
# ----> 1 model("water")
#
# NameError: name 'model' is not defined

# %%
original_data = pd.read_csv('../dataset/mohler2_cleaned.csv')
original_data = original_data.drop(labels='Unnamed: 0', axis=1)
original_data = original_data.rename(columns={'question_number':'question_id','question_text':'question','answer_model':'ref_answer','answer_student':'student_answer','score_avg':'grade'})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-24a44a9a2318> in <module>()
# ----> 1 original_data = pd.read_csv('../dataset/mohler2_cleaned.csv')
#       2 original_data = original_data.drop(labels='Unnamed: 0', axis=1)
#       3 original_data = original_data.rename(columns={'question_number':'question_id','question_text':'question','answer_model':'ref_answer','answer_student':'student_answer','score_avg':'grade'})
#
# ~/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/anaconda3/envs/maluuba/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'../dataset/mohler2_cleaned.csv' does not exist

# %%
## question Demoting functions

def student_demoting(data):
    return " ".join(x for x in data['student_modified'].split() if x not in data['qn_modified'])

def ref_demoting(data):
    return " ".join(x for x in data['ref_modified'].split() if x not in data['qn_modified'])  


def word_embed(word):
    try:
        vec = model[word]
        vec = vec.reshape(1,vec.shape[0])
    except:
        vec = np.zeros((1, 300))
        #this is hardcoded
    return vec

def model_embed_ref(data):
    sentence  = data ['ref_modified']
    sentence_array = [word_embed(word) for word in sentence.split()]
    return np.sum(sentence_array,axis=0)

def model_embed_stud(data):
    sentence  = data ['stud_modified']
    sentence_array = [word_embed(word) for word in sentence.split()]
    return np.sum(sentence_array,axis=0)

# %%
df = original_data.copy()

#converting to lower case
df['qn_modified'] = df['question'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['ref_modified'] = df['ref_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['qn_modified'] = df['qn_modified'].str.replace('[^\w\s]','')
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['qn_modified'] = df['qn_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

##numeric removal
df['qn_modified'] = df['qn_modified'].apply(lambda x: " ".join(word for word in x.split() if not word.isdigit()))
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(word for word in x.split() if not word.isdigit()))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(word for word in x.split() if not word.isdigit()))



#lemmatisation
df['qn_modified'] = df['qn_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))

#question demoting
df['student_demoted'] = df.apply(student_demoting,axis=1)
df['ref_demoted'] = df.apply(ref_demoting,axis=1)

#length ratio
df['length_ratio'] = df['student_modified'].apply(lambda x: len(x)) / df['ref_modified'].apply(lambda x: len(x))

#rounding the grades
df['grades_round']= df['grade'].apply(lambda x: round(x))


# #getting the word embeddings
# df['embed_ref'] = df.apply(model_embed_ref,axis = 1)
# df['embed_stud'] = df.apply(model_embed_stud,axis = 1)

df
# Out:
#       question_id                                           question  \
# 0             1.1  What is the role of a prototype program in pro...
# 1             1.1  What is the role of a prototype program in pro...
# 2             1.1  What is the role of a prototype program in pro...
# 3             1.1  What is the role of a prototype program in pro...
# 4             1.1  What is the role of a prototype program in pro...
# 5             1.1  What is the role of a prototype program in pro...
# 6             1.1  What is the role of a prototype program in pro...
# 7             1.1  What is the role of a prototype program in pro...
# 8             1.1  What is the role of a prototype program in pro...
# 9             1.1  What is the role of a prototype program in pro...
# 10            1.1  What is the role of a prototype program in pro...
# 11            1.1  What is the role of a prototype program in pro...
# 12            1.1  What is the role of a prototype program in pro...
# 13            1.1  What is the role of a prototype program in pro...
# 14            1.1  What is the role of a prototype program in pro...
# 15            1.1  What is the role of a prototype program in pro...
# 16            1.1  What is the role of a prototype program in pro...
# 17            1.1  What is the role of a prototype program in pro...
# 18            1.1  What is the role of a prototype program in pro...
# 19            1.1  What is the role of a prototype program in pro...
# 20            1.1  What is the role of a prototype program in pro...
# 21            1.1  What is the role of a prototype program in pro...
# 22            1.1  What is the role of a prototype program in pro...
# 23            1.1  What is the role of a prototype program in pro...
# 24            1.1  What is the role of a prototype program in pro...
# 25            1.1  What is the role of a prototype program in pro...
# 26            1.1  What is the role of a prototype program in pro...
# 27            1.1  What is the role of a prototype program in pro...
# 28            1.1  What is the role of a prototype program in pro...
# 29            1.2  What stages in the software life cycle are inf...
# ...           ...                                                ...
# 2412         12.9  How do you delete a node from a binary search ...
# 2413         12.9  How do you delete a node from a binary search ...
# 2414         12.1  How many steps does it take to search a node i...
# 2415         12.1  How many steps does it take to search a node i...
# 2416         12.1  How many steps does it take to search a node i...
# 2417         12.1  How many steps does it take to search a node i...
# 2418         12.1  How many steps does it take to search a node i...
# 2419         12.1  How many steps does it take to search a node i...
# 2420         12.1  How many steps does it take to search a node i...
# 2421         12.1  How many steps does it take to search a node i...
# 2422         12.1  How many steps does it take to search a node i...
# 2423         12.1  How many steps does it take to search a node i...
# 2424         12.1  How many steps does it take to search a node i...
# 2425         12.1  How many steps does it take to search a node i...
# 2426         12.1  How many steps does it take to search a node i...
# 2427         12.1  How many steps does it take to search a node i...
# 2428         12.1  How many steps does it take to search a node i...
# 2429         12.1  How many steps does it take to search a node i...
# 2430         12.1  How many steps does it take to search a node i...
# 2431         12.1  How many steps does it take to search a node i...
# 2432         12.1  How many steps does it take to search a node i...
# 2433         12.1  How many steps does it take to search a node i...
# 2434         12.1  How many steps does it take to search a node i...
# 2435         12.1  How many steps does it take to search a node i...
# 2436         12.1  How many steps does it take to search a node i...
# 2437         12.1  How many steps does it take to search a node i...
# 2438         12.1  How many steps does it take to search a node i...
# 2439         12.1  How many steps does it take to search a node i...
# 2440         12.1  How many steps does it take to search a node i...
# 2441         12.1  How many steps does it take to search a node i...
#
#                                              ref_answer  \
# 0     To simulate the behaviour of portions of the d...
# 1     To simulate the behaviour of portions of the d...
# 2     To simulate the behaviour of portions of the d...
# 3     To simulate the behaviour of portions of the d...
# 4     To simulate the behaviour of portions of the d...
# 5     To simulate the behaviour of portions of the d...
# 6     To simulate the behaviour of portions of the d...
# 7     To simulate the behaviour of portions of the d...
# 8     To simulate the behaviour of portions of the d...
# 9     To simulate the behaviour of portions of the d...
# 10    To simulate the behaviour of portions of the d...
# 11    To simulate the behaviour of portions of the d...
# 12    To simulate the behaviour of portions of the d...
# 13    To simulate the behaviour of portions of the d...
# 14    To simulate the behaviour of portions of the d...
# 15    To simulate the behaviour of portions of the d...
# 16    To simulate the behaviour of portions of the d...
# 17    To simulate the behaviour of portions of the d...
# 18    To simulate the behaviour of portions of the d...
# 19    To simulate the behaviour of portions of the d...
# 20    To simulate the behaviour of portions of the d...
# 21    To simulate the behaviour of portions of the d...
# 22    To simulate the behaviour of portions of the d...
# 23    To simulate the behaviour of portions of the d...
# 24    To simulate the behaviour of portions of the d...
# 25    To simulate the behaviour of portions of the d...
# 26    To simulate the behaviour of portions of the d...
# 27    To simulate the behaviour of portions of the d...
# 28    To simulate the behaviour of portions of the d...
# 29    The testing stage can influence both the codin...
# ...                                                 ...
# 2412  Find the node  then replace it with the leftmo...
# 2413  Find the node  then replace it with the leftmo...
# 2414                            The height of the tree.
# 2415                            The height of the tree.
# 2416                            The height of the tree.
# 2417                            The height of the tree.
# 2418                            The height of the tree.
# 2419                            The height of the tree.
# 2420                            The height of the tree.
# 2421                            The height of the tree.
# 2422                            The height of the tree.
# 2423                            The height of the tree.
# 2424                            The height of the tree.
# 2425                            The height of the tree.
# 2426                            The height of the tree.
# 2427                            The height of the tree.
# 2428                            The height of the tree.
# 2429                            The height of the tree.
# 2430                            The height of the tree.
# 2431                            The height of the tree.
# 2432                            The height of the tree.
# 2433                            The height of the tree.
# 2434                            The height of the tree.
# 2435                            The height of the tree.
# 2436                            The height of the tree.
# 2437                            The height of the tree.
# 2438                            The height of the tree.
# 2439                            The height of the tree.
# 2440                            The height of the tree.
# 2441                            The height of the tree.
#
#                                          student_answer  grade  \
# 0     High risk problems are address in the prototyp...    3.5
# 1     To simulate portions of the desired final prod...    5.0
# 2     A prototype program simulates the behaviors of...    4.0
# 3     Defined in the Specification phase a prototype...    5.0
# 4     It is used to let the users have a first idea ...    3.0
# 5     To find problem and errors in a program before...    2.0
# 6     To address major issues in the creation of the...    2.5
# 7     you can break the whole program into prototype...    5.0
# 8     To provide an example or model of how the fini...    3.5
# 9     Simulating the behavior of only a portion of t...    5.0
# 10    A program that stimulates the behavior of port...    5.0
# 11    A program that simulates the behavior of porti...    5.0
# 12    To lay out the basics and give you a starting ...    2.0
# 13    To simulate problem solving for parts of the p...    4.5
# 14    A prototype program provides a basic groundwor...    2.0
# 15    A prototype program is a part of the Specifica...    4.5
# 16    Program that simulates the behavior of portion...    5.0
# 17    it provides a limited proof of concept to veri...    2.0
# 18    It tests the main function of the program whil...    2.0
# 19    To get early feedback from users in early stag...    2.5
# 20    it simulates the behavior of portions of the d...    5.0
# 21    It simulates the behavior of portions of the d...    5.0
# 22    A prototype program is used in problem solving...    1.5
# 23    To ease the understanding of problem under dis...    2.5
# 24    it simulates the behavior of portions of the d...    5.0
# 25    The role of a prototype program is to help spo...    2.0
# 26    the prototype program gives a general idea of ...    3.0
# 27    to show that a certain part of the program wor...    3.0
# 28    Prototype programming is an approach to progra...    2.5
# 29    Refining and possibly the design if the testin...    3.5
# ...                                                 ...    ...
# 2412  if it has no children  you just delete it. if ...    4.0
# 2413  pointer to the child and delete it has 2 child...    3.0
# 2414  Log -LRB- n -RRB- where n is the number of nod...    5.0
# 2415                           log -LRB- n -RRB- steps     5.0
# 2416   The number of levels and the height of the tree     5.0
# 2417         It is the same as the height of the tree.     5.0
# 2418  Given n elements  it would take n divided by 2...    1.5
# 2419                                             log n     5.0
# 2420  Depends on the location of the node you are lo...    2.0
# 2421  2 to the power of n where n is the of levels t...    2.0
# 2422  The number of steps to search a node is the fu...    3.5
# 2423   It would take n divided by 2 elements  given n.     1.5
# 2424                                 log -LRB- n -RRB-     5.0
# 2425                               O -LRB- log n -RRB-     5.0
# 2426                   O -LRB- Log -LRB- n -RRB- -RRB-     5.0
# 2427  If the binary search tree is constructed effic...    5.0
# 2428                   N  n being the number of nodes.     4.0
# 2429  depending on the way that the tree is ordered ...    5.0
# 2430                                 log -LRB- n -RRB-     5.0
# 2431  worst case scenario equals the number of level...    5.0
# 2432              3 steps at most.  There are 3 cases.     1.5
# 2433  log -LRB- n -RRB- where n equals the total num...    5.0
# 2434  the same number of steps as the number of leve...    5.0
# 2435  to find a node in a binary search tree takes a...    5.0
# 2436  three steps visit the root node  then go to ri...    2.5
# 2437                                             log n     5.0
# 2438  -LRB- n -LRB- n minus 1 -RRB- -RRB- divided by 2     1.5
# 2439                                              2n-1     2.5
# 2440  it takes at most h steps  where h is the heigh...    5.0
# 2441  it depends on the install search tree then fro...    1.5
#
#                                             qn_modified  \
# 0                role prototype program problem solving
# 1                role prototype program problem solving
# 2                role prototype program problem solving
# 3                role prototype program problem solving
# 4                role prototype program problem solving
# 5                role prototype program problem solving
# 6                role prototype program problem solving
# 7                role prototype program problem solving
# 8                role prototype program problem solving
# 9                role prototype program problem solving
# 10               role prototype program problem solving
# 11               role prototype program problem solving
# 12               role prototype program problem solving
# 13               role prototype program problem solving
# 14               role prototype program problem solving
# 15               role prototype program problem solving
# 16               role prototype program problem solving
# 17               role prototype program problem solving
# 18               role prototype program problem solving
# 19               role prototype program problem solving
# 20               role prototype program problem solving
# 21               role prototype program problem solving
# 22               role prototype program problem solving
# 23               role prototype program problem solving
# 24               role prototype program problem solving
# 25               role prototype program problem solving
# 26               role prototype program problem solving
# 27               role prototype program problem solving
# 28               role prototype program problem solving
# 29    stage software life cycle influenced testing s...
# ...                                                 ...
# 2412                     delete node binary search tree
# 2413                     delete node binary search tree
# 2414      many step take search node binary search tree
# 2415      many step take search node binary search tree
# 2416      many step take search node binary search tree
# 2417      many step take search node binary search tree
# 2418      many step take search node binary search tree
# 2419      many step take search node binary search tree
# 2420      many step take search node binary search tree
# 2421      many step take search node binary search tree
# 2422      many step take search node binary search tree
# 2423      many step take search node binary search tree
# 2424      many step take search node binary search tree
# 2425      many step take search node binary search tree
# 2426      many step take search node binary search tree
# 2427      many step take search node binary search tree
# 2428      many step take search node binary search tree
# 2429      many step take search node binary search tree
# 2430      many step take search node binary search tree
# 2431      many step take search node binary search tree
# 2432      many step take search node binary search tree
# 2433      many step take search node binary search tree
# 2434      many step take search node binary search tree
# 2435      many step take search node binary search tree
# 2436      many step take search node binary search tree
# 2437      many step take search node binary search tree
# 2438      many step take search node binary search tree
# 2439      many step take search node binary search tree
# 2440      many step take search node binary search tree
# 2441      many step take search node binary search tree
#
#                                            ref_modified  \
# 0     simulate behaviour portion desired software pr...
# 1     simulate behaviour portion desired software pr...
# 2     simulate behaviour portion desired software pr...
# 3     simulate behaviour portion desired software pr...
# 4     simulate behaviour portion desired software pr...
# 5     simulate behaviour portion desired software pr...
# 6     simulate behaviour portion desired software pr...
# 7     simulate behaviour portion desired software pr...
# 8     simulate behaviour portion desired software pr...
# 9     simulate behaviour portion desired software pr...
# 10    simulate behaviour portion desired software pr...
# 11    simulate behaviour portion desired software pr...
# 12    simulate behaviour portion desired software pr...
# 13    simulate behaviour portion desired software pr...
# 14    simulate behaviour portion desired software pr...
# 15    simulate behaviour portion desired software pr...
# 16    simulate behaviour portion desired software pr...
# 17    simulate behaviour portion desired software pr...
# 18    simulate behaviour portion desired software pr...
# 19    simulate behaviour portion desired software pr...
# 20    simulate behaviour portion desired software pr...
# 21    simulate behaviour portion desired software pr...
# 22    simulate behaviour portion desired software pr...
# 23    simulate behaviour portion desired software pr...
# 24    simulate behaviour portion desired software pr...
# 25    simulate behaviour portion desired software pr...
# 26    simulate behaviour portion desired software pr...
# 27    simulate behaviour portion desired software pr...
# 28    simulate behaviour portion desired software pr...
# 29    testing stage influence coding stage phase sol...
# ...                                                 ...
# 2412  find node replace leftmost node right subtree ...
# 2413  find node replace leftmost node right subtree ...
# 2414                                        height tree
# 2415                                        height tree
# 2416                                        height tree
# 2417                                        height tree
# 2418                                        height tree
# 2419                                        height tree
# 2420                                        height tree
# 2421                                        height tree
# 2422                                        height tree
# 2423                                        height tree
# 2424                                        height tree
# 2425                                        height tree
# 2426                                        height tree
# 2427                                        height tree
# 2428                                        height tree
# 2429                                        height tree
# 2430                                        height tree
# 2431                                        height tree
# 2432                                        height tree
# 2433                                        height tree
# 2434                                        height tree
# 2435                                        height tree
# 2436                                        height tree
# 2437                                        height tree
# 2438                                        height tree
# 2439                                        height tree
# 2440                                        height tree
# 2441                                        height tree
#
#                                        student_modified  \
# 0     high risk problem address prototype program ma...
# 1     simulate portion desired final product quick e...
# 2     prototype program simulates behavior portion d...
# 3     defined specification phase prototype stimulat...
# 4     used let user first idea completed program all...
# 5                  find problem error program finalized
# 6     address major issue creation program way accou...
# 7     break whole program prototype program simulate...
# 8     provide example model finished program perfom ...
# 9     simulating behavior portion desired software p...
# 10    program stimulates behavior portion desired so...
# 11    program simulates behavior portion desired sof...
# 12    lay basic give starting point actual problem s...
# 13                simulate problem solving part problem
# 14    prototype program provides basic groundwork en...
# 15    prototype program part specification phase sof...
# 16    program simulates behavior portion desired sof...
# 17    provides limited proof concept verify client a...
# 18      test main function program leaving finer detail
# 19    get early feedback user early stage developmen...
# 20    simulates behavior portion desired software pr...
# 21    simulates behavior portion desired software pr...
# 22    prototype program used problem solving collect...
# 23    ease understanding problem discussion ease und...
# 24    simulates behavior portion desired software pr...
# 25    role prototype program help spot key problem m...
# 26    prototype program give general idea end produc...
# 27              show certain part program work supposed
# 28    prototype programming approach programming ena...
# 29    refining possibly design testing phase reveals...
# ...                                                 ...
# 2412  child delete one child replace node whichever ...
# 2413  pointer child delete child set node child dele...
# 2414                        log lrb n rrb n number node
# 2415                                 log lrb n rrb step
# 2416                           number level height tree
# 2417                                        height tree
# 2418  given n element would take n divided step find...
# 2419                                              log n
# 2420  depends location node looking root one step el...
# 2421                        power n n level binary tree
# 2422           number step search node function n minus
# 2423               would take n divided element given n
# 2424                                      log lrb n rrb
# 2425                                      lrb log n rrb
# 2426                              lrb log lrb n rrb rrb
# 2427  binary search tree constructed efficiently bes...
# 2428                                    n n number node
# 2429  depending way tree ordered could anywhere log ...
# 2430                                      log lrb n rrb
# 2431  worst case scenario equal number level tree ie...
# 2432                                          step case
# 2433       log lrb n rrb n equal total number node tree
# 2434           number step number level generation tree
# 2435  find node binary search tree take number step ...
# 2436  three step visit root node go right subtree vi...
# 2437                                              log n
# 2438                  lrb n lrb n minus rrb rrb divided
# 2439                                                2n1
# 2440                          take h step h height tree
# 2441  depends install search tree whatever case repe...
#
#                                         student_demoted  \
# 0     high risk address make sure feasible may also ...
# 1     simulate portion desired final product quick e...
# 2     simulates behavior portion desired software pr...
# 3     defined specification phase stimulates behavio...
# 4     used let user first idea completed allow clien...
# 5                                  find error finalized
# 6     address major issue creation way account possi...
# 7                       break whole simulate part final
# 8     provide example model finished perfom provides...
# 9     simulating behavior portion desired software p...
# 10    stimulates behavior portion desired software p...
# 11    simulates behavior portion desired software pr...
# 12                 lay basic give starting point actual
# 13                                        simulate part
# 14    provides basic groundwork enhance improve solu...
# 15    part specification phase software employed ill...
# 16    simulates behavior portion desired software pr...
# 17    provides limited proof concept verify client a...
# 18              test main function leaving finer detail
# 19    get early feedback user early stage developmen...
# 20    simulates behavior portion desired software pr...
# 21    simulates behavior portion desired software pr...
# 22                                    used collect data
# 23     ease understanding discussion ease understanding
# 24    simulates behavior portion desired software pr...
# 25            help spot key may arise actual programing
# 26    give general idea end product without time eff...
# 27                      show certain part work supposed
# 28    programming approach programming enables one t...
# 29    refining possibly design phase reveals problem...
# ...                                                 ...
# 2412  child one child replace whichever child child ...
# 2413  pointer child child set child th middle take p...
# 2414                                 log lrb rrb number
# 2415                                        log lrb rrb
# 2416                                number level height
# 2417                                             height
# 2418         given element would divided find criterion
# 2419                                                log
# 2420  depends location looking root one else smaller...
# 2421                                        power level
# 2422                              number function minus
# 2423                        would divided element given
# 2424                                        log lrb rrb
# 2425                                        lrb log rrb
# 2426                                lrb log lrb rrb rrb
# 2427  constructed efficiently best case scenario lrb...
# 2428                                             number
# 2429   depending way ordered could anywhere log lrb rrb
# 2430                                        log lrb rrb
# 2431  worst case scenario equal number level ie fart...
# 2432                                               case
# 2433                     log lrb rrb equal total number
# 2434                     number number level generation
# 2435                                  find number level
# 2436  three visit root go right subtree visiting rig...
# 2437                                                log
# 2438                      lrb lrb minus rrb rrb divided
# 2439                                                2n1
# 2440                                             height
# 2441  depends install whatever case repeat back alon...
#
#                                             ref_demoted  length_ratio  \
# 0     simulate behaviour portion desired software pr...      2.666667
# 1     simulate behaviour portion desired software pr...      2.372549
# 2     simulate behaviour portion desired software pr...      1.764706
# 3     simulate behaviour portion desired software pr...      3.549020
# 4     simulate behaviour portion desired software pr...      3.156863
# 5     simulate behaviour portion desired software pr...      0.705882
# 6     simulate behaviour portion desired software pr...      1.980392
# 7     simulate behaviour portion desired software pr...      1.274510
# 8     simulate behaviour portion desired software pr...      2.882353
# 9     simulate behaviour portion desired software pr...      1.019608
# 10    simulate behaviour portion desired software pr...      1.176471
# 11    simulate behaviour portion desired software pr...      1.156863
# 12    simulate behaviour portion desired software pr...      1.019608
# 13    simulate behaviour portion desired software pr...      0.725490
# 14    simulate behaviour portion desired software pr...      1.490196
# 15    simulate behaviour portion desired software pr...      3.156863
# 16    simulate behaviour portion desired software pr...      1.156863
# 17    simulate behaviour portion desired software pr...      1.627451
# 18    simulate behaviour portion desired software pr...      0.921569
# 19    simulate behaviour portion desired software pr...      2.882353
# 20    simulate behaviour portion desired software pr...      1.000000
# 21    simulate behaviour portion desired software pr...      1.000000
# 22    simulate behaviour portion desired software pr...      1.156863
# 23    simulate behaviour portion desired software pr...      1.254902
# 24    simulate behaviour portion desired software pr...      1.000000
# 25    simulate behaviour portion desired software pr...      1.411765
# 26    simulate behaviour portion desired software pr...      1.725490
# 27    simulate behaviour portion desired software pr...      0.764706
# 28    simulate behaviour portion desired software pr...      5.588235
# 29               coding phase solution refinement phase      3.121622
# ...                                                 ...           ...
# 2412  find replace leftmost right subtree rightmost ...      1.452055
# 2413  find replace leftmost right subtree rightmost ...      1.013699
# 2414                                             height      2.454545
# 2415                                             height      1.636364
# 2416                                             height      2.181818
# 2417                                             height      1.000000
# 2418                                             height      5.727273
# 2419                                             height      0.454545
# 2420                                             height      9.636364
# 2421                                             height      2.454545
# 2422                                             height      3.636364
# 2423                                             height      3.272727
# 2424                                             height      1.181818
# 2425                                             height      1.181818
# 2426                                             height      1.909091
# 2427                                             height     26.909091
# 2428                                             height      1.363636
# 2429                                             height      5.636364
# 2430                                             height      1.181818
# 2431                                             height     10.000000
# 2432                                             height      0.818182
# 2433                                             height      4.000000
# 2434                                             height      3.636364
# 2435                                             height      5.090909
# 2436                                             height      7.727273
# 2437                                             height      0.454545
# 2438                                             height      3.000000
# 2439                                             height      0.272727
# 2440                                             height      2.272727
# 2441                                             height      7.000000
#
#       grades_round
# 0                4
# 1                5
# 2                4
# 3                5
# 4                3
# 5                2
# 6                2
# 7                5
# 8                4
# 9                5
# 10               5
# 11               5
# 12               2
# 13               4
# 14               2
# 15               4
# 16               5
# 17               2
# 18               2
# 19               2
# 20               5
# 21               5
# 22               2
# 23               2
# 24               5
# 25               2
# 26               3
# 27               3
# 28               2
# 29               4
# ...            ...
# 2412             4
# 2413             3
# 2414             5
# 2415             5
# 2416             5
# 2417             5
# 2418             2
# 2419             5
# 2420             2
# 2421             2
# 2422             4
# 2423             2
# 2424             5
# 2425             5
# 2426             5
# 2427             5
# 2428             4
# 2429             5
# 2430             5
# 2431             5
# 2432             2
# 2433             5
# 2434             5
# 2435             5
# 2436             2
# 2437             5
# 2438             2
# 2439             2
# 2440             5
# 2441             2
#
# [2442 rows x 12 columns]

# %%
# Bag of words creation
CV = CountVectorizer()
bag_of_word_vector = CV.fit_transform(df['student_modified'])
bag_of_word_vector = bag_of_word_vector.toarray()

# Tf-idf creation
Tf = TfidfVectorizer()
tfidf_vector = Tf.fit_transform(df['student_modified'])
tfidf_vector = tfidf_vector.toarray()

# %%
plt.figure()
ax = df['grades_round'].value_counts().plot(kind='bar')

ax.set_title('Class Distribution Over Entries')
ax.set_xlabel('Class')
ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
df = pd.read_pickle("./feature.pkl")

# %%
def cos_similarity(data):
    return 1 - spatial.distance.cosine(data['embed_ref'],data['embed_stud'])
def align_ratio(data):
    return (2*len(data['aligned'])) / (len(data['ref_answer'].split()) + len(data['student_answer'].split()))

# %%
def word_embed(word):
    try:
        vec = model[word]
        vec = vec.reshape(1,vec.shape[0])
    except:
        vec = np.zeros((1, 300))
        #this is hardcoded
    return vec

def model_embed_ref(data):
    sentence  = data ['ref_demoted']
    sentence_array = [word_embed(word) for word in sentence.split()]
    return np.sum(sentence_array,axis=0)

def model_embed_stud(data):
    sentence  = data ['student_demoted']
    sentence_array = [word_embed(word) for word in sentence.split()]
    return np.sum(sentence_array,axis=0)

def cos_similarity_demo(data):
    return 1 - spatial.distance.cosine(data['embed_ref_demoted'],data['embed_stud_demoted'])

def cos_similarity(data):
    return 1 - spatial.distance.cosine(data['embed_ref'],data['embed_stud'])

def align_ratio(data):
    return (2*len(data['aligned'])) / (len(data['ref_answer'].split()) + len(data['student_answer'].split()))

def align_ratio_demo(data):
    if (len(data['ref_demoted'].split()) + len(data['student_demoted'].split())) == 0:
        return 0.0
    else:
        return (2*len(data['aligned_demoted'])) / (len(data['ref_demoted'].split()) + len(data['student_demoted'].split()))

# %%
df['cos_similarity']=df.apply(cos_similarity, axis=1)
df['align_ratio']=df.apply(align_ratio, axis=1)

# %%
df['len_norm'] = df['length_ratio'].apply(lambda x: x/np.max(df['length_ratio']))

# %%
df
# Out:
#       question_id                                           question  \
# 0             1.1  What is the role of a prototype program in pro...
# 1             1.1  What is the role of a prototype program in pro...
# 2             1.1  What is the role of a prototype program in pro...
# 3             1.1  What is the role of a prototype program in pro...
# 4             1.1  What is the role of a prototype program in pro...
# 5             1.1  What is the role of a prototype program in pro...
# 6             1.1  What is the role of a prototype program in pro...
# 7             1.1  What is the role of a prototype program in pro...
# 8             1.1  What is the role of a prototype program in pro...
# 9             1.1  What is the role of a prototype program in pro...
# 10            1.1  What is the role of a prototype program in pro...
# 11            1.1  What is the role of a prototype program in pro...
# 12            1.1  What is the role of a prototype program in pro...
# 13            1.1  What is the role of a prototype program in pro...
# 14            1.1  What is the role of a prototype program in pro...
# 15            1.1  What is the role of a prototype program in pro...
# 16            1.1  What is the role of a prototype program in pro...
# 17            1.1  What is the role of a prototype program in pro...
# 18            1.1  What is the role of a prototype program in pro...
# 19            1.1  What is the role of a prototype program in pro...
# 20            1.1  What is the role of a prototype program in pro...
# 21            1.1  What is the role of a prototype program in pro...
# 22            1.1  What is the role of a prototype program in pro...
# 23            1.1  What is the role of a prototype program in pro...
# 24            1.1  What is the role of a prototype program in pro...
# 25            1.1  What is the role of a prototype program in pro...
# 26            1.1  What is the role of a prototype program in pro...
# 27            1.1  What is the role of a prototype program in pro...
# 28            1.1  What is the role of a prototype program in pro...
# 29            1.2  What stages in the software life cycle are inf...
# ...           ...                                                ...
# 2412         12.9  How do you delete a node from a binary search ...
# 2413         12.9  How do you delete a node from a binary search ...
# 2414         12.1  How many steps does it take to search a node i...
# 2415         12.1  How many steps does it take to search a node i...
# 2416         12.1  How many steps does it take to search a node i...
# 2417         12.1  How many steps does it take to search a node i...
# 2418         12.1  How many steps does it take to search a node i...
# 2419         12.1  How many steps does it take to search a node i...
# 2420         12.1  How many steps does it take to search a node i...
# 2421         12.1  How many steps does it take to search a node i...
# 2422         12.1  How many steps does it take to search a node i...
# 2423         12.1  How many steps does it take to search a node i...
# 2424         12.1  How many steps does it take to search a node i...
# 2425         12.1  How many steps does it take to search a node i...
# 2426         12.1  How many steps does it take to search a node i...
# 2427         12.1  How many steps does it take to search a node i...
# 2428         12.1  How many steps does it take to search a node i...
# 2429         12.1  How many steps does it take to search a node i...
# 2430         12.1  How many steps does it take to search a node i...
# 2431         12.1  How many steps does it take to search a node i...
# 2432         12.1  How many steps does it take to search a node i...
# 2433         12.1  How many steps does it take to search a node i...
# 2434         12.1  How many steps does it take to search a node i...
# 2435         12.1  How many steps does it take to search a node i...
# 2436         12.1  How many steps does it take to search a node i...
# 2437         12.1  How many steps does it take to search a node i...
# 2438         12.1  How many steps does it take to search a node i...
# 2439         12.1  How many steps does it take to search a node i...
# 2440         12.1  How many steps does it take to search a node i...
# 2441         12.1  How many steps does it take to search a node i...
#
#                                              ref_answer  \
# 0     To simulate the behaviour of portions of the d...
# 1     To simulate the behaviour of portions of the d...
# 2     To simulate the behaviour of portions of the d...
# 3     To simulate the behaviour of portions of the d...
# 4     To simulate the behaviour of portions of the d...
# 5     To simulate the behaviour of portions of the d...
# 6     To simulate the behaviour of portions of the d...
# 7     To simulate the behaviour of portions of the d...
# 8     To simulate the behaviour of portions of the d...
# 9     To simulate the behaviour of portions of the d...
# 10    To simulate the behaviour of portions of the d...
# 11    To simulate the behaviour of portions of the d...
# 12    To simulate the behaviour of portions of the d...
# 13    To simulate the behaviour of portions of the d...
# 14    To simulate the behaviour of portions of the d...
# 15    To simulate the behaviour of portions of the d...
# 16    To simulate the behaviour of portions of the d...
# 17    To simulate the behaviour of portions of the d...
# 18    To simulate the behaviour of portions of the d...
# 19    To simulate the behaviour of portions of the d...
# 20    To simulate the behaviour of portions of the d...
# 21    To simulate the behaviour of portions of the d...
# 22    To simulate the behaviour of portions of the d...
# 23    To simulate the behaviour of portions of the d...
# 24    To simulate the behaviour of portions of the d...
# 25    To simulate the behaviour of portions of the d...
# 26    To simulate the behaviour of portions of the d...
# 27    To simulate the behaviour of portions of the d...
# 28    To simulate the behaviour of portions of the d...
# 29    The testing stage can influence both the codin...
# ...                                                 ...
# 2412  Find the node  then replace it with the leftmo...
# 2413  Find the node  then replace it with the leftmo...
# 2414                            The height of the tree.
# 2415                            The height of the tree.
# 2416                            The height of the tree.
# 2417                            The height of the tree.
# 2418                            The height of the tree.
# 2419                            The height of the tree.
# 2420                            The height of the tree.
# 2421                            The height of the tree.
# 2422                            The height of the tree.
# 2423                            The height of the tree.
# 2424                            The height of the tree.
# 2425                            The height of the tree.
# 2426                            The height of the tree.
# 2427                            The height of the tree.
# 2428                            The height of the tree.
# 2429                            The height of the tree.
# 2430                            The height of the tree.
# 2431                            The height of the tree.
# 2432                            The height of the tree.
# 2433                            The height of the tree.
# 2434                            The height of the tree.
# 2435                            The height of the tree.
# 2436                            The height of the tree.
# 2437                            The height of the tree.
# 2438                            The height of the tree.
# 2439                            The height of the tree.
# 2440                            The height of the tree.
# 2441                            The height of the tree.
#
#                                          student_answer  grade  \
# 0     High risk problems are address in the prototyp...    3.5
# 1     To simulate portions of the desired final prod...    5.0
# 2     A prototype program simulates the behaviors of...    4.0
# 3     Defined in the Specification phase a prototype...    5.0
# 4     It is used to let the users have a first idea ...    3.0
# 5     To find problem and errors in a program before...    2.0
# 6     To address major issues in the creation of the...    2.5
# 7     you can break the whole program into prototype...    5.0
# 8     To provide an example or model of how the fini...    3.5
# 9     Simulating the behavior of only a portion of t...    5.0
# 10    A program that stimulates the behavior of port...    5.0
# 11    A program that simulates the behavior of porti...    5.0
# 12    To lay out the basics and give you a starting ...    2.0
# 13    To simulate problem solving for parts of the p...    4.5
# 14    A prototype program provides a basic groundwor...    2.0
# 15    A prototype program is a part of the Specifica...    4.5
# 16    Program that simulates the behavior of portion...    5.0
# 17    it provides a limited proof of concept to veri...    2.0
# 18    It tests the main function of the program whil...    2.0
# 19    To get early feedback from users in early stag...    2.5
# 20    it simulates the behavior of portions of the d...    5.0
# 21    It simulates the behavior of portions of the d...    5.0
# 22    A prototype program is used in problem solving...    1.5
# 23    To ease the understanding of problem under dis...    2.5
# 24    it simulates the behavior of portions of the d...    5.0
# 25    The role of a prototype program is to help spo...    2.0
# 26    the prototype program gives a general idea of ...    3.0
# 27    to show that a certain part of the program wor...    3.0
# 28    Prototype programming is an approach to progra...    2.5
# 29    Refining and possibly the design if the testin...    3.5
# ...                                                 ...    ...
# 2412  if it has no children  you just delete it. if ...    4.0
# 2413  pointer to the child and delete it has 2 child...    3.0
# 2414  Log -LRB- n -RRB- where n is the number of nod...    5.0
# 2415                           log -LRB- n -RRB- steps     5.0
# 2416   The number of levels and the height of the tree     5.0
# 2417         It is the same as the height of the tree.     5.0
# 2418  Given n elements  it would take n divided by 2...    1.5
# 2419                                             log n     5.0
# 2420  Depends on the location of the node you are lo...    2.0
# 2421  2 to the power of n where n is the of levels t...    2.0
# 2422  The number of steps to search a node is the fu...    3.5
# 2423   It would take n divided by 2 elements  given n.     1.5
# 2424                                 log -LRB- n -RRB-     5.0
# 2425                               O -LRB- log n -RRB-     5.0
# 2426                   O -LRB- Log -LRB- n -RRB- -RRB-     5.0
# 2427  If the binary search tree is constructed effic...    5.0
# 2428                   N  n being the number of nodes.     4.0
# 2429  depending on the way that the tree is ordered ...    5.0
# 2430                                 log -LRB- n -RRB-     5.0
# 2431  worst case scenario equals the number of level...    5.0
# 2432              3 steps at most.  There are 3 cases.     1.5
# 2433  log -LRB- n -RRB- where n equals the total num...    5.0
# 2434  the same number of steps as the number of leve...    5.0
# 2435  to find a node in a binary search tree takes a...    5.0
# 2436  three steps visit the root node  then go to ri...    2.5
# 2437                                             log n     5.0
# 2438  -LRB- n -LRB- n minus 1 -RRB- -RRB- divided by 2     1.5
# 2439                                              2n-1     2.5
# 2440  it takes at most h steps  where h is the heigh...    5.0
# 2441  it depends on the install search tree then fro...    1.5
#
#                                             qn_modified  \
# 0     what is the role of a prototype program in pro...
# 1     what is the role of a prototype program in pro...
# 2     what is the role of a prototype program in pro...
# 3     what is the role of a prototype program in pro...
# 4     what is the role of a prototype program in pro...
# 5     what is the role of a prototype program in pro...
# 6     what is the role of a prototype program in pro...
# 7     what is the role of a prototype program in pro...
# 8     what is the role of a prototype program in pro...
# 9     what is the role of a prototype program in pro...
# 10    what is the role of a prototype program in pro...
# 11    what is the role of a prototype program in pro...
# 12    what is the role of a prototype program in pro...
# 13    what is the role of a prototype program in pro...
# 14    what is the role of a prototype program in pro...
# 15    what is the role of a prototype program in pro...
# 16    what is the role of a prototype program in pro...
# 17    what is the role of a prototype program in pro...
# 18    what is the role of a prototype program in pro...
# 19    what is the role of a prototype program in pro...
# 20    what is the role of a prototype program in pro...
# 21    what is the role of a prototype program in pro...
# 22    what is the role of a prototype program in pro...
# 23    what is the role of a prototype program in pro...
# 24    what is the role of a prototype program in pro...
# 25    what is the role of a prototype program in pro...
# 26    what is the role of a prototype program in pro...
# 27    what is the role of a prototype program in pro...
# 28    what is the role of a prototype program in pro...
# 29    what stage in the software life cycle are infl...
# ...                                                 ...
# 2412  how do you delete a node from a binary search ...
# 2413  how do you delete a node from a binary search ...
# 2414  how many step doe it take to search a node in ...
# 2415  how many step doe it take to search a node in ...
# 2416  how many step doe it take to search a node in ...
# 2417  how many step doe it take to search a node in ...
# 2418  how many step doe it take to search a node in ...
# 2419  how many step doe it take to search a node in ...
# 2420  how many step doe it take to search a node in ...
# 2421  how many step doe it take to search a node in ...
# 2422  how many step doe it take to search a node in ...
# 2423  how many step doe it take to search a node in ...
# 2424  how many step doe it take to search a node in ...
# 2425  how many step doe it take to search a node in ...
# 2426  how many step doe it take to search a node in ...
# 2427  how many step doe it take to search a node in ...
# 2428  how many step doe it take to search a node in ...
# 2429  how many step doe it take to search a node in ...
# 2430  how many step doe it take to search a node in ...
# 2431  how many step doe it take to search a node in ...
# 2432  how many step doe it take to search a node in ...
# 2433  how many step doe it take to search a node in ...
# 2434  how many step doe it take to search a node in ...
# 2435  how many step doe it take to search a node in ...
# 2436  how many step doe it take to search a node in ...
# 2437  how many step doe it take to search a node in ...
# 2438  how many step doe it take to search a node in ...
# 2439  how many step doe it take to search a node in ...
# 2440  how many step doe it take to search a node in ...
# 2441  how many step doe it take to search a node in ...
#
#                                            ref_modified  \
# 0     to simulate the behaviour of portion of the de...
# 1     to simulate the behaviour of portion of the de...
# 2     to simulate the behaviour of portion of the de...
# 3     to simulate the behaviour of portion of the de...
# 4     to simulate the behaviour of portion of the de...
# 5     to simulate the behaviour of portion of the de...
# 6     to simulate the behaviour of portion of the de...
# 7     to simulate the behaviour of portion of the de...
# 8     to simulate the behaviour of portion of the de...
# 9     to simulate the behaviour of portion of the de...
# 10    to simulate the behaviour of portion of the de...
# 11    to simulate the behaviour of portion of the de...
# 12    to simulate the behaviour of portion of the de...
# 13    to simulate the behaviour of portion of the de...
# 14    to simulate the behaviour of portion of the de...
# 15    to simulate the behaviour of portion of the de...
# 16    to simulate the behaviour of portion of the de...
# 17    to simulate the behaviour of portion of the de...
# 18    to simulate the behaviour of portion of the de...
# 19    to simulate the behaviour of portion of the de...
# 20    to simulate the behaviour of portion of the de...
# 21    to simulate the behaviour of portion of the de...
# 22    to simulate the behaviour of portion of the de...
# 23    to simulate the behaviour of portion of the de...
# 24    to simulate the behaviour of portion of the de...
# 25    to simulate the behaviour of portion of the de...
# 26    to simulate the behaviour of portion of the de...
# 27    to simulate the behaviour of portion of the de...
# 28    to simulate the behaviour of portion of the de...
# 29    the testing stage can influence both the codin...
# ...                                                 ...
# 2412  find the node then replace it with the leftmos...
# 2413  find the node then replace it with the leftmos...
# 2414                             the height of the tree
# 2415                             the height of the tree
# 2416                             the height of the tree
# 2417                             the height of the tree
# 2418                             the height of the tree
# 2419                             the height of the tree
# 2420                             the height of the tree
# 2421                             the height of the tree
# 2422                             the height of the tree
# 2423                             the height of the tree
# 2424                             the height of the tree
# 2425                             the height of the tree
# 2426                             the height of the tree
# 2427                             the height of the tree
# 2428                             the height of the tree
# 2429                             the height of the tree
# 2430                             the height of the tree
# 2431                             the height of the tree
# 2432                             the height of the tree
# 2433                             the height of the tree
# 2434                             the height of the tree
# 2435                             the height of the tree
# 2436                             the height of the tree
# 2437                             the height of the tree
# 2438                             the height of the tree
# 2439                             the height of the tree
# 2440                             the height of the tree
# 2441                             the height of the tree
#
#                                        student_modified  \
# 0     high risk problem are address in the prototype...
# 1     to simulate portion of the desired final produ...
# 2     a prototype program simulates the behavior of ...
# 3     defined in the specification phase a prototype...
# 4     it is used to let the user have a first idea o...
# 5     to find problem and error in a program before ...
# 6     to address major issue in the creation of the ...
# 7     you can break the whole program into prototype...
# 8     to provide an example or model of how the fini...
# 9     simulating the behavior of only a portion of t...
# 10    a program that stimulates the behavior of port...
# 11    a program that simulates the behavior of porti...
# 12    to lay out the basic and give you a starting p...
# 13    to simulate problem solving for part of the pr...
# 14    a prototype program provides a basic groundwor...
# 15    a prototype program is a part of the specifica...
# 16    program that simulates the behavior of portion...
# 17    it provides a limited proof of concept to veri...
# 18    it test the main function of the program while...
# 19    to get early feedback from user in early stage...
# 20    it simulates the behavior of portion of the de...
# 21    it simulates the behavior of portion of the de...
# 22    a prototype program is used in problem solving...
# 23    to ease the understanding of problem under dis...
# 24    it simulates the behavior of portion of the de...
# 25    the role of a prototype program is to help spo...
# 26    the prototype program give a general idea of w...
# 27    to show that a certain part of the program wor...
# 28    prototype programming is an approach to progra...
# 29    refining and possibly the design if the testin...
# ...                                                 ...
# 2412  if it ha no child you just delete it if it onl...
# 2413  pointer to the child and delete it ha 2 child ...
# 2414        log lrb n rrb where n is the number of node
# 2415                                 log lrb n rrb step
# 2416     the number of level and the height of the tree
# 2417            it is the same a the height of the tree
# 2418  given n element it would take n divided by 2 s...
# 2419                                              log n
# 2420  depends on the location of the node you are lo...
# 2421  2 to the power of n where n is the of level th...
# 2422  the number of step to search a node is the fun...
# 2423       it would take n divided by 2 element given n
# 2424                                      log lrb n rrb
# 2425                                    o lrb log n rrb
# 2426                            o lrb log lrb n rrb rrb
# 2427  if the binary search tree is constructed effic...
# 2428                       n n being the number of node
# 2429  depending on the way that the tree is ordered ...
# 2430                                      log lrb n rrb
# 2431  worst case scenario equal the number of level ...
# 2432                    3 step at most there are 3 case
# 2433  log lrb n rrb where n equal the total number o...
# 2434  the same number of step a the number of level ...
# 2435  to find a node in a binary search tree take at...
# 2436  three step visit the root node then go to righ...
# 2437                                              log n
# 2438           lrb n lrb n minus 1 rrb rrb divided by 2
# 2439                                                2n1
# 2440  it take at most h step where h is the height o...
# 2441  it depends on the install search tree then fro...
#
#                                         student_demoted  \
# 0     high risk are address make sure that feasible ...
# 1     simulate portion desired final product with qu...
# 2     simulates behavior portion desired software pr...
# 3     defined specification phase stimulates behavio...
# 4     it used let user have first idea completed and...
# 5                    find and error before it finalized
# 6     address major issue creation there no way acco...
# 7          you can break whole into simulate part final
# 8     provide an example or model how finished shoul...
# 9     simulating behavior only portion desired softw...
# 10    that stimulates behavior portion desired softw...
# 11    that simulates behavior portion desired softwa...
# 12     lay out basic and give you starting point actual
# 13                                    simulate for part
# 14    provides basic groundwork from which further e...
# 15    part specification phase software it employed ...
# 16    that simulates behavior portion desired softwa...
# 17    it provides limited proof concept verify with ...
# 18    it test main function while leaving out finer ...
# 19    get early feedback from user early stage devel...
# 20    it simulates behavior portion desired software...
# 21    it simulates behavior portion desired software...
# 22                                used collect data for
# 23    ease understanding under discussion and ease u...
# 24    it simulates behavior portion desired software...
# 25    help spot key that may arise during actual pro...
# 26    give general idea end product will do without ...
# 27              show that certain part work it supposed
# 28    programming an approach programming that enabl...
# 29    refining and possibly design phase reveals pro...
# ...                                                 ...
# 2412  if it ha child just it if it only ha one child...
# 2413  pointer to the child and it ha 2 child set the...
# 2414                 log lrb rrb where is the number of
# 2415                                        log lrb rrb
# 2416          the number of level and the height of the
# 2417                      is the same the height of the
# 2418  given element would divided by 2 find the crit...
# 2419                                                log
# 2420  depends on the location of the you are looking...
# 2421        2 the power of where is the of level the ha
# 2422              the number of is the function minus 1
# 2423                   would divided by 2 element given
# 2424                                        log lrb rrb
# 2425                                        lrb log rrb
# 2426                                lrb log lrb rrb rrb
# 2427  if the is constructed efficiently best case sc...
# 2428                                being the number of
# 2429  depending on the way that the is ordered could...
# 2430                                        log lrb rrb
# 2431  worst case scenario equal the number of level ...
# 2432                         3 at most there are 3 case
# 2433    log lrb rrb where equal the total number of the
# 2434  the same number of the number of level or gene...
# 2435  find at most the same number of there are leve...
# 2436  three visit the root then go right subtree aft...
# 2437                                                log
# 2438               lrb lrb minus 1 rrb rrb divided by 2
# 2439                                                2n1
# 2440                 at most where is the height of the
# 2441  depends on the install then from there for wha...
#
#                                             ref_demoted  length_ratio  \
# 0     simulate behaviour portion desired software pr...      2.764706
# 1     simulate behaviour portion desired software pr...      2.911765
# 2     simulate behaviour portion desired software pr...      1.661765
# 3     simulate behaviour portion desired software pr...      3.632353
# 4     simulate behaviour portion desired software pr...      3.279412
# 5     simulate behaviour portion desired software pr...      0.897059
# 6     simulate behaviour portion desired software pr...      2.470588
# 7     simulate behaviour portion desired software pr...      1.352941
# 8     simulate behaviour portion desired software pr...      3.044118
# 9     simulate behaviour portion desired software pr...      1.073529
# 10    simulate behaviour portion desired software pr...      1.191176
# 11    simulate behaviour portion desired software pr...      1.176471
# 12    simulate behaviour portion desired software pr...      1.176471
# 13    simulate behaviour portion desired software pr...      0.750000
# 14    simulate behaviour portion desired software pr...      1.661765
# 15    simulate behaviour portion desired software pr...      3.264706
# 16    simulate behaviour portion desired software pr...      1.147059
# 17    simulate behaviour portion desired software pr...      1.676471
# 18    simulate behaviour portion desired software pr...      1.102941
# 19    simulate behaviour portion desired software pr...      3.058824
# 20    simulate behaviour portion desired software pr...      1.000000
# 21    simulate behaviour portion desired software pr...      1.000000
# 22    simulate behaviour portion desired software pr...      1.147059
# 23    simulate behaviour portion desired software pr...      1.544118
# 24    simulate behaviour portion desired software pr...      1.000000
# 25    simulate behaviour portion desired software pr...      1.514706
# 26    simulate behaviour portion desired software pr...      1.955882
# 27    simulate behaviour portion desired software pr...      0.985294
# 28    simulate behaviour portion desired software pr...      5.750000
# 29    can both coding phase 5 and solution refinemen...      3.233010
# ...                                                 ...           ...
# 2412  find the then replace it with the leftmost it ...      1.948718
# 2413  find the then replace it with the leftmost it ...      1.119658
# 2414                                  the height of the      1.954545
# 2415                                  the height of the      0.818182
# 2416                                  the height of the      2.090909
# 2417                                  the height of the      1.772727
# 2418                                  the height of the      3.545455
# 2419                                  the height of the      0.227273
# 2420                                  the height of the     10.318182
# 2421                                  the height of the      2.818182
# 2422                                  the height of the      2.772727
# 2423                                  the height of the      2.000000
# 2424                                  the height of the      0.590909
# 2425                                  the height of the      0.681818
# 2426                                  the height of the      1.045455
# 2427                                  the height of the     21.000000
# 2428                                  the height of the      1.272727
# 2429                                  the height of the      4.500000
# 2430                                  the height of the      0.590909
# 2431                                  the height of the      7.090909
# 2432                                  the height of the      1.409091
# 2433                                  the height of the      2.909091
# 2434                                  the height of the      3.227273
# 2435                                  the height of the      4.772727
# 2436                                  the height of the      4.681818
# 2437                                  the height of the      0.227273
# 2438                                  the height of the      1.818182
# 2439                                  the height of the      0.136364
# 2440                                  the height of the      2.545455
# 2441                                  the height of the      6.136364
#
#       grades_round                                          embed_ref  \
# 0                4  [[0.31087402343750004, 0.12618164062500004, 0....
# 1                5  [[0.31087402343750004, 0.12618164062500004, 0....
# 2                4  [[0.31087402343750004, 0.12618164062500004, 0....
# 3                5  [[0.31087402343750004, 0.12618164062500004, 0....
# 4                3  [[0.31087402343750004, 0.12618164062500004, 0....
# 5                2  [[0.31087402343750004, 0.12618164062500004, 0....
# 6                2  [[0.31087402343750004, 0.12618164062500004, 0....
# 7                5  [[0.31087402343750004, 0.12618164062500004, 0....
# 8                4  [[0.31087402343750004, 0.12618164062500004, 0....
# 9                5  [[0.31087402343750004, 0.12618164062500004, 0....
# 10               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 11               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 12               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 13               4  [[0.31087402343750004, 0.12618164062500004, 0....
# 14               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 15               4  [[0.31087402343750004, 0.12618164062500004, 0....
# 16               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 17               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 18               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 19               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 20               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 21               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 22               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 23               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 24               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 25               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 26               3  [[0.31087402343750004, 0.12618164062500004, 0....
# 27               3  [[0.31087402343750004, 0.12618164062500004, 0....
# 28               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 29               4  [[0.4525048828125, 0.905751953125, 0.370107421...
# ...            ...                                                ...
# 2412             4  [[1.05466796875, -0.5786061096191406, 0.897563...
# 2413             3  [[1.05466796875, -0.5786061096191406, 0.897563...
# 2414             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2415             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2416             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2417             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2418             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2419             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2420             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2421             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2422             4  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2423             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2424             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2425             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2426             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2427             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2428             4  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2429             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2430             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2431             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2432             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2433             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2434             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2435             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2436             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2437             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2438             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2439             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2440             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2441             2  [[0.76439453125, 0.59056640625, -0.10254882812...
#
#                                              embed_stud  cos_similarity  \
# 0     [[-0.34491821289062496, 0.24433044433593754, 1...        0.655149
# 1     [[2.425458984375, 0.7010594177246094, 0.774389...        0.697226
# 2     [[-0.10392089843749999, 0.23617462158203129, 0...        0.839926
# 3     [[0.34676391601562506, 0.9747241210937501, 1.0...        0.742990
# 4     [[0.5336535644531251, 0.509168930053711, 1.255...        0.724661
# 5     [[0.13824584960937503, -0.00038215637207028585...        0.458110
# 6     [[0.23454956054687504, 0.8501024627685547, 1.3...        0.560865
# 7     [[0.332530517578125, 0.6316943359375, 0.691752...        0.663866
# 8     [[0.05676513671875005, 1.2948251342773438, 0.9...        0.562880
# 9     [[0.43350341796875, 0.05172851562500003, 0.363...        0.902768
# 10    [[0.14334228515625003, 0.23910644531250003, 0....        0.809672
# 11    [[0.23489501953125003, 0.23336914062500003, 0....        0.889566
# 12    [[1.316468505859375, -0.04476806640624997, 0.5...        0.503739
# 13    [[0.38663818359375, 0.18162109375000002, -0.09...        0.521211
# 14    [[-0.6906201171874999, 0.4286511611938477, 0.0...        0.569116
# 15    [[0.7327722167968751, 0.7340367889404298, 1.55...        0.627678
# 16    [[0.22489501953125002, 0.22336914062500002, 0....        0.889604
# 17    [[-0.24441406249999997, -0.6598670196533203, -...        0.664602
# 18    [[0.67961669921875, 0.036624679565429696, 0.67...        0.569071
# 19    [[0.37262207031250005, 0.9042926406860352, 1.0...        0.633415
# 20    [[0.40861083984375, 0.1551451873779297, 0.395,...        0.907300
# 21    [[0.40861083984375, 0.1551451873779297, 0.395,...        0.907300
# 22    [[0.45408203125, 0.2513232421875, 0.2932849121...        0.554236
# 23    [[0.24287109375000004, 0.7482421875, -0.230456...        0.516916
# 24    [[0.40861083984375, 0.1551451873779297, 0.395,...        0.907300
# 25    [[0.331116943359375, 0.6653759765625, 0.574616...        0.603787
# 26    [[0.9762030029296875, 0.901083984375, 1.016318...        0.630681
# 27    [[0.29389648437500004, 0.3487308502197266, 0.8...        0.515416
# 28    [[0.7873583984375001, 1.935110206604004, 1.471...        0.634564
# 29    [[-0.15825195312499996, 0.694643783569336, 3.1...        0.725834
# ...                                                 ...             ...
# 2412  [[3.6437084960937494, -1.3757750701904297, 3.0...        0.763812
# 2413  [[1.9301269531249998, 0.7210605621337891, 1.81...        0.773599
# 2414  [[0.339234619140625, -0.20107910156249997, -0....        0.374598
# 2415  [[-0.06624267578124998, 0.12498046875, -0.2155...        0.214974
# 2416  [[0.85373046875, 0.6771405029296875, 0.0973828...        0.897911
# 2417  [[1.116893310546875, 0.6198668670654297, 0.218...        0.882932
# 2418  [[0.5539453125, 0.1284215545654297, 0.44505859...        0.367725
# 2419  [[0.11981201, -0.0034179688, -0.34594727, 0.10...        0.200887
# 2420  [[1.86367919921875, -0.3933474731445312, 2.994...        0.453676
# 2421  [[1.170289306640625, 0.3023846435546875, 0.647...        0.585515
# 2422  [[0.390565185546875, -0.3468310546875, 0.24667...        0.383735
# 2423  [[0.49865723, -0.09520149, 0.58691406, 0.91845...        0.322014
# 2424  [[0.13981201171875002, 0.016582031250000004, -...        0.187241
# 2425  [[-0.02425048828124999, 0.09861328124999999, -...        0.185939
# 2426  [[-0.004250488281249989, 0.11861328124999998, ...        0.175073
# 2427  [[4.394963378906248, 1.3501769256591798, 1.676...        0.617910
# 2428  [[0.005483398437500002, -0.10462402343749999, ...        0.306180
# 2429  [[1.160218505859375, -0.14454719543457029, 0.8...        0.554343
# 2430  [[0.13981201171875002, 0.016582031250000004, -...        0.187241
# 2431  [[0.7894091796875, 0.37974788665771486, 2.1871...        0.578449
# 2432  [[0.0871582, -0.2479248, 0.34973145, 0.4655761...        0.305757
# 2433  [[1.01699951171875, -0.14053222656249997, 0.04...        0.582611
# 2434  [[0.9424546051025391, 0.6572430419921875, 0.86...        0.633996
# 2435  [[1.3814111328125, 0.12925964355468755, 0.1615...        0.623290
# 2436  [[0.10518554687500002, 0.794486083984375, 0.91...        0.395713
# 2437  [[0.11981201, -0.0034179688, -0.34594727, 0.10...        0.200887
# 2438  [[0.12465576171875001, -0.43485351562499996, 0...        0.177868
# 2439  [[0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0....       -0.155715
# 2440  [[0.04567504882812501, 0.9564244842529297, 0.3...        0.713810
# 2441  [[1.8198449707031248, 0.5125815963745117, 0.80...        0.556482
#
#       len_norm
# 0     0.056231
# 1     0.059222
# 2     0.033799
# 3     0.073878
# 4     0.066700
# 5     0.018245
# 6     0.050249
# 7     0.027517
# 8     0.061914
# 9     0.021834
# 10    0.024227
# 11    0.023928
# 12    0.023928
# 13    0.015254
# 14    0.033799
# 15    0.066401
# 16    0.023330
# 17    0.034098
# 18    0.022433
# 19    0.062213
# 20    0.020339
# 21    0.020339
# 22    0.023330
# 23    0.031406
# 24    0.020339
# 25    0.030808
# 26    0.039781
# 27    0.020040
# 28    0.116949
# 29    0.065756
# ...        ...
# 2412  0.039635
# 2413  0.022773
# 2414  0.039753
# 2415  0.016641
# 2416  0.042527
# 2417  0.036055
# 2418  0.072111
# 2419  0.004622
# 2420  0.209861
# 2421  0.057319
# 2422  0.056394
# 2423  0.040678
# 2424  0.012018
# 2425  0.013867
# 2426  0.021263
# 2427  0.427119
# 2428  0.025886
# 2429  0.091525
# 2430  0.012018
# 2431  0.144222
# 2432  0.028659
# 2433  0.059168
# 2434  0.065639
# 2435  0.097072
# 2436  0.095223
# 2437  0.004622
# 2438  0.036980
# 2439  0.002773
# 2440  0.051772
# 2441  0.124807
#
# [2442 rows x 16 columns]

# %%
#load word2vec model, here GoogleNews is used
model = gensim.models.KeyedVectors.load_word2vec_format('../GoogleNews-vectors-negative300.bin', binary=True)
#two sample sentences 
s1 = 'the first sentence'
s2 = 'the second text'

#calculate distance between two sentences using WMD algorithm
distance = model.wmdistance(s1, s2)

print ('distance = %.3f' % distance)

# %%
short_df = df[['student_answer','student_modified', 'grade','question' , 'embed_ref','embed_stud' ,'len_norm','cos_similarity']]
short_df['grades_round']= short_df['grade'].apply(lambda x: round(x))
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#getting the seed index
classes = short_df['grades_round'].unique()
seed_index = []
for i in classes:
    seed_index.append(short_df['grades_round'][short_df['grades_round']==i].index[0])
# print(type(df['cos_similarity'][0]))
# for i in range(len(df)):
#     if df['len_norm'][i] == NaN:
#         print (i)

# %%
np.sum(df['cos_similarity'].isnull().values)
# Out:
# 0

# %%
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(short_df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

# X = student_answer_count_vector
# X.shape
# Y = short_df['grades_round'].values
# Out:
# (2442, 2231)

# %%
#getting the input and output data
# X = short_df['embed_stud'].values
# X = np.concatenate( X, axis=0 ) ## for converting array of array into array
Y = short_df['grades_round'].values
X = np.concatenate((df['len_norm'].values[np.newaxis, :].T,df['cos_similarity'].values[np.newaxis, :].T),axis = 1)

# %%
X.shape
# Out:
# (2442, 2)

# %%
act_data = short_df.copy()
accuracy_list = []

# initialising
# train_idx = [0, 1, 4 ,5,52,605]
train_idx = seed_index
X_train = X[train_idx]
y_train = Y[train_idx]
# print(y_train)
# generating the pool
X_pool = np.delete(X, train_idx, axis=0)
y_pool = np.delete(Y, train_idx)

act_data = act_data.drop(axis=0,index = train_idx)
act_data.reset_index(drop = True,inplace=True)


# initializing the active learner
lr = LogisticRegression()
# lr = MultinomialNB()
learner = ActiveLearner(
    estimator = lr,
#     estimator = RandomForestClassifier(n_estimators=5),
#     estimator=KNeighborsClassifier(n_neighbors=3),
    X_training=X_train, y_training=y_train
)

# pool-based sampling
n_queries = 40
for idx in range(n_queries):
    query_idx, query_instance = learner.query(X_pool)
    print("\nQ: ", act_data.loc[int(query_idx),'question'])
    print("A: ",act_data.loc[int(query_idx),'student_answer'])
    print("Actual grade: ",y_pool[query_idx].reshape(1, ))
    print ("Class probabilities: ",learner.predict_proba(X_pool[query_idx].reshape(1, -1)))
    human_label = int(input("\nGive me a grade:"))
    learner.teach(
        X=X_pool[query_idx].reshape(1, -1),
        y=[human_label]
    )
    
    # remove queried instance from pool
    X_pool = np.delete(X_pool, query_idx, axis=0)
    y_pool = np.delete(y_pool, query_idx)
    
    act_data = act_data.drop(axis=0,index = query_idx)
    act_data.reset_index(drop=True, inplace=True)
    
    accuracy_list.append(learner.score(X,Y))
    print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X, Y)))
# Out:
# Q:  How many steps does it take to search a node in a binary search tree?
# A:  3 steps at most.  There are 3 cases.
# Actual grade:  [2]
# Class probabilities:  [[0.16668297 0.16667368 0.16668282 0.16664305 0.16666679 0.16665069]]
#
# Give me a grade:2
# Accuracy after query no. 1: 0.109337
#
# Q:  What data structure is more appropriate for scheduling printing jobs at a printer  a stack or a queue?
# A:  a queue.
# Actual grade:  [5]
# Class probabilities:  [[0.14239934 0.15368006 0.20299274 0.16936583 0.16423266 0.16732938]]
#
# Give me a grade:5
# Accuracy after query no. 2: 0.509828
#
# Q:  How are linked lists passed as arguments to a function?
# A:  You have to pass the head pointer to a function since it has access to the entire list.
# Actual grade:  [4]
# Class probabilities:  [[0.1501323  0.15046786 0.19823648 0.15162358 0.15135058 0.19818921]]
#
# Give me a grade:4
# Accuracy after query no. 3: 0.508600
#
# Q:  What is the alternative way to solve a problem that could be solved through recursive functions?
# A:  iteratively
# Actual grade:  [5]
# Class probabilities:  [[0.14387112 0.1443733  0.18911366 0.14482573 0.18888857 0.18892761]]
#
# Give me a grade:5
# Accuracy after query no. 4: 0.507371
#
# Q:  What are the two main functions defined by a queue?
# A:  enqueue  which inserts a specified element at the head of the specified queue  and dequeue  which removes the specified element from the queue.
# Actual grade:  [5]
# Class probabilities:  [[0.15145714 0.14565419 0.19051746 0.13894459 0.18224055 0.19118606]]
#
# Give me a grade:5
# Accuracy after query no. 5: 0.507371
#
# Q:  How many steps does it take to search a node in a binary search tree?
# A:  2n-1
# Actual grade:  [2]
# Class probabilities:  [[0.14629313 0.14008359 0.18129351 0.1319271  0.1694734  0.23092927]]
#
# Give me a grade:2
# Accuracy after query no. 6: 0.507781
#
# Q:  What is the experimental approach for measuring the running time of an algorithm?
# A:  BIG-OH
# Actual grade:  [2]
# Class probabilities:  [[0.13603114 0.1318472  0.22321415 0.12621502 0.1609943  0.2216982 ]]
#
# Give me a grade:2
# Accuracy after query no. 7: 0.509828
#
# Q:  What are the two main functions defined by a queue?
# A:  enque -LRB- Data -RRB-   Deque -LRB- -RRB-
# Actual grade:  [5]
# Class probabilities:  [[0.12345463 0.12397347 0.23432924 0.12454637 0.15980525 0.23389104]]
#
# Give me a grade:5
# Accuracy after query no. 8: 0.505733
#
# Q:  How many comparisons does it take to find an element in a binary search tree?
# A:  nLog -LRB- n -RRB-
# Actual grade:  [2]
# Class probabilities:  [[0.12403851 0.12154054 0.24418605 0.11806844 0.14966735 0.24249911]]
#
# Give me a grade:2
# Accuracy after query no. 9: 0.508600
#
# Q:  What is the stack operation corresponding to the enqueue operation in queues?
# A:  The stack operation is almost the opposite of the enqueue operation.
# Actual grade:  [2]
# Class probabilities:  [[0.11505209 0.11473343 0.25128729 0.1159762  0.15142119 0.2515298 ]]
#
# Give me a grade:2
# Accuracy after query no. 10: 0.498362
#
# Q:  When does C++ create a default constructor?
# A:  When there are no arguments passed.
# Actual grade:  [2]
# Class probabilities:  [[0.10925211 0.11196248 0.25817861 0.11524657 0.1472119  0.25814833]]
#
# Give me a grade:2
# Accuracy after query no. 11: 0.447584
#
# Q:  How are overloaded functions differentiated by the compiler?
# A:  Overloaded functions are differentiated by their parameters.
# Actual grade:  [4]
# Class probabilities:  [[0.1019166  0.10688571 0.26611719 0.1133738  0.14557628 0.26613042]]
#
# Give me a grade:4
# Accuracy after query no. 12: 0.447584
#
# Q:  What are the different ways to pass a pointer to a function?
# A:  you can pass a pointer to a pointer or pass a reference to pointer.
# Actual grade:  [2]
# Class probabilities:  [[0.09814604 0.10282502 0.25274512 0.10893679 0.1845248  0.25282224]]
#
# Give me a grade:2
# Accuracy after query no. 13: 0.159296
#
# Q:  Using an index outside the bounds of the array generates an error. Is this a compilation error or a run-time error?
# A:  Its a run-time error.
# Actual grade:  [5]
# Class probabilities:  [[0.08742296 0.09490007 0.26011219 0.10535041 0.19148683 0.26072755]]
#
# Give me a grade:5
# Accuracy after query no. 14: 0.463554
#
# Q:  What is the main advantage of a doubly-linked list over a basic linked list?
# A:  they have double pointers  so each node can point forwards or backwards.  Making it a little easer to get to where you need.
# Actual grade:  [4]
# Class probabilities:  [[0.09138716 0.09504797 0.2746107  0.09978314 0.16445151 0.27471952]]
#
# Give me a grade:4
# Accuracy after query no. 15: 0.463554
#
# Q:  Which implementation (array-based vs. list-based) is preferred for a queue  and why?
# A:  list based  its much simpler and the run time is better
# Actual grade:  [4]
# Class probabilities:  [[0.08858026 0.0920635  0.26361786 0.0966018  0.19545259 0.26368399]]
#
# Give me a grade:4
# Accuracy after query no. 16: 0.463554
#
# Q:  Which implementation (array-based vs. list-based) is preferred for a queue  and why?
# A:  list based.  It can dynamically grow and has fewer restrictions.
# Actual grade:  [5]
# Class probabilities:  [[0.08591969 0.08924252 0.25332038 0.09358225 0.22457426 0.25336091]]
#
# Give me a grade:5
# Accuracy after query no. 17: 0.498362
#
# Q:  What are the different ways to pass a pointer to a function?
# A:  you can pass it where either the pointer cant be moved  the data pointed to cant be changed  or both or neither
# Actual grade:  [4]
# Class probabilities:  [[0.08801628 0.08990378 0.26266651 0.0922151  0.20479241 0.26240592]]
#
# Give me a grade:4
# Accuracy after query no. 18: 0.498362
#
# Q:  What is a linked list?
# A:  linear collection of self-referential nodes connected by pointers.
# Actual grade:  [4]
# Class probabilities:  [[0.08576526 0.08761091 0.25453924 0.08991949 0.22710469 0.25506041]]
#
# Give me a grade:4
# Accuracy after query no. 19: 0.321048
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Testing  refining  production  and maintenance.
# Actual grade:  [4]
# Class probabilities:  [[0.0839711  0.08572646 0.24759036 0.08785796 0.24762445 0.24722967]]
#
# Give me a grade:4
# Accuracy after query no. 20: 0.292383
#
# Q:  How are objects initialized when they are created?
# A:  by giving them a value
# Actual grade:  [2]
# Class probabilities:  [[0.0854828  0.08625348 0.25528835 0.08712885 0.2553741  0.23047242]]
#
# Give me a grade:2
# Accuracy after query no. 21: 0.292383
#
# Q:  What is the role of a header-file?
# A:  To allow the compiler to recognize the classes when used elsewhere.
# Actual grade:  [4]
# Class probabilities:  [[0.08030639 0.08193212 0.25993398 0.08394394 0.26001674 0.23386683]]
#
# Give me a grade:4
# Accuracy after query no. 22: 0.291974
#
# Q:  How many comparisons does it take to find an element in a binary search tree?
# A:  O -LRB- log n -RRB-
# Actual grade:  [5]
# Class probabilities:  [[0.08183971 0.08261014 0.26653529 0.08341998 0.26651807 0.21907681]]
#
# Give me a grade:5
# Accuracy after query no. 23: 0.291974
#
# Q:  How can an array be addressed in pointer/offset notation?
# A:  multiplied by f [3]
# Actual grade:  [2]
# Class probabilities:  [[0.08022385 0.08098116 0.259902   0.0817734  0.26012513 0.23699446]]
#
# Give me a grade:2
# Accuracy after query no. 24: 0.293202
#
# Q:  What are the two different ways of specifying the length of an array?
# A:  define it as array [5] or array [1 2 3 4 5]
# Actual grade:  [4]
# Class probabilities:  [[0.07553469 0.07701323 0.26431456 0.07883782 0.26460055 0.23969915]]
#
# Give me a grade:4
# Accuracy after query no. 25: 0.292383
#
# Q:  How are bi-dimensional arrays stored in memory  by rows or by columns?
# A:  By column.
# Actual grade:  [1]
# Class probabilities:  [[0.07680478 0.07755059 0.27051723 0.07846115 0.27018904 0.22647721]]
#
# Give me a grade:1
# Accuracy after query no. 26: 0.292793
#
# Q:  How many comparisons does it take to find an element in a binary search tree?
# A:  O -LRB- log n -RRB-
# Actual grade:  [5]
# Class probabilities:  [[0.0757518  0.09593738 0.26498747 0.07724944 0.26452062 0.22155328]]
#
# Give me a grade:5
# Accuracy after query no. 27: 0.292793
#
# Q:  How many steps does it take to search a node in a binary search tree?
# A:  Log -LRB- n -RRB- where n is the number of nodes.
# Actual grade:  [5]
# Class probabilities:  [[0.07418955 0.09387851 0.25926553 0.07579819 0.25871381 0.23815442]]
# Give me a grade:5
# Accuracy after query no. 28: 0.297707
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  Refining and Coding
# Actual grade:  [5]
# Class probabilities:  [[0.07312466 0.09239529 0.25357824 0.07454368 0.25303683 0.2533213 ]]
#
# Give me a grade:5
# Accuracy after query no. 29: 0.464373
#
# Q:  What are the elements typically included in a class definition?
# A:  return type and input parameters
# Actual grade:  [2]
# Class probabilities:  [[0.07452336 0.09273134 0.26020147 0.0744361  0.23765906 0.26044869]]
#
# Give me a grade:2
# Accuracy after query no. 30: 0.463964
#
# Q:  What stages in the software life cycle are influenced by the testing stage?
# A:  coding and refining
# Actual grade:  [5]
# Class probabilities:  [[0.07050941 0.08895561 0.26285859 0.07193448 0.24278952 0.2629524 ]]
#
# Give me a grade:5
# Accuracy after query no. 31: 0.508190
#
# Q:  What are the elements typically included in a class definition?
# A:  Constructor  functions  and variables native to the class.
# Actual grade:  [4]
# Class probabilities:  [[0.07165208 0.08912627 0.26918214 0.07178703 0.22871322 0.26953925]]
#
# Give me a grade:4
# Accuracy after query no. 32: 0.508190
#
# Q:  What are the main advantages associated with object-oriented programming?
# A:  Existing classes can be feused  Program maintenance and verification are easier
# Actual grade:  [4]
# Class probabilities:  [[0.07048494 0.08756624 0.26429525 0.07065855 0.24308655 0.26390847]]
#
# Give me a grade:4
# Accuracy after query no. 33: 0.294021
#
# Q:  How many constructors can be created for a class?
# A:  As many as needed.
# Actual grade:  [5]
# Class probabilities:  [[0.06960803 0.08636551 0.2588721  0.06963201 0.25703504 0.25848732]]
#
# Give me a grade:5
# Accuracy after query no. 34: 0.505733
#
# Q:  What is the scope of global variables?
# A:  The entire program
# Actual grade:  [4]
# Class probabilities:  [[0.07078053 0.08662618 0.26432455 0.06955884 0.24369079 0.26501912]]
#
# Give me a grade:4
# Accuracy after query no. 35: 0.294840
#
# Q:  Using an index outside the bounds of the array generates an error. Is this a compilation error or a run-time error?
# A:  run time
# Actual grade:  [5]
# Class probabilities:  [[0.06996884 0.08546717 0.25933038 0.06860849 0.25759927 0.25902585]]
#
# Give me a grade:5
# Accuracy after query no. 36: 0.506143
#
# Q:  What are the access-specifiers that can be used in a C++ class definition?
# A:  static  long  unsigned
# Actual grade:  [0]
# Class probabilities:  [[0.07157307 0.08601149 0.26549677 0.06870405 0.24295993 0.26525469]]
#
# Give me a grade:0
# Accuracy after query no. 37: 0.506143
#
# Q:  How are bi-dimensional arrays stored in memory  by rows or by columns?
# A:  columns
# Actual grade:  [1]
# Class probabilities:  [[0.08860372 0.0848583  0.26008436 0.06788997 0.23840409 0.26015957]]
#
# Give me a grade:1
# Accuracy after query no. 38: 0.506143
#
# Q:  What is the stack operation corresponding to the enqueue operation in queues?
# A:  FIFO: First in First out
# Actual grade:  [2]
# Class probabilities:  [[0.08659997 0.10093673 0.25563282 0.06689745 0.23480296 0.25513006]]
#
# Give me a grade:2
# Accuracy after query no. 39: 0.506552
#
# Q:  How many steps does it take to search a node in a binary search tree?
# A:  log -LRB- n -RRB- steps
# Actual grade:  [5]
# Class probabilities:  [[0.08192783 0.09686572 0.25843058 0.06490983 0.23918241 0.25868363]]
#
# Give me a grade:5
# Accuracy after query no. 40: 0.506143

# %%
from sklearn.model_selection import train_test_split
check_X = np.copy(X)
check_Y = np.copy(Y)

X_train,X_test,Y_train,Y_test = train_test_split(check_X,check_Y,test_size = 0.2)
logisticRegr = LogisticRegression()
logisticRegr.fit(X_train, Y_train)
score = logisticRegr.score(X_test, Y_test)

print(score)
# Out:
# 0.50920245398773

# %%
learner.score(X_test,Y_test)
# Out:
# 0.4887525562372188

# %%
df = pd.read_pickle("./feature.pkl")  
df
# Out:
#       question_id                                           question  \
# 0             1.1  What is the role of a prototype program in pro...
# 1             1.1  What is the role of a prototype program in pro...
# 2             1.1  What is the role of a prototype program in pro...
# 3             1.1  What is the role of a prototype program in pro...
# 4             1.1  What is the role of a prototype program in pro...
# 5             1.1  What is the role of a prototype program in pro...
# 6             1.1  What is the role of a prototype program in pro...
# 7             1.1  What is the role of a prototype program in pro...
# 8             1.1  What is the role of a prototype program in pro...
# 9             1.1  What is the role of a prototype program in pro...
# 10            1.1  What is the role of a prototype program in pro...
# 11            1.1  What is the role of a prototype program in pro...
# 12            1.1  What is the role of a prototype program in pro...
# 13            1.1  What is the role of a prototype program in pro...
# 14            1.1  What is the role of a prototype program in pro...
# 15            1.1  What is the role of a prototype program in pro...
# 16            1.1  What is the role of a prototype program in pro...
# 17            1.1  What is the role of a prototype program in pro...
# 18            1.1  What is the role of a prototype program in pro...
# 19            1.1  What is the role of a prototype program in pro...
# 20            1.1  What is the role of a prototype program in pro...
# 21            1.1  What is the role of a prototype program in pro...
# 22            1.1  What is the role of a prototype program in pro...
# 23            1.1  What is the role of a prototype program in pro...
# 24            1.1  What is the role of a prototype program in pro...
# 25            1.1  What is the role of a prototype program in pro...
# 26            1.1  What is the role of a prototype program in pro...
# 27            1.1  What is the role of a prototype program in pro...
# 28            1.1  What is the role of a prototype program in pro...
# 29            1.2  What stages in the software life cycle are inf...
# ...           ...                                                ...
# 2412         12.9  How do you delete a node from a binary search ...
# 2413         12.9  How do you delete a node from a binary search ...
# 2414         12.1  How many steps does it take to search a node i...
# 2415         12.1  How many steps does it take to search a node i...
# 2416         12.1  How many steps does it take to search a node i...
# 2417         12.1  How many steps does it take to search a node i...
# 2418         12.1  How many steps does it take to search a node i...
# 2419         12.1  How many steps does it take to search a node i...
# 2420         12.1  How many steps does it take to search a node i...
# 2421         12.1  How many steps does it take to search a node i...
# 2422         12.1  How many steps does it take to search a node i...
# 2423         12.1  How many steps does it take to search a node i...
# 2424         12.1  How many steps does it take to search a node i...
# 2425         12.1  How many steps does it take to search a node i...
# 2426         12.1  How many steps does it take to search a node i...
# 2427         12.1  How many steps does it take to search a node i...
# 2428         12.1  How many steps does it take to search a node i...
# 2429         12.1  How many steps does it take to search a node i...
# 2430         12.1  How many steps does it take to search a node i...
# 2431         12.1  How many steps does it take to search a node i...
# 2432         12.1  How many steps does it take to search a node i...
# 2433         12.1  How many steps does it take to search a node i...
# 2434         12.1  How many steps does it take to search a node i...
# 2435         12.1  How many steps does it take to search a node i...
# 2436         12.1  How many steps does it take to search a node i...
# 2437         12.1  How many steps does it take to search a node i...
# 2438         12.1  How many steps does it take to search a node i...
# 2439         12.1  How many steps does it take to search a node i...
# 2440         12.1  How many steps does it take to search a node i...
# 2441         12.1  How many steps does it take to search a node i...
#
#                                              ref_answer  \
# 0     To simulate the behaviour of portions of the d...
# 1     To simulate the behaviour of portions of the d...
# 2     To simulate the behaviour of portions of the d...
# 3     To simulate the behaviour of portions of the d...
# 4     To simulate the behaviour of portions of the d...
# 5     To simulate the behaviour of portions of the d...
# 6     To simulate the behaviour of portions of the d...
# 7     To simulate the behaviour of portions of the d...
# 8     To simulate the behaviour of portions of the d...
# 9     To simulate the behaviour of portions of the d...
# 10    To simulate the behaviour of portions of the d...
# 11    To simulate the behaviour of portions of the d...
# 12    To simulate the behaviour of portions of the d...
# 13    To simulate the behaviour of portions of the d...
# 14    To simulate the behaviour of portions of the d...
# 15    To simulate the behaviour of portions of the d...
# 16    To simulate the behaviour of portions of the d...
# 17    To simulate the behaviour of portions of the d...
# 18    To simulate the behaviour of portions of the d...
# 19    To simulate the behaviour of portions of the d...
# 20    To simulate the behaviour of portions of the d...
# 21    To simulate the behaviour of portions of the d...
# 22    To simulate the behaviour of portions of the d...
# 23    To simulate the behaviour of portions of the d...
# 24    To simulate the behaviour of portions of the d...
# 25    To simulate the behaviour of portions of the d...
# 26    To simulate the behaviour of portions of the d...
# 27    To simulate the behaviour of portions of the d...
# 28    To simulate the behaviour of portions of the d...
# 29    The testing stage can influence both the codin...
# ...                                                 ...
# 2412  Find the node  then replace it with the leftmo...
# 2413  Find the node  then replace it with the leftmo...
# 2414                            The height of the tree.
# 2415                            The height of the tree.
# 2416                            The height of the tree.
# 2417                            The height of the tree.
# 2418                            The height of the tree.
# 2419                            The height of the tree.
# 2420                            The height of the tree.
# 2421                            The height of the tree.
# 2422                            The height of the tree.
# 2423                            The height of the tree.
# 2424                            The height of the tree.
# 2425                            The height of the tree.
# 2426                            The height of the tree.
# 2427                            The height of the tree.
# 2428                            The height of the tree.
# 2429                            The height of the tree.
# 2430                            The height of the tree.
# 2431                            The height of the tree.
# 2432                            The height of the tree.
# 2433                            The height of the tree.
# 2434                            The height of the tree.
# 2435                            The height of the tree.
# 2436                            The height of the tree.
# 2437                            The height of the tree.
# 2438                            The height of the tree.
# 2439                            The height of the tree.
# 2440                            The height of the tree.
# 2441                            The height of the tree.
#
#                                          student_answer  grade  \
# 0     High risk problems are address in the prototyp...    3.5
# 1     To simulate portions of the desired final prod...    5.0
# 2     A prototype program simulates the behaviors of...    4.0
# 3     Defined in the Specification phase a prototype...    5.0
# 4     It is used to let the users have a first idea ...    3.0
# 5     To find problem and errors in a program before...    2.0
# 6     To address major issues in the creation of the...    2.5
# 7     you can break the whole program into prototype...    5.0
# 8     To provide an example or model of how the fini...    3.5
# 9     Simulating the behavior of only a portion of t...    5.0
# 10    A program that stimulates the behavior of port...    5.0
# 11    A program that simulates the behavior of porti...    5.0
# 12    To lay out the basics and give you a starting ...    2.0
# 13    To simulate problem solving for parts of the p...    4.5
# 14    A prototype program provides a basic groundwor...    2.0
# 15    A prototype program is a part of the Specifica...    4.5
# 16    Program that simulates the behavior of portion...    5.0
# 17    it provides a limited proof of concept to veri...    2.0
# 18    It tests the main function of the program whil...    2.0
# 19    To get early feedback from users in early stag...    2.5
# 20    it simulates the behavior of portions of the d...    5.0
# 21    It simulates the behavior of portions of the d...    5.0
# 22    A prototype program is used in problem solving...    1.5
# 23    To ease the understanding of problem under dis...    2.5
# 24    it simulates the behavior of portions of the d...    5.0
# 25    The role of a prototype program is to help spo...    2.0
# 26    the prototype program gives a general idea of ...    3.0
# 27    to show that a certain part of the program wor...    3.0
# 28    Prototype programming is an approach to progra...    2.5
# 29    Refining and possibly the design if the testin...    3.5
# ...                                                 ...    ...
# 2412  if it has no children  you just delete it. if ...    4.0
# 2413  pointer to the child and delete it has 2 child...    3.0
# 2414  Log -LRB- n -RRB- where n is the number of nod...    5.0
# 2415                           log -LRB- n -RRB- steps     5.0
# 2416   The number of levels and the height of the tree     5.0
# 2417         It is the same as the height of the tree.     5.0
# 2418  Given n elements  it would take n divided by 2...    1.5
# 2419                                             log n     5.0
# 2420  Depends on the location of the node you are lo...    2.0
# 2421  2 to the power of n where n is the of levels t...    2.0
# 2422  The number of steps to search a node is the fu...    3.5
# 2423   It would take n divided by 2 elements  given n.     1.5
# 2424                                 log -LRB- n -RRB-     5.0
# 2425                               O -LRB- log n -RRB-     5.0
# 2426                   O -LRB- Log -LRB- n -RRB- -RRB-     5.0
# 2427  If the binary search tree is constructed effic...    5.0
# 2428                   N  n being the number of nodes.     4.0
# 2429  depending on the way that the tree is ordered ...    5.0
# 2430                                 log -LRB- n -RRB-     5.0
# 2431  worst case scenario equals the number of level...    5.0
# 2432              3 steps at most.  There are 3 cases.     1.5
# 2433  log -LRB- n -RRB- where n equals the total num...    5.0
# 2434  the same number of steps as the number of leve...    5.0
# 2435  to find a node in a binary search tree takes a...    5.0
# 2436  three steps visit the root node  then go to ri...    2.5
# 2437                                             log n     5.0
# 2438  -LRB- n -LRB- n minus 1 -RRB- -RRB- divided by 2     1.5
# 2439                                              2n-1     2.5
# 2440  it takes at most h steps  where h is the heigh...    5.0
# 2441  it depends on the install search tree then fro...    1.5
#
#                                             qn_modified  \
# 0        what role prototype program in problem solving
# 1        what role prototype program in problem solving
# 2        what role prototype program in problem solving
# 3        what role prototype program in problem solving
# 4        what role prototype program in problem solving
# 5        what role prototype program in problem solving
# 6        what role prototype program in problem solving
# 7        what role prototype program in problem solving
# 8        what role prototype program in problem solving
# 9        what role prototype program in problem solving
# 10       what role prototype program in problem solving
# 11       what role prototype program in problem solving
# 12       what role prototype program in problem solving
# 13       what role prototype program in problem solving
# 14       what role prototype program in problem solving
# 15       what role prototype program in problem solving
# 16       what role prototype program in problem solving
# 17       what role prototype program in problem solving
# 18       what role prototype program in problem solving
# 19       what role prototype program in problem solving
# 20       what role prototype program in problem solving
# 21       what role prototype program in problem solving
# 22       what role prototype program in problem solving
# 23       what role prototype program in problem solving
# 24       what role prototype program in problem solving
# 25       what role prototype program in problem solving
# 26       what role prototype program in problem solving
# 27       what role prototype program in problem solving
# 28       what role prototype program in problem solving
# 29    what stage in software life cycle influenced t...
# ...                                                 ...
# 2412     how do you delete node from binary search tree
# 2413     how do you delete node from binary search tree
# 2414  how many step doe it take to search node in bi...
# 2415  how many step doe it take to search node in bi...
# 2416  how many step doe it take to search node in bi...
# 2417  how many step doe it take to search node in bi...
# 2418  how many step doe it take to search node in bi...
# 2419  how many step doe it take to search node in bi...
# 2420  how many step doe it take to search node in bi...
# 2421  how many step doe it take to search node in bi...
# 2422  how many step doe it take to search node in bi...
# 2423  how many step doe it take to search node in bi...
# 2424  how many step doe it take to search node in bi...
# 2425  how many step doe it take to search node in bi...
# 2426  how many step doe it take to search node in bi...
# 2427  how many step doe it take to search node in bi...
# 2428  how many step doe it take to search node in bi...
# 2429  how many step doe it take to search node in bi...
# 2430  how many step doe it take to search node in bi...
# 2431  how many step doe it take to search node in bi...
# 2432  how many step doe it take to search node in bi...
# 2433  how many step doe it take to search node in bi...
# 2434  how many step doe it take to search node in bi...
# 2435  how many step doe it take to search node in bi...
# 2436  how many step doe it take to search node in bi...
# 2437  how many step doe it take to search node in bi...
# 2438  how many step doe it take to search node in bi...
# 2439  how many step doe it take to search node in bi...
# 2440  how many step doe it take to search node in bi...
# 2441  how many step doe it take to search node in bi...
#
#                                            ref_modified  \
# 0     to simulate behaviour portion desired software...
# 1     to simulate behaviour portion desired software...
# 2     to simulate behaviour portion desired software...
# 3     to simulate behaviour portion desired software...
# 4     to simulate behaviour portion desired software...
# 5     to simulate behaviour portion desired software...
# 6     to simulate behaviour portion desired software...
# 7     to simulate behaviour portion desired software...
# 8     to simulate behaviour portion desired software...
# 9     to simulate behaviour portion desired software...
# 10    to simulate behaviour portion desired software...
# 11    to simulate behaviour portion desired software...
# 12    to simulate behaviour portion desired software...
# 13    to simulate behaviour portion desired software...
# 14    to simulate behaviour portion desired software...
# 15    to simulate behaviour portion desired software...
# 16    to simulate behaviour portion desired software...
# 17    to simulate behaviour portion desired software...
# 18    to simulate behaviour portion desired software...
# 19    to simulate behaviour portion desired software...
# 20    to simulate behaviour portion desired software...
# 21    to simulate behaviour portion desired software...
# 22    to simulate behaviour portion desired software...
# 23    to simulate behaviour portion desired software...
# 24    to simulate behaviour portion desired software...
# 25    to simulate behaviour portion desired software...
# 26    to simulate behaviour portion desired software...
# 27    to simulate behaviour portion desired software...
# 28    to simulate behaviour portion desired software...
# 29    testing stage can influence both coding stage ...
# ...                                                 ...
# 2412  find node then replace it leftmost node from i...
# 2413  find node then replace it leftmost node from i...
# 2414                                        height tree
# 2415                                        height tree
# 2416                                        height tree
# 2417                                        height tree
# 2418                                        height tree
# 2419                                        height tree
# 2420                                        height tree
# 2421                                        height tree
# 2422                                        height tree
# 2423                                        height tree
# 2424                                        height tree
# 2425                                        height tree
# 2426                                        height tree
# 2427                                        height tree
# 2428                                        height tree
# 2429                                        height tree
# 2430                                        height tree
# 2431                                        height tree
# 2432                                        height tree
# 2433                                        height tree
# 2434                                        height tree
# 2435                                        height tree
# 2436                                        height tree
# 2437                                        height tree
# 2438                                        height tree
# 2439                                        height tree
# 2440                                        height tree
# 2441                                        height tree
#
#                                        student_modified  \
# 0     high risk problem address in prototype program...
# 1     to simulate portion desired final product quic...
# 2     prototype program simulates behavior portion d...
# 3     defined in specification phase prototype stimu...
# 4     it used to let user first idea completed progr...
# 5     to find problem and error in program before it...
# 6     to address major issue in creation program the...
# 7     you can break whole program into prototype pro...
# 8     to provide example or model how finished progr...
# 9     simulating behavior only portion desired softw...
# 10    program that stimulates behavior portion desir...
# 11    program that simulates behavior portion desire...
# 12    to lay out basic and give you starting point i...
# 13             to simulate problem solving part problem
# 14    prototype program provides basic groundwork fr...
# 15    prototype program part specification phase sof...
# 16    program that simulates behavior portion desire...
# 17    it provides limited proof concept to verify cl...
# 18    it test main function program while leaving ou...
# 19    to get early feedback from user in early stage...
# 20    it simulates behavior portion desired software...
# 21    it simulates behavior portion desired software...
# 22    prototype program used in problem solving to c...
# 23    to ease understanding problem under discussion...
# 24    it simulates behavior portion desired software...
# 25    role prototype program to help spot key proble...
# 26    prototype program give general idea what end p...
# 27    to show that certain part program work it supp...
# 28    prototype programming approach to programming ...
# 29    refining and possibly design if testing phase ...
# ...                                                 ...
# 2412  if it no child you just delete it if it only o...
# 2413  pointer to child and delete it child set node ...
# 2414                  log lrb n rrb where n number node
# 2415                                 log lrb n rrb step
# 2416                       number level and height tree
# 2417                                it same height tree
# 2418  given n element it would take n divided step t...
# 2419                                              log n
# 2420  depends on location node you looking if it roo...
# 2421               to power n where n level binary tree
# 2422        number step to search node function n minus
# 2423            it would take n divided element given n
# 2424                                      log lrb n rrb
# 2425                                    o lrb log n rrb
# 2426                            o lrb log lrb n rrb rrb
# 2427  if binary search tree constructed efficiently ...
# 2428                              n n being number node
# 2429  depending on way that tree ordered it could be...
# 2430                                      log lrb n rrb
# 2431  worst case scenario equal number level tree ie...
# 2432                               step most there case
# 2433  log lrb n rrb where n equal total number node ...
# 2434  same number step number level or generation in...
# 2435  to find node in binary search tree take most s...
# 2436  three step visit root node then go to right su...
# 2437                                              log n
# 2438                  lrb n lrb n minus rrb rrb divided
# 2439                                                2n1
# 2440            it take most h step where h height tree
# 2441  it depends on install search tree then from th...
#
#                                         student_demoted  \
# 0     high risk address make sure that feasible may ...
# 1     simulate portion desired final product quick a...
# 2     simulates behavior portion desired software pr...
# 3     defined specification phase stimulates behavio...
# 4     it used let user first idea completed and allo...
# 5                    find and error before it finalized
# 6     address major issue creation there no way acco...
# 7          you can break whole into simulate part final
# 8     provide example or model how finished should p...
# 9     simulating behavior only portion desired softw...
# 10    that stimulates behavior portion desired softw...
# 11    that simulates behavior portion desired softwa...
# 12     lay out basic and give you starting point actual
# 13                                        simulate part
# 14    provides basic groundwork from which further e...
# 15    part specification phase software it employed ...
# 16    that simulates behavior portion desired softwa...
# 17    it provides limited proof concept verify clien...
# 18    it test main function while leaving out finer ...
# 19    get early feedback from user early stage devel...
# 20    it simulates behavior portion desired software...
# 21    it simulates behavior portion desired software...
# 22                                    used collect data
# 23    ease understanding under discussion and ease u...
# 24    it simulates behavior portion desired software...
# 25    help spot key that may arise during actual pro...
# 26    give general idea end product will do without ...
# 27              show that certain part work it supposed
# 28    programming approach programming that enables ...
# 29    refining and possibly design phase reveals pro...
# ...                                                 ...
# 2412  if it child just it if it only one child just ...
# 2413  pointer to child and it child set to child and...
# 2414                           log lrb rrb where number
# 2415                                        log lrb rrb
# 2416                            number level and height
# 2417                                        same height
# 2418         given element would divided find criterion
# 2419                                                log
# 2420  depends on location you looking if root one el...
# 2421                                  power where level
# 2422                              number function minus
# 2423                        would divided element given
# 2424                                        log lrb rrb
# 2425                                        lrb log rrb
# 2426                                lrb log lrb rrb rrb
# 2427  if constructed efficiently best case scenario ...
# 2428                                       being number
# 2429  depending on way that ordered could be anywher...
# 2430                                        log lrb rrb
# 2431  worst case scenario equal number level ie fart...
# 2432                                    most there case
# 2433               log lrb rrb where equal total number
# 2434             same number number level or generation
# 2435                  find most same number there level
# 2436  three visit root then go right subtree after v...
# 2437                                                log
# 2438                      lrb lrb minus rrb rrb divided
# 2439                                                2n1
# 2440                                  most where height
# 2441  depends on install then from there whatever ca...
#
#                                             ref_demoted  length_ratio  \
# 0     simulate behaviour portion desired software pr...      3.055556
# 1     simulate behaviour portion desired software pr...      3.074074
# 2     simulate behaviour portion desired software pr...      1.722222
# 3     simulate behaviour portion desired software pr...      3.814815
# 4     simulate behaviour portion desired software pr...      3.462963
# 5     simulate behaviour portion desired software pr...      1.037037
# 6     simulate behaviour portion desired software pr...      2.518519
# 7     simulate behaviour portion desired software pr...      1.500000
# 8     simulate behaviour portion desired software pr...      3.388889
# 9     simulate behaviour portion desired software pr...      1.055556
# 10    simulate behaviour portion desired software pr...      1.203704
# 11    simulate behaviour portion desired software pr...      1.185185
# 12    simulate behaviour portion desired software pr...      1.296296
# 13    simulate behaviour portion desired software pr...      0.740741
# 14    simulate behaviour portion desired software pr...      1.944444
# 15    simulate behaviour portion desired software pr...      3.555556
# 16    simulate behaviour portion desired software pr...      1.185185
# 17    simulate behaviour portion desired software pr...      1.777778
# 18    simulate behaviour portion desired software pr...      1.111111
# 19    simulate behaviour portion desired software pr...      3.555556
# 20    simulate behaviour portion desired software pr...      1.000000
# 21    simulate behaviour portion desired software pr...      1.000000
# 22    simulate behaviour portion desired software pr...      1.203704
# 23    simulate behaviour portion desired software pr...      1.611111
# 24    simulate behaviour portion desired software pr...      1.000000
# 25    simulate behaviour portion desired software pr...      1.611111
# 26    simulate behaviour portion desired software pr...      2.074074
# 27    simulate behaviour portion desired software pr...      0.981481
# 28    simulate behaviour portion desired software pr...      6.388889
# 29    can both coding phase and solution refinement ...      3.448276
# ...                                                 ...           ...
# 2412  find then replace it leftmost it right subtree...      1.840000
# 2413  find then replace it leftmost it right subtree...      1.100000
# 2414                                             height      3.000000
# 2415                                             height      1.636364
# 2416                                             height      2.545455
# 2417                                             height      1.727273
# 2418                                             height      6.272727
# 2419                                             height      0.454545
# 2420                                             height     15.272727
# 2421                                             height      3.272727
# 2422                                             height      3.909091
# 2423                                             height      3.545455
# 2424                                             height      1.181818
# 2425                                             height      1.363636
# 2426                                             height      2.090909
# 2427                                             height     33.727273
# 2428                                             height      1.909091
# 2429                                             height      8.000000
# 2430                                             height      1.181818
# 2431                                             height     11.000000
# 2432                                             height      1.818182
# 2433                                             height      4.818182
# 2434                                             height      4.636364
# 2435                                             height      7.090909
# 2436                                             height      9.000000
# 2437                                             height      0.454545
# 2438                                             height      3.000000
# 2439                                             height      0.272727
# 2440                                             height      3.545455
# 2441                                             height      9.545455
#
#       grades_round                                          embed_ref  \
# 0                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 1                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 2                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 3                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 4                3  [[0.13071777343750002, -0.10377929687499998, 0...
# 5                2  [[0.13071777343750002, -0.10377929687499998, 0...
# 6                2  [[0.13071777343750002, -0.10377929687499998, 0...
# 7                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 8                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 9                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 10               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 11               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 12               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 13               4  [[0.13071777343750002, -0.10377929687499998, 0...
# 14               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 15               4  [[0.13071777343750002, -0.10377929687499998, 0...
# 16               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 17               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 18               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 19               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 20               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 21               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 22               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 23               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 24               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 25               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 26               3  [[0.13071777343750002, -0.10377929687499998, 0...
# 27               3  [[0.13071777343750002, -0.10377929687499998, 0...
# 28               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 29               4  [[-0.03724121093749999, 0.728505859375, 0.1627...
# ...            ...                                                ...
# 2412             4  [[0.8393359375, -0.9155201721191406, 0.7835498...
# 2413             3  [[0.8393359375, -0.9155201721191406, 0.7835498...
# 2414             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2415             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2416             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2417             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2418             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2419             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2420             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2421             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2422             4  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2423             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2424             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2425             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2426             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2427             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2428             4  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2429             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2430             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2431             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2432             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2433             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2434             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2435             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2436             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2437             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2438             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2439             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2440             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2441             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
#
#                                              embed_stud
# 0     [[-0.5155224609375, 0.008998413085937518, 1.30...
# 1     [[2.15602783203125, 0.4706297302246094, 0.2766...
# 2     [[-0.28229736328125, 0.043576965332031245, 0.2...
# 3     [[-0.127725830078125, 0.53630615234375, 0.3706...
# 4     [[0.23586181640625004, 0.06217674255371097, 0....
# 5     [[0.12119628906250002, 0.0628600311279297, 0.0...
# 6     [[-0.10513183593749997, 0.6872704315185547, 0....
# 7     [[0.162374267578125, 0.4117333984375, 0.582143...
# 8     [[-0.33944580078125, 0.7594540405273438, 0.717...
# 9     [[0.24334717, -0.18823242, 0.23413086, 0.12432...
# 10    [[-0.046813965, -0.0008544922, 0.48388672, 0.4...
# 11    [[0.04473877, -0.006591797, 0.5078125, 0.23901...
# 12    [[1.146312255859375, -0.26472900390625, 0.4583...
# 13    [[0.30833984375, 0.11400390625000001, -0.20218...
# 14    [[-0.7306201171875, 0.3886511611938477, 0.0168...
# 15    [[0.48851684570312504, 0.6005602264404297, 1.0...
# 16    [[0.04473877, -0.006591797, 0.5078125, 0.23901...
# 17    [[-0.39966796875, -0.9118006134033203, -0.5778...
# 18    [[0.42938232, -0.28831673, 0.5189209, 0.293945...
# 19    [[0.18246582031250003, 0.6643317031860352, 0.9...
# 20    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 21    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 22    [[0.368734130859375, 0.2569482421875, 0.016927...
# 23    [[-0.01736328125, 0.41330078125, -0.3998706054...
# 24    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 25    [[0.1439111328125, 0.5086572265625, 0.28313232...
# 26    [[0.6358905029296875, 0.461162109375, 0.797099...
# 27    [[0.17676879882812502, 0.2869925689697266, 0.5...
# 28    [[0.08475952148437504, 0.729856300354004, 0.79...
# 29    [[-0.643990478515625, 0.17536643981933597, 2.5...
# ...                                                 ...
# 2412  [[2.47820068359375, -1.9582750701904297, 2.420...
# 2413  [[1.284130859375, 0.3819492340087891, 1.449673...
# 2414  [[0.24210693359375002, -0.24281738281249998, -...
# 2415  [[-0.06624267578124998, 0.12498046875, -0.2155...
# 2416  [[0.59349609375, 0.3421990966796875, -0.072031...
# 2417  [[0.8496094, 0.35816765, -0.122802734, 0.25219...
# 2418  [[0.48265625, 0.1604039764404297, 0.1828515625...
# 2419  [[0.11981201, -0.0034179688, -0.34594727, 0.10...
# 2420  [[1.5667529296875, -0.7187771606445312, 1.6323...
# 2421  [[0.57732177734375, 0.12149597167968751, 0.140...
# 2422  [[0.152578125, -0.4102880859375, -0.1097509765...
# 2423  [[0.5074463, 0.0417614, 0.37451172, 0.70996094...
# 2424  [[0.13981201171875002, 0.016582031250000004, -...
# 2425  [[-0.02425048828124999, 0.09861328124999999, -...
# 2426  [[-0.004250488281249989, 0.11861328124999998, ...
# 2427  [[3.789757080078124, 0.8338683319091797, 0.085...
# 2428  [[-0.08459473, -0.21960449, 0.028198242, 0.352...
# 2429  [[0.9930126953125, -0.2812659454345703, 0.5872...
# 2430  [[0.13981201171875002, 0.016582031250000004, -...
# 2431  [[0.29675293, -0.13927555, 1.7305908, 1.922637...
# 2432  [[0.012939453, -0.016967773, 0.119262695, 0.11...
# 2433  [[0.84684326171875, -0.3604931640625, -0.06605...
# 2434  [[0.67222023, 0.31230164, 0.6809082, 0.5546875...
# 2435  [[1.3265283203125, -0.06673645019531249, -0.15...
# 2436  [[0.02510742187500003, 0.689505615234375, 0.86...
# 2437  [[0.11981201, -0.0034179688, -0.34594727, 0.10...
# 2438  [[0.08266357421875001, -0.20462890624999996, 0...
# 2439  [[0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0....
# 2440  [[-0.07293701, 0.8473034, -0.040893555, 0.2551...
# 2441  [[1.4141846, 0.09828472, 0.32574463, 1.3451843...
#
# [2442 rows x 14 columns]

# %%
sentence1 = df['ref_modified'][0]
sentence2 = df['student_modified'][1]
print(sentence1)
# Out:
# to simulate the behaviour of portion of the desired software product

# %%
df.to_pickle("./feature_trial.pkl", protocol=2)

# %%
np.random.randn(10)
# Out:
# array([ 1.47180745,  1.41203125,  0.78110225, -0.73916318, -0.47343952,
#        -0.69500319,  0.19979711,  1.44240719, -1.35692967,  0.05365978])

# %%
len(df)
df['e'] = np.random.randn(len(df))

# %%
df
# Out:
#       question_id                                           question  \
# 0             1.1  What is the role of a prototype program in pro...
# 1             1.1  What is the role of a prototype program in pro...
# 2             1.1  What is the role of a prototype program in pro...
# 3             1.1  What is the role of a prototype program in pro...
# 4             1.1  What is the role of a prototype program in pro...
# 5             1.1  What is the role of a prototype program in pro...
# 6             1.1  What is the role of a prototype program in pro...
# 7             1.1  What is the role of a prototype program in pro...
# 8             1.1  What is the role of a prototype program in pro...
# 9             1.1  What is the role of a prototype program in pro...
# 10            1.1  What is the role of a prototype program in pro...
# 11            1.1  What is the role of a prototype program in pro...
# 12            1.1  What is the role of a prototype program in pro...
# 13            1.1  What is the role of a prototype program in pro...
# 14            1.1  What is the role of a prototype program in pro...
# 15            1.1  What is the role of a prototype program in pro...
# 16            1.1  What is the role of a prototype program in pro...
# 17            1.1  What is the role of a prototype program in pro...
# 18            1.1  What is the role of a prototype program in pro...
# 19            1.1  What is the role of a prototype program in pro...
# 20            1.1  What is the role of a prototype program in pro...
# 21            1.1  What is the role of a prototype program in pro...
# 22            1.1  What is the role of a prototype program in pro...
# 23            1.1  What is the role of a prototype program in pro...
# 24            1.1  What is the role of a prototype program in pro...
# 25            1.1  What is the role of a prototype program in pro...
# 26            1.1  What is the role of a prototype program in pro...
# 27            1.1  What is the role of a prototype program in pro...
# 28            1.1  What is the role of a prototype program in pro...
# 29            1.2  What stages in the software life cycle are inf...
# ...           ...                                                ...
# 2412         12.9  How do you delete a node from a binary search ...
# 2413         12.9  How do you delete a node from a binary search ...
# 2414         12.1  How many steps does it take to search a node i...
# 2415         12.1  How many steps does it take to search a node i...
# 2416         12.1  How many steps does it take to search a node i...
# 2417         12.1  How many steps does it take to search a node i...
# 2418         12.1  How many steps does it take to search a node i...
# 2419         12.1  How many steps does it take to search a node i...
# 2420         12.1  How many steps does it take to search a node i...
# 2421         12.1  How many steps does it take to search a node i...
# 2422         12.1  How many steps does it take to search a node i...
# 2423         12.1  How many steps does it take to search a node i...
# 2424         12.1  How many steps does it take to search a node i...
# 2425         12.1  How many steps does it take to search a node i...
# 2426         12.1  How many steps does it take to search a node i...
# 2427         12.1  How many steps does it take to search a node i...
# 2428         12.1  How many steps does it take to search a node i...
# 2429         12.1  How many steps does it take to search a node i...
# 2430         12.1  How many steps does it take to search a node i...
# 2431         12.1  How many steps does it take to search a node i...
# 2432         12.1  How many steps does it take to search a node i...
# 2433         12.1  How many steps does it take to search a node i...
# 2434         12.1  How many steps does it take to search a node i...
# 2435         12.1  How many steps does it take to search a node i...
# 2436         12.1  How many steps does it take to search a node i...
# 2437         12.1  How many steps does it take to search a node i...
# 2438         12.1  How many steps does it take to search a node i...
# 2439         12.1  How many steps does it take to search a node i...
# 2440         12.1  How many steps does it take to search a node i...
# 2441         12.1  How many steps does it take to search a node i...
#
#                                              ref_answer  \
# 0     To simulate the behaviour of portions of the d...
# 1     To simulate the behaviour of portions of the d...
# 2     To simulate the behaviour of portions of the d...
# 3     To simulate the behaviour of portions of the d...
# 4     To simulate the behaviour of portions of the d...
# 5     To simulate the behaviour of portions of the d...
# 6     To simulate the behaviour of portions of the d...
# 7     To simulate the behaviour of portions of the d...
# 8     To simulate the behaviour of portions of the d...
# 9     To simulate the behaviour of portions of the d...
# 10    To simulate the behaviour of portions of the d...
# 11    To simulate the behaviour of portions of the d...
# 12    To simulate the behaviour of portions of the d...
# 13    To simulate the behaviour of portions of the d...
# 14    To simulate the behaviour of portions of the d...
# 15    To simulate the behaviour of portions of the d...
# 16    To simulate the behaviour of portions of the d...
# 17    To simulate the behaviour of portions of the d...
# 18    To simulate the behaviour of portions of the d...
# 19    To simulate the behaviour of portions of the d...
# 20    To simulate the behaviour of portions of the d...
# 21    To simulate the behaviour of portions of the d...
# 22    To simulate the behaviour of portions of the d...
# 23    To simulate the behaviour of portions of the d...
# 24    To simulate the behaviour of portions of the d...
# 25    To simulate the behaviour of portions of the d...
# 26    To simulate the behaviour of portions of the d...
# 27    To simulate the behaviour of portions of the d...
# 28    To simulate the behaviour of portions of the d...
# 29    The testing stage can influence both the codin...
# ...                                                 ...
# 2412  Find the node  then replace it with the leftmo...
# 2413  Find the node  then replace it with the leftmo...
# 2414                            The height of the tree.
# 2415                            The height of the tree.
# 2416                            The height of the tree.
# 2417                            The height of the tree.
# 2418                            The height of the tree.
# 2419                            The height of the tree.
# 2420                            The height of the tree.
# 2421                            The height of the tree.
# 2422                            The height of the tree.
# 2423                            The height of the tree.
# 2424                            The height of the tree.
# 2425                            The height of the tree.
# 2426                            The height of the tree.
# 2427                            The height of the tree.
# 2428                            The height of the tree.
# 2429                            The height of the tree.
# 2430                            The height of the tree.
# 2431                            The height of the tree.
# 2432                            The height of the tree.
# 2433                            The height of the tree.
# 2434                            The height of the tree.
# 2435                            The height of the tree.
# 2436                            The height of the tree.
# 2437                            The height of the tree.
# 2438                            The height of the tree.
# 2439                            The height of the tree.
# 2440                            The height of the tree.
# 2441                            The height of the tree.
#
#                                          student_answer  grade  \
# 0     High risk problems are address in the prototyp...    3.5
# 1     To simulate portions of the desired final prod...    5.0
# 2     A prototype program simulates the behaviors of...    4.0
# 3     Defined in the Specification phase a prototype...    5.0
# 4     It is used to let the users have a first idea ...    3.0
# 5     To find problem and errors in a program before...    2.0
# 6     To address major issues in the creation of the...    2.5
# 7     you can break the whole program into prototype...    5.0
# 8     To provide an example or model of how the fini...    3.5
# 9     Simulating the behavior of only a portion of t...    5.0
# 10    A program that stimulates the behavior of port...    5.0
# 11    A program that simulates the behavior of porti...    5.0
# 12    To lay out the basics and give you a starting ...    2.0
# 13    To simulate problem solving for parts of the p...    4.5
# 14    A prototype program provides a basic groundwor...    2.0
# 15    A prototype program is a part of the Specifica...    4.5
# 16    Program that simulates the behavior of portion...    5.0
# 17    it provides a limited proof of concept to veri...    2.0
# 18    It tests the main function of the program whil...    2.0
# 19    To get early feedback from users in early stag...    2.5
# 20    it simulates the behavior of portions of the d...    5.0
# 21    It simulates the behavior of portions of the d...    5.0
# 22    A prototype program is used in problem solving...    1.5
# 23    To ease the understanding of problem under dis...    2.5
# 24    it simulates the behavior of portions of the d...    5.0
# 25    The role of a prototype program is to help spo...    2.0
# 26    the prototype program gives a general idea of ...    3.0
# 27    to show that a certain part of the program wor...    3.0
# 28    Prototype programming is an approach to progra...    2.5
# 29    Refining and possibly the design if the testin...    3.5
# ...                                                 ...    ...
# 2412  if it has no children  you just delete it. if ...    4.0
# 2413  pointer to the child and delete it has 2 child...    3.0
# 2414  Log -LRB- n -RRB- where n is the number of nod...    5.0
# 2415                           log -LRB- n -RRB- steps     5.0
# 2416   The number of levels and the height of the tree     5.0
# 2417         It is the same as the height of the tree.     5.0
# 2418  Given n elements  it would take n divided by 2...    1.5
# 2419                                             log n     5.0
# 2420  Depends on the location of the node you are lo...    2.0
# 2421  2 to the power of n where n is the of levels t...    2.0
# 2422  The number of steps to search a node is the fu...    3.5
# 2423   It would take n divided by 2 elements  given n.     1.5
# 2424                                 log -LRB- n -RRB-     5.0
# 2425                               O -LRB- log n -RRB-     5.0
# 2426                   O -LRB- Log -LRB- n -RRB- -RRB-     5.0
# 2427  If the binary search tree is constructed effic...    5.0
# 2428                   N  n being the number of nodes.     4.0
# 2429  depending on the way that the tree is ordered ...    5.0
# 2430                                 log -LRB- n -RRB-     5.0
# 2431  worst case scenario equals the number of level...    5.0
# 2432              3 steps at most.  There are 3 cases.     1.5
# 2433  log -LRB- n -RRB- where n equals the total num...    5.0
# 2434  the same number of steps as the number of leve...    5.0
# 2435  to find a node in a binary search tree takes a...    5.0
# 2436  three steps visit the root node  then go to ri...    2.5
# 2437                                             log n     5.0
# 2438  -LRB- n -LRB- n minus 1 -RRB- -RRB- divided by 2     1.5
# 2439                                              2n-1     2.5
# 2440  it takes at most h steps  where h is the heigh...    5.0
# 2441  it depends on the install search tree then fro...    1.5
#
#                                             qn_modified  \
# 0     what is the role of a prototype program in pro...
# 1     what is the role of a prototype program in pro...
# 2     what is the role of a prototype program in pro...
# 3     what is the role of a prototype program in pro...
# 4     what is the role of a prototype program in pro...
# 5     what is the role of a prototype program in pro...
# 6     what is the role of a prototype program in pro...
# 7     what is the role of a prototype program in pro...
# 8     what is the role of a prototype program in pro...
# 9     what is the role of a prototype program in pro...
# 10    what is the role of a prototype program in pro...
# 11    what is the role of a prototype program in pro...
# 12    what is the role of a prototype program in pro...
# 13    what is the role of a prototype program in pro...
# 14    what is the role of a prototype program in pro...
# 15    what is the role of a prototype program in pro...
# 16    what is the role of a prototype program in pro...
# 17    what is the role of a prototype program in pro...
# 18    what is the role of a prototype program in pro...
# 19    what is the role of a prototype program in pro...
# 20    what is the role of a prototype program in pro...
# 21    what is the role of a prototype program in pro...
# 22    what is the role of a prototype program in pro...
# 23    what is the role of a prototype program in pro...
# 24    what is the role of a prototype program in pro...
# 25    what is the role of a prototype program in pro...
# 26    what is the role of a prototype program in pro...
# 27    what is the role of a prototype program in pro...
# 28    what is the role of a prototype program in pro...
# 29    what stage in the software life cycle are infl...
# ...                                                 ...
# 2412  how do you delete a node from a binary search ...
# 2413  how do you delete a node from a binary search ...
# 2414  how many step doe it take to search a node in ...
# 2415  how many step doe it take to search a node in ...
# 2416  how many step doe it take to search a node in ...
# 2417  how many step doe it take to search a node in ...
# 2418  how many step doe it take to search a node in ...
# 2419  how many step doe it take to search a node in ...
# 2420  how many step doe it take to search a node in ...
# 2421  how many step doe it take to search a node in ...
# 2422  how many step doe it take to search a node in ...
# 2423  how many step doe it take to search a node in ...
# 2424  how many step doe it take to search a node in ...
# 2425  how many step doe it take to search a node in ...
# 2426  how many step doe it take to search a node in ...
# 2427  how many step doe it take to search a node in ...
# 2428  how many step doe it take to search a node in ...
# 2429  how many step doe it take to search a node in ...
# 2430  how many step doe it take to search a node in ...
# 2431  how many step doe it take to search a node in ...
# 2432  how many step doe it take to search a node in ...
# 2433  how many step doe it take to search a node in ...
# 2434  how many step doe it take to search a node in ...
# 2435  how many step doe it take to search a node in ...
# 2436  how many step doe it take to search a node in ...
# 2437  how many step doe it take to search a node in ...
# 2438  how many step doe it take to search a node in ...
# 2439  how many step doe it take to search a node in ...
# 2440  how many step doe it take to search a node in ...
# 2441  how many step doe it take to search a node in ...
#
#                                            ref_modified  \
# 0     to simulate the behaviour of portion of the de...
# 1     to simulate the behaviour of portion of the de...
# 2     to simulate the behaviour of portion of the de...
# 3     to simulate the behaviour of portion of the de...
# 4     to simulate the behaviour of portion of the de...
# 5     to simulate the behaviour of portion of the de...
# 6     to simulate the behaviour of portion of the de...
# 7     to simulate the behaviour of portion of the de...
# 8     to simulate the behaviour of portion of the de...
# 9     to simulate the behaviour of portion of the de...
# 10    to simulate the behaviour of portion of the de...
# 11    to simulate the behaviour of portion of the de...
# 12    to simulate the behaviour of portion of the de...
# 13    to simulate the behaviour of portion of the de...
# 14    to simulate the behaviour of portion of the de...
# 15    to simulate the behaviour of portion of the de...
# 16    to simulate the behaviour of portion of the de...
# 17    to simulate the behaviour of portion of the de...
# 18    to simulate the behaviour of portion of the de...
# 19    to simulate the behaviour of portion of the de...
# 20    to simulate the behaviour of portion of the de...
# 21    to simulate the behaviour of portion of the de...
# 22    to simulate the behaviour of portion of the de...
# 23    to simulate the behaviour of portion of the de...
# 24    to simulate the behaviour of portion of the de...
# 25    to simulate the behaviour of portion of the de...
# 26    to simulate the behaviour of portion of the de...
# 27    to simulate the behaviour of portion of the de...
# 28    to simulate the behaviour of portion of the de...
# 29    the testing stage can influence both the codin...
# ...                                                 ...
# 2412  find the node then replace it with the leftmos...
# 2413  find the node then replace it with the leftmos...
# 2414                             the height of the tree
# 2415                             the height of the tree
# 2416                             the height of the tree
# 2417                             the height of the tree
# 2418                             the height of the tree
# 2419                             the height of the tree
# 2420                             the height of the tree
# 2421                             the height of the tree
# 2422                             the height of the tree
# 2423                             the height of the tree
# 2424                             the height of the tree
# 2425                             the height of the tree
# 2426                             the height of the tree
# 2427                             the height of the tree
# 2428                             the height of the tree
# 2429                             the height of the tree
# 2430                             the height of the tree
# 2431                             the height of the tree
# 2432                             the height of the tree
# 2433                             the height of the tree
# 2434                             the height of the tree
# 2435                             the height of the tree
# 2436                             the height of the tree
# 2437                             the height of the tree
# 2438                             the height of the tree
# 2439                             the height of the tree
# 2440                             the height of the tree
# 2441                             the height of the tree
#
#                                        student_modified  \
# 0     high risk problem are address in the prototype...
# 1     to simulate portion of the desired final produ...
# 2     a prototype program simulates the behavior of ...
# 3     defined in the specification phase a prototype...
# 4     it is used to let the user have a first idea o...
# 5     to find problem and error in a program before ...
# 6     to address major issue in the creation of the ...
# 7     you can break the whole program into prototype...
# 8     to provide an example or model of how the fini...
# 9     simulating the behavior of only a portion of t...
# 10    a program that stimulates the behavior of port...
# 11    a program that simulates the behavior of porti...
# 12    to lay out the basic and give you a starting p...
# 13    to simulate problem solving for part of the pr...
# 14    a prototype program provides a basic groundwor...
# 15    a prototype program is a part of the specifica...
# 16    program that simulates the behavior of portion...
# 17    it provides a limited proof of concept to veri...
# 18    it test the main function of the program while...
# 19    to get early feedback from user in early stage...
# 20    it simulates the behavior of portion of the de...
# 21    it simulates the behavior of portion of the de...
# 22    a prototype program is used in problem solving...
# 23    to ease the understanding of problem under dis...
# 24    it simulates the behavior of portion of the de...
# 25    the role of a prototype program is to help spo...
# 26    the prototype program give a general idea of w...
# 27    to show that a certain part of the program wor...
# 28    prototype programming is an approach to progra...
# 29    refining and possibly the design if the testin...
# ...                                                 ...
# 2412  if it ha no child you just delete it if it onl...
# 2413  pointer to the child and delete it ha 2 child ...
# 2414        log lrb n rrb where n is the number of node
# 2415                                 log lrb n rrb step
# 2416     the number of level and the height of the tree
# 2417            it is the same a the height of the tree
# 2418  given n element it would take n divided by 2 s...
# 2419                                              log n
# 2420  depends on the location of the node you are lo...
# 2421  2 to the power of n where n is the of level th...
# 2422  the number of step to search a node is the fun...
# 2423       it would take n divided by 2 element given n
# 2424                                      log lrb n rrb
# 2425                                    o lrb log n rrb
# 2426                            o lrb log lrb n rrb rrb
# 2427  if the binary search tree is constructed effic...
# 2428                       n n being the number of node
# 2429  depending on the way that the tree is ordered ...
# 2430                                      log lrb n rrb
# 2431  worst case scenario equal the number of level ...
# 2432                    3 step at most there are 3 case
# 2433  log lrb n rrb where n equal the total number o...
# 2434  the same number of step a the number of level ...
# 2435  to find a node in a binary search tree take at...
# 2436  three step visit the root node then go to righ...
# 2437                                              log n
# 2438           lrb n lrb n minus 1 rrb rrb divided by 2
# 2439                                                2n1
# 2440  it take at most h step where h is the height o...
# 2441  it depends on the install search tree then fro...
#
#                                         student_demoted  \
# 0     high risk are address make sure that feasible ...
# 1     simulate portion desired final product with qu...
# 2     simulates behavior portion desired software pr...
# 3     defined specification phase stimulates behavio...
# 4     it used let user have first idea completed and...
# 5                    find and error before it finalized
# 6     address major issue creation there no way acco...
# 7          you can break whole into simulate part final
# 8     provide an example or model how finished shoul...
# 9     simulating behavior only portion desired softw...
# 10    that stimulates behavior portion desired softw...
# 11    that simulates behavior portion desired softwa...
# 12     lay out basic and give you starting point actual
# 13                                    simulate for part
# 14    provides basic groundwork from which further e...
# 15    part specification phase software it employed ...
# 16    that simulates behavior portion desired softwa...
# 17    it provides limited proof concept verify with ...
# 18    it test main function while leaving out finer ...
# 19    get early feedback from user early stage devel...
# 20    it simulates behavior portion desired software...
# 21    it simulates behavior portion desired software...
# 22                                used collect data for
# 23    ease understanding under discussion and ease u...
# 24    it simulates behavior portion desired software...
# 25    help spot key that may arise during actual pro...
# 26    give general idea end product will do without ...
# 27              show that certain part work it supposed
# 28    programming an approach programming that enabl...
# 29    refining and possibly design phase reveals pro...
# ...                                                 ...
# 2412  if it ha child just it if it only ha one child...
# 2413  pointer to the child and it ha 2 child set the...
# 2414                 log lrb rrb where is the number of
# 2415                                        log lrb rrb
# 2416          the number of level and the height of the
# 2417                      is the same the height of the
# 2418  given element would divided by 2 find the crit...
# 2419                                                log
# 2420  depends on the location of the you are looking...
# 2421        2 the power of where is the of level the ha
# 2422              the number of is the function minus 1
# 2423                   would divided by 2 element given
# 2424                                        log lrb rrb
# 2425                                        lrb log rrb
# 2426                                lrb log lrb rrb rrb
# 2427  if the is constructed efficiently best case sc...
# 2428                                being the number of
# 2429  depending on the way that the is ordered could...
# 2430                                        log lrb rrb
# 2431  worst case scenario equal the number of level ...
# 2432                         3 at most there are 3 case
# 2433    log lrb rrb where equal the total number of the
# 2434  the same number of the number of level or gene...
# 2435  find at most the same number of there are leve...
# 2436  three visit the root then go right subtree aft...
# 2437                                                log
# 2438               lrb lrb minus 1 rrb rrb divided by 2
# 2439                                                2n1
# 2440                 at most where is the height of the
# 2441  depends on the install then from there for wha...
#
#                                             ref_demoted  length_ratio  \
# 0     simulate behaviour portion desired software pr...      2.764706
# 1     simulate behaviour portion desired software pr...      2.911765
# 2     simulate behaviour portion desired software pr...      1.661765
# 3     simulate behaviour portion desired software pr...      3.632353
# 4     simulate behaviour portion desired software pr...      3.279412
# 5     simulate behaviour portion desired software pr...      0.897059
# 6     simulate behaviour portion desired software pr...      2.470588
# 7     simulate behaviour portion desired software pr...      1.352941
# 8     simulate behaviour portion desired software pr...      3.044118
# 9     simulate behaviour portion desired software pr...      1.073529
# 10    simulate behaviour portion desired software pr...      1.191176
# 11    simulate behaviour portion desired software pr...      1.176471
# 12    simulate behaviour portion desired software pr...      1.176471
# 13    simulate behaviour portion desired software pr...      0.750000
# 14    simulate behaviour portion desired software pr...      1.661765
# 15    simulate behaviour portion desired software pr...      3.264706
# 16    simulate behaviour portion desired software pr...      1.147059
# 17    simulate behaviour portion desired software pr...      1.676471
# 18    simulate behaviour portion desired software pr...      1.102941
# 19    simulate behaviour portion desired software pr...      3.058824
# 20    simulate behaviour portion desired software pr...      1.000000
# 21    simulate behaviour portion desired software pr...      1.000000
# 22    simulate behaviour portion desired software pr...      1.147059
# 23    simulate behaviour portion desired software pr...      1.544118
# 24    simulate behaviour portion desired software pr...      1.000000
# 25    simulate behaviour portion desired software pr...      1.514706
# 26    simulate behaviour portion desired software pr...      1.955882
# 27    simulate behaviour portion desired software pr...      0.985294
# 28    simulate behaviour portion desired software pr...      5.750000
# 29    can both coding phase 5 and solution refinemen...      3.233010
# ...                                                 ...           ...
# 2412  find the then replace it with the leftmost it ...      1.948718
# 2413  find the then replace it with the leftmost it ...      1.119658
# 2414                                  the height of the      1.954545
# 2415                                  the height of the      0.818182
# 2416                                  the height of the      2.090909
# 2417                                  the height of the      1.772727
# 2418                                  the height of the      3.545455
# 2419                                  the height of the      0.227273
# 2420                                  the height of the     10.318182
# 2421                                  the height of the      2.818182
# 2422                                  the height of the      2.772727
# 2423                                  the height of the      2.000000
# 2424                                  the height of the      0.590909
# 2425                                  the height of the      0.681818
# 2426                                  the height of the      1.045455
# 2427                                  the height of the     21.000000
# 2428                                  the height of the      1.272727
# 2429                                  the height of the      4.500000
# 2430                                  the height of the      0.590909
# 2431                                  the height of the      7.090909
# 2432                                  the height of the      1.409091
# 2433                                  the height of the      2.909091
# 2434                                  the height of the      3.227273
# 2435                                  the height of the      4.772727
# 2436                                  the height of the      4.681818
# 2437                                  the height of the      0.227273
# 2438                                  the height of the      1.818182
# 2439                                  the height of the      0.136364
# 2440                                  the height of the      2.545455
# 2441                                  the height of the      6.136364
#
#       grades_round                                          embed_ref  \
# 0                4  [[0.31087402343750004, 0.12618164062500004, 0....
# 1                5  [[0.31087402343750004, 0.12618164062500004, 0....
# 2                4  [[0.31087402343750004, 0.12618164062500004, 0....
# 3                5  [[0.31087402343750004, 0.12618164062500004, 0....
# 4                3  [[0.31087402343750004, 0.12618164062500004, 0....
# 5                2  [[0.31087402343750004, 0.12618164062500004, 0....
# 6                2  [[0.31087402343750004, 0.12618164062500004, 0....
# 7                5  [[0.31087402343750004, 0.12618164062500004, 0....
# 8                4  [[0.31087402343750004, 0.12618164062500004, 0....
# 9                5  [[0.31087402343750004, 0.12618164062500004, 0....
# 10               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 11               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 12               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 13               4  [[0.31087402343750004, 0.12618164062500004, 0....
# 14               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 15               4  [[0.31087402343750004, 0.12618164062500004, 0....
# 16               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 17               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 18               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 19               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 20               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 21               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 22               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 23               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 24               5  [[0.31087402343750004, 0.12618164062500004, 0....
# 25               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 26               3  [[0.31087402343750004, 0.12618164062500004, 0....
# 27               3  [[0.31087402343750004, 0.12618164062500004, 0....
# 28               2  [[0.31087402343750004, 0.12618164062500004, 0....
# 29               4  [[0.4525048828125, 0.905751953125, 0.370107421...
# ...            ...                                                ...
# 2412             4  [[1.05466796875, -0.5786061096191406, 0.897563...
# 2413             3  [[1.05466796875, -0.5786061096191406, 0.897563...
# 2414             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2415             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2416             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2417             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2418             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2419             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2420             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2421             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2422             4  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2423             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2424             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2425             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2426             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2427             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2428             4  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2429             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2430             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2431             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2432             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2433             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2434             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2435             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2436             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2437             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2438             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2439             2  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2440             5  [[0.76439453125, 0.59056640625, -0.10254882812...
# 2441             2  [[0.76439453125, 0.59056640625, -0.10254882812...
#
#                                              embed_stud         e
# 0     [[-0.34491821289062496, 0.24433044433593754, 1...  1.002981
# 1     [[2.425458984375, 0.7010594177246094, 0.774389...  0.036798
# 2     [[-0.10392089843749999, 0.23617462158203129, 0...  0.848556
# 3     [[0.34676391601562506, 0.9747241210937501, 1.0... -2.269228
# 4     [[0.5336535644531251, 0.509168930053711, 1.255...  1.307041
# 5     [[0.13824584960937503, -0.00038215637207028585... -0.256376
# 6     [[0.23454956054687504, 0.8501024627685547, 1.3...  0.240542
# 7     [[0.332530517578125, 0.6316943359375, 0.691752...  0.133074
# 8     [[0.05676513671875005, 1.2948251342773438, 0.9...  0.131362
# 9     [[0.43350341796875, 0.05172851562500003, 0.363... -0.631951
# 10    [[0.14334228515625003, 0.23910644531250003, 0.... -1.479281
# 11    [[0.23489501953125003, 0.23336914062500003, 0.... -0.903454
# 12    [[1.316468505859375, -0.04476806640624997, 0.5... -1.234580
# 13    [[0.38663818359375, 0.18162109375000002, -0.09...  0.217329
# 14    [[-0.6906201171874999, 0.4286511611938477, 0.0...  1.101930
# 15    [[0.7327722167968751, 0.7340367889404298, 1.55... -1.033737
# 16    [[0.22489501953125002, 0.22336914062500002, 0....  1.369014
# 17    [[-0.24441406249999997, -0.6598670196533203, -...  0.876165
# 18    [[0.67961669921875, 0.036624679565429696, 0.67...  0.129092
# 19    [[0.37262207031250005, 0.9042926406860352, 1.0... -0.067112
# 20    [[0.40861083984375, 0.1551451873779297, 0.395,... -1.333687
# 21    [[0.40861083984375, 0.1551451873779297, 0.395,... -0.088753
# 22    [[0.45408203125, 0.2513232421875, 0.2932849121...  1.162620
# 23    [[0.24287109375000004, 0.7482421875, -0.230456... -1.048202
# 24    [[0.40861083984375, 0.1551451873779297, 0.395,... -0.901619
# 25    [[0.331116943359375, 0.6653759765625, 0.574616...  1.231897
# 26    [[0.9762030029296875, 0.901083984375, 1.016318...  0.949064
# 27    [[0.29389648437500004, 0.3487308502197266, 0.8...  0.523148
# 28    [[0.7873583984375001, 1.935110206604004, 1.471... -1.204016
# 29    [[-0.15825195312499996, 0.694643783569336, 3.1... -0.175719
# ...                                                 ...       ...
# 2412  [[3.6437084960937494, -1.3757750701904297, 3.0...  0.710811
# 2413  [[1.9301269531249998, 0.7210605621337891, 1.81... -1.956930
# 2414  [[0.339234619140625, -0.20107910156249997, -0.... -0.213874
# 2415  [[-0.06624267578124998, 0.12498046875, -0.2155... -0.682451
# 2416  [[0.85373046875, 0.6771405029296875, 0.0973828...  0.987313
# 2417  [[1.116893310546875, 0.6198668670654297, 0.218... -0.507634
# 2418  [[0.5539453125, 0.1284215545654297, 0.44505859... -0.025762
# 2419  [[0.11981201, -0.0034179688, -0.34594727, 0.10... -0.008267
# 2420  [[1.86367919921875, -0.3933474731445312, 2.994...  1.688897
# 2421  [[1.170289306640625, 0.3023846435546875, 0.647... -1.278316
# 2422  [[0.390565185546875, -0.3468310546875, 0.24667...  1.626117
# 2423  [[0.49865723, -0.09520149, 0.58691406, 0.91845... -0.648465
# 2424  [[0.13981201171875002, 0.016582031250000004, -... -1.012759
# 2425  [[-0.02425048828124999, 0.09861328124999999, -... -0.941771
# 2426  [[-0.004250488281249989, 0.11861328124999998, ... -1.149169
# 2427  [[4.394963378906248, 1.3501769256591798, 1.676... -0.786857
# 2428  [[0.005483398437500002, -0.10462402343749999, ... -0.567828
# 2429  [[1.160218505859375, -0.14454719543457029, 0.8... -0.024622
# 2430  [[0.13981201171875002, 0.016582031250000004, -...  0.871020
# 2431  [[0.7894091796875, 0.37974788665771486, 2.1871... -0.155678
# 2432  [[0.0871582, -0.2479248, 0.34973145, 0.4655761... -1.205362
# 2433  [[1.01699951171875, -0.14053222656249997, 0.04... -0.179988
# 2434  [[0.9424546051025391, 0.6572430419921875, 0.86...  1.857088
# 2435  [[1.3814111328125, 0.12925964355468755, 0.1615... -1.118554
# 2436  [[0.10518554687500002, 0.794486083984375, 0.91... -0.507956
# 2437  [[0.11981201, -0.0034179688, -0.34594727, 0.10... -0.217688
# 2438  [[0.12465576171875001, -0.43485351562499996, 0...  0.677985
# 2439  [[0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.... -0.843944
# 2440  [[0.04567504882812501, 0.9564244842529297, 0.3...  1.089696
# 2441  [[1.8198449707031248, 0.5125815963745117, 0.80... -0.028058
#
# [2442 rows x 15 columns]

# %%
x = 'my age is 222 '
' '.join(x for x in x.split() if not x.isdigit())
# Out:
# 'my age is'

# %%
len(df['ref_modified'].unique())
# Out:
# 84

# %%
df = df.head()

# %%
df
# Out:
#    question_id                                           question  \
# 0          1.1  What is the role of a prototype program in pro...
# 1          1.1  What is the role of a prototype program in pro...
# 2          1.1  What is the role of a prototype program in pro...
# 3          1.1  What is the role of a prototype program in pro...
# 4          1.1  What is the role of a prototype program in pro...
#
#                                           ref_answer  \
# 0  To simulate the behaviour of portions of the d...
# 1  To simulate the behaviour of portions of the d...
# 2  To simulate the behaviour of portions of the d...
# 3  To simulate the behaviour of portions of the d...
# 4  To simulate the behaviour of portions of the d...
#
#                                       student_answer  grade  \
# 0  High risk problems are address in the prototyp...    3.5
# 1  To simulate portions of the desired final prod...    5.0
# 2  A prototype program simulates the behaviors of...    4.0
# 3  Defined in the Specification phase a prototype...    5.0
# 4  It is used to let the users have a first idea ...    3.0
#
#                                       qn_modified  \
# 0  what role prototype program in problem solving
# 1  what role prototype program in problem solving
# 2  what role prototype program in problem solving
# 3  what role prototype program in problem solving
# 4  what role prototype program in problem solving
#
#                                         ref_modified  \
# 0  to simulate behaviour portion desired software...
# 1  to simulate behaviour portion desired software...
# 2  to simulate behaviour portion desired software...
# 3  to simulate behaviour portion desired software...
# 4  to simulate behaviour portion desired software...
#
#                                     student_modified  \
# 0  high risk problem address in prototype program...
# 1  to simulate portion desired final product quic...
# 2  prototype program simulates behavior portion d...
# 3  defined in specification phase prototype stimu...
# 4  it used to let user first idea completed progr...
#
#                                      student_demoted  \
# 0  high risk address make sure that feasible may ...
# 1  simulate portion desired final product quick a...
# 2  simulates behavior portion desired software pr...
# 3  defined specification phase stimulates behavio...
# 4  it used let user first idea completed and allo...
#
#                                          ref_demoted  length_ratio  \
# 0  simulate behaviour portion desired software pr...      3.055556
# 1  simulate behaviour portion desired software pr...      3.074074
# 2  simulate behaviour portion desired software pr...      1.722222
# 3  simulate behaviour portion desired software pr...      3.814815
# 4  simulate behaviour portion desired software pr...      3.462963
#
#    grades_round                                          embed_ref  \
# 0             4  [[0.13071777343750002, -0.10377929687499998, 0...
# 1             5  [[0.13071777343750002, -0.10377929687499998, 0...
# 2             4  [[0.13071777343750002, -0.10377929687499998, 0...
# 3             5  [[0.13071777343750002, -0.10377929687499998, 0...
# 4             3  [[0.13071777343750002, -0.10377929687499998, 0...
#
#                                           embed_stud
# 0  [[-0.5155224609375, 0.008998413085937518, 1.30...
# 1  [[2.15602783203125, 0.4706297302246094, 0.2766...
# 2  [[-0.28229736328125, 0.043576965332031245, 0.2...
# 3  [[-0.127725830078125, 0.53630615234375, 0.3706...
# 4  [[0.23586181640625004, 0.06217674255371097, 0....

# %%
df = pd.read_pickle("./feature_saved.pkl") 
df
# Out:
#       question_id                                           question  \
# 0             1.1  What is the role of a prototype program in pro...
# 1             1.1  What is the role of a prototype program in pro...
# 2             1.1  What is the role of a prototype program in pro...
# 3             1.1  What is the role of a prototype program in pro...
# 4             1.1  What is the role of a prototype program in pro...
# 5             1.1  What is the role of a prototype program in pro...
# 6             1.1  What is the role of a prototype program in pro...
# 7             1.1  What is the role of a prototype program in pro...
# 8             1.1  What is the role of a prototype program in pro...
# 9             1.1  What is the role of a prototype program in pro...
# 10            1.1  What is the role of a prototype program in pro...
# 11            1.1  What is the role of a prototype program in pro...
# 12            1.1  What is the role of a prototype program in pro...
# 13            1.1  What is the role of a prototype program in pro...
# 14            1.1  What is the role of a prototype program in pro...
# 15            1.1  What is the role of a prototype program in pro...
# 16            1.1  What is the role of a prototype program in pro...
# 17            1.1  What is the role of a prototype program in pro...
# 18            1.1  What is the role of a prototype program in pro...
# 19            1.1  What is the role of a prototype program in pro...
# 20            1.1  What is the role of a prototype program in pro...
# 21            1.1  What is the role of a prototype program in pro...
# 22            1.1  What is the role of a prototype program in pro...
# 23            1.1  What is the role of a prototype program in pro...
# 24            1.1  What is the role of a prototype program in pro...
# 25            1.1  What is the role of a prototype program in pro...
# 26            1.1  What is the role of a prototype program in pro...
# 27            1.1  What is the role of a prototype program in pro...
# 28            1.1  What is the role of a prototype program in pro...
# 29            1.2  What stages in the software life cycle are inf...
# ...           ...                                                ...
# 2412         12.9  How do you delete a node from a binary search ...
# 2413         12.9  How do you delete a node from a binary search ...
# 2414         12.1  How many steps does it take to search a node i...
# 2415         12.1  How many steps does it take to search a node i...
# 2416         12.1  How many steps does it take to search a node i...
# 2417         12.1  How many steps does it take to search a node i...
# 2418         12.1  How many steps does it take to search a node i...
# 2419         12.1  How many steps does it take to search a node i...
# 2420         12.1  How many steps does it take to search a node i...
# 2421         12.1  How many steps does it take to search a node i...
# 2422         12.1  How many steps does it take to search a node i...
# 2423         12.1  How many steps does it take to search a node i...
# 2424         12.1  How many steps does it take to search a node i...
# 2425         12.1  How many steps does it take to search a node i...
# 2426         12.1  How many steps does it take to search a node i...
# 2427         12.1  How many steps does it take to search a node i...
# 2428         12.1  How many steps does it take to search a node i...
# 2429         12.1  How many steps does it take to search a node i...
# 2430         12.1  How many steps does it take to search a node i...
# 2431         12.1  How many steps does it take to search a node i...
# 2432         12.1  How many steps does it take to search a node i...
# 2433         12.1  How many steps does it take to search a node i...
# 2434         12.1  How many steps does it take to search a node i...
# 2435         12.1  How many steps does it take to search a node i...
# 2436         12.1  How many steps does it take to search a node i...
# 2437         12.1  How many steps does it take to search a node i...
# 2438         12.1  How many steps does it take to search a node i...
# 2439         12.1  How many steps does it take to search a node i...
# 2440         12.1  How many steps does it take to search a node i...
# 2441         12.1  How many steps does it take to search a node i...
#
#                                              ref_answer  \
# 0     To simulate the behaviour of portions of the d...
# 1     To simulate the behaviour of portions of the d...
# 2     To simulate the behaviour of portions of the d...
# 3     To simulate the behaviour of portions of the d...
# 4     To simulate the behaviour of portions of the d...
# 5     To simulate the behaviour of portions of the d...
# 6     To simulate the behaviour of portions of the d...
# 7     To simulate the behaviour of portions of the d...
# 8     To simulate the behaviour of portions of the d...
# 9     To simulate the behaviour of portions of the d...
# 10    To simulate the behaviour of portions of the d...
# 11    To simulate the behaviour of portions of the d...
# 12    To simulate the behaviour of portions of the d...
# 13    To simulate the behaviour of portions of the d...
# 14    To simulate the behaviour of portions of the d...
# 15    To simulate the behaviour of portions of the d...
# 16    To simulate the behaviour of portions of the d...
# 17    To simulate the behaviour of portions of the d...
# 18    To simulate the behaviour of portions of the d...
# 19    To simulate the behaviour of portions of the d...
# 20    To simulate the behaviour of portions of the d...
# 21    To simulate the behaviour of portions of the d...
# 22    To simulate the behaviour of portions of the d...
# 23    To simulate the behaviour of portions of the d...
# 24    To simulate the behaviour of portions of the d...
# 25    To simulate the behaviour of portions of the d...
# 26    To simulate the behaviour of portions of the d...
# 27    To simulate the behaviour of portions of the d...
# 28    To simulate the behaviour of portions of the d...
# 29    The testing stage can influence both the codin...
# ...                                                 ...
# 2412  Find the node  then replace it with the leftmo...
# 2413  Find the node  then replace it with the leftmo...
# 2414                            The height of the tree.
# 2415                            The height of the tree.
# 2416                            The height of the tree.
# 2417                            The height of the tree.
# 2418                            The height of the tree.
# 2419                            The height of the tree.
# 2420                            The height of the tree.
# 2421                            The height of the tree.
# 2422                            The height of the tree.
# 2423                            The height of the tree.
# 2424                            The height of the tree.
# 2425                            The height of the tree.
# 2426                            The height of the tree.
# 2427                            The height of the tree.
# 2428                            The height of the tree.
# 2429                            The height of the tree.
# 2430                            The height of the tree.
# 2431                            The height of the tree.
# 2432                            The height of the tree.
# 2433                            The height of the tree.
# 2434                            The height of the tree.
# 2435                            The height of the tree.
# 2436                            The height of the tree.
# 2437                            The height of the tree.
# 2438                            The height of the tree.
# 2439                            The height of the tree.
# 2440                            The height of the tree.
# 2441                            The height of the tree.
#
#                                          student_answer  grade  \
# 0     High risk problems are address in the prototyp...    3.5
# 1     To simulate portions of the desired final prod...    5.0
# 2     A prototype program simulates the behaviors of...    4.0
# 3     Defined in the Specification phase a prototype...    5.0
# 4     It is used to let the users have a first idea ...    3.0
# 5     To find problem and errors in a program before...    2.0
# 6     To address major issues in the creation of the...    2.5
# 7     you can break the whole program into prototype...    5.0
# 8     To provide an example or model of how the fini...    3.5
# 9     Simulating the behavior of only a portion of t...    5.0
# 10    A program that stimulates the behavior of port...    5.0
# 11    A program that simulates the behavior of porti...    5.0
# 12    To lay out the basics and give you a starting ...    2.0
# 13    To simulate problem solving for parts of the p...    4.5
# 14    A prototype program provides a basic groundwor...    2.0
# 15    A prototype program is a part of the Specifica...    4.5
# 16    Program that simulates the behavior of portion...    5.0
# 17    it provides a limited proof of concept to veri...    2.0
# 18    It tests the main function of the program whil...    2.0
# 19    To get early feedback from users in early stag...    2.5
# 20    it simulates the behavior of portions of the d...    5.0
# 21    It simulates the behavior of portions of the d...    5.0
# 22    A prototype program is used in problem solving...    1.5
# 23    To ease the understanding of problem under dis...    2.5
# 24    it simulates the behavior of portions of the d...    5.0
# 25    The role of a prototype program is to help spo...    2.0
# 26    the prototype program gives a general idea of ...    3.0
# 27    to show that a certain part of the program wor...    3.0
# 28    Prototype programming is an approach to progra...    2.5
# 29    Refining and possibly the design if the testin...    3.5
# ...                                                 ...    ...
# 2412  if it has no children  you just delete it. if ...    4.0
# 2413  pointer to the child and delete it has 2 child...    3.0
# 2414  Log -LRB- n -RRB- where n is the number of nod...    5.0
# 2415                           log -LRB- n -RRB- steps     5.0
# 2416   The number of levels and the height of the tree     5.0
# 2417         It is the same as the height of the tree.     5.0
# 2418  Given n elements  it would take n divided by 2...    1.5
# 2419                                             log n     5.0
# 2420  Depends on the location of the node you are lo...    2.0
# 2421  2 to the power of n where n is the of levels t...    2.0
# 2422  The number of steps to search a node is the fu...    3.5
# 2423   It would take n divided by 2 elements  given n.     1.5
# 2424                                 log -LRB- n -RRB-     5.0
# 2425                               O -LRB- log n -RRB-     5.0
# 2426                   O -LRB- Log -LRB- n -RRB- -RRB-     5.0
# 2427  If the binary search tree is constructed effic...    5.0
# 2428                   N  n being the number of nodes.     4.0
# 2429  depending on the way that the tree is ordered ...    5.0
# 2430                                 log -LRB- n -RRB-     5.0
# 2431  worst case scenario equals the number of level...    5.0
# 2432              3 steps at most.  There are 3 cases.     1.5
# 2433  log -LRB- n -RRB- where n equals the total num...    5.0
# 2434  the same number of steps as the number of leve...    5.0
# 2435  to find a node in a binary search tree takes a...    5.0
# 2436  three steps visit the root node  then go to ri...    2.5
# 2437                                             log n     5.0
# 2438  -LRB- n -LRB- n minus 1 -RRB- -RRB- divided by 2     1.5
# 2439                                              2n-1     2.5
# 2440  it takes at most h steps  where h is the heigh...    5.0
# 2441  it depends on the install search tree then fro...    1.5
#
#                                             qn_modified  \
# 0        what role prototype program in problem solving
# 1        what role prototype program in problem solving
# 2        what role prototype program in problem solving
# 3        what role prototype program in problem solving
# 4        what role prototype program in problem solving
# 5        what role prototype program in problem solving
# 6        what role prototype program in problem solving
# 7        what role prototype program in problem solving
# 8        what role prototype program in problem solving
# 9        what role prototype program in problem solving
# 10       what role prototype program in problem solving
# 11       what role prototype program in problem solving
# 12       what role prototype program in problem solving
# 13       what role prototype program in problem solving
# 14       what role prototype program in problem solving
# 15       what role prototype program in problem solving
# 16       what role prototype program in problem solving
# 17       what role prototype program in problem solving
# 18       what role prototype program in problem solving
# 19       what role prototype program in problem solving
# 20       what role prototype program in problem solving
# 21       what role prototype program in problem solving
# 22       what role prototype program in problem solving
# 23       what role prototype program in problem solving
# 24       what role prototype program in problem solving
# 25       what role prototype program in problem solving
# 26       what role prototype program in problem solving
# 27       what role prototype program in problem solving
# 28       what role prototype program in problem solving
# 29    what stage in software life cycle influenced t...
# ...                                                 ...
# 2412     how do you delete node from binary search tree
# 2413     how do you delete node from binary search tree
# 2414  how many step doe it take to search node in bi...
# 2415  how many step doe it take to search node in bi...
# 2416  how many step doe it take to search node in bi...
# 2417  how many step doe it take to search node in bi...
# 2418  how many step doe it take to search node in bi...
# 2419  how many step doe it take to search node in bi...
# 2420  how many step doe it take to search node in bi...
# 2421  how many step doe it take to search node in bi...
# 2422  how many step doe it take to search node in bi...
# 2423  how many step doe it take to search node in bi...
# 2424  how many step doe it take to search node in bi...
# 2425  how many step doe it take to search node in bi...
# 2426  how many step doe it take to search node in bi...
# 2427  how many step doe it take to search node in bi...
# 2428  how many step doe it take to search node in bi...
# 2429  how many step doe it take to search node in bi...
# 2430  how many step doe it take to search node in bi...
# 2431  how many step doe it take to search node in bi...
# 2432  how many step doe it take to search node in bi...
# 2433  how many step doe it take to search node in bi...
# 2434  how many step doe it take to search node in bi...
# 2435  how many step doe it take to search node in bi...
# 2436  how many step doe it take to search node in bi...
# 2437  how many step doe it take to search node in bi...
# 2438  how many step doe it take to search node in bi...
# 2439  how many step doe it take to search node in bi...
# 2440  how many step doe it take to search node in bi...
# 2441  how many step doe it take to search node in bi...
#
#                                            ref_modified  \
# 0     to simulate behaviour portion desired software...
# 1     to simulate behaviour portion desired software...
# 2     to simulate behaviour portion desired software...
# 3     to simulate behaviour portion desired software...
# 4     to simulate behaviour portion desired software...
# 5     to simulate behaviour portion desired software...
# 6     to simulate behaviour portion desired software...
# 7     to simulate behaviour portion desired software...
# 8     to simulate behaviour portion desired software...
# 9     to simulate behaviour portion desired software...
# 10    to simulate behaviour portion desired software...
# 11    to simulate behaviour portion desired software...
# 12    to simulate behaviour portion desired software...
# 13    to simulate behaviour portion desired software...
# 14    to simulate behaviour portion desired software...
# 15    to simulate behaviour portion desired software...
# 16    to simulate behaviour portion desired software...
# 17    to simulate behaviour portion desired software...
# 18    to simulate behaviour portion desired software...
# 19    to simulate behaviour portion desired software...
# 20    to simulate behaviour portion desired software...
# 21    to simulate behaviour portion desired software...
# 22    to simulate behaviour portion desired software...
# 23    to simulate behaviour portion desired software...
# 24    to simulate behaviour portion desired software...
# 25    to simulate behaviour portion desired software...
# 26    to simulate behaviour portion desired software...
# 27    to simulate behaviour portion desired software...
# 28    to simulate behaviour portion desired software...
# 29    testing stage can influence both coding stage ...
# ...                                                 ...
# 2412  find node then replace it leftmost node from i...
# 2413  find node then replace it leftmost node from i...
# 2414                                        height tree
# 2415                                        height tree
# 2416                                        height tree
# 2417                                        height tree
# 2418                                        height tree
# 2419                                        height tree
# 2420                                        height tree
# 2421                                        height tree
# 2422                                        height tree
# 2423                                        height tree
# 2424                                        height tree
# 2425                                        height tree
# 2426                                        height tree
# 2427                                        height tree
# 2428                                        height tree
# 2429                                        height tree
# 2430                                        height tree
# 2431                                        height tree
# 2432                                        height tree
# 2433                                        height tree
# 2434                                        height tree
# 2435                                        height tree
# 2436                                        height tree
# 2437                                        height tree
# 2438                                        height tree
# 2439                                        height tree
# 2440                                        height tree
# 2441                                        height tree
#
#                                        student_modified  \
# 0     high risk problem address in prototype program...
# 1     to simulate portion desired final product quic...
# 2     prototype program simulates behavior portion d...
# 3     defined in specification phase prototype stimu...
# 4     it used to let user first idea completed progr...
# 5     to find problem and error in program before it...
# 6     to address major issue in creation program the...
# 7     you can break whole program into prototype pro...
# 8     to provide example or model how finished progr...
# 9     simulating behavior only portion desired softw...
# 10    program that stimulates behavior portion desir...
# 11    program that simulates behavior portion desire...
# 12    to lay out basic and give you starting point i...
# 13             to simulate problem solving part problem
# 14    prototype program provides basic groundwork fr...
# 15    prototype program part specification phase sof...
# 16    program that simulates behavior portion desire...
# 17    it provides limited proof concept to verify cl...
# 18    it test main function program while leaving ou...
# 19    to get early feedback from user in early stage...
# 20    it simulates behavior portion desired software...
# 21    it simulates behavior portion desired software...
# 22    prototype program used in problem solving to c...
# 23    to ease understanding problem under discussion...
# 24    it simulates behavior portion desired software...
# 25    role prototype program to help spot key proble...
# 26    prototype program give general idea what end p...
# 27    to show that certain part program work it supp...
# 28    prototype programming approach to programming ...
# 29    refining and possibly design if testing phase ...
# ...                                                 ...
# 2412  if it no child you just delete it if it only o...
# 2413  pointer to child and delete it child set node ...
# 2414                  log lrb n rrb where n number node
# 2415                                 log lrb n rrb step
# 2416                       number level and height tree
# 2417                                it same height tree
# 2418  given n element it would take n divided step t...
# 2419                                              log n
# 2420  depends on location node you looking if it roo...
# 2421               to power n where n level binary tree
# 2422        number step to search node function n minus
# 2423            it would take n divided element given n
# 2424                                      log lrb n rrb
# 2425                                    o lrb log n rrb
# 2426                            o lrb log lrb n rrb rrb
# 2427  if binary search tree constructed efficiently ...
# 2428                              n n being number node
# 2429  depending on way that tree ordered it could be...
# 2430                                      log lrb n rrb
# 2431  worst case scenario equal number level tree ie...
# 2432                               step most there case
# 2433  log lrb n rrb where n equal total number node ...
# 2434  same number step number level or generation in...
# 2435  to find node in binary search tree take most s...
# 2436  three step visit root node then go to right su...
# 2437                                              log n
# 2438                  lrb n lrb n minus rrb rrb divided
# 2439                                                2n1
# 2440            it take most h step where h height tree
# 2441  it depends on install search tree then from th...
#
#                                         student_demoted  \
# 0     high risk address make sure that feasible may ...
# 1     simulate portion desired final product quick a...
# 2     simulates behavior portion desired software pr...
# 3     defined specification phase stimulates behavio...
# 4     it used let user first idea completed and allo...
# 5                    find and error before it finalized
# 6     address major issue creation there no way acco...
# 7          you can break whole into simulate part final
# 8     provide example or model how finished should p...
# 9     simulating behavior only portion desired softw...
# 10    that stimulates behavior portion desired softw...
# 11    that simulates behavior portion desired softwa...
# 12     lay out basic and give you starting point actual
# 13                                        simulate part
# 14    provides basic groundwork from which further e...
# 15    part specification phase software it employed ...
# 16    that simulates behavior portion desired softwa...
# 17    it provides limited proof concept verify clien...
# 18    it test main function while leaving out finer ...
# 19    get early feedback from user early stage devel...
# 20    it simulates behavior portion desired software...
# 21    it simulates behavior portion desired software...
# 22                                    used collect data
# 23    ease understanding under discussion and ease u...
# 24    it simulates behavior portion desired software...
# 25    help spot key that may arise during actual pro...
# 26    give general idea end product will do without ...
# 27              show that certain part work it supposed
# 28    programming approach programming that enables ...
# 29    refining and possibly design phase reveals pro...
# ...                                                 ...
# 2412  if it child just it if it only one child just ...
# 2413  pointer to child and it child set to child and...
# 2414                           log lrb rrb where number
# 2415                                        log lrb rrb
# 2416                            number level and height
# 2417                                        same height
# 2418         given element would divided find criterion
# 2419                                                log
# 2420  depends on location you looking if root one el...
# 2421                                  power where level
# 2422                              number function minus
# 2423                        would divided element given
# 2424                                        log lrb rrb
# 2425                                        lrb log rrb
# 2426                                lrb log lrb rrb rrb
# 2427  if constructed efficiently best case scenario ...
# 2428                                       being number
# 2429  depending on way that ordered could be anywher...
# 2430                                        log lrb rrb
# 2431  worst case scenario equal number level ie fart...
# 2432                                    most there case
# 2433               log lrb rrb where equal total number
# 2434             same number number level or generation
# 2435                  find most same number there level
# 2436  three visit root then go right subtree after v...
# 2437                                                log
# 2438                      lrb lrb minus rrb rrb divided
# 2439                                                2n1
# 2440                                  most where height
# 2441  depends on install then from there whatever ca...
#
#                                             ref_demoted  length_ratio  \
# 0     simulate behaviour portion desired software pr...      3.055556
# 1     simulate behaviour portion desired software pr...      3.074074
# 2     simulate behaviour portion desired software pr...      1.722222
# 3     simulate behaviour portion desired software pr...      3.814815
# 4     simulate behaviour portion desired software pr...      3.462963
# 5     simulate behaviour portion desired software pr...      1.037037
# 6     simulate behaviour portion desired software pr...      2.518519
# 7     simulate behaviour portion desired software pr...      1.500000
# 8     simulate behaviour portion desired software pr...      3.388889
# 9     simulate behaviour portion desired software pr...      1.055556
# 10    simulate behaviour portion desired software pr...      1.203704
# 11    simulate behaviour portion desired software pr...      1.185185
# 12    simulate behaviour portion desired software pr...      1.296296
# 13    simulate behaviour portion desired software pr...      0.740741
# 14    simulate behaviour portion desired software pr...      1.944444
# 15    simulate behaviour portion desired software pr...      3.555556
# 16    simulate behaviour portion desired software pr...      1.185185
# 17    simulate behaviour portion desired software pr...      1.777778
# 18    simulate behaviour portion desired software pr...      1.111111
# 19    simulate behaviour portion desired software pr...      3.555556
# 20    simulate behaviour portion desired software pr...      1.000000
# 21    simulate behaviour portion desired software pr...      1.000000
# 22    simulate behaviour portion desired software pr...      1.203704
# 23    simulate behaviour portion desired software pr...      1.611111
# 24    simulate behaviour portion desired software pr...      1.000000
# 25    simulate behaviour portion desired software pr...      1.611111
# 26    simulate behaviour portion desired software pr...      2.074074
# 27    simulate behaviour portion desired software pr...      0.981481
# 28    simulate behaviour portion desired software pr...      6.388889
# 29    can both coding phase and solution refinement ...      3.448276
# ...                                                 ...           ...
# 2412  find then replace it leftmost it right subtree...      1.840000
# 2413  find then replace it leftmost it right subtree...      1.100000
# 2414                                             height      3.000000
# 2415                                             height      1.636364
# 2416                                             height      2.545455
# 2417                                             height      1.727273
# 2418                                             height      6.272727
# 2419                                             height      0.454545
# 2420                                             height     15.272727
# 2421                                             height      3.272727
# 2422                                             height      3.909091
# 2423                                             height      3.545455
# 2424                                             height      1.181818
# 2425                                             height      1.363636
# 2426                                             height      2.090909
# 2427                                             height     33.727273
# 2428                                             height      1.909091
# 2429                                             height      8.000000
# 2430                                             height      1.181818
# 2431                                             height     11.000000
# 2432                                             height      1.818182
# 2433                                             height      4.818182
# 2434                                             height      4.636364
# 2435                                             height      7.090909
# 2436                                             height      9.000000
# 2437                                             height      0.454545
# 2438                                             height      3.000000
# 2439                                             height      0.272727
# 2440                                             height      3.545455
# 2441                                             height      9.545455
#
#       grades_round                                          embed_ref  \
# 0                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 1                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 2                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 3                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 4                3  [[0.13071777343750002, -0.10377929687499998, 0...
# 5                2  [[0.13071777343750002, -0.10377929687499998, 0...
# 6                2  [[0.13071777343750002, -0.10377929687499998, 0...
# 7                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 8                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 9                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 10               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 11               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 12               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 13               4  [[0.13071777343750002, -0.10377929687499998, 0...
# 14               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 15               4  [[0.13071777343750002, -0.10377929687499998, 0...
# 16               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 17               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 18               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 19               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 20               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 21               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 22               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 23               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 24               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 25               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 26               3  [[0.13071777343750002, -0.10377929687499998, 0...
# 27               3  [[0.13071777343750002, -0.10377929687499998, 0...
# 28               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 29               4  [[-0.03724121093749999, 0.728505859375, 0.1627...
# ...            ...                                                ...
# 2412             4  [[0.8393359375, -0.9155201721191406, 0.7835498...
# 2413             3  [[0.8393359375, -0.9155201721191406, 0.7835498...
# 2414             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2415             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2416             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2417             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2418             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2419             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2420             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2421             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2422             4  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2423             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2424             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2425             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2426             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2427             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2428             4  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2429             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2430             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2431             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2432             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2433             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2434             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2435             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2436             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2437             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2438             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2439             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2440             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2441             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
#
#                                              embed_stud  \
# 0     [[-0.5155224609375, 0.008998413085937518, 1.30...
# 1     [[2.15602783203125, 0.4706297302246094, 0.2766...
# 2     [[-0.28229736328125, 0.043576965332031245, 0.2...
# 3     [[-0.127725830078125, 0.53630615234375, 0.3706...
# 4     [[0.23586181640625004, 0.06217674255371097, 0....
# 5     [[0.12119628906250002, 0.0628600311279297, 0.0...
# 6     [[-0.10513183593749997, 0.6872704315185547, 0....
# 7     [[0.162374267578125, 0.4117333984375, 0.582143...
# 8     [[-0.33944580078125, 0.7594540405273438, 0.717...
# 9     [[0.24334717, -0.18823242, 0.23413086, 0.12432...
# 10    [[-0.046813965, -0.0008544922, 0.48388672, 0.4...
# 11    [[0.04473877, -0.006591797, 0.5078125, 0.23901...
# 12    [[1.146312255859375, -0.26472900390625, 0.4583...
# 13    [[0.30833984375, 0.11400390625000001, -0.20218...
# 14    [[-0.7306201171875, 0.3886511611938477, 0.0168...
# 15    [[0.48851684570312504, 0.6005602264404297, 1.0...
# 16    [[0.04473877, -0.006591797, 0.5078125, 0.23901...
# 17    [[-0.39966796875, -0.9118006134033203, -0.5778...
# 18    [[0.42938232, -0.28831673, 0.5189209, 0.293945...
# 19    [[0.18246582031250003, 0.6643317031860352, 0.9...
# 20    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 21    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 22    [[0.368734130859375, 0.2569482421875, 0.016927...
# 23    [[-0.01736328125, 0.41330078125, -0.3998706054...
# 24    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 25    [[0.1439111328125, 0.5086572265625, 0.28313232...
# 26    [[0.6358905029296875, 0.461162109375, 0.797099...
# 27    [[0.17676879882812502, 0.2869925689697266, 0.5...
# 28    [[0.08475952148437504, 0.729856300354004, 0.79...
# 29    [[-0.643990478515625, 0.17536643981933597, 2.5...
# ...                                                 ...
# 2412  [[2.47820068359375, -1.9582750701904297, 2.420...
# 2413  [[1.284130859375, 0.3819492340087891, 1.449673...
# 2414  [[0.24210693359375002, -0.24281738281249998, -...
# 2415  [[-0.06624267578124998, 0.12498046875, -0.2155...
# 2416  [[0.59349609375, 0.3421990966796875, -0.072031...
# 2417  [[0.8496094, 0.35816765, -0.122802734, 0.25219...
# 2418  [[0.48265625, 0.1604039764404297, 0.1828515625...
# 2419  [[0.11981201, -0.0034179688, -0.34594727, 0.10...
# 2420  [[1.5667529296875, -0.7187771606445312, 1.6323...
# 2421  [[0.57732177734375, 0.12149597167968751, 0.140...
# 2422  [[0.152578125, -0.4102880859375, -0.1097509765...
# 2423  [[0.5074463, 0.0417614, 0.37451172, 0.70996094...
# 2424  [[0.13981201171875002, 0.016582031250000004, -...
# 2425  [[-0.02425048828124999, 0.09861328124999999, -...
# 2426  [[-0.004250488281249989, 0.11861328124999998, ...
# 2427  [[3.789757080078124, 0.8338683319091797, 0.085...
# 2428  [[-0.08459473, -0.21960449, 0.028198242, 0.352...
# 2429  [[0.9930126953125, -0.2812659454345703, 0.5872...
# 2430  [[0.13981201171875002, 0.016582031250000004, -...
# 2431  [[0.29675293, -0.13927555, 1.7305908, 1.922637...
# 2432  [[0.012939453, -0.016967773, 0.119262695, 0.11...
# 2433  [[0.84684326171875, -0.3604931640625, -0.06605...
# 2434  [[0.67222023, 0.31230164, 0.6809082, 0.5546875...
# 2435  [[1.3265283203125, -0.06673645019531249, -0.15...
# 2436  [[0.02510742187500003, 0.689505615234375, 0.86...
# 2437  [[0.11981201, -0.0034179688, -0.34594727, 0.10...
# 2438  [[0.08266357421875001, -0.20462890624999996, 0...
# 2439  [[0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0....
# 2440  [[-0.07293701, 0.8473034, -0.040893555, 0.2551...
# 2441  [[1.4141846, 0.09828472, 0.32574463, 1.3451843...
#
#                                                 aligned
# 0                                [[software, software]]
# 1     [[to, to], [simulate, simulate], [portion, por...
# 2     [[portion, portion], [desired, desired], [soft...
# 3     [[portion, portion], [desired, desired], [soft...
# 4           [[software, software], [product, generate]]
# 5                                                    []
# 6                                                    []
# 7     [[to, to], [simulate, simulate], [portion, part]]
# 8                                                    []
# 9     [[product, product], [portion, portion], [desi...
# 10    [[product, product], [portion, portion], [desi...
# 11    [[product, product], [portion, portion], [desi...
# 12                                                   []
# 13    [[to, to], [simulate, simulate], [portion, part]]
# 14                                                   []
# 15              [[software, software], [portion, part]]
# 16    [[product, product], [portion, portion], [desi...
# 17                                                   []
# 18                                                   []
# 19                                    [[desired, like]]
# 20    [[product, product], [portion, portion], [desi...
# 21    [[product, product], [portion, portion], [desi...
# 22                                                   []
# 23                                                   []
# 24    [[product, product], [portion, portion], [desi...
# 25                                                   []
# 26                                 [[product, product]]
# 27                                    [[portion, part]]
# 28                              [[product, proceeding]]
# 29    [[influence, affected], [can, can], [testing, ...
# ...                                                 ...
# 2412  [[replace, replace], [it, it], [node, node], [...
# 2413             [[node, node], [node, node], [it, it]]
# 2414                                                 []
# 2415                                                 []
# 2416                   [[tree, tree], [height, height]]
# 2417                   [[tree, tree], [height, height]]
# 2418                                                 []
# 2419                                                 []
# 2420                                                 []
# 2421                                     [[tree, tree]]
# 2422                                                 []
# 2423                                                 []
# 2424                                                 []
# 2425                                                 []
# 2426                                                 []
# 2427                     [[tree, tree], [height, time]]
# 2428                                                 []
# 2429                                     [[tree, tree]]
# 2430                                                 []
# 2431                                     [[tree, tree]]
# 2432                                                 []
# 2433                                     [[tree, tree]]
# 2434                                     [[tree, tree]]
# 2435                                     [[tree, tree]]
# 2436                                                 []
# 2437                                                 []
# 2438                                                 []
# 2439                                                 []
# 2440                   [[tree, tree], [height, height]]
# 2441                                     [[tree, tree]]
#
# [2442 rows x 15 columns]

# %%
## question Demoting functions

def student_demoting(data):
    return " ".join(x for x in data['student_modified'].split() if x not in data['qn_modified'])

def ref_demoting(data):
    return " ".join(x for x in data['ref_modified'].split() if x not in data['qn_modified'])

# %%
#question demoting
df['student_demoted'] = df.apply(student_demoting,axis=1)
df['ref_demoted'] = df.apply(ref_demoting,axis=1)

# %%
##numeric removal
df['ref_demoted'] = df['ref_demoted'].apply(lambda x: " ".join(word for word in x.split() if not word.isdigit()))
df['student_demoted'] = df['student_demoted'].apply(lambda x: " ".join(word for word in x.split() if not word.isdigit()))

# %%
df.to_pickle("./feature_trail_demoted.pkl", protocol=2)

# %%
df = pd.read_pickle("./feature_trail_demoted.pkl")

# %%
df
# Out:
#       question_id                                           question  \
# 0             1.1  What is the role of a prototype program in pro...
# 1             1.1  What is the role of a prototype program in pro...
# 2             1.1  What is the role of a prototype program in pro...
# 3             1.1  What is the role of a prototype program in pro...
# 4             1.1  What is the role of a prototype program in pro...
# 5             1.1  What is the role of a prototype program in pro...
# 6             1.1  What is the role of a prototype program in pro...
# 7             1.1  What is the role of a prototype program in pro...
# 8             1.1  What is the role of a prototype program in pro...
# 9             1.1  What is the role of a prototype program in pro...
# 10            1.1  What is the role of a prototype program in pro...
# 11            1.1  What is the role of a prototype program in pro...
# 12            1.1  What is the role of a prototype program in pro...
# 13            1.1  What is the role of a prototype program in pro...
# 14            1.1  What is the role of a prototype program in pro...
# 15            1.1  What is the role of a prototype program in pro...
# 16            1.1  What is the role of a prototype program in pro...
# 17            1.1  What is the role of a prototype program in pro...
# 18            1.1  What is the role of a prototype program in pro...
# 19            1.1  What is the role of a prototype program in pro...
# 20            1.1  What is the role of a prototype program in pro...
# 21            1.1  What is the role of a prototype program in pro...
# 22            1.1  What is the role of a prototype program in pro...
# 23            1.1  What is the role of a prototype program in pro...
# 24            1.1  What is the role of a prototype program in pro...
# 25            1.1  What is the role of a prototype program in pro...
# 26            1.1  What is the role of a prototype program in pro...
# 27            1.1  What is the role of a prototype program in pro...
# 28            1.1  What is the role of a prototype program in pro...
# 29            1.2  What stages in the software life cycle are inf...
# ...           ...                                                ...
# 2412         12.9  How do you delete a node from a binary search ...
# 2413         12.9  How do you delete a node from a binary search ...
# 2414         12.1  How many steps does it take to search a node i...
# 2415         12.1  How many steps does it take to search a node i...
# 2416         12.1  How many steps does it take to search a node i...
# 2417         12.1  How many steps does it take to search a node i...
# 2418         12.1  How many steps does it take to search a node i...
# 2419         12.1  How many steps does it take to search a node i...
# 2420         12.1  How many steps does it take to search a node i...
# 2421         12.1  How many steps does it take to search a node i...
# 2422         12.1  How many steps does it take to search a node i...
# 2423         12.1  How many steps does it take to search a node i...
# 2424         12.1  How many steps does it take to search a node i...
# 2425         12.1  How many steps does it take to search a node i...
# 2426         12.1  How many steps does it take to search a node i...
# 2427         12.1  How many steps does it take to search a node i...
# 2428         12.1  How many steps does it take to search a node i...
# 2429         12.1  How many steps does it take to search a node i...
# 2430         12.1  How many steps does it take to search a node i...
# 2431         12.1  How many steps does it take to search a node i...
# 2432         12.1  How many steps does it take to search a node i...
# 2433         12.1  How many steps does it take to search a node i...
# 2434         12.1  How many steps does it take to search a node i...
# 2435         12.1  How many steps does it take to search a node i...
# 2436         12.1  How many steps does it take to search a node i...
# 2437         12.1  How many steps does it take to search a node i...
# 2438         12.1  How many steps does it take to search a node i...
# 2439         12.1  How many steps does it take to search a node i...
# 2440         12.1  How many steps does it take to search a node i...
# 2441         12.1  How many steps does it take to search a node i...
#
#                                              ref_answer  \
# 0     To simulate the behaviour of portions of the d...
# 1     To simulate the behaviour of portions of the d...
# 2     To simulate the behaviour of portions of the d...
# 3     To simulate the behaviour of portions of the d...
# 4     To simulate the behaviour of portions of the d...
# 5     To simulate the behaviour of portions of the d...
# 6     To simulate the behaviour of portions of the d...
# 7     To simulate the behaviour of portions of the d...
# 8     To simulate the behaviour of portions of the d...
# 9     To simulate the behaviour of portions of the d...
# 10    To simulate the behaviour of portions of the d...
# 11    To simulate the behaviour of portions of the d...
# 12    To simulate the behaviour of portions of the d...
# 13    To simulate the behaviour of portions of the d...
# 14    To simulate the behaviour of portions of the d...
# 15    To simulate the behaviour of portions of the d...
# 16    To simulate the behaviour of portions of the d...
# 17    To simulate the behaviour of portions of the d...
# 18    To simulate the behaviour of portions of the d...
# 19    To simulate the behaviour of portions of the d...
# 20    To simulate the behaviour of portions of the d...
# 21    To simulate the behaviour of portions of the d...
# 22    To simulate the behaviour of portions of the d...
# 23    To simulate the behaviour of portions of the d...
# 24    To simulate the behaviour of portions of the d...
# 25    To simulate the behaviour of portions of the d...
# 26    To simulate the behaviour of portions of the d...
# 27    To simulate the behaviour of portions of the d...
# 28    To simulate the behaviour of portions of the d...
# 29    The testing stage can influence both the codin...
# ...                                                 ...
# 2412  Find the node  then replace it with the leftmo...
# 2413  Find the node  then replace it with the leftmo...
# 2414                            The height of the tree.
# 2415                            The height of the tree.
# 2416                            The height of the tree.
# 2417                            The height of the tree.
# 2418                            The height of the tree.
# 2419                            The height of the tree.
# 2420                            The height of the tree.
# 2421                            The height of the tree.
# 2422                            The height of the tree.
# 2423                            The height of the tree.
# 2424                            The height of the tree.
# 2425                            The height of the tree.
# 2426                            The height of the tree.
# 2427                            The height of the tree.
# 2428                            The height of the tree.
# 2429                            The height of the tree.
# 2430                            The height of the tree.
# 2431                            The height of the tree.
# 2432                            The height of the tree.
# 2433                            The height of the tree.
# 2434                            The height of the tree.
# 2435                            The height of the tree.
# 2436                            The height of the tree.
# 2437                            The height of the tree.
# 2438                            The height of the tree.
# 2439                            The height of the tree.
# 2440                            The height of the tree.
# 2441                            The height of the tree.
#
#                                          student_answer  grade  \
# 0     High risk problems are address in the prototyp...    3.5
# 1     To simulate portions of the desired final prod...    5.0
# 2     A prototype program simulates the behaviors of...    4.0
# 3     Defined in the Specification phase a prototype...    5.0
# 4     It is used to let the users have a first idea ...    3.0
# 5     To find problem and errors in a program before...    2.0
# 6     To address major issues in the creation of the...    2.5
# 7     you can break the whole program into prototype...    5.0
# 8     To provide an example or model of how the fini...    3.5
# 9     Simulating the behavior of only a portion of t...    5.0
# 10    A program that stimulates the behavior of port...    5.0
# 11    A program that simulates the behavior of porti...    5.0
# 12    To lay out the basics and give you a starting ...    2.0
# 13    To simulate problem solving for parts of the p...    4.5
# 14    A prototype program provides a basic groundwor...    2.0
# 15    A prototype program is a part of the Specifica...    4.5
# 16    Program that simulates the behavior of portion...    5.0
# 17    it provides a limited proof of concept to veri...    2.0
# 18    It tests the main function of the program whil...    2.0
# 19    To get early feedback from users in early stag...    2.5
# 20    it simulates the behavior of portions of the d...    5.0
# 21    It simulates the behavior of portions of the d...    5.0
# 22    A prototype program is used in problem solving...    1.5
# 23    To ease the understanding of problem under dis...    2.5
# 24    it simulates the behavior of portions of the d...    5.0
# 25    The role of a prototype program is to help spo...    2.0
# 26    the prototype program gives a general idea of ...    3.0
# 27    to show that a certain part of the program wor...    3.0
# 28    Prototype programming is an approach to progra...    2.5
# 29    Refining and possibly the design if the testin...    3.5
# ...                                                 ...    ...
# 2412  if it has no children  you just delete it. if ...    4.0
# 2413  pointer to the child and delete it has 2 child...    3.0
# 2414  Log -LRB- n -RRB- where n is the number of nod...    5.0
# 2415                           log -LRB- n -RRB- steps     5.0
# 2416   The number of levels and the height of the tree     5.0
# 2417         It is the same as the height of the tree.     5.0
# 2418  Given n elements  it would take n divided by 2...    1.5
# 2419                                             log n     5.0
# 2420  Depends on the location of the node you are lo...    2.0
# 2421  2 to the power of n where n is the of levels t...    2.0
# 2422  The number of steps to search a node is the fu...    3.5
# 2423   It would take n divided by 2 elements  given n.     1.5
# 2424                                 log -LRB- n -RRB-     5.0
# 2425                               O -LRB- log n -RRB-     5.0
# 2426                   O -LRB- Log -LRB- n -RRB- -RRB-     5.0
# 2427  If the binary search tree is constructed effic...    5.0
# 2428                   N  n being the number of nodes.     4.0
# 2429  depending on the way that the tree is ordered ...    5.0
# 2430                                 log -LRB- n -RRB-     5.0
# 2431  worst case scenario equals the number of level...    5.0
# 2432              3 steps at most.  There are 3 cases.     1.5
# 2433  log -LRB- n -RRB- where n equals the total num...    5.0
# 2434  the same number of steps as the number of leve...    5.0
# 2435  to find a node in a binary search tree takes a...    5.0
# 2436  three steps visit the root node  then go to ri...    2.5
# 2437                                             log n     5.0
# 2438  -LRB- n -LRB- n minus 1 -RRB- -RRB- divided by 2     1.5
# 2439                                              2n-1     2.5
# 2440  it takes at most h steps  where h is the heigh...    5.0
# 2441  it depends on the install search tree then fro...    1.5
#
#                                             qn_modified  \
# 0        what role prototype program in problem solving
# 1        what role prototype program in problem solving
# 2        what role prototype program in problem solving
# 3        what role prototype program in problem solving
# 4        what role prototype program in problem solving
# 5        what role prototype program in problem solving
# 6        what role prototype program in problem solving
# 7        what role prototype program in problem solving
# 8        what role prototype program in problem solving
# 9        what role prototype program in problem solving
# 10       what role prototype program in problem solving
# 11       what role prototype program in problem solving
# 12       what role prototype program in problem solving
# 13       what role prototype program in problem solving
# 14       what role prototype program in problem solving
# 15       what role prototype program in problem solving
# 16       what role prototype program in problem solving
# 17       what role prototype program in problem solving
# 18       what role prototype program in problem solving
# 19       what role prototype program in problem solving
# 20       what role prototype program in problem solving
# 21       what role prototype program in problem solving
# 22       what role prototype program in problem solving
# 23       what role prototype program in problem solving
# 24       what role prototype program in problem solving
# 25       what role prototype program in problem solving
# 26       what role prototype program in problem solving
# 27       what role prototype program in problem solving
# 28       what role prototype program in problem solving
# 29    what stage in software life cycle influenced t...
# ...                                                 ...
# 2412     how do you delete node from binary search tree
# 2413     how do you delete node from binary search tree
# 2414  how many step doe it take to search node in bi...
# 2415  how many step doe it take to search node in bi...
# 2416  how many step doe it take to search node in bi...
# 2417  how many step doe it take to search node in bi...
# 2418  how many step doe it take to search node in bi...
# 2419  how many step doe it take to search node in bi...
# 2420  how many step doe it take to search node in bi...
# 2421  how many step doe it take to search node in bi...
# 2422  how many step doe it take to search node in bi...
# 2423  how many step doe it take to search node in bi...
# 2424  how many step doe it take to search node in bi...
# 2425  how many step doe it take to search node in bi...
# 2426  how many step doe it take to search node in bi...
# 2427  how many step doe it take to search node in bi...
# 2428  how many step doe it take to search node in bi...
# 2429  how many step doe it take to search node in bi...
# 2430  how many step doe it take to search node in bi...
# 2431  how many step doe it take to search node in bi...
# 2432  how many step doe it take to search node in bi...
# 2433  how many step doe it take to search node in bi...
# 2434  how many step doe it take to search node in bi...
# 2435  how many step doe it take to search node in bi...
# 2436  how many step doe it take to search node in bi...
# 2437  how many step doe it take to search node in bi...
# 2438  how many step doe it take to search node in bi...
# 2439  how many step doe it take to search node in bi...
# 2440  how many step doe it take to search node in bi...
# 2441  how many step doe it take to search node in bi...
#
#                                            ref_modified  \
# 0     to simulate behaviour portion desired software...
# 1     to simulate behaviour portion desired software...
# 2     to simulate behaviour portion desired software...
# 3     to simulate behaviour portion desired software...
# 4     to simulate behaviour portion desired software...
# 5     to simulate behaviour portion desired software...
# 6     to simulate behaviour portion desired software...
# 7     to simulate behaviour portion desired software...
# 8     to simulate behaviour portion desired software...
# 9     to simulate behaviour portion desired software...
# 10    to simulate behaviour portion desired software...
# 11    to simulate behaviour portion desired software...
# 12    to simulate behaviour portion desired software...
# 13    to simulate behaviour portion desired software...
# 14    to simulate behaviour portion desired software...
# 15    to simulate behaviour portion desired software...
# 16    to simulate behaviour portion desired software...
# 17    to simulate behaviour portion desired software...
# 18    to simulate behaviour portion desired software...
# 19    to simulate behaviour portion desired software...
# 20    to simulate behaviour portion desired software...
# 21    to simulate behaviour portion desired software...
# 22    to simulate behaviour portion desired software...
# 23    to simulate behaviour portion desired software...
# 24    to simulate behaviour portion desired software...
# 25    to simulate behaviour portion desired software...
# 26    to simulate behaviour portion desired software...
# 27    to simulate behaviour portion desired software...
# 28    to simulate behaviour portion desired software...
# 29    testing stage can influence both coding stage ...
# ...                                                 ...
# 2412  find node then replace it leftmost node from i...
# 2413  find node then replace it leftmost node from i...
# 2414                                        height tree
# 2415                                        height tree
# 2416                                        height tree
# 2417                                        height tree
# 2418                                        height tree
# 2419                                        height tree
# 2420                                        height tree
# 2421                                        height tree
# 2422                                        height tree
# 2423                                        height tree
# 2424                                        height tree
# 2425                                        height tree
# 2426                                        height tree
# 2427                                        height tree
# 2428                                        height tree
# 2429                                        height tree
# 2430                                        height tree
# 2431                                        height tree
# 2432                                        height tree
# 2433                                        height tree
# 2434                                        height tree
# 2435                                        height tree
# 2436                                        height tree
# 2437                                        height tree
# 2438                                        height tree
# 2439                                        height tree
# 2440                                        height tree
# 2441                                        height tree
#
#                                        student_modified  \
# 0     high risk problem address in prototype program...
# 1     to simulate portion desired final product quic...
# 2     prototype program simulates behavior portion d...
# 3     defined in specification phase prototype stimu...
# 4     it used to let user first idea completed progr...
# 5     to find problem and error in program before it...
# 6     to address major issue in creation program the...
# 7     you can break whole program into prototype pro...
# 8     to provide example or model how finished progr...
# 9     simulating behavior only portion desired softw...
# 10    program that stimulates behavior portion desir...
# 11    program that simulates behavior portion desire...
# 12    to lay out basic and give you starting point i...
# 13             to simulate problem solving part problem
# 14    prototype program provides basic groundwork fr...
# 15    prototype program part specification phase sof...
# 16    program that simulates behavior portion desire...
# 17    it provides limited proof concept to verify cl...
# 18    it test main function program while leaving ou...
# 19    to get early feedback from user in early stage...
# 20    it simulates behavior portion desired software...
# 21    it simulates behavior portion desired software...
# 22    prototype program used in problem solving to c...
# 23    to ease understanding problem under discussion...
# 24    it simulates behavior portion desired software...
# 25    role prototype program to help spot key proble...
# 26    prototype program give general idea what end p...
# 27    to show that certain part program work it supp...
# 28    prototype programming approach to programming ...
# 29    refining and possibly design if testing phase ...
# ...                                                 ...
# 2412  if it no child you just delete it if it only o...
# 2413  pointer to child and delete it child set node ...
# 2414                  log lrb n rrb where n number node
# 2415                                 log lrb n rrb step
# 2416                       number level and height tree
# 2417                                it same height tree
# 2418  given n element it would take n divided step t...
# 2419                                              log n
# 2420  depends on location node you looking if it roo...
# 2421               to power n where n level binary tree
# 2422        number step to search node function n minus
# 2423            it would take n divided element given n
# 2424                                      log lrb n rrb
# 2425                                    o lrb log n rrb
# 2426                            o lrb log lrb n rrb rrb
# 2427  if binary search tree constructed efficiently ...
# 2428                              n n being number node
# 2429  depending on way that tree ordered it could be...
# 2430                                      log lrb n rrb
# 2431  worst case scenario equal number level tree ie...
# 2432                               step most there case
# 2433  log lrb n rrb where n equal total number node ...
# 2434  same number step number level or generation in...
# 2435  to find node in binary search tree take most s...
# 2436  three step visit root node then go to right su...
# 2437                                              log n
# 2438                  lrb n lrb n minus rrb rrb divided
# 2439                                                2n1
# 2440            it take most h step where h height tree
# 2441  it depends on install search tree then from th...
#
#                                         student_demoted  \
# 0     high risk address make sure that feasible may ...
# 1     simulate portion desired final product quick a...
# 2     simulates behavior portion desired software pr...
# 3     defined specification phase stimulates behavio...
# 4     it used let user first idea completed and allo...
# 5                    find and error before it finalized
# 6     address major issue creation there no way acco...
# 7          you can break whole into simulate part final
# 8     provide example or model how finished should p...
# 9     simulating behavior only portion desired softw...
# 10    that stimulates behavior portion desired softw...
# 11    that simulates behavior portion desired softwa...
# 12     lay out basic and give you starting point actual
# 13                                        simulate part
# 14    provides basic groundwork from which further e...
# 15    part specification phase software it employed ...
# 16    that simulates behavior portion desired softwa...
# 17    it provides limited proof concept verify clien...
# 18    it test main function while leaving out finer ...
# 19    get early feedback from user early stage devel...
# 20    it simulates behavior portion desired software...
# 21    it simulates behavior portion desired software...
# 22                                    used collect data
# 23    ease understanding under discussion and ease u...
# 24    it simulates behavior portion desired software...
# 25    help spot key that may arise during actual pro...
# 26    give general idea end product will do without ...
# 27              show that certain part work it supposed
# 28    programming approach programming that enables ...
# 29    refining and possibly design phase reveals pro...
# ...                                                 ...
# 2412  if it child just it if it only one child just ...
# 2413  pointer to child and it child set to child and...
# 2414                           log lrb rrb where number
# 2415                                        log lrb rrb
# 2416                            number level and height
# 2417                                        same height
# 2418         given element would divided find criterion
# 2419                                                log
# 2420  depends on location you looking if root one el...
# 2421                                  power where level
# 2422                              number function minus
# 2423                        would divided element given
# 2424                                        log lrb rrb
# 2425                                        lrb log rrb
# 2426                                lrb log lrb rrb rrb
# 2427  if constructed efficiently best case scenario ...
# 2428                                       being number
# 2429  depending on way that ordered could be anywher...
# 2430                                        log lrb rrb
# 2431  worst case scenario equal number level ie fart...
# 2432                                    most there case
# 2433               log lrb rrb where equal total number
# 2434             same number number level or generation
# 2435                  find most same number there level
# 2436  three visit root then go right subtree after v...
# 2437                                                log
# 2438                      lrb lrb minus rrb rrb divided
# 2439                                                2n1
# 2440                                  most where height
# 2441  depends on install then from there whatever ca...
#
#                                             ref_demoted  length_ratio  \
# 0     simulate behaviour portion desired software pr...      3.055556
# 1     simulate behaviour portion desired software pr...      3.074074
# 2     simulate behaviour portion desired software pr...      1.722222
# 3     simulate behaviour portion desired software pr...      3.814815
# 4     simulate behaviour portion desired software pr...      3.462963
# 5     simulate behaviour portion desired software pr...      1.037037
# 6     simulate behaviour portion desired software pr...      2.518519
# 7     simulate behaviour portion desired software pr...      1.500000
# 8     simulate behaviour portion desired software pr...      3.388889
# 9     simulate behaviour portion desired software pr...      1.055556
# 10    simulate behaviour portion desired software pr...      1.203704
# 11    simulate behaviour portion desired software pr...      1.185185
# 12    simulate behaviour portion desired software pr...      1.296296
# 13    simulate behaviour portion desired software pr...      0.740741
# 14    simulate behaviour portion desired software pr...      1.944444
# 15    simulate behaviour portion desired software pr...      3.555556
# 16    simulate behaviour portion desired software pr...      1.185185
# 17    simulate behaviour portion desired software pr...      1.777778
# 18    simulate behaviour portion desired software pr...      1.111111
# 19    simulate behaviour portion desired software pr...      3.555556
# 20    simulate behaviour portion desired software pr...      1.000000
# 21    simulate behaviour portion desired software pr...      1.000000
# 22    simulate behaviour portion desired software pr...      1.203704
# 23    simulate behaviour portion desired software pr...      1.611111
# 24    simulate behaviour portion desired software pr...      1.000000
# 25    simulate behaviour portion desired software pr...      1.611111
# 26    simulate behaviour portion desired software pr...      2.074074
# 27    simulate behaviour portion desired software pr...      0.981481
# 28    simulate behaviour portion desired software pr...      6.388889
# 29    can both coding phase and solution refinement ...      3.448276
# ...                                                 ...           ...
# 2412  find then replace it leftmost it right subtree...      1.840000
# 2413  find then replace it leftmost it right subtree...      1.100000
# 2414                                             height      3.000000
# 2415                                             height      1.636364
# 2416                                             height      2.545455
# 2417                                             height      1.727273
# 2418                                             height      6.272727
# 2419                                             height      0.454545
# 2420                                             height     15.272727
# 2421                                             height      3.272727
# 2422                                             height      3.909091
# 2423                                             height      3.545455
# 2424                                             height      1.181818
# 2425                                             height      1.363636
# 2426                                             height      2.090909
# 2427                                             height     33.727273
# 2428                                             height      1.909091
# 2429                                             height      8.000000
# 2430                                             height      1.181818
# 2431                                             height     11.000000
# 2432                                             height      1.818182
# 2433                                             height      4.818182
# 2434                                             height      4.636364
# 2435                                             height      7.090909
# 2436                                             height      9.000000
# 2437                                             height      0.454545
# 2438                                             height      3.000000
# 2439                                             height      0.272727
# 2440                                             height      3.545455
# 2441                                             height      9.545455
#
#       grades_round                                          embed_ref  \
# 0                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 1                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 2                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 3                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 4                3  [[0.13071777343750002, -0.10377929687499998, 0...
# 5                2  [[0.13071777343750002, -0.10377929687499998, 0...
# 6                2  [[0.13071777343750002, -0.10377929687499998, 0...
# 7                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 8                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 9                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 10               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 11               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 12               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 13               4  [[0.13071777343750002, -0.10377929687499998, 0...
# 14               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 15               4  [[0.13071777343750002, -0.10377929687499998, 0...
# 16               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 17               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 18               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 19               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 20               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 21               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 22               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 23               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 24               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 25               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 26               3  [[0.13071777343750002, -0.10377929687499998, 0...
# 27               3  [[0.13071777343750002, -0.10377929687499998, 0...
# 28               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 29               4  [[-0.03724121093749999, 0.728505859375, 0.1627...
# ...            ...                                                ...
# 2412             4  [[0.8393359375, -0.9155201721191406, 0.7835498...
# 2413             3  [[0.8393359375, -0.9155201721191406, 0.7835498...
# 2414             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2415             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2416             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2417             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2418             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2419             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2420             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2421             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2422             4  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2423             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2424             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2425             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2426             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2427             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2428             4  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2429             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2430             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2431             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2432             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2433             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2434             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2435             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2436             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2437             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2438             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2439             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2440             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2441             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
#
#                                              embed_stud  \
# 0     [[-0.5155224609375, 0.008998413085937518, 1.30...
# 1     [[2.15602783203125, 0.4706297302246094, 0.2766...
# 2     [[-0.28229736328125, 0.043576965332031245, 0.2...
# 3     [[-0.127725830078125, 0.53630615234375, 0.3706...
# 4     [[0.23586181640625004, 0.06217674255371097, 0....
# 5     [[0.12119628906250002, 0.0628600311279297, 0.0...
# 6     [[-0.10513183593749997, 0.6872704315185547, 0....
# 7     [[0.162374267578125, 0.4117333984375, 0.582143...
# 8     [[-0.33944580078125, 0.7594540405273438, 0.717...
# 9     [[0.24334717, -0.18823242, 0.23413086, 0.12432...
# 10    [[-0.046813965, -0.0008544922, 0.48388672, 0.4...
# 11    [[0.04473877, -0.006591797, 0.5078125, 0.23901...
# 12    [[1.146312255859375, -0.26472900390625, 0.4583...
# 13    [[0.30833984375, 0.11400390625000001, -0.20218...
# 14    [[-0.7306201171875, 0.3886511611938477, 0.0168...
# 15    [[0.48851684570312504, 0.6005602264404297, 1.0...
# 16    [[0.04473877, -0.006591797, 0.5078125, 0.23901...
# 17    [[-0.39966796875, -0.9118006134033203, -0.5778...
# 18    [[0.42938232, -0.28831673, 0.5189209, 0.293945...
# 19    [[0.18246582031250003, 0.6643317031860352, 0.9...
# 20    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 21    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 22    [[0.368734130859375, 0.2569482421875, 0.016927...
# 23    [[-0.01736328125, 0.41330078125, -0.3998706054...
# 24    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 25    [[0.1439111328125, 0.5086572265625, 0.28313232...
# 26    [[0.6358905029296875, 0.461162109375, 0.797099...
# 27    [[0.17676879882812502, 0.2869925689697266, 0.5...
# 28    [[0.08475952148437504, 0.729856300354004, 0.79...
# 29    [[-0.643990478515625, 0.17536643981933597, 2.5...
# ...                                                 ...
# 2412  [[2.47820068359375, -1.9582750701904297, 2.420...
# 2413  [[1.284130859375, 0.3819492340087891, 1.449673...
# 2414  [[0.24210693359375002, -0.24281738281249998, -...
# 2415  [[-0.06624267578124998, 0.12498046875, -0.2155...
# 2416  [[0.59349609375, 0.3421990966796875, -0.072031...
# 2417  [[0.8496094, 0.35816765, -0.122802734, 0.25219...
# 2418  [[0.48265625, 0.1604039764404297, 0.1828515625...
# 2419  [[0.11981201, -0.0034179688, -0.34594727, 0.10...
# 2420  [[1.5667529296875, -0.7187771606445312, 1.6323...
# 2421  [[0.57732177734375, 0.12149597167968751, 0.140...
# 2422  [[0.152578125, -0.4102880859375, -0.1097509765...
# 2423  [[0.5074463, 0.0417614, 0.37451172, 0.70996094...
# 2424  [[0.13981201171875002, 0.016582031250000004, -...
# 2425  [[-0.02425048828124999, 0.09861328124999999, -...
# 2426  [[-0.004250488281249989, 0.11861328124999998, ...
# 2427  [[3.789757080078124, 0.8338683319091797, 0.085...
# 2428  [[-0.08459473, -0.21960449, 0.028198242, 0.352...
# 2429  [[0.9930126953125, -0.2812659454345703, 0.5872...
# 2430  [[0.13981201171875002, 0.016582031250000004, -...
# 2431  [[0.29675293, -0.13927555, 1.7305908, 1.922637...
# 2432  [[0.012939453, -0.016967773, 0.119262695, 0.11...
# 2433  [[0.84684326171875, -0.3604931640625, -0.06605...
# 2434  [[0.67222023, 0.31230164, 0.6809082, 0.5546875...
# 2435  [[1.3265283203125, -0.06673645019531249, -0.15...
# 2436  [[0.02510742187500003, 0.689505615234375, 0.86...
# 2437  [[0.11981201, -0.0034179688, -0.34594727, 0.10...
# 2438  [[0.08266357421875001, -0.20462890624999996, 0...
# 2439  [[0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0....
# 2440  [[-0.07293701, 0.8473034, -0.040893555, 0.2551...
# 2441  [[1.4141846, 0.09828472, 0.32574463, 1.3451843...
#
#                                                 aligned
# 0                                [[software, software]]
# 1     [[to, to], [simulate, simulate], [portion, por...
# 2     [[portion, portion], [desired, desired], [soft...
# 3     [[portion, portion], [desired, desired], [soft...
# 4           [[software, software], [product, generate]]
# 5                                                    []
# 6                                                    []
# 7     [[to, to], [simulate, simulate], [portion, part]]
# 8                                                    []
# 9     [[product, product], [portion, portion], [desi...
# 10    [[product, product], [portion, portion], [desi...
# 11    [[product, product], [portion, portion], [desi...
# 12                                                   []
# 13    [[to, to], [simulate, simulate], [portion, part]]
# 14                                                   []
# 15              [[software, software], [portion, part]]
# 16    [[product, product], [portion, portion], [desi...
# 17                                                   []
# 18                                                   []
# 19                                    [[desired, like]]
# 20    [[product, product], [portion, portion], [desi...
# 21    [[product, product], [portion, portion], [desi...
# 22                                                   []
# 23                                                   []
# 24    [[product, product], [portion, portion], [desi...
# 25                                                   []
# 26                                 [[product, product]]
# 27                                    [[portion, part]]
# 28                              [[product, proceeding]]
# 29    [[influence, affected], [can, can], [testing, ...
# ...                                                 ...
# 2412  [[replace, replace], [it, it], [node, node], [...
# 2413             [[node, node], [node, node], [it, it]]
# 2414                                                 []
# 2415                                                 []
# 2416                   [[tree, tree], [height, height]]
# 2417                   [[tree, tree], [height, height]]
# 2418                                                 []
# 2419                                                 []
# 2420                                                 []
# 2421                                     [[tree, tree]]
# 2422                                                 []
# 2423                                                 []
# 2424                                                 []
# 2425                                                 []
# 2426                                                 []
# 2427                     [[tree, tree], [height, time]]
# 2428                                                 []
# 2429                                     [[tree, tree]]
# 2430                                                 []
# 2431                                     [[tree, tree]]
# 2432                                                 []
# 2433                                     [[tree, tree]]
# 2434                                     [[tree, tree]]
# 2435                                     [[tree, tree]]
# 2436                                                 []
# 2437                                                 []
# 2438                                                 []
# 2439                                                 []
# 2440                   [[tree, tree], [height, height]]
# 2441                                     [[tree, tree]]
#
# [2442 rows x 15 columns]

# %%
df['cos_similarity']=df.apply(cos_similarity, axis=1)
df['align_ratio']=df.apply(align_ratio, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ff5c581347db> in <module>()
# ----> 1 df['cos_similarity']=df.apply(cos_similarity, axis=1)
#       2 df['align_ratio']=df.apply(align_ratio, axis=1)
#
# NameError: name 'cos_similarity' is not defined

# %%
df
# Out:
#       question_id                                           question  \
# 0             1.1  What is the role of a prototype program in pro...
# 1             1.1  What is the role of a prototype program in pro...
# 2             1.1  What is the role of a prototype program in pro...
# 3             1.1  What is the role of a prototype program in pro...
# 4             1.1  What is the role of a prototype program in pro...
# 5             1.1  What is the role of a prototype program in pro...
# 6             1.1  What is the role of a prototype program in pro...
# 7             1.1  What is the role of a prototype program in pro...
# 8             1.1  What is the role of a prototype program in pro...
# 9             1.1  What is the role of a prototype program in pro...
# 10            1.1  What is the role of a prototype program in pro...
# 11            1.1  What is the role of a prototype program in pro...
# 12            1.1  What is the role of a prototype program in pro...
# 13            1.1  What is the role of a prototype program in pro...
# 14            1.1  What is the role of a prototype program in pro...
# 15            1.1  What is the role of a prototype program in pro...
# 16            1.1  What is the role of a prototype program in pro...
# 17            1.1  What is the role of a prototype program in pro...
# 18            1.1  What is the role of a prototype program in pro...
# 19            1.1  What is the role of a prototype program in pro...
# 20            1.1  What is the role of a prototype program in pro...
# 21            1.1  What is the role of a prototype program in pro...
# 22            1.1  What is the role of a prototype program in pro...
# 23            1.1  What is the role of a prototype program in pro...
# 24            1.1  What is the role of a prototype program in pro...
# 25            1.1  What is the role of a prototype program in pro...
# 26            1.1  What is the role of a prototype program in pro...
# 27            1.1  What is the role of a prototype program in pro...
# 28            1.1  What is the role of a prototype program in pro...
# 29            1.2  What stages in the software life cycle are inf...
# ...           ...                                                ...
# 2412         12.9  How do you delete a node from a binary search ...
# 2413         12.9  How do you delete a node from a binary search ...
# 2414         12.1  How many steps does it take to search a node i...
# 2415         12.1  How many steps does it take to search a node i...
# 2416         12.1  How many steps does it take to search a node i...
# 2417         12.1  How many steps does it take to search a node i...
# 2418         12.1  How many steps does it take to search a node i...
# 2419         12.1  How many steps does it take to search a node i...
# 2420         12.1  How many steps does it take to search a node i...
# 2421         12.1  How many steps does it take to search a node i...
# 2422         12.1  How many steps does it take to search a node i...
# 2423         12.1  How many steps does it take to search a node i...
# 2424         12.1  How many steps does it take to search a node i...
# 2425         12.1  How many steps does it take to search a node i...
# 2426         12.1  How many steps does it take to search a node i...
# 2427         12.1  How many steps does it take to search a node i...
# 2428         12.1  How many steps does it take to search a node i...
# 2429         12.1  How many steps does it take to search a node i...
# 2430         12.1  How many steps does it take to search a node i...
# 2431         12.1  How many steps does it take to search a node i...
# 2432         12.1  How many steps does it take to search a node i...
# 2433         12.1  How many steps does it take to search a node i...
# 2434         12.1  How many steps does it take to search a node i...
# 2435         12.1  How many steps does it take to search a node i...
# 2436         12.1  How many steps does it take to search a node i...
# 2437         12.1  How many steps does it take to search a node i...
# 2438         12.1  How many steps does it take to search a node i...
# 2439         12.1  How many steps does it take to search a node i...
# 2440         12.1  How many steps does it take to search a node i...
# 2441         12.1  How many steps does it take to search a node i...
#
#                                              ref_answer  \
# 0     To simulate the behaviour of portions of the d...
# 1     To simulate the behaviour of portions of the d...
# 2     To simulate the behaviour of portions of the d...
# 3     To simulate the behaviour of portions of the d...
# 4     To simulate the behaviour of portions of the d...
# 5     To simulate the behaviour of portions of the d...
# 6     To simulate the behaviour of portions of the d...
# 7     To simulate the behaviour of portions of the d...
# 8     To simulate the behaviour of portions of the d...
# 9     To simulate the behaviour of portions of the d...
# 10    To simulate the behaviour of portions of the d...
# 11    To simulate the behaviour of portions of the d...
# 12    To simulate the behaviour of portions of the d...
# 13    To simulate the behaviour of portions of the d...
# 14    To simulate the behaviour of portions of the d...
# 15    To simulate the behaviour of portions of the d...
# 16    To simulate the behaviour of portions of the d...
# 17    To simulate the behaviour of portions of the d...
# 18    To simulate the behaviour of portions of the d...
# 19    To simulate the behaviour of portions of the d...
# 20    To simulate the behaviour of portions of the d...
# 21    To simulate the behaviour of portions of the d...
# 22    To simulate the behaviour of portions of the d...
# 23    To simulate the behaviour of portions of the d...
# 24    To simulate the behaviour of portions of the d...
# 25    To simulate the behaviour of portions of the d...
# 26    To simulate the behaviour of portions of the d...
# 27    To simulate the behaviour of portions of the d...
# 28    To simulate the behaviour of portions of the d...
# 29    The testing stage can influence both the codin...
# ...                                                 ...
# 2412  Find the node  then replace it with the leftmo...
# 2413  Find the node  then replace it with the leftmo...
# 2414                            The height of the tree.
# 2415                            The height of the tree.
# 2416                            The height of the tree.
# 2417                            The height of the tree.
# 2418                            The height of the tree.
# 2419                            The height of the tree.
# 2420                            The height of the tree.
# 2421                            The height of the tree.
# 2422                            The height of the tree.
# 2423                            The height of the tree.
# 2424                            The height of the tree.
# 2425                            The height of the tree.
# 2426                            The height of the tree.
# 2427                            The height of the tree.
# 2428                            The height of the tree.
# 2429                            The height of the tree.
# 2430                            The height of the tree.
# 2431                            The height of the tree.
# 2432                            The height of the tree.
# 2433                            The height of the tree.
# 2434                            The height of the tree.
# 2435                            The height of the tree.
# 2436                            The height of the tree.
# 2437                            The height of the tree.
# 2438                            The height of the tree.
# 2439                            The height of the tree.
# 2440                            The height of the tree.
# 2441                            The height of the tree.
#
#                                          student_answer  grade  \
# 0     High risk problems are address in the prototyp...    3.5
# 1     To simulate portions of the desired final prod...    5.0
# 2     A prototype program simulates the behaviors of...    4.0
# 3     Defined in the Specification phase a prototype...    5.0
# 4     It is used to let the users have a first idea ...    3.0
# 5     To find problem and errors in a program before...    2.0
# 6     To address major issues in the creation of the...    2.5
# 7     you can break the whole program into prototype...    5.0
# 8     To provide an example or model of how the fini...    3.5
# 9     Simulating the behavior of only a portion of t...    5.0
# 10    A program that stimulates the behavior of port...    5.0
# 11    A program that simulates the behavior of porti...    5.0
# 12    To lay out the basics and give you a starting ...    2.0
# 13    To simulate problem solving for parts of the p...    4.5
# 14    A prototype program provides a basic groundwor...    2.0
# 15    A prototype program is a part of the Specifica...    4.5
# 16    Program that simulates the behavior of portion...    5.0
# 17    it provides a limited proof of concept to veri...    2.0
# 18    It tests the main function of the program whil...    2.0
# 19    To get early feedback from users in early stag...    2.5
# 20    it simulates the behavior of portions of the d...    5.0
# 21    It simulates the behavior of portions of the d...    5.0
# 22    A prototype program is used in problem solving...    1.5
# 23    To ease the understanding of problem under dis...    2.5
# 24    it simulates the behavior of portions of the d...    5.0
# 25    The role of a prototype program is to help spo...    2.0
# 26    the prototype program gives a general idea of ...    3.0
# 27    to show that a certain part of the program wor...    3.0
# 28    Prototype programming is an approach to progra...    2.5
# 29    Refining and possibly the design if the testin...    3.5
# ...                                                 ...    ...
# 2412  if it has no children  you just delete it. if ...    4.0
# 2413  pointer to the child and delete it has 2 child...    3.0
# 2414  Log -LRB- n -RRB- where n is the number of nod...    5.0
# 2415                           log -LRB- n -RRB- steps     5.0
# 2416   The number of levels and the height of the tree     5.0
# 2417         It is the same as the height of the tree.     5.0
# 2418  Given n elements  it would take n divided by 2...    1.5
# 2419                                             log n     5.0
# 2420  Depends on the location of the node you are lo...    2.0
# 2421  2 to the power of n where n is the of levels t...    2.0
# 2422  The number of steps to search a node is the fu...    3.5
# 2423   It would take n divided by 2 elements  given n.     1.5
# 2424                                 log -LRB- n -RRB-     5.0
# 2425                               O -LRB- log n -RRB-     5.0
# 2426                   O -LRB- Log -LRB- n -RRB- -RRB-     5.0
# 2427  If the binary search tree is constructed effic...    5.0
# 2428                   N  n being the number of nodes.     4.0
# 2429  depending on the way that the tree is ordered ...    5.0
# 2430                                 log -LRB- n -RRB-     5.0
# 2431  worst case scenario equals the number of level...    5.0
# 2432              3 steps at most.  There are 3 cases.     1.5
# 2433  log -LRB- n -RRB- where n equals the total num...    5.0
# 2434  the same number of steps as the number of leve...    5.0
# 2435  to find a node in a binary search tree takes a...    5.0
# 2436  three steps visit the root node  then go to ri...    2.5
# 2437                                             log n     5.0
# 2438  -LRB- n -LRB- n minus 1 -RRB- -RRB- divided by 2     1.5
# 2439                                              2n-1     2.5
# 2440  it takes at most h steps  where h is the heigh...    5.0
# 2441  it depends on the install search tree then fro...    1.5
#
#                                             qn_modified  \
# 0        what role prototype program in problem solving
# 1        what role prototype program in problem solving
# 2        what role prototype program in problem solving
# 3        what role prototype program in problem solving
# 4        what role prototype program in problem solving
# 5        what role prototype program in problem solving
# 6        what role prototype program in problem solving
# 7        what role prototype program in problem solving
# 8        what role prototype program in problem solving
# 9        what role prototype program in problem solving
# 10       what role prototype program in problem solving
# 11       what role prototype program in problem solving
# 12       what role prototype program in problem solving
# 13       what role prototype program in problem solving
# 14       what role prototype program in problem solving
# 15       what role prototype program in problem solving
# 16       what role prototype program in problem solving
# 17       what role prototype program in problem solving
# 18       what role prototype program in problem solving
# 19       what role prototype program in problem solving
# 20       what role prototype program in problem solving
# 21       what role prototype program in problem solving
# 22       what role prototype program in problem solving
# 23       what role prototype program in problem solving
# 24       what role prototype program in problem solving
# 25       what role prototype program in problem solving
# 26       what role prototype program in problem solving
# 27       what role prototype program in problem solving
# 28       what role prototype program in problem solving
# 29    what stage in software life cycle influenced t...
# ...                                                 ...
# 2412     how do you delete node from binary search tree
# 2413     how do you delete node from binary search tree
# 2414  how many step doe it take to search node in bi...
# 2415  how many step doe it take to search node in bi...
# 2416  how many step doe it take to search node in bi...
# 2417  how many step doe it take to search node in bi...
# 2418  how many step doe it take to search node in bi...
# 2419  how many step doe it take to search node in bi...
# 2420  how many step doe it take to search node in bi...
# 2421  how many step doe it take to search node in bi...
# 2422  how many step doe it take to search node in bi...
# 2423  how many step doe it take to search node in bi...
# 2424  how many step doe it take to search node in bi...
# 2425  how many step doe it take to search node in bi...
# 2426  how many step doe it take to search node in bi...
# 2427  how many step doe it take to search node in bi...
# 2428  how many step doe it take to search node in bi...
# 2429  how many step doe it take to search node in bi...
# 2430  how many step doe it take to search node in bi...
# 2431  how many step doe it take to search node in bi...
# 2432  how many step doe it take to search node in bi...
# 2433  how many step doe it take to search node in bi...
# 2434  how many step doe it take to search node in bi...
# 2435  how many step doe it take to search node in bi...
# 2436  how many step doe it take to search node in bi...
# 2437  how many step doe it take to search node in bi...
# 2438  how many step doe it take to search node in bi...
# 2439  how many step doe it take to search node in bi...
# 2440  how many step doe it take to search node in bi...
# 2441  how many step doe it take to search node in bi...
#
#                                            ref_modified  \
# 0     to simulate behaviour portion desired software...
# 1     to simulate behaviour portion desired software...
# 2     to simulate behaviour portion desired software...
# 3     to simulate behaviour portion desired software...
# 4     to simulate behaviour portion desired software...
# 5     to simulate behaviour portion desired software...
# 6     to simulate behaviour portion desired software...
# 7     to simulate behaviour portion desired software...
# 8     to simulate behaviour portion desired software...
# 9     to simulate behaviour portion desired software...
# 10    to simulate behaviour portion desired software...
# 11    to simulate behaviour portion desired software...
# 12    to simulate behaviour portion desired software...
# 13    to simulate behaviour portion desired software...
# 14    to simulate behaviour portion desired software...
# 15    to simulate behaviour portion desired software...
# 16    to simulate behaviour portion desired software...
# 17    to simulate behaviour portion desired software...
# 18    to simulate behaviour portion desired software...
# 19    to simulate behaviour portion desired software...
# 20    to simulate behaviour portion desired software...
# 21    to simulate behaviour portion desired software...
# 22    to simulate behaviour portion desired software...
# 23    to simulate behaviour portion desired software...
# 24    to simulate behaviour portion desired software...
# 25    to simulate behaviour portion desired software...
# 26    to simulate behaviour portion desired software...
# 27    to simulate behaviour portion desired software...
# 28    to simulate behaviour portion desired software...
# 29    testing stage can influence both coding stage ...
# ...                                                 ...
# 2412  find node then replace it leftmost node from i...
# 2413  find node then replace it leftmost node from i...
# 2414                                        height tree
# 2415                                        height tree
# 2416                                        height tree
# 2417                                        height tree
# 2418                                        height tree
# 2419                                        height tree
# 2420                                        height tree
# 2421                                        height tree
# 2422                                        height tree
# 2423                                        height tree
# 2424                                        height tree
# 2425                                        height tree
# 2426                                        height tree
# 2427                                        height tree
# 2428                                        height tree
# 2429                                        height tree
# 2430                                        height tree
# 2431                                        height tree
# 2432                                        height tree
# 2433                                        height tree
# 2434                                        height tree
# 2435                                        height tree
# 2436                                        height tree
# 2437                                        height tree
# 2438                                        height tree
# 2439                                        height tree
# 2440                                        height tree
# 2441                                        height tree
#
#                                        student_modified  \
# 0     high risk problem address in prototype program...
# 1     to simulate portion desired final product quic...
# 2     prototype program simulates behavior portion d...
# 3     defined in specification phase prototype stimu...
# 4     it used to let user first idea completed progr...
# 5     to find problem and error in program before it...
# 6     to address major issue in creation program the...
# 7     you can break whole program into prototype pro...
# 8     to provide example or model how finished progr...
# 9     simulating behavior only portion desired softw...
# 10    program that stimulates behavior portion desir...
# 11    program that simulates behavior portion desire...
# 12    to lay out basic and give you starting point i...
# 13             to simulate problem solving part problem
# 14    prototype program provides basic groundwork fr...
# 15    prototype program part specification phase sof...
# 16    program that simulates behavior portion desire...
# 17    it provides limited proof concept to verify cl...
# 18    it test main function program while leaving ou...
# 19    to get early feedback from user in early stage...
# 20    it simulates behavior portion desired software...
# 21    it simulates behavior portion desired software...
# 22    prototype program used in problem solving to c...
# 23    to ease understanding problem under discussion...
# 24    it simulates behavior portion desired software...
# 25    role prototype program to help spot key proble...
# 26    prototype program give general idea what end p...
# 27    to show that certain part program work it supp...
# 28    prototype programming approach to programming ...
# 29    refining and possibly design if testing phase ...
# ...                                                 ...
# 2412  if it no child you just delete it if it only o...
# 2413  pointer to child and delete it child set node ...
# 2414                  log lrb n rrb where n number node
# 2415                                 log lrb n rrb step
# 2416                       number level and height tree
# 2417                                it same height tree
# 2418  given n element it would take n divided step t...
# 2419                                              log n
# 2420  depends on location node you looking if it roo...
# 2421               to power n where n level binary tree
# 2422        number step to search node function n minus
# 2423            it would take n divided element given n
# 2424                                      log lrb n rrb
# 2425                                    o lrb log n rrb
# 2426                            o lrb log lrb n rrb rrb
# 2427  if binary search tree constructed efficiently ...
# 2428                              n n being number node
# 2429  depending on way that tree ordered it could be...
# 2430                                      log lrb n rrb
# 2431  worst case scenario equal number level tree ie...
# 2432                               step most there case
# 2433  log lrb n rrb where n equal total number node ...
# 2434  same number step number level or generation in...
# 2435  to find node in binary search tree take most s...
# 2436  three step visit root node then go to right su...
# 2437                                              log n
# 2438                  lrb n lrb n minus rrb rrb divided
# 2439                                                2n1
# 2440            it take most h step where h height tree
# 2441  it depends on install search tree then from th...
#
#                                         student_demoted  \
# 0     high risk address make sure that feasible may ...
# 1     simulate portion desired final product quick a...
# 2     simulates behavior portion desired software pr...
# 3     defined specification phase stimulates behavio...
# 4     it used let user first idea completed and allo...
# 5                    find and error before it finalized
# 6     address major issue creation there no way acco...
# 7          you can break whole into simulate part final
# 8     provide example or model how finished should p...
# 9     simulating behavior only portion desired softw...
# 10    that stimulates behavior portion desired softw...
# 11    that simulates behavior portion desired softwa...
# 12     lay out basic and give you starting point actual
# 13                                        simulate part
# 14    provides basic groundwork from which further e...
# 15    part specification phase software it employed ...
# 16    that simulates behavior portion desired softwa...
# 17    it provides limited proof concept verify clien...
# 18    it test main function while leaving out finer ...
# 19    get early feedback from user early stage devel...
# 20    it simulates behavior portion desired software...
# 21    it simulates behavior portion desired software...
# 22                                    used collect data
# 23    ease understanding under discussion and ease u...
# 24    it simulates behavior portion desired software...
# 25    help spot key that may arise during actual pro...
# 26    give general idea end product will do without ...
# 27              show that certain part work it supposed
# 28    programming approach programming that enables ...
# 29    refining and possibly design phase reveals pro...
# ...                                                 ...
# 2412  if it child just it if it only one child just ...
# 2413  pointer to child and it child set to child and...
# 2414                           log lrb rrb where number
# 2415                                        log lrb rrb
# 2416                            number level and height
# 2417                                        same height
# 2418         given element would divided find criterion
# 2419                                                log
# 2420  depends on location you looking if root one el...
# 2421                                  power where level
# 2422                              number function minus
# 2423                        would divided element given
# 2424                                        log lrb rrb
# 2425                                        lrb log rrb
# 2426                                lrb log lrb rrb rrb
# 2427  if constructed efficiently best case scenario ...
# 2428                                       being number
# 2429  depending on way that ordered could be anywher...
# 2430                                        log lrb rrb
# 2431  worst case scenario equal number level ie fart...
# 2432                                    most there case
# 2433               log lrb rrb where equal total number
# 2434             same number number level or generation
# 2435                  find most same number there level
# 2436  three visit root then go right subtree after v...
# 2437                                                log
# 2438                      lrb lrb minus rrb rrb divided
# 2439                                                2n1
# 2440                                  most where height
# 2441  depends on install then from there whatever ca...
#
#                                             ref_demoted  length_ratio  \
# 0     simulate behaviour portion desired software pr...      3.055556
# 1     simulate behaviour portion desired software pr...      3.074074
# 2     simulate behaviour portion desired software pr...      1.722222
# 3     simulate behaviour portion desired software pr...      3.814815
# 4     simulate behaviour portion desired software pr...      3.462963
# 5     simulate behaviour portion desired software pr...      1.037037
# 6     simulate behaviour portion desired software pr...      2.518519
# 7     simulate behaviour portion desired software pr...      1.500000
# 8     simulate behaviour portion desired software pr...      3.388889
# 9     simulate behaviour portion desired software pr...      1.055556
# 10    simulate behaviour portion desired software pr...      1.203704
# 11    simulate behaviour portion desired software pr...      1.185185
# 12    simulate behaviour portion desired software pr...      1.296296
# 13    simulate behaviour portion desired software pr...      0.740741
# 14    simulate behaviour portion desired software pr...      1.944444
# 15    simulate behaviour portion desired software pr...      3.555556
# 16    simulate behaviour portion desired software pr...      1.185185
# 17    simulate behaviour portion desired software pr...      1.777778
# 18    simulate behaviour portion desired software pr...      1.111111
# 19    simulate behaviour portion desired software pr...      3.555556
# 20    simulate behaviour portion desired software pr...      1.000000
# 21    simulate behaviour portion desired software pr...      1.000000
# 22    simulate behaviour portion desired software pr...      1.203704
# 23    simulate behaviour portion desired software pr...      1.611111
# 24    simulate behaviour portion desired software pr...      1.000000
# 25    simulate behaviour portion desired software pr...      1.611111
# 26    simulate behaviour portion desired software pr...      2.074074
# 27    simulate behaviour portion desired software pr...      0.981481
# 28    simulate behaviour portion desired software pr...      6.388889
# 29    can both coding phase and solution refinement ...      3.448276
# ...                                                 ...           ...
# 2412  find then replace it leftmost it right subtree...      1.840000
# 2413  find then replace it leftmost it right subtree...      1.100000
# 2414                                             height      3.000000
# 2415                                             height      1.636364
# 2416                                             height      2.545455
# 2417                                             height      1.727273
# 2418                                             height      6.272727
# 2419                                             height      0.454545
# 2420                                             height     15.272727
# 2421                                             height      3.272727
# 2422                                             height      3.909091
# 2423                                             height      3.545455
# 2424                                             height      1.181818
# 2425                                             height      1.363636
# 2426                                             height      2.090909
# 2427                                             height     33.727273
# 2428                                             height      1.909091
# 2429                                             height      8.000000
# 2430                                             height      1.181818
# 2431                                             height     11.000000
# 2432                                             height      1.818182
# 2433                                             height      4.818182
# 2434                                             height      4.636364
# 2435                                             height      7.090909
# 2436                                             height      9.000000
# 2437                                             height      0.454545
# 2438                                             height      3.000000
# 2439                                             height      0.272727
# 2440                                             height      3.545455
# 2441                                             height      9.545455
#
#       grades_round                                          embed_ref  \
# 0                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 1                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 2                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 3                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 4                3  [[0.13071777343750002, -0.10377929687499998, 0...
# 5                2  [[0.13071777343750002, -0.10377929687499998, 0...
# 6                2  [[0.13071777343750002, -0.10377929687499998, 0...
# 7                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 8                4  [[0.13071777343750002, -0.10377929687499998, 0...
# 9                5  [[0.13071777343750002, -0.10377929687499998, 0...
# 10               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 11               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 12               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 13               4  [[0.13071777343750002, -0.10377929687499998, 0...
# 14               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 15               4  [[0.13071777343750002, -0.10377929687499998, 0...
# 16               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 17               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 18               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 19               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 20               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 21               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 22               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 23               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 24               5  [[0.13071777343750002, -0.10377929687499998, 0...
# 25               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 26               3  [[0.13071777343750002, -0.10377929687499998, 0...
# 27               3  [[0.13071777343750002, -0.10377929687499998, 0...
# 28               2  [[0.13071777343750002, -0.10377929687499998, 0...
# 29               4  [[-0.03724121093749999, 0.728505859375, 0.1627...
# ...            ...                                                ...
# 2412             4  [[0.8393359375, -0.9155201721191406, 0.7835498...
# 2413             3  [[0.8393359375, -0.9155201721191406, 0.7835498...
# 2414             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2415             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2416             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2417             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2418             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2419             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2420             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2421             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2422             4  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2423             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2424             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2425             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2426             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2427             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2428             4  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2429             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2430             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2431             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2432             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2433             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2434             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2435             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2436             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2437             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2438             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2439             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2440             5  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
# 2441             2  [[0.5942383, 0.37060547, -0.2121582, -0.020263...
#
#                                              embed_stud  \
# 0     [[-0.5155224609375, 0.008998413085937518, 1.30...
# 1     [[2.15602783203125, 0.4706297302246094, 0.2766...
# 2     [[-0.28229736328125, 0.043576965332031245, 0.2...
# 3     [[-0.127725830078125, 0.53630615234375, 0.3706...
# 4     [[0.23586181640625004, 0.06217674255371097, 0....
# 5     [[0.12119628906250002, 0.0628600311279297, 0.0...
# 6     [[-0.10513183593749997, 0.6872704315185547, 0....
# 7     [[0.162374267578125, 0.4117333984375, 0.582143...
# 8     [[-0.33944580078125, 0.7594540405273438, 0.717...
# 9     [[0.24334717, -0.18823242, 0.23413086, 0.12432...
# 10    [[-0.046813965, -0.0008544922, 0.48388672, 0.4...
# 11    [[0.04473877, -0.006591797, 0.5078125, 0.23901...
# 12    [[1.146312255859375, -0.26472900390625, 0.4583...
# 13    [[0.30833984375, 0.11400390625000001, -0.20218...
# 14    [[-0.7306201171875, 0.3886511611938477, 0.0168...
# 15    [[0.48851684570312504, 0.6005602264404297, 1.0...
# 16    [[0.04473877, -0.006591797, 0.5078125, 0.23901...
# 17    [[-0.39966796875, -0.9118006134033203, -0.5778...
# 18    [[0.42938232, -0.28831673, 0.5189209, 0.293945...
# 19    [[0.18246582031250003, 0.6643317031860352, 0.9...
# 20    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 21    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 22    [[0.368734130859375, 0.2569482421875, 0.016927...
# 23    [[-0.01736328125, 0.41330078125, -0.3998706054...
# 24    [[0.22845459, -0.07481575, 0.27539062, 0.15551...
# 25    [[0.1439111328125, 0.5086572265625, 0.28313232...
# 26    [[0.6358905029296875, 0.461162109375, 0.797099...
# 27    [[0.17676879882812502, 0.2869925689697266, 0.5...
# 28    [[0.08475952148437504, 0.729856300354004, 0.79...
# 29    [[-0.643990478515625, 0.17536643981933597, 2.5...
# ...                                                 ...
# 2412  [[2.47820068359375, -1.9582750701904297, 2.420...
# 2413  [[1.284130859375, 0.3819492340087891, 1.449673...
# 2414  [[0.24210693359375002, -0.24281738281249998, -...
# 2415  [[-0.06624267578124998, 0.12498046875, -0.2155...
# 2416  [[0.59349609375, 0.3421990966796875, -0.072031...
# 2417  [[0.8496094, 0.35816765, -0.122802734, 0.25219...
# 2418  [[0.48265625, 0.1604039764404297, 0.1828515625...
# 2419  [[0.11981201, -0.0034179688, -0.34594727, 0.10...
# 2420  [[1.5667529296875, -0.7187771606445312, 1.6323...
# 2421  [[0.57732177734375, 0.12149597167968751, 0.140...
# 2422  [[0.152578125, -0.4102880859375, -0.1097509765...
# 2423  [[0.5074463, 0.0417614, 0.37451172, 0.70996094...
# 2424  [[0.13981201171875002, 0.016582031250000004, -...
# 2425  [[-0.02425048828124999, 0.09861328124999999, -...
# 2426  [[-0.004250488281249989, 0.11861328124999998, ...
# 2427  [[3.789757080078124, 0.8338683319091797, 0.085...
# 2428  [[-0.08459473, -0.21960449, 0.028198242, 0.352...
# 2429  [[0.9930126953125, -0.2812659454345703, 0.5872...
# 2430  [[0.13981201171875002, 0.016582031250000004, -...
# 2431  [[0.29675293, -0.13927555, 1.7305908, 1.922637...
# 2432  [[0.012939453, -0.016967773, 0.119262695, 0.11...
# 2433  [[0.84684326171875, -0.3604931640625, -0.06605...
# 2434  [[0.67222023, 0.31230164, 0.6809082, 0.5546875...
# 2435  [[1.3265283203125, -0.06673645019531249, -0.15...
# 2436  [[0.02510742187500003, 0.689505615234375, 0.86...
# 2437  [[0.11981201, -0.0034179688, -0.34594727, 0.10...
# 2438  [[0.08266357421875001, -0.20462890624999996, 0...
# 2439  [[0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0....
# 2440  [[-0.07293701, 0.8473034, -0.040893555, 0.2551...
# 2441  [[1.4141846, 0.09828472, 0.32574463, 1.3451843...
#
#                                                 aligned
# 0                                [[software, software]]
# 1     [[to, to], [simulate, simulate], [portion, por...
# 2     [[portion, portion], [desired, desired], [soft...
# 3     [[portion, portion], [desired, desired], [soft...
# 4           [[software, software], [product, generate]]
# 5                                                    []
# 6                                                    []
# 7     [[to, to], [simulate, simulate], [portion, part]]
# 8                                                    []
# 9     [[product, product], [portion, portion], [desi...
# 10    [[product, product], [portion, portion], [desi...
# 11    [[product, product], [portion, portion], [desi...
# 12                                                   []
# 13    [[to, to], [simulate, simulate], [portion, part]]
# 14                                                   []
# 15              [[software, software], [portion, part]]
# 16    [[product, product], [portion, portion], [desi...
# 17                                                   []
# 18                                                   []
# 19                                    [[desired, like]]
# 20    [[product, product], [portion, portion], [desi...
# 21    [[product, product], [portion, portion], [desi...
# 22                                                   []
# 23                                                   []
# 24    [[product, product], [portion, portion], [desi...
# 25                                                   []
# 26                                 [[product, product]]
# 27                                    [[portion, part]]
# 28                              [[product, proceeding]]
# 29    [[influence, affected], [can, can], [testing, ...
# ...                                                 ...
# 2412  [[replace, replace], [it, it], [node, node], [...
# 2413             [[node, node], [node, node], [it, it]]
# 2414                                                 []
# 2415                                                 []
# 2416                   [[tree, tree], [height, height]]
# 2417                   [[tree, tree], [height, height]]
# 2418                                                 []
# 2419                                                 []
# 2420                                                 []
# 2421                                     [[tree, tree]]
# 2422                                                 []
# 2423                                                 []
# 2424                                                 []
# 2425                                                 []
# 2426                                                 []
# 2427                     [[tree, tree], [height, time]]
# 2428                                                 []
# 2429                                     [[tree, tree]]
# 2430                                                 []
# 2431                                     [[tree, tree]]
# 2432                                                 []
# 2433                                     [[tree, tree]]
# 2434                                     [[tree, tree]]
# 2435                                     [[tree, tree]]
# 2436                                                 []
# 2437                                                 []
# 2438                                                 []
# 2439                                                 []
# 2440                   [[tree, tree], [height, height]]
# 2441                                     [[tree, tree]]
#
# [2442 rows x 15 columns]

# %%
df['grade'].unique()
# Out:
# array([3.5  , 5.   , 4.   , 3.   , 2.   , 2.5  , 4.5  , 1.5  , 1.   ,
#        0.   , 0.5  , 4.125, 3.75 , 1.75 , 2.25 , 3.625, 3.25 , 4.75 ])

# %%
df = pd.read_pickle("../../dataset/final_dataset/sem_final_train.pkl")
df
# Out:
#       Unnamed: 0                                           question ques_id  \
# 0              0  You used several methods to separate and ident...  EM_45b
# 1              1  You used several methods to separate and ident...  EM_45b
# 2              2  You used several methods to separate and ident...  EM_45b
# 3              3  You used several methods to separate and ident...  EM_45b
# 4              4  You used several methods to separate and ident...  EM_45b
# 5              5  You used several methods to separate and ident...  EM_45b
# 6              6  You used several methods to separate and ident...  EM_45b
# 7              7  You used several methods to separate and ident...  EM_45b
# 8              8  You used several methods to separate and ident...  EM_45b
# 9              9  You used several methods to separate and ident...  EM_45b
# 10            10  You used several methods to separate and ident...  EM_45b
# 11            11  You used several methods to separate and ident...  EM_45b
# 12            12  You used several methods to separate and ident...  EM_45b
# 13            13  You used several methods to separate and ident...  EM_45b
# 14            14  You used several methods to separate and ident...  EM_45b
# 15            15  You used several methods to separate and ident...  EM_45b
# 16            16  You used several methods to separate and ident...  EM_45b
# 17            17  You used several methods to separate and ident...  EM_45b
# 18            18  You used several methods to separate and ident...  EM_45b
# 19            19  You used several methods to separate and ident...  EM_45b
# 20            20  You used several methods to separate and ident...  EM_45b
# 21            21  You used several methods to separate and ident...  EM_45b
# 22            22  You used several methods to separate and ident...  EM_45b
# 23            23  You used several methods to separate and ident...  EM_45b
# 24            24  You used several methods to separate and ident...  EM_45b
# 25            25  You used several methods to separate and ident...  EM_45b
# 26            26  You used several methods to separate and ident...  EM_45b
# 27            27  You used several methods to separate and ident...  EM_45b
# 28            28  You used several methods to separate and ident...  EM_45b
# 29            29  You used several methods to separate and ident...  EM_45b
# ...          ...                                                ...     ...
# 4939        4939  When conducting a controlled experiment, why d...   VB_29
# 4940        4940  When conducting a controlled experiment, why d...   VB_29
# 4941        4941  When conducting a controlled experiment, why d...   VB_29
# 4942        4942  When conducting a controlled experiment, why d...   VB_29
# 4943        4943  When conducting a controlled experiment, why d...   VB_29
# 4944        4944  When conducting a controlled experiment, why d...   VB_29
# 4945        4945  When conducting a controlled experiment, why d...   VB_29
# 4946        4946  When conducting a controlled experiment, why d...   VB_29
# 4947        4947  When conducting a controlled experiment, why d...   VB_29
# 4948        4948  When conducting a controlled experiment, why d...   VB_29
# 4949        4949  When conducting a controlled experiment, why d...   VB_29
# 4950        4950  When conducting a controlled experiment, why d...   VB_29
# 4951        4951  When conducting a controlled experiment, why d...   VB_29
# 4952        4952  When conducting a controlled experiment, why d...   VB_29
# 4953        4953  When conducting a controlled experiment, why d...   VB_29
# 4954        4954  When conducting a controlled experiment, why d...   VB_29
# 4955        4955  When conducting a controlled experiment, why d...   VB_29
# 4956        4956  When conducting a controlled experiment, why d...   VB_29
# 4957        4957  When conducting a controlled experiment, why d...   VB_29
# 4958        4958  When conducting a controlled experiment, why d...   VB_29
# 4959        4959  When conducting a controlled experiment, why d...   VB_29
# 4960        4960  When conducting a controlled experiment, why d...   VB_29
# 4961        4961  When conducting a controlled experiment, why d...   VB_29
# 4962        4962  When conducting a controlled experiment, why d...   VB_29
# 4963        4963  When conducting a controlled experiment, why d...   VB_29
# 4964        4964  When conducting a controlled experiment, why d...   VB_29
# 4965        4965  When conducting a controlled experiment, why d...   VB_29
# 4966        4966  When conducting a controlled experiment, why d...   VB_29
# 4967        4967  When conducting a controlled experiment, why d...   VB_29
# 4968        4968  When conducting a controlled experiment, why d...   VB_29
#
#                                        reference_answer  \
# 0           The water was evaporated, leaving the salt.
# 1           The water was evaporated, leaving the salt.
# 2           The water was evaporated, leaving the salt.
# 3           The water was evaporated, leaving the salt.
# 4           The water was evaporated, leaving the salt.
# 5           The water was evaporated, leaving the salt.
# 6           The water was evaporated, leaving the salt.
# 7           The water was evaporated, leaving the salt.
# 8           The water was evaporated, leaving the salt.
# 9           The water was evaporated, leaving the salt.
# 10          The water was evaporated, leaving the salt.
# 11          The water was evaporated, leaving the salt.
# 12          The water was evaporated, leaving the salt.
# 13          The water was evaporated, leaving the salt.
# 14          The water was evaporated, leaving the salt.
# 15          The water was evaporated, leaving the salt.
# 16          The water was evaporated, leaving the salt.
# 17          The water was evaporated, leaving the salt.
# 18          The water was evaporated, leaving the salt.
# 19          The water was evaporated, leaving the salt.
# 20          The water was evaporated, leaving the salt.
# 21          The water was evaporated, leaving the salt.
# 22          The water was evaporated, leaving the salt.
# 23          The water was evaporated, leaving the salt.
# 24          The water was evaporated, leaving the salt.
# 25          The water was evaporated, leaving the salt.
# 26          The water was evaporated, leaving the salt.
# 27          The water was evaporated, leaving the salt.
# 28          The water was evaporated, leaving the salt.
# 29          The water was evaporated, leaving the salt.
# ...                                                 ...
# 4939  A standard is used for comparison to determine...
# 4940  A standard is used for comparison to determine...
# 4941  A standard is used for comparison to determine...
# 4942  A standard is used for comparison to determine...
# 4943  A standard is used for comparison to determine...
# 4944  A standard is used for comparison to determine...
# 4945  A standard is used for comparison to determine...
# 4946  A standard is used for comparison to determine...
# 4947  A standard is used for comparison to determine...
# 4948  A standard is used for comparison to determine...
# 4949  A standard is used for comparison to determine...
# 4950  A standard is used for comparison to determine...
# 4951  A standard is used for comparison to determine...
# 4952  A standard is used for comparison to determine...
# 4953  A standard is used for comparison to determine...
# 4954  A standard is used for comparison to determine...
# 4955  A standard is used for comparison to determine...
# 4956  A standard is used for comparison to determine...
# 4957  A standard is used for comparison to determine...
# 4958  A standard is used for comparison to determine...
# 4959  A standard is used for comparison to determine...
# 4960  A standard is used for comparison to determine...
# 4961  A standard is used for comparison to determine...
# 4962  A standard is used for comparison to determine...
# 4963  A standard is used for comparison to determine...
# 4964  A standard is used for comparison to determine...
# 4965  A standard is used for comparison to determine...
# 4966  A standard is used for comparison to determine...
# 4967  A standard is used for comparison to determine...
# 4968  A standard is used for comparison to determine...
#
#                                          student_answer  \
# 0                By letting it sit in a dish for a day.
# 1     Let the water evaporate and the salt is left b...
# 2          The water evaporated and left salt crystals.
# 3     I saw a pinkish grayish color that was blockin...
# 4     You have to slowly tip the vial for only the w...
# 5     By pouring the water and salt into the thing, ...
# 6                       By slowly pouring it in a tray.
# 7     The water evaporated so there was only salt left.
# 8     We put the water with the salt in it and put i...
# 9     I separated the salt from the water because th...
# 10                   Because you can see salt in water.
# 11                           I let the water evaporate.
# 12                The water dried up and left the salt.
# 13                          We let the water evaporate.
# 14                                  The water dried up.
# 15    You just get water and the smashed mock rock a...
# 16    You put the water, a little bit, in a cup and ...
# 17    We evaporated the salt from the water because ...
# 18    We put the water and salt in the Petri dish. T...
# 19    We poured the salt into a Petri dish and poure...
# 20                                   By the Petri dish.
# 21    By putting water in a Petri dish and letting t...
# 22                      Poured the top of the vial out.
# 23    The salt dissolved and the water evaporated an...
# 24    We put it in a evaporation dish and the water ...
# 25                    I put it on the evaporating dish.
# 26                  By pouring the water into the salt.
# 27               We poured the water out of the bottle.
# 28                         Letting the water evaporate.
# 29    Put it on a dish and then the water gets in th...
# ...                                                 ...
# 4939  So that control your experiment without changi...
# 4940                  To keep the variables controlled.
# 4941  You use a standard so you can tell what happen...
# 4942  You would use a standard to change any variabl...
# 4943  You use a standard to control your procedure, ...
# 4944   To compare the new experiment with the standard.
# 4945  You use a standard because when you change som...
# 4946  You use a standard because without a standard,...
# 4947  So you can see what you did after you do the o...
# 4948  You use a standard to see if you can try a les...
# 4949  You use a standard so that you can test it and...
# 4950  When conducting a controlled experiment you us...
# 4951  You use a standard so you can change the varia...
# 4952  You use a standard because that what you know ...
# 4953  In a controlled experiment you use a standard ...
# 4954                           To compare your answers.
# 4955  We use a standard first because we could know ...
# 4956  You use a standard is to know what you will do...
# 4957  So when you change variables you can compare y...
# 4958  So you can test the standard and can switch on...
# 4959  Because you want to know what is the regular w...
# 4960                   So you can compare your answers.
# 4961   To compare the experiment with the standard one.
# 4962            So when you are done you could compare.
# 4963       So you compare at the end of the experiment.
# 4964  To see if the standard might be faster than th...
# 4965               Because you can compare the results.
# 4966         To help control the controlled experiment.
# 4967                         To control any experiment.
# 4968  Because without a standard you will not know t...
#
#                             result  grades_round  \
# 0                       irrelevant             1
# 1                          correct             4
# 2                          correct             4
# 3                       irrelevant             1
# 4                       irrelevant             1
# 5                          correct             4
# 6                       irrelevant             1
# 7                          correct             4
# 8                          correct             4
# 9                       irrelevant             1
# 10                      irrelevant             1
# 11                         correct             4
# 12                         correct             4
# 13                         correct             4
# 14                         correct             4
# 15                      irrelevant             1
# 16    partially_correct_incomplete             3
# 17                         correct             4
# 18                         correct             4
# 19                      irrelevant             1
# 20                      irrelevant             1
# 21                         correct             4
# 22                      irrelevant             1
# 23                         correct             4
# 24                         correct             4
# 25                         correct             4
# 26                      irrelevant             1
# 27                      irrelevant             1
# 28                         correct             4
# 29                         correct             4
# ...                            ...           ...
# 4939                       correct             4
# 4940                    irrelevant             1
# 4941                       correct             4
# 4942                       correct             4
# 4943  partially_correct_incomplete             3
# 4944  partially_correct_incomplete             3
# 4945                       correct             4
# 4946  partially_correct_incomplete             3
# 4947  partially_correct_incomplete             3
# 4948                       correct             4
# 4949  partially_correct_incomplete             3
# 4950                       correct             4
# 4951  partially_correct_incomplete             3
# 4952                    irrelevant             1
# 4953  partially_correct_incomplete             3
# 4954                    irrelevant             1
# 4955  partially_correct_incomplete             3
# 4956                    irrelevant             1
# 4957  partially_correct_incomplete             3
# 4958  partially_correct_incomplete             3
# 4959  partially_correct_incomplete             3
# 4960  partially_correct_incomplete             3
# 4961  partially_correct_incomplete             3
# 4962  partially_correct_incomplete             3
# 4963  partially_correct_incomplete             3
# 4964  partially_correct_incomplete             3
# 4965  partially_correct_incomplete             3
# 4966                    irrelevant             1
# 4967                    irrelevant             1
# 4968                    irrelevant             1
#
#                                        student_modified
# 0                                  letting sit dish day
# 1                  let water evaporate salt left behind
# 2                    water evaporated left salt crystal
# 3              saw pinkish grayish color blocking water
# 4                              slowly tip vial water go
# 5      pouring water salt thing letting water evaporate
# 6                                   slowly pouring tray
# 7                            water evaporated salt left
# 8            put water salt put outside water evaporate
# 9       separated salt water salt rock bottom water top
# 10                                       see salt water
# 11                                  let water evaporate
# 12                                water dried left salt
# 13                                  let water evaporate
# 14                                          water dried
# 15    get water smashed mock rock put smashed rock w...
# 16             put water little bit cup leave overnight
# 17     evaporated salt water water evaporated separated
# 18    put water salt petri dish water evaporated sal...
# 19                  poured salt petri dish poured water
# 20                                           petri dish
# 21     putting water petri dish letting water evaporate
# 22                                      poured top vial
# 23     salt dissolved water evaporated salt went bottom
# 24                put evaporation dish water evaporated
# 25                                 put evaporating dish
# 26                                   pouring water salt
# 27                                  poured water bottle
# 28                              letting water evaporate
# 29                     put dish water get air salt stay
# ...                                                 ...
# 4939   control experiment without changing one variable
# 4940                           keep variable controlled
# 4941  use standard tell happened controlled experime...
# 4942  would use standard change variable one variabl...
# 4943  use standard control procedure like get wrong see
# 4944                    compare new experiment standard
# 4945  use standard change something variable change ...
# 4946               use standard without standard change
# 4947  see trial make controlled experiment look back...
# 4948     use standard see try le amount time experiment
# 4949  use standard test compare standard compare var...
# 4950  conducting controlled experiment use standard ...
# 4951  use standard change variable needed experiment...
# 4952  use standard know experiment standard help lot...
# 4953  controlled experiment use standard testing som...
# 4954                                     compare answer
# 4955  use standard first could know went could use s...
# 4956                           use standard know happen
# 4957               change variable compare standard one
# 4958      test standard switch one variable make proven
# 4959            want know regular way compare first way
# 4960                                     compare answer
# 4961                    compare experiment standard one
# 4962                                 done could compare
# 4963                             compare end experiment
# 4964                          see standard might faster
# 4965                                     compare result
# 4966                 help control controlled experiment
# 4967                                 control experiment
# 4968                         without standard know step
#
# [4969 rows x 8 columns]

# %%
## question Demoting functions

def student_demoting(data):
    return " ".join(x for x in data['student_modified'].split() if x not in data['qn_modified'])

def ref_demoting(data):
    return " ".join(x for x in data['ref_modified'].split() if x not in data['qn_modified'])  


#converting to lower case
df['qn_modified'] = df['question'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['ref_modified'] = df['reference_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['student_modified'] = df['student_answer'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#punctuation removal
df['qn_modified'] = df['qn_modified'].str.replace('[^\w\s]','')
df['ref_modified'] = df['ref_modified'].str.replace('[^\w\s]','')
df['student_modified'] = df['student_modified'].str.replace('[^\w\s]','')

#stop word removal
stop = stopwords.words('english')
df['qn_modified'] = df['qn_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# ##numeric removal
# df['qn_modified'] = df['qn_modified'].apply(lambda x: " ".join(word for word in x.split() if not word.isdigit()))
# df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join(word for word in x.split() if not word.isdigit()))
# df['student_modified'] = df['student_modified'].apply(lambda x: " ".join(word for word in x.split() if not word.isdigit()))

#lemmatisation
df['qn_modified'] = df['qn_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['ref_modified'] = df['ref_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))
df['student_modified'] = df['student_modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in word_tokenize(x)]))

#question demoting
df['student_demoted'] = df.apply(student_demoting,axis=1)
df['ref_demoted'] = df.apply(ref_demoting,axis=1)

#length ratio
df['length_ratio'] = df['student_modified'].apply(lambda x: len(x)) / df['ref_modified'].apply(lambda x: len(x))

# %%
df
# Out:
#       Unnamed: 0                                           question ques_id  \
# 0              0  You used several methods to separate and ident...  EM_45b
# 1              1  You used several methods to separate and ident...  EM_45b
# 2              2  You used several methods to separate and ident...  EM_45b
# 3              3  You used several methods to separate and ident...  EM_45b
# 4              4  You used several methods to separate and ident...  EM_45b
# 5              5  You used several methods to separate and ident...  EM_45b
# 6              6  You used several methods to separate and ident...  EM_45b
# 7              7  You used several methods to separate and ident...  EM_45b
# 8              8  You used several methods to separate and ident...  EM_45b
# 9              9  You used several methods to separate and ident...  EM_45b
# 10            10  You used several methods to separate and ident...  EM_45b
# 11            11  You used several methods to separate and ident...  EM_45b
# 12            12  You used several methods to separate and ident...  EM_45b
# 13            13  You used several methods to separate and ident...  EM_45b
# 14            14  You used several methods to separate and ident...  EM_45b
# 15            15  You used several methods to separate and ident...  EM_45b
# 16            16  You used several methods to separate and ident...  EM_45b
# 17            17  You used several methods to separate and ident...  EM_45b
# 18            18  You used several methods to separate and ident...  EM_45b
# 19            19  You used several methods to separate and ident...  EM_45b
# 20            20  You used several methods to separate and ident...  EM_45b
# 21            21  You used several methods to separate and ident...  EM_45b
# 22            22  You used several methods to separate and ident...  EM_45b
# 23            23  You used several methods to separate and ident...  EM_45b
# 24            24  You used several methods to separate and ident...  EM_45b
# 25            25  You used several methods to separate and ident...  EM_45b
# 26            26  You used several methods to separate and ident...  EM_45b
# 27            27  You used several methods to separate and ident...  EM_45b
# 28            28  You used several methods to separate and ident...  EM_45b
# 29            29  You used several methods to separate and ident...  EM_45b
# ...          ...                                                ...     ...
# 4939        4939  When conducting a controlled experiment, why d...   VB_29
# 4940        4940  When conducting a controlled experiment, why d...   VB_29
# 4941        4941  When conducting a controlled experiment, why d...   VB_29
# 4942        4942  When conducting a controlled experiment, why d...   VB_29
# 4943        4943  When conducting a controlled experiment, why d...   VB_29
# 4944        4944  When conducting a controlled experiment, why d...   VB_29
# 4945        4945  When conducting a controlled experiment, why d...   VB_29
# 4946        4946  When conducting a controlled experiment, why d...   VB_29
# 4947        4947  When conducting a controlled experiment, why d...   VB_29
# 4948        4948  When conducting a controlled experiment, why d...   VB_29
# 4949        4949  When conducting a controlled experiment, why d...   VB_29
# 4950        4950  When conducting a controlled experiment, why d...   VB_29
# 4951        4951  When conducting a controlled experiment, why d...   VB_29
# 4952        4952  When conducting a controlled experiment, why d...   VB_29
# 4953        4953  When conducting a controlled experiment, why d...   VB_29
# 4954        4954  When conducting a controlled experiment, why d...   VB_29
# 4955        4955  When conducting a controlled experiment, why d...   VB_29
# 4956        4956  When conducting a controlled experiment, why d...   VB_29
# 4957        4957  When conducting a controlled experiment, why d...   VB_29
# 4958        4958  When conducting a controlled experiment, why d...   VB_29
# 4959        4959  When conducting a controlled experiment, why d...   VB_29
# 4960        4960  When conducting a controlled experiment, why d...   VB_29
# 4961        4961  When conducting a controlled experiment, why d...   VB_29
# 4962        4962  When conducting a controlled experiment, why d...   VB_29
# 4963        4963  When conducting a controlled experiment, why d...   VB_29
# 4964        4964  When conducting a controlled experiment, why d...   VB_29
# 4965        4965  When conducting a controlled experiment, why d...   VB_29
# 4966        4966  When conducting a controlled experiment, why d...   VB_29
# 4967        4967  When conducting a controlled experiment, why d...   VB_29
# 4968        4968  When conducting a controlled experiment, why d...   VB_29
#
#                                        reference_answer  \
# 0           The water was evaporated, leaving the salt.
# 1           The water was evaporated, leaving the salt.
# 2           The water was evaporated, leaving the salt.
# 3           The water was evaporated, leaving the salt.
# 4           The water was evaporated, leaving the salt.
# 5           The water was evaporated, leaving the salt.
# 6           The water was evaporated, leaving the salt.
# 7           The water was evaporated, leaving the salt.
# 8           The water was evaporated, leaving the salt.
# 9           The water was evaporated, leaving the salt.
# 10          The water was evaporated, leaving the salt.
# 11          The water was evaporated, leaving the salt.
# 12          The water was evaporated, leaving the salt.
# 13          The water was evaporated, leaving the salt.
# 14          The water was evaporated, leaving the salt.
# 15          The water was evaporated, leaving the salt.
# 16          The water was evaporated, leaving the salt.
# 17          The water was evaporated, leaving the salt.
# 18          The water was evaporated, leaving the salt.
# 19          The water was evaporated, leaving the salt.
# 20          The water was evaporated, leaving the salt.
# 21          The water was evaporated, leaving the salt.
# 22          The water was evaporated, leaving the salt.
# 23          The water was evaporated, leaving the salt.
# 24          The water was evaporated, leaving the salt.
# 25          The water was evaporated, leaving the salt.
# 26          The water was evaporated, leaving the salt.
# 27          The water was evaporated, leaving the salt.
# 28          The water was evaporated, leaving the salt.
# 29          The water was evaporated, leaving the salt.
# ...                                                 ...
# 4939  A standard is used for comparison to determine...
# 4940  A standard is used for comparison to determine...
# 4941  A standard is used for comparison to determine...
# 4942  A standard is used for comparison to determine...
# 4943  A standard is used for comparison to determine...
# 4944  A standard is used for comparison to determine...
# 4945  A standard is used for comparison to determine...
# 4946  A standard is used for comparison to determine...
# 4947  A standard is used for comparison to determine...
# 4948  A standard is used for comparison to determine...
# 4949  A standard is used for comparison to determine...
# 4950  A standard is used for comparison to determine...
# 4951  A standard is used for comparison to determine...
# 4952  A standard is used for comparison to determine...
# 4953  A standard is used for comparison to determine...
# 4954  A standard is used for comparison to determine...
# 4955  A standard is used for comparison to determine...
# 4956  A standard is used for comparison to determine...
# 4957  A standard is used for comparison to determine...
# 4958  A standard is used for comparison to determine...
# 4959  A standard is used for comparison to determine...
# 4960  A standard is used for comparison to determine...
# 4961  A standard is used for comparison to determine...
# 4962  A standard is used for comparison to determine...
# 4963  A standard is used for comparison to determine...
# 4964  A standard is used for comparison to determine...
# 4965  A standard is used for comparison to determine...
# 4966  A standard is used for comparison to determine...
# 4967  A standard is used for comparison to determine...
# 4968  A standard is used for comparison to determine...
#
#                                          student_answer  \
# 0                By letting it sit in a dish for a day.
# 1     Let the water evaporate and the salt is left b...
# 2          The water evaporated and left salt crystals.
# 3     I saw a pinkish grayish color that was blockin...
# 4     You have to slowly tip the vial for only the w...
# 5     By pouring the water and salt into the thing, ...
# 6                       By slowly pouring it in a tray.
# 7     The water evaporated so there was only salt left.
# 8     We put the water with the salt in it and put i...
# 9     I separated the salt from the water because th...
# 10                   Because you can see salt in water.
# 11                           I let the water evaporate.
# 12                The water dried up and left the salt.
# 13                          We let the water evaporate.
# 14                                  The water dried up.
# 15    You just get water and the smashed mock rock a...
# 16    You put the water, a little bit, in a cup and ...
# 17    We evaporated the salt from the water because ...
# 18    We put the water and salt in the Petri dish. T...
# 19    We poured the salt into a Petri dish and poure...
# 20                                   By the Petri dish.
# 21    By putting water in a Petri dish and letting t...
# 22                      Poured the top of the vial out.
# 23    The salt dissolved and the water evaporated an...
# 24    We put it in a evaporation dish and the water ...
# 25                    I put it on the evaporating dish.
# 26                  By pouring the water into the salt.
# 27               We poured the water out of the bottle.
# 28                         Letting the water evaporate.
# 29    Put it on a dish and then the water gets in th...
# ...                                                 ...
# 4939  So that control your experiment without changi...
# 4940                  To keep the variables controlled.
# 4941  You use a standard so you can tell what happen...
# 4942  You would use a standard to change any variabl...
# 4943  You use a standard to control your procedure, ...
# 4944   To compare the new experiment with the standard.
# 4945  You use a standard because when you change som...
# 4946  You use a standard because without a standard,...
# 4947  So you can see what you did after you do the o...
# 4948  You use a standard to see if you can try a les...
# 4949  You use a standard so that you can test it and...
# 4950  When conducting a controlled experiment you us...
# 4951  You use a standard so you can change the varia...
# 4952  You use a standard because that what you know ...
# 4953  In a controlled experiment you use a standard ...
# 4954                           To compare your answers.
# 4955  We use a standard first because we could know ...
# 4956  You use a standard is to know what you will do...
# 4957  So when you change variables you can compare y...
# 4958  So you can test the standard and can switch on...
# 4959  Because you want to know what is the regular w...
# 4960                   So you can compare your answers.
# 4961   To compare the experiment with the standard one.
# 4962            So when you are done you could compare.
# 4963       So you compare at the end of the experiment.
# 4964  To see if the standard might be faster than th...
# 4965               Because you can compare the results.
# 4966         To help control the controlled experiment.
# 4967                         To control any experiment.
# 4968  Because without a standard you will not know t...
#
#                             result  grades_round  \
# 0                       irrelevant             1
# 1                          correct             4
# 2                          correct             4
# 3                       irrelevant             1
# 4                       irrelevant             1
# 5                          correct             4
# 6                       irrelevant             1
# 7                          correct             4
# 8                          correct             4
# 9                       irrelevant             1
# 10                      irrelevant             1
# 11                         correct             4
# 12                         correct             4
# 13                         correct             4
# 14                         correct             4
# 15                      irrelevant             1
# 16    partially_correct_incomplete             3
# 17                         correct             4
# 18                         correct             4
# 19                      irrelevant             1
# 20                      irrelevant             1
# 21                         correct             4
# 22                      irrelevant             1
# 23                         correct             4
# 24                         correct             4
# 25                         correct             4
# 26                      irrelevant             1
# 27                      irrelevant             1
# 28                         correct             4
# 29                         correct             4
# ...                            ...           ...
# 4939                       correct             4
# 4940                    irrelevant             1
# 4941                       correct             4
# 4942                       correct             4
# 4943  partially_correct_incomplete             3
# 4944  partially_correct_incomplete             3
# 4945                       correct             4
# 4946  partially_correct_incomplete             3
# 4947  partially_correct_incomplete             3
# 4948                       correct             4
# 4949  partially_correct_incomplete             3
# 4950                       correct             4
# 4951  partially_correct_incomplete             3
# 4952                    irrelevant             1
# 4953  partially_correct_incomplete             3
# 4954                    irrelevant             1
# 4955  partially_correct_incomplete             3
# 4956                    irrelevant             1
# 4957  partially_correct_incomplete             3
# 4958  partially_correct_incomplete             3
# 4959  partially_correct_incomplete             3
# 4960  partially_correct_incomplete             3
# 4961  partially_correct_incomplete             3
# 4962  partially_correct_incomplete             3
# 4963  partially_correct_incomplete             3
# 4964  partially_correct_incomplete             3
# 4965  partially_correct_incomplete             3
# 4966                    irrelevant             1
# 4967                    irrelevant             1
# 4968                    irrelevant             1
#
#                                        student_modified  \
# 0                                  letting sit dish day
# 1                  let water evaporate salt left behind
# 2                    water evaporated left salt crystal
# 3              saw pinkish grayish color blocking water
# 4                              slowly tip vial water go
# 5      pouring water salt thing letting water evaporate
# 6                                   slowly pouring tray
# 7                            water evaporated salt left
# 8            put water salt put outside water evaporate
# 9       separated salt water salt rock bottom water top
# 10                                       see salt water
# 11                                  let water evaporate
# 12                                water dried left salt
# 13                                  let water evaporate
# 14                                          water dried
# 15    get water smashed mock rock put smashed rock w...
# 16             put water little bit cup leave overnight
# 17     evaporated salt water water evaporated separated
# 18    put water salt petri dish water evaporated sal...
# 19                  poured salt petri dish poured water
# 20                                           petri dish
# 21     putting water petri dish letting water evaporate
# 22                                      poured top vial
# 23     salt dissolved water evaporated salt went bottom
# 24                put evaporation dish water evaporated
# 25                                 put evaporating dish
# 26                                   pouring water salt
# 27                                  poured water bottle
# 28                              letting water evaporate
# 29                     put dish water get air salt stay
# ...                                                 ...
# 4939   control experiment without changing one variable
# 4940                           keep variable controlled
# 4941  use standard tell happened controlled experime...
# 4942  would use standard change variable one variabl...
# 4943  use standard control procedure like get wrong see
# 4944                    compare new experiment standard
# 4945  use standard change something variable change ...
# 4946               use standard without standard change
# 4947  see trial make controlled experiment look back...
# 4948     use standard see try le amount time experiment
# 4949  use standard test compare standard compare var...
# 4950  conducting controlled experiment use standard ...
# 4951  use standard change variable needed experiment...
# 4952  use standard know experiment standard help lot...
# 4953  controlled experiment use standard testing som...
# 4954                                     compare answer
# 4955  use standard first could know went could use s...
# 4956                           use standard know happen
# 4957               change variable compare standard one
# 4958      test standard switch one variable make proven
# 4959            want know regular way compare first way
# 4960                                     compare answer
# 4961                    compare experiment standard one
# 4962                                 done could compare
# 4963                             compare end experiment
# 4964                          see standard might faster
# 4965                                     compare result
# 4966                 help control controlled experiment
# 4967                                 control experiment
# 4968                         without standard know step
#
#                                             qn_modified  \
# 0     used several method separate identify substanc...
# 1     used several method separate identify substanc...
# 2     used several method separate identify substanc...
# 3     used several method separate identify substanc...
# 4     used several method separate identify substanc...
# 5     used several method separate identify substanc...
# 6     used several method separate identify substanc...
# 7     used several method separate identify substanc...
# 8     used several method separate identify substanc...
# 9     used several method separate identify substanc...
# 10    used several method separate identify substanc...
# 11    used several method separate identify substanc...
# 12    used several method separate identify substanc...
# 13    used several method separate identify substanc...
# 14    used several method separate identify substanc...
# 15    used several method separate identify substanc...
# 16    used several method separate identify substanc...
# 17    used several method separate identify substanc...
# 18    used several method separate identify substanc...
# 19    used several method separate identify substanc...
# 20    used several method separate identify substanc...
# 21    used several method separate identify substanc...
# 22    used several method separate identify substanc...
# 23    used several method separate identify substanc...
# 24    used several method separate identify substanc...
# 25    used several method separate identify substanc...
# 26    used several method separate identify substanc...
# 27    used several method separate identify substanc...
# 28    used several method separate identify substanc...
# 29    used several method separate identify substanc...
# ...                                                 ...
# 4939      conducting controlled experiment use standard
# 4940      conducting controlled experiment use standard
# 4941      conducting controlled experiment use standard
# 4942      conducting controlled experiment use standard
# 4943      conducting controlled experiment use standard
# 4944      conducting controlled experiment use standard
# 4945      conducting controlled experiment use standard
# 4946      conducting controlled experiment use standard
# 4947      conducting controlled experiment use standard
# 4948      conducting controlled experiment use standard
# 4949      conducting controlled experiment use standard
# 4950      conducting controlled experiment use standard
# 4951      conducting controlled experiment use standard
# 4952      conducting controlled experiment use standard
# 4953      conducting controlled experiment use standard
# 4954      conducting controlled experiment use standard
# 4955      conducting controlled experiment use standard
# 4956      conducting controlled experiment use standard
# 4957      conducting controlled experiment use standard
# 4958      conducting controlled experiment use standard
# 4959      conducting controlled experiment use standard
# 4960      conducting controlled experiment use standard
# 4961      conducting controlled experiment use standard
# 4962      conducting controlled experiment use standard
# 4963      conducting controlled experiment use standard
# 4964      conducting controlled experiment use standard
# 4965      conducting controlled experiment use standard
# 4966      conducting controlled experiment use standard
# 4967      conducting controlled experiment use standard
# 4968      conducting controlled experiment use standard
#
#                                            ref_modified  \
# 0                         water evaporated leaving salt
# 1                         water evaporated leaving salt
# 2                         water evaporated leaving salt
# 3                         water evaporated leaving salt
# 4                         water evaporated leaving salt
# 5                         water evaporated leaving salt
# 6                         water evaporated leaving salt
# 7                         water evaporated leaving salt
# 8                         water evaporated leaving salt
# 9                         water evaporated leaving salt
# 10                        water evaporated leaving salt
# 11                        water evaporated leaving salt
# 12                        water evaporated leaving salt
# 13                        water evaporated leaving salt
# 14                        water evaporated leaving salt
# 15                        water evaporated leaving salt
# 16                        water evaporated leaving salt
# 17                        water evaporated leaving salt
# 18                        water evaporated leaving salt
# 19                        water evaporated leaving salt
# 20                        water evaporated leaving salt
# 21                        water evaporated leaving salt
# 22                        water evaporated leaving salt
# 23                        water evaporated leaving salt
# 24                        water evaporated leaving salt
# 25                        water evaporated leaving salt
# 26                        water evaporated leaving salt
# 27                        water evaporated leaving salt
# 28                        water evaporated leaving salt
# 29                        water evaporated leaving salt
# ...                                                 ...
# 4939  standard used comparison determine changing on...
# 4940  standard used comparison determine changing on...
# 4941  standard used comparison determine changing on...
# 4942  standard used comparison determine changing on...
# 4943  standard used comparison determine changing on...
# 4944  standard used comparison determine changing on...
# 4945  standard used comparison determine changing on...
# 4946  standard used comparison determine changing on...
# 4947  standard used comparison determine changing on...
# 4948  standard used comparison determine changing on...
# 4949  standard used comparison determine changing on...
# 4950  standard used comparison determine changing on...
# 4951  standard used comparison determine changing on...
# 4952  standard used comparison determine changing on...
# 4953  standard used comparison determine changing on...
# 4954  standard used comparison determine changing on...
# 4955  standard used comparison determine changing on...
# 4956  standard used comparison determine changing on...
# 4957  standard used comparison determine changing on...
# 4958  standard used comparison determine changing on...
# 4959  standard used comparison determine changing on...
# 4960  standard used comparison determine changing on...
# 4961  standard used comparison determine changing on...
# 4962  standard used comparison determine changing on...
# 4963  standard used comparison determine changing on...
# 4964  standard used comparison determine changing on...
# 4965  standard used comparison determine changing on...
# 4966  standard used comparison determine changing on...
# 4967  standard used comparison determine changing on...
# 4968  standard used comparison determine changing on...
#
#                                         student_demoted  \
# 0                                  letting sit dish day
# 1                             let evaporate left behind
# 2                               evaporated left crystal
# 3                    saw pinkish grayish color blocking
# 4                                    slowly tip vial go
# 5                       pouring thing letting evaporate
# 6                                   slowly pouring tray
# 7                                       evaporated left
# 8                             put put outside evaporate
# 9                                  separated bottom top
# 10                                                  see
# 11                                        let evaporate
# 12                                           dried left
# 13                                        let evaporate
# 14                                                dried
# 15                     get smashed put smashed together
# 16                   put little bit cup leave overnight
# 17                      evaporated evaporated separated
# 18             put petri dish evaporated became crystal
# 19                             poured petri dish poured
# 20                                           petri dish
# 21                 putting petri dish letting evaporate
# 22                                      poured top vial
# 23                     dissolved evaporated went bottom
# 24                      put evaporation dish evaporated
# 25                                 put evaporating dish
# 26                                              pouring
# 27                                        poured bottle
# 28                                    letting evaporate
# 29                                put dish get air stay
# ...                                                 ...
# 4939                      without changing one variable
# 4940                                      keep variable
# 4941             tell happened change one variable time
# 4942         would change variable one variable changed
# 4943                       procedure like get wrong see
# 4944                                        compare new
# 4945              change something variable change know
# 4946                                     without change
# 4947  see trial make look back change one variable time
# 4948                                see try amount time
# 4949                      test compare compare variable
# 4950                        compare result see accurate
# 4951   change variable needed also change variable time
# 4952                                      know help lot
# 4953         testing something else compare answer come
# 4954                                     compare answer
# 4955        first could know went could score went test
# 4956                                        know happen
# 4957                        change variable compare one
# 4958               test switch one variable make proven
# 4959            want know regular way compare first way
# 4960                                     compare answer
# 4961                                        compare one
# 4962                                 done could compare
# 4963                                        compare end
# 4964                                   see might faster
# 4965                                     compare result
# 4966                                               help
# 4967
# 4968                                  without know step
#
#                                             ref_demoted  length_ratio
# 0                                    evaporated leaving      0.689655
# 1                                    evaporated leaving      1.241379
# 2                                    evaporated leaving      1.172414
# 3                                    evaporated leaving      1.379310
# 4                                    evaporated leaving      0.827586
# 5                                    evaporated leaving      1.655172
# 6                                    evaporated leaving      0.655172
# 7                                    evaporated leaving      0.896552
# 8                                    evaporated leaving      1.448276
# 9                                    evaporated leaving      1.620690
# 10                                   evaporated leaving      0.482759
# 11                                   evaporated leaving      0.655172
# 12                                   evaporated leaving      0.724138
# 13                                   evaporated leaving      0.655172
# 14                                   evaporated leaving      0.379310
# 15                                   evaporated leaving      2.034483
# 16                                   evaporated leaving      1.379310
# 17                                   evaporated leaving      1.655172
# 18                                   evaporated leaving      2.137931
# 19                                   evaporated leaving      1.206897
# 20                                   evaporated leaving      0.344828
# 21                                   evaporated leaving      1.655172
# 22                                   evaporated leaving      0.517241
# 23                                   evaporated leaving      1.655172
# 24                                   evaporated leaving      1.275862
# 25                                   evaporated leaving      0.689655
# 26                                   evaporated leaving      0.620690
# 27                                   evaporated leaving      0.655172
# 28                                   evaporated leaving      0.793103
# 29                                   evaporated leaving      1.103448
# ...                                                 ...           ...
# 4939  used comparison determine changing one variabl...      0.685714
# 4940  used comparison determine changing one variabl...      0.342857
# 4941  used comparison determine changing one variabl...      1.042857
# 4942  used comparison determine changing one variabl...      0.785714
# 4943  used comparison determine changing one variabl...      0.700000
# 4944  used comparison determine changing one variabl...      0.442857
# 4945  used comparison determine changing one variabl...      0.714286
# 4946  used comparison determine changing one variabl...      0.514286
# 4947  used comparison determine changing one variabl...      1.014286
# 4948  used comparison determine changing one variabl...      0.657143
# 4949  used comparison determine changing one variabl...      0.728571
# 4950  used comparison determine changing one variabl...      1.042857
# 4951  used comparison determine changing one variabl...      1.028571
# 4952  used comparison determine changing one variabl...      0.814286
# 4953  used comparison determine changing one variabl...      1.228571
# 4954  used comparison determine changing one variabl...      0.200000
# 4955  used comparison determine changing one variabl...      0.857143
# 4956  used comparison determine changing one variabl...      0.342857
# 4957  used comparison determine changing one variabl...      0.514286
# 4958  used comparison determine changing one variabl...      0.642857
# 4959  used comparison determine changing one variabl...      0.557143
# 4960  used comparison determine changing one variabl...      0.200000
# 4961  used comparison determine changing one variabl...      0.442857
# 4962  used comparison determine changing one variabl...      0.257143
# 4963  used comparison determine changing one variabl...      0.314286
# 4964  used comparison determine changing one variabl...      0.357143
# 4965  used comparison determine changing one variabl...      0.200000
# 4966  used comparison determine changing one variabl...      0.485714
# 4967  used comparison determine changing one variabl...      0.257143
# 4968  used comparison determine changing one variabl...      0.371429
#
# [4969 rows x 13 columns]

# %%
df = pd.read_pickle("../../../../../sem_eval_test3_cosine.pkl")
df.to_pickle("../../../../../sem_eval_test3_cosine.pkl",protocol=2)

# %% [markdown]
# # semeval cleaning

# %%
df = pd.read_pickle("../../../../../sem_eval_test1_aligned.pkl")

# %%
df
# Out:
#      Unnamed: 0                                           question ques_id  \
# 0             0  You used several methods to separate and ident...  EM_45b
# 1             1  You used several methods to separate and ident...  EM_45b
# 2             2  You used several methods to separate and ident...  EM_45b
# 3             3  You used several methods to separate and ident...  EM_45b
# 4             4  You used several methods to separate and ident...  EM_45c
# 5             5  You used several methods to separate and ident...  EM_45c
# 6             6  You used several methods to separate and ident...  EM_45c
# 7             7  You used several methods to separate and ident...  EM_45c
# 8             8  Ms. Teridann, a geologist, made a chart showin...  EM_16b
# 9             9  Ms. Teridann, a geologist, made a chart showin...  EM_16b
# 10           10  Ms. Teridann, a geologist, made a chart showin...  EM_16b
# 11           11  Ms. Teridann, a geologist, made a chart showin...  EM_16b
# 12           12  Georgia found one brown mineral and one black ...  EM_21a
# 13           13  Georgia found one brown mineral and one black ...  EM_21a
# 14           14  Georgia found one brown mineral and one black ...  EM_21a
# 15           15  Georgia found one brown mineral and one black ...  EM_21a
# 16           16  Georgia found one brown mineral and one black ...  EM_21b
# 17           17  Georgia found one brown mineral and one black ...  EM_21b
# 18           18  Georgia found one brown mineral and one black ...  EM_21b
# 19           19  Georgia found one brown mineral and one black ...  EM_21b
# 20           20  If Phil, a geologist, wants to test for calcit...  EM_43b
# 21           21  If Phil, a geologist, wants to test for calcit...  EM_43b
# 22           22  If Phil, a geologist, wants to test for calcit...  EM_43b
# 23           23  If Phil, a geologist, wants to test for calcit...  EM_43b
# 24           24  Describe how you can tell the difference betwe...   EM_46
# 25           25  Describe how you can tell the difference betwe...   EM_46
# 26           26  Describe how you can tell the difference betwe...   EM_46
# 27           27  Describe how you can tell the difference betwe...   EM_46
# 28           28  Emily evaporated a solution and drew a picture...  EM_48b
# 29           29  Emily evaporated a solution and drew a picture...  EM_48b
# ..          ...                                                ...     ...
# 510         510  Explain in one sentence what each graph tells ...   VB_5a
# 511         511  Explain in one sentence what each graph tells ...   VB_5a
# 512         512  Explain in one sentence what each graph tells ...   VB_5b
# 513         513  Explain in one sentence what each graph tells ...   VB_5b
# 514         514  Explain in one sentence what each graph tells ...   VB_5b
# 515         515  Explain in one sentence what each graph tells ...   VB_5b
# 516         516  Describe what the graph tells you about the re...  VB_22c
# 517         517  Describe what the graph tells you about the re...  VB_22c
# 518         518  Describe what the graph tells you about the re...  VB_22c
# 519         519  Describe what the graph tells you about the re...  VB_22c
# 520         520  Don wanted to find out if a battery powered to...   VB_42
# 521         521  Don wanted to find out if a battery powered to...   VB_42
# 522         522  Don wanted to find out if a battery powered to...   VB_42
# 523         523  Don wanted to find out if a battery powered to...   VB_42
# 524         524  3 girls wanted to see who could throw a ball t...  VB_15a
# 525         525  3 girls wanted to see who could throw a ball t...  VB_15a
# 526         526  3 girls wanted to see who could throw a ball t...  VB_15a
# 527         527  3 girls wanted to see who could throw a ball t...  VB_15a
# 528         528  3 girls wanted to see who could throw a ball t...  VB_15b
# 529         529  3 girls wanted to see who could throw a ball t...  VB_15b
# 530         530  3 girls wanted to see who could throw a ball t...  VB_15b
# 531         531  3 girls wanted to see who could throw a ball t...  VB_15b
# 532         532  3 girls wanted to see who could throw a ball t...  VB_15c
# 533         533  3 girls wanted to see who could throw a ball t...  VB_15c
# 534         534  3 girls wanted to see who could throw a ball t...  VB_15c
# 535         535  3 girls wanted to see who could throw a ball t...  VB_15c
# 536         536  When conducting a controlled experiment, why d...   VB_29
# 537         537  When conducting a controlled experiment, why d...   VB_29
# 538         538  When conducting a controlled experiment, why d...   VB_29
# 539         539  When conducting a controlled experiment, why d...   VB_29
#
#                                       reference_answer  \
# 0          The water was evaporated, leaving the salt.
# 1          The water was evaporated, leaving the salt.
# 2          The water was evaporated, leaving the salt.
# 3          The water was evaporated, leaving the salt.
# 4     The crystals were square with Xs on the surface.
# 5     The crystals were square with Xs on the surface.
# 6     The crystals were square with Xs on the surface.
# 7     The crystals were square with Xs on the surface.
# 8    Topaz would be the hardest of the 4 minerals b...
# 9    Topaz would be the hardest of the 4 minerals b...
# 10   Topaz would be the hardest of the 4 minerals b...
# 11   Topaz would be the hardest of the 4 minerals b...
# 12   Rub the minerals together and see which one sc...
# 13   Rub the minerals together and see which one sc...
# 14   Rub the minerals together and see which one sc...
# 15   Rub the minerals together and see which one sc...
# 16   The harder mineral will leave a scratch on the...
# 17   The harder mineral will leave a scratch on the...
# 18   The harder mineral will leave a scratch on the...
# 19   The harder mineral will leave a scratch on the...
# 20   Put acid on a rock. If the acid fizzes, Phil w...
# 21   Put acid on a rock. If the acid fizzes, Phil w...
# 22   Put acid on a rock. If the acid fizzes, Phil w...
# 23   Put acid on a rock. If the acid fizzes, Phil w...
# 24   The crystals have different shapes. Salt cryst...
# 25   The crystals have different shapes. Salt cryst...
# 26   The crystals have different shapes. Salt cryst...
# 27   The crystals have different shapes. Salt cryst...
# 28   The crystals are the same shape as the alum cr...
# 29   The crystals are the same shape as the alum cr...
# ..                                                 ...
# 510  As time increases, the number of tree rings al...
# 511  As time increases, the number of tree rings al...
# 512  As time increases, the speed of light stays th...
# 513  As time increases, the speed of light stays th...
# 514  As time increases, the speed of light stays th...
# 515  As time increases, the speed of light stays th...
# 516  When less than 3 scoops of fertilizer are used...
# 517  When less than 3 scoops of fertilizer are used...
# 518  When less than 3 scoops of fertilizer are used...
# 519  When less than 3 scoops of fertilizer are used...
# 520  The more blocks the truck carries, the less di...
# 521  The more blocks the truck carries, the less di...
# 522  The more blocks the truck carries, the less di...
# 523  The more blocks the truck carries, the less di...
# 524  The launch position (line on the playground) i...
# 525  The launch position (line on the playground) i...
# 526  The launch position (line on the playground) i...
# 527  The launch position (line on the playground) i...
# 528  Different girls are throwing the balls. The gi...
# 529  Different girls are throwing the balls. The gi...
# 530  Different girls are throwing the balls. The gi...
# 531  Different girls are throwing the balls. The gi...
# 532  All variables except the girl need to be held ...
# 533  All variables except the girl need to be held ...
# 534  All variables except the girl need to be held ...
# 535  All variables except the girl need to be held ...
# 536  A standard is used for comparison to determine...
# 537  A standard is used for comparison to determine...
# 538  A standard is used for comparison to determine...
# 539  A standard is used for comparison to determine...
#
#                                         student_answer  \
# 0                             We evaporated the water.
# 1    We poured just the water into another thing an...
# 2    We kept the salt in the vial and put the water...
# 3                               Get all the water out.
# 4                    Well because we broke them apart.
# 5                       By looking very closely at it.
# 6    We know the crystals were salt because we iden...
# 7                         Because I look at the chart.
# 8    Topaz is most like mineral Z because Topaz can...
# 9    Topaz is harder than X, Y, and Z. Because it c...
# 10                       Topaz is harder than X, Y, Z.
# 11   Topaz would be the hardest because none of the...
# 12                She can rub them against each other.
# 13                              Rubbing them together.
# 14   Rub one of the minerals against the other one ...
# 15   Rub them together and see if one scratches the...
# 16                      The one that starts to gather.
# 17                           That it stay the scratch.
# 18                         Which one leaves a scratch.
# 19   The harder one leave a scratch on the less scr...
# 20   He would put vinegar on the rock get the stran...
# 21                                               Move.
# 22              Cube to in test and look for crystals.
# 23                       If it fizzles it has calcite.
# 24   Calcite crystals are flaky and salt crystals w...
# 25   Calcite crystals look different than salt crys...
# 26   The mock rock is smelt like flour but the crys...
# 27   Crystals are already there so calcite will lea...
# 28                         The pictures look the same.
# 29   Because the minerals on the top look just the ...
# ..                                                 ...
# 510  This graph shows that the number of tree rings...
# 511                       They look like it increases.
# 512  How fast the light speeds and how many times i...
# 513  This graph shows that the light was getting li...
# 514      The speed of light does not change over time.
# 515  The light is staying the same and the time is ...
# 516  The more or less of fertilizer about the same ...
# 517  The more you scoop you scoop, the higher, but ...
# 518  The relationship is that they had scoops of fe...
# 519  Too little scoops of fertilizer is too less bu...
# 520  The more blocks the less far it goes the less ...
# 521  When he had 0 blocks it went 5 meters and when...
# 522  The more blocks he adds the more heavier it ge...
# 523  The truck goes slower and slower to travel in ...
# 524        They controlled where they let the ball go.
# 525                   The same spot to throw the ball.
# 526                                    Their strength.
# 527                        They all start in the line.
# 528     What kind of balls and how to throw the balls.
# 529   They did not control the distance the ball went.
# 530  Who got the running start and who did not and ...
# 531  When they are running, standing or stepping. T...
# 532  They all should stand and throw the same ball ...
# 533  They could all go at the same speed and same d...
# 534  They all had to bring the same kind of ball. A...
# 535                            Have the ball the same.
# 536                        In a controlled experiment.
# 537  You need to have a standard so you can tell th...
# 538  You use a standard because you know it will be...
# 539  So when you start with the standard it will he...
#
#                            result  grades_round  \
# 0                         correct             4
# 1                         correct             4
# 2                      irrelevant             1
# 3    partially_correct_incomplete             3
# 4                      irrelevant             1
# 5                      irrelevant             1
# 6                      irrelevant             1
# 7                      irrelevant             1
# 8                         correct             4
# 9                         correct             4
# 10   partially_correct_incomplete             3
# 11                  contradictory             2
# 12   partially_correct_incomplete             3
# 13   partially_correct_incomplete             3
# 14                        correct             4
# 15                        correct             4
# 16                     irrelevant             1
# 17   partially_correct_incomplete             3
# 18   partially_correct_incomplete             3
# 19                        correct             4
# 20   partially_correct_incomplete             3
# 21                     irrelevant             1
# 22                     irrelevant             1
# 23   partially_correct_incomplete             3
# 24   partially_correct_incomplete             3
# 25   partially_correct_incomplete             3
# 26                     irrelevant             1
# 27                     irrelevant             1
# 28   partially_correct_incomplete             3
# 29   partially_correct_incomplete             3
# ..                            ...           ...
# 510                       correct             4
# 511  partially_correct_incomplete             3
# 512                    irrelevant             1
# 513                    irrelevant             1
# 514                       correct             4
# 515                       correct             4
# 516                 contradictory             2
# 517  partially_correct_incomplete             3
# 518                       correct             4
# 519  partially_correct_incomplete             3
# 520                       correct             4
# 521                       correct             4
# 522                       correct             4
# 523  partially_correct_incomplete             3
# 524                    irrelevant             1
# 525  partially_correct_incomplete             3
# 526                    irrelevant             1
# 527  partially_correct_incomplete             3
# 528  partially_correct_incomplete             3
# 529                    irrelevant             1
# 530                       correct             4
# 531                       correct             4
# 532                       correct             4
# 533                       correct             4
# 534  partially_correct_incomplete             3
# 535  partially_correct_incomplete             3
# 536                    irrelevant             1
# 537  partially_correct_incomplete             3
# 538  partially_correct_incomplete             3
# 539                    irrelevant             1
#
#                                       student_modified  \
# 0                                     evaporated water
# 1       poured water another thing let water evaporate
# 2                  kept salt vial put water petri dish
# 3                                            get water
# 4                                     well broke apart
# 5                                      looking closely
# 6                         know crystal salt identified
# 7                                           look chart
# 8    topaz like mineral z topaz can not scratched a...
# 9            topaz harder x z could get scratched tool
# 10                                    topaz harder x z
# 11     topaz would hardest none tool could scratch x z
# 12                                                 rub
# 13                                    rubbing together
# 14                rub one mineral one see mark scratch
# 15                        rub together see one scratch
# 16                                    one start gather
# 17                                        stay scratch
# 18                                    one leaf scratch
# 19         harder one leave scratch le scratch mineral
# 20   would put vinegar rock get strange quiet see c...
# 21                                                move
# 22                              cube test look crystal
# 23                                      fizzle calcite
# 24   calcite crystal flaky salt crystal flaky squar...
# 25         calcite crystal look different salt crystal
# 26                  mock rock smelt like flour crystal
# 27   crystal already calcite leave different crysta...
# 28                                        picture look
# 29                        mineral top look alum bottom
# ..                                                 ...
# 510  graph show number tree ring increasing certain...
# 511                                 look like increase
# 512                      fast light speed many time go
# 513    graph show light getting lighter lighter minute
# 514                            speed light change time
# 515                      light staying time increasing
# 516                                 le fertilizer mass
# 517                 scoop scoop higher get deep le get
# 518  relationship scoop fertilizer numbered 0 one 2...
# 519  little scoop fertilizer le put much weigh le w...
# 520                block le far go le block farther go
# 521  0 block went 5 meter 2 went 3 meter 4 went one...
# 522     block add heavier get heavier slow distance go
# 523            truck go slower slower travel 10 second
# 524                             controlled let ball go
# 525                                    spot throw ball
# 526                                           strength
# 527                                         start line
# 528                               kind ball throw ball
# 529                         control distance ball went
# 530             got running start different ball throw
# 531      running standing stepping different kind ball
# 532             stand throw ball controlled experiment
# 533  could go speed distance get line could use kin...
# 534                             bring kind ball weight
# 535                                               ball
# 536                              controlled experiment
# 537  need standard tell difference experiment tell ...
# 538  use standard know controlled something random ...
# 539          start standard help understand experiment
#
#                                            qn_modified  \
# 0    used several method separate identify substanc...
# 1    used several method separate identify substanc...
# 2    used several method separate identify substanc...
# 3    used several method separate identify substanc...
# 4    used several method separate identify substanc...
# 5    used several method separate identify substanc...
# 6    used several method separate identify substanc...
# 7    used several method separate identify substanc...
# 8    m teridann geologist made chart showing scratc...
# 9    m teridann geologist made chart showing scratc...
# 10   m teridann geologist made chart showing scratc...
# 11   m teridann geologist made chart showing scratc...
# 12   georgia found one brown mineral one black mine...
# 13   georgia found one brown mineral one black mine...
# 14   georgia found one brown mineral one black mine...
# 15   georgia found one brown mineral one black mine...
# 16   georgia found one brown mineral one black mine...
# 17   georgia found one brown mineral one black mine...
# 18   georgia found one brown mineral one black mine...
# 19   georgia found one brown mineral one black mine...
# 20   phil geologist want test calcite field bring a...
# 21   phil geologist want test calcite field bring a...
# 22   phil geologist want test calcite field bring a...
# 23   phil geologist want test calcite field bring a...
# 24   describe tell difference crystal calcite test ...
# 25   describe tell difference crystal calcite test ...
# 26   describe tell difference crystal calcite test ...
# 27   describe tell difference crystal calcite test ...
# 28   emily evaporated solution drew picture crystal...
# 29   emily evaporated solution drew picture crystal...
# ..                                                 ...
# 510  explain one sentence graph tell graph number t...
# 511  explain one sentence graph tell graph number t...
# 512  explain one sentence graph tell graph b speed ...
# 513  explain one sentence graph tell graph b speed ...
# 514  explain one sentence graph tell graph b speed ...
# 515  explain one sentence graph tell graph b speed ...
# 516  describe graph tell relationship number scoop ...
# 517  describe graph tell relationship number scoop ...
# 518  describe graph tell relationship number scoop ...
# 519  describe graph tell relationship number scoop ...
# 520  wanted find battery powered toy truck would al...
# 521  wanted find battery powered toy truck would al...
# 522  wanted find battery powered toy truck would al...
# 523  wanted find battery powered toy truck would al...
# 524  3 girl wanted see could throw ball farthest gi...
# 525  3 girl wanted see could throw ball farthest gi...
# 526  3 girl wanted see could throw ball farthest gi...
# 527  3 girl wanted see could throw ball farthest gi...
# 528  3 girl wanted see could throw ball farthest gi...
# 529  3 girl wanted see could throw ball farthest gi...
# 530  3 girl wanted see could throw ball farthest gi...
# 531  3 girl wanted see could throw ball farthest gi...
# 532  3 girl wanted see could throw ball farthest gi...
# 533  3 girl wanted see could throw ball farthest gi...
# 534  3 girl wanted see could throw ball farthest gi...
# 535  3 girl wanted see could throw ball farthest gi...
# 536      conducting controlled experiment use standard
# 537      conducting controlled experiment use standard
# 538      conducting controlled experiment use standard
# 539      conducting controlled experiment use standard
#
#                                           ref_modified  \
# 0                        water evaporated leaving salt
# 1                        water evaporated leaving salt
# 2                        water evaporated leaving salt
# 3                        water evaporated leaving salt
# 4                             crystal square x surface
# 5                             crystal square x surface
# 6                             crystal square x surface
# 7                             crystal square x surface
# 8    topaz would hardest 4 mineral none tool could ...
# 9    topaz would hardest 4 mineral none tool could ...
# 10   topaz would hardest 4 mineral none tool could ...
# 11   topaz would hardest 4 mineral none tool could ...
# 12                rub mineral together see one scratch
# 13                rub mineral together see one scratch
# 14                rub mineral together see one scratch
# 15                rub mineral together see one scratch
# 16   harder mineral leave scratch le hard mineral b...
# 17   harder mineral leave scratch le hard mineral b...
# 18   harder mineral leave scratch le hard mineral b...
# 19   harder mineral leave scratch le hard mineral b...
# 20   put acid rock acid fizz phil would know rock c...
# 21   put acid rock acid fizz phil would know rock c...
# 22   put acid rock acid fizz phil would know rock c...
# 23   put acid rock acid fizz phil would know rock c...
# 24   crystal different shape salt crystal square li...
# 25   crystal different shape salt crystal square li...
# 26   crystal different shape salt crystal square li...
# 27   crystal different shape salt crystal square li...
# 28                          crystal shape alum crystal
# 29                          crystal shape alum crystal
# ..                                                 ...
# 510       time increase number tree ring also increase
# 511       time increase number tree ring also increase
# 512    time increase speed light stay remains constant
# 513    time increase speed light stay remains constant
# 514    time increase speed light stay remains constant
# 515    time increase speed light stay remains constant
# 516  le 3 scoop fertilizer used fertilizer used gre...
# 517  le 3 scoop fertilizer used fertilizer used gre...
# 518  le 3 scoop fertilizer used fertilizer used gre...
# 519  le 3 scoop fertilizer used fertilizer used gre...
# 520  block truck carry le distance truck travel 10 ...
# 521  block truck carry le distance truck travel 10 ...
# 522  block truck carry le distance truck travel 10 ...
# 523  block truck carry le distance truck travel 10 ...
# 524  launch position line playground variable contr...
# 525  launch position line playground variable contr...
# 526  launch position line playground variable contr...
# 527  launch position line playground variable contr...
# 528  different girl throwing ball girl use differen...
# 529  different girl throwing ball girl use differen...
# 530  different girl throwing ball girl use differen...
# 531  different girl throwing ball girl use differen...
# 532  variable except girl need held constant contro...
# 533  variable except girl need held constant contro...
# 534  variable except girl need held constant contro...
# 535  variable except girl need held constant contro...
# 536  standard used comparison determine changing on...
# 537  standard used comparison determine changing on...
# 538  standard used comparison determine changing on...
# 539  standard used comparison determine changing on...
#
#                                        student_demoted  \
# 0                                           evaporated
# 1                   poured another thing let evaporate
# 2                             kept vial put petri dish
# 3                                                  get
# 4                                     well broke apart
# 5                                      looking closely
# 6                                           identified
# 7                                           look chart
# 8                              like anything one thing
# 9                                     harder could get
# 10                                              harder
# 11                            would hardest none could
# 12                                                 rub
# 13                                    rubbing together
# 14                                rub see mark scratch
# 15                            rub together see scratch
# 16                                        start gather
# 17                                        stay scratch
# 18                                        leaf scratch
# 19                            leave scratch le scratch
# 20                      put rock get strange quiet see
# 21                                                move
# 22                                   cube look crystal
# 23                                              fizzle
# 24                          flaky flaky square instead
# 25                                      look different
# 26                          mock rock smelt like flour
# 27                      already leave different behind
# 28                                                look
# 29                             mineral top look bottom
# ..                                                 ...
# 510                     show increasing certain amount
# 511                                 look like increase
# 512                                       fast many go
# 513                show getting lighter lighter minute
# 514                                             change
# 515                                 staying increasing
# 516                                                 le
# 517                             higher get deep le get
# 518  numbered 0 one 2 3 4 5 6 numbered 00 02 04 etc...
# 519  little le put much weigh le well put much le good
# 520                                  far go farther go
# 521           went 5 meter 2 went 3 meter 4 went meter
# 522                    add heavier get heavier slow go
# 523                                   go slower slower
# 524                                     controlled let
# 525                                               spot
# 526                                           strength
# 527
# 528                                               kind
# 529                                      distance went
# 530                                          different
# 531                   standing stepping different kind
# 532                                              stand
# 533                        speed distance get use kind
# 534                                  bring kind weight
# 535
# 536
# 537                 need tell difference tell far went
# 538                   know something random might work
# 539                              start help understand
#
#                                            ref_demoted  length_ratio  \
# 0                                   evaporated leaving      0.551724
# 1                                   evaporated leaving      1.586207
# 2                                   evaporated leaving      1.206897
# 3                                   evaporated leaving      0.310345
# 4                                     square x surface      0.666667
# 5                                     square x surface      0.625000
# 6                                     square x surface      1.166667
# 7                                     square x surface      0.416667
# 8           would hardest 4 none could least one could      0.864583
# 9           would hardest 4 none could least one could      0.427083
# 10          would hardest 4 none could least one could      0.166667
# 11          would hardest 4 none could least one could      0.489583
# 12                            rub together see scratch      0.083333
# 13                            rub together see scratch      0.444444
# 14                            rub together see scratch      1.000000
# 15                            rub together see scratch      0.777778
# 16                            leave scratch le scratch      0.183908
# 17                            leave scratch le scratch      0.137931
# 18                            leave scratch le scratch      0.183908
# 19                            leave scratch le scratch      0.494253
# 20                             put rock fizz know rock      1.000000
# 21                             put rock fizz know rock      0.076923
# 22                             put rock fizz know rock      0.423077
# 23                             put rock fizz know rock      0.269231
# 24   different shape square little x shaped like ne...      0.555556
# 25   different shape square little x shaped like ne...      0.434343
# 26   different shape square little x shaped like ne...      0.343434
# 27   different shape square little x shaped like ne...      0.545455
# 28                                                          0.461538
# 29                                                          1.076923
# ..                                                 ...           ...
# 510                             increase also increase      1.318182
# 511                             increase also increase      0.409091
# 512                     increase stay remains constant      0.617021
# 513                     increase stay remains constant      1.000000
# 514                     increase stay remains constant      0.489362
# 515                     increase stay remains constant      0.617021
# 516              le 3 used used greater 3 used used le      0.135338
# 517              le 3 used used greater 3 used used le      0.255639
# 518              le 3 used used greater 3 used used le      1.308271
# 519              le 3 used used greater 3 used used le      0.496241
# 520                                              carry      0.673077
# 521                                              carry      1.000000
# 522                                              carry      0.884615
# 523                                              carry      0.750000
# 524                         launch position controlled      0.431373
# 525                         launch position controlled      0.294118
# 526                         launch position controlled      0.156863
# 527                         launch position controlled      0.196078
# 528  different throwing use different launch techni...      0.217391
# 529  different throwing use different launch techni...      0.282609
# 530  different throwing use different launch techni...      0.413043
# 531  different throwing use different launch techni...      0.489130
# 532  variable except held constant use launch techn...      0.413043
# 533  variable except held constant use launch techn...      0.565217
# 534  variable except held constant use launch techn...      0.239130
# 535  variable except held constant use launch techn...      0.043478
# 536  used comparison determine changing one variabl...      0.300000
# 537  used comparison determine changing one variabl...      0.771429
# 538  used comparison determine changing one variabl...      1.114286
# 539  used comparison determine changing one variabl...      0.585714
#
#                                              embed_ref  \
# 0    [[0.06713867, 0.51220703, 0.32043457, -0.32836...
# 1    [[0.06713867, 0.51220703, 0.32043457, -0.32836...
# 2    [[0.06713867, 0.51220703, 0.32043457, -0.32836...
# 3    [[0.06713867, 0.51220703, 0.32043457, -0.32836...
# 4    [[-0.3585205, -0.125, 0.71728516, -0.30647278,...
# 5    [[-0.3585205, -0.125, 0.71728516, -0.30647278,...
# 6    [[-0.3585205, -0.125, 0.71728516, -0.30647278,...
# 7    [[-0.3585205, -0.125, 0.71728516, -0.30647278,...
# 8    [[0.9230957, -0.6287842, 1.4970703, 1.9587402,...
# 9    [[0.9230957, -0.6287842, 1.4970703, 1.9587402,...
# 10   [[0.9230957, -0.6287842, 1.4970703, 1.9587402,...
# 11   [[0.9230957, -0.6287842, 1.4970703, 1.9587402,...
# 12   [[-0.07824707, -0.38409424, 0.31591797, 0.9750...
# 13   [[-0.07824707, -0.38409424, 0.31591797, 0.9750...
# 14   [[-0.07824707, -0.38409424, 0.31591797, 0.9750...
# 15   [[-0.07824707, -0.38409424, 0.31591797, 0.9750...
# 16   [[0.6187134, -0.095825195, 0.52423096, 1.86462...
# 17   [[0.6187134, -0.095825195, 0.52423096, 1.86462...
# 18   [[0.6187134, -0.095825195, 0.52423096, 1.86462...
# 19   [[0.6187134, -0.095825195, 0.52423096, 1.86462...
# 20   [[-0.08331299, 0.7799072, 0.23844147, 0.788203...
# 21   [[-0.08331299, 0.7799072, 0.23844147, 0.788203...
# 22   [[-0.08331299, 0.7799072, 0.23844147, 0.788203...
# 23   [[-0.08331299, 0.7799072, 0.23844147, 0.788203...
# 24   [[-0.4272461, 0.8457031, 0.5647583, 0.8872833,...
# 25   [[-0.4272461, 0.8457031, 0.5647583, 0.8872833,...
# 26   [[-0.4272461, 0.8457031, 0.5647583, 0.8872833,...
# 27   [[-0.4272461, 0.8457031, 0.5647583, 0.8872833,...
# 28   [[0.12792969, 0.095703125, 0.1381836, -0.09188...
# 29   [[0.12792969, 0.095703125, 0.1381836, -0.09188...
# ..                                                 ...
# 510  [[0.24536133, -0.19354248, -0.5960388, 0.39526...
# 511  [[0.24536133, -0.19354248, -0.5960388, 0.39526...
# 512  [[0.38690186, 0.625, 0.01739502, 0.44873047, -...
# 513  [[0.38690186, 0.625, 0.01739502, 0.44873047, -...
# 514  [[0.38690186, 0.625, 0.01739502, 0.44873047, -...
# 515  [[0.38690186, 0.625, 0.01739502, 0.44873047, -...
# 516  [[0.87890625, 3.0974731, 0.51708984, 2.4692383...
# 517  [[0.87890625, 3.0974731, 0.51708984, 2.4692383...
# 518  [[0.87890625, 3.0974731, 0.51708984, 2.4692383...
# 519  [[0.87890625, 3.0974731, 0.51708984, 2.4692383...
# 520  [[0.47630859375, 0.81877685546875, 0.206609497...
# 521  [[0.47630859375, 0.81877685546875, 0.206609497...
# 522  [[0.47630859375, 0.81877685546875, 0.206609497...
# 523  [[0.47630859375, 0.81877685546875, 0.206609497...
# 524  [[-0.032714844, 0.22265625, -0.29559326, 0.197...
# 525  [[-0.032714844, 0.22265625, -0.29559326, 0.197...
# 526  [[-0.032714844, 0.22265625, -0.29559326, 0.197...
# 527  [[-0.032714844, 0.22265625, -0.29559326, 0.197...
# 528  [[1.09729, 0.22117615, 0.5294342, 0.7518921, -...
# 529  [[1.09729, 0.22117615, 0.5294342, 0.7518921, -...
# 530  [[1.09729, 0.22117615, 0.5294342, 0.7518921, -...
# 531  [[1.09729, 0.22117615, 0.5294342, 0.7518921, -...
# 532  [[1.0891113, 0.22525024, 0.17041016, 0.5397339...
# 533  [[1.0891113, 0.22525024, 0.17041016, 0.5397339...
# 534  [[1.0891113, 0.22525024, 0.17041016, 0.5397339...
# 535  [[1.0891113, 0.22525024, 0.17041016, 0.5397339...
# 536  [[-0.008056641, 0.14331055, -0.052001953, 1.07...
# 537  [[-0.008056641, 0.14331055, -0.052001953, 1.07...
# 538  [[-0.008056641, 0.14331055, -0.052001953, 1.07...
# 539  [[-0.008056641, 0.14331055, -0.052001953, 1.07...
#
#                                             embed_stud  \
# 0    [[-0.030761719, 0.18359375, 0.10412598, -0.293...
# 1    [[0.4050293, 0.7039795, 0.47973633, 0.23632812...
# 2    [[-0.5404053, 0.7597656, 1.0896988, 0.17456055...
# 3    [[-0.11816406, 0.046875, -0.17822266, -0.06347...
# 4    [[0.032226562, 0.017578125, -0.2939453, 0.1542...
# 5    [[-0.057617188, 0.2535553, 0.119140625, 0.2019...
# 6    [[-0.21411133, -0.22290039, 0.5083008, 0.13691...
# 7    [[-0.3154297, -0.103515625, -0.41455078, 0.133...
# 8    [[-0.2607422, 0.47216797, 0.8532257, 1.6469727...
# 9    [[0.018066406, 0.09301758, -0.10534668, 0.7578...
# 10   [[-0.37646484, -0.12011719, -0.005126953, 0.49...
# 11   [[0.23168945, -0.22772217, 0.857666, 0.8873291...
# 12   [[0.06201172, -0.048828125, 0.10986328, 0.0639...
# 13   [[-0.1043396, -0.060546875, 0.005126953, 0.344...
# 14   [[0.02722168, -0.3040161, 0.6796875, 1.081543,...
# 15   [[-0.08935547, -0.31573486, 0.1977539, 0.89697...
# 16   [[0.15771484, 0.009521484, 0.06750488, 0.46386...
# 17   [[-0.042541504, -0.0770874, -0.027832031, 0.38...
# 18   [[0.09765625, 0.15093994, 0.26818848, 0.467773...
# 19   [[0.1529541, -0.063964844, 0.49291992, 1.11962...
# 20   [[0.6566162, 0.6447449, -0.41725922, 0.9347534...
# 21   [[-0.061279297, 0.14355469, -0.2109375, 0.0688...
# 22   [[-0.33422852, -0.15039062, 0.31884766, 0.0583...
# 23   [[0.29345703, 0.3154297, -0.27514648, 0.367919...
# 24   [[-0.2154541, -0.10070801, 0.78759766, 0.38659...
# 25   [[-0.20922852, -0.032226562, 0.16125488, 0.220...
# 26   [[0.059326172, 0.22955322, 0.09736633, 0.48994...
# 27   [[0.3234253, -0.436615, 0.13330078, 0.12911987...
# 28   [[-0.07421875, 0.4091797, -0.06982422, 0.02709...
# 29   [[-0.2515869, 0.46289062, 0.3149414, 0.2827148...
# ..                                                 ...
# 510  [[0.5420532, -0.40306473, -0.30267334, 0.37939...
# 511  [[-0.17333984, 0.19433594, -0.13822937, 0.4609...
# 512  [[0.47314453, 0.70983887, 0.45013428, 0.264160...
# 513  [[0.22857666, 0.051757812, -0.5135498, -0.1403...
# 514  [[0.1015625, 0.5649414, 0.32208252, 0.0546875,...
# 515  [[0.083496094, 0.42419434, -0.2662964, 0.14208...
# 516  [[0.16064453, 0.6557617, 0.20117188, 0.1821289...
# 517  [[-0.6044922, 0.057922363, -0.5214844, 0.87207...
# 518  [[0.56125, -0.46981689453125, -0.0005786132812...
# 519  [[-0.076293945, 2.0543518, -0.2980194, 1.29101...
# 520  [[-0.25195312, 0.7852783, 0.7375488, 0.4645996...
# 521  [[0.46826172, 0.9082031, 1.1535645, -0.5073242...
# 522  [[0.60650635, 0.85546875, -0.43684387, 0.53295...
# 523  [[0.6633203125, 0.3834130859375, -0.0035498046...
# 524  [[0.19958496, 0.13366699, 0.18640137, 0.209960...
# 525  [[0.23864746, 0.07104492, 0.09863281, 0.019531...
# 526  [[0.13671875, 0.19238281, 0.01171875, 0.099121...
# 527  [[-0.13208008, 0.16064453, 0.012390137, 0.2182...
# 528  [[0.40112305, 0.08068848, 0.18896484, 0.394531...
# 529  [[0.091674805, 0.6505127, -0.02949524, -0.4309...
# 530  [[0.41271973, 0.26293945, 0.058166504, 0.42950...
# 531  [[0.27319336, 0.5531006, 0.29718018, 0.4412231...
# 532  [[0.46142578, 0.17773438, 0.0009765625, 0.2832...
# 533  [[0.33874512, 0.6365967, 0.41209412, 1.060791,...
# 534  [[0.11779785, 0.28308105, 0.24121094, 0.153564...
# 535  [[-0.014282227, 0.026489258, 0.037353516, -0.1...
# 536  [[0.20214844, 0.10986328, -0.12792969, 0.06542...
# 537  [[0.16693115, 0.014038086, 0.17993164, 0.52954...
# 538  [[0.3894043, 0.061279297, 0.17333984, 1.167968...
# 539  [[-0.007080078, 0.3095703, -0.07385254, 0.5745...
#
#                                      embed_ref_demoted  \
# 0    [[0.2758789, 0.15283203, -0.00036621094, -0.19...
# 1    [[0.2758789, 0.15283203, -0.00036621094, -0.19...
# 2    [[0.2758789, 0.15283203, -0.00036621094, -0.19...
# 3    [[0.2758789, 0.15283203, -0.00036621094, -0.19...
# 4    [[-0.4041748, 0.14453125, 0.64404297, -0.30325...
# 5    [[-0.4041748, 0.14453125, 0.64404297, -0.30325...
# 6    [[-0.4041748, 0.14453125, 0.64404297, -0.30325...
# 7    [[-0.4041748, 0.14453125, 0.64404297, -0.30325...
# 8    [[0.6855469, -0.4970703, 1.0170898, 1.2084961,...
# 9    [[0.6855469, -0.4970703, 1.0170898, 1.2084961,...
# 10   [[0.6855469, -0.4970703, 1.0170898, 1.2084961,...
# 11   [[0.6855469, -0.4970703, 1.0170898, 1.2084961,...
# 12   [[-0.13500977, -0.17022705, 0.041503906, 0.730...
# 13   [[-0.13500977, -0.17022705, 0.041503906, 0.730...
# 14   [[-0.13500977, -0.17022705, 0.041503906, 0.730...
# 15   [[-0.13500977, -0.17022705, 0.041503906, 0.730...
# 16   [[-0.015136719, 0.30810547, 0.39135742, 0.5864...
# 17   [[-0.015136719, 0.30810547, 0.39135742, 0.5864...
# 18   [[-0.015136719, 0.30810547, 0.39135742, 0.5864...
# 19   [[-0.015136719, 0.30810547, 0.39135742, 0.5864...
# 20   [[0.33514404, 0.16027832, -0.046043396, 0.5110...
# 21   [[0.33514404, 0.16027832, -0.046043396, 0.5110...
# 22   [[0.33514404, 0.16027832, -0.046043396, 0.5110...
# 23   [[0.33514404, 0.16027832, -0.046043396, 0.5110...
# 24   [[-0.40771484, 1.2509766, 0.380188, 0.88082886...
# 25   [[-0.40771484, 1.2509766, 0.380188, 0.88082886...
# 26   [[-0.40771484, 1.2509766, 0.380188, 0.88082886...
# 27   [[-0.40771484, 1.2509766, 0.380188, 0.88082886...
# 28                                                   0
# 29                                                   0
# ..                                                 ...
# 510  [[-0.15844727, -0.23406982, -0.3229065, 0.4187...
# 511  [[-0.15844727, -0.23406982, -0.3229065, 0.4187...
# 512  [[0.22528076, -0.033203125, -0.37695312, 0.585...
# 513  [[0.22528076, -0.033203125, -0.37695312, 0.585...
# 514  [[0.22528076, -0.033203125, -0.37695312, 0.585...
# 515  [[0.22528076, -0.033203125, -0.37695312, 0.585...
# 516  [[0.6899414, 0.74560547, 1.3051758, 0.8925781,...
# 517  [[0.6899414, 0.74560547, 1.3051758, 0.8925781,...
# 518  [[0.6899414, 0.74560547, 1.3051758, 0.8925781,...
# 519  [[0.6899414, 0.74560547, 1.3051758, 0.8925781,...
# 520  [[0.04248047, 0.006286621, 0.006378174, 0.0742...
# 521  [[0.04248047, 0.006286621, 0.006378174, 0.0742...
# 522  [[0.04248047, 0.006286621, 0.006378174, 0.0742...
# 523  [[0.04248047, 0.006286621, 0.006378174, 0.0742...
# 524  [[-0.13134766, 0.12695312, -0.36450195, -0.187...
# 525  [[-0.13134766, 0.12695312, -0.36450195, -0.187...
# 526  [[-0.13134766, 0.12695312, -0.36450195, -0.187...
# 527  [[-0.13134766, 0.12695312, -0.36450195, -0.187...
# 528  [[0.70983887, 0.15698242, 0.2613678, 1.187439,...
# 529  [[0.70983887, 0.15698242, 0.2613678, 1.187439,...
# 530  [[0.70983887, 0.15698242, 0.2613678, 1.187439,...
# 531  [[0.70983887, 0.15698242, 0.2613678, 1.187439,...
# 532  [[0.484375, 0.009033203, 0.1352539, 0.6720581,...
# 533  [[0.484375, 0.009033203, 0.1352539, 0.6720581,...
# 534  [[0.484375, 0.009033203, 0.1352539, 0.6720581,...
# 535  [[0.484375, 0.009033203, 0.1352539, 0.6720581,...
# 536  [[0.0949707, 0.064697266, -0.17358398, 0.81150...
# 537  [[0.0949707, 0.064697266, -0.17358398, 0.81150...
# 538  [[0.0949707, 0.064697266, -0.17358398, 0.81150...
# 539  [[0.0949707, 0.064697266, -0.17358398, 0.81150...
#
#                                     embed_stud_demoted  \
# 0    [[0.12060547, 0.046875, -0.012573242, -0.11523...
# 1    [[0.7077637, 0.430542, 0.24633789, 0.59375, -0...
# 2    [[-0.33166504, 0.40039062, 0.768898, 0.3066406...
# 3    [[0.033203125, -0.08984375, -0.29492188, 0.115...
# 4    [[0.032226562, 0.017578125, -0.2939453, 0.1542...
# 5    [[-0.057617188, 0.2535553, 0.119140625, 0.2019...
# 6    [[-0.14746094, -0.05883789, 0.203125, 0.018798...
# 7    [[-0.3154297, -0.103515625, -0.41455078, 0.133...
# 8    [[0.38989258, 0.0063476562, 0.3002472, 0.52661...
# 9    [[0.2680664, -0.21606445, -0.3173828, 0.556640...
# 10   [[0.111328125, -0.15820312, -0.17285156, 0.289...
# 11   [[0.39697266, -0.16723633, 0.54785156, 0.52587...
# 12   [[0.06201172, -0.048828125, 0.10986328, 0.0639...
# 13   [[-0.1043396, -0.060546875, 0.005126953, 0.344...
# 14   [[-0.07519531, 0.055358887, 0.24902344, 0.6713...
# 15   [[-0.13500977, -0.17022705, 0.041503906, 0.730...
# 16   [[0.11206055, 0.1550293, -0.08874512, 0.297851...
# 17   [[-0.042541504, -0.0770874, -0.027832031, 0.38...
# 18   [[0.052001953, 0.29644775, 0.11193848, 0.30175...
# 19   [[-0.015136719, 0.30810547, 0.39135742, 0.5864...
# 20   [[0.6742554, 0.338562, -0.40724945, 0.7792969,...
# 21   [[-0.061279297, 0.14355469, -0.2109375, 0.0688...
# 22   [[-0.19165039, -0.11352539, 0.18310547, 0.1203...
# 23   [[0.39257812, 0.13476562, -0.035888672, 0.3984...
# 24   [[-0.15026855, 0.03503418, 0.67626953, 0.37692...
# 25   [[-0.14404297, 0.103515625, 0.049926758, 0.210...
# 26   [[0.013671875, 0.49908447, 0.024124146, 0.4931...
# 27   [[0.3312378, -0.07821655, 0.22607422, 0.166076...
# 28   [[-0.17089844, 0.1796875, 0.022949219, 0.07421...
# 29   [[-0.366333, 0.19726562, 0.24121094, 0.1953125...
# ..                                                 ...
# 510  [[0.15319824, -0.029529572, -0.07373047, 0.284...
# 511  [[-0.17333984, 0.19433594, -0.13822937, 0.4609...
# 512  [[0.31152344, 0.051635742, 0.055786133, 0.4008...
# 513  [[0.11364746, 0.2919922, -0.6607666, -0.007080...
# 514  [[-0.060058594, -0.09326172, -0.072265625, 0.1...
# 515  [[0.0009765625, 0.06286621, -0.37158203, 0.220...
# 516  [[-0.13476562, 0.28515625, 0.19628906, 0.05615...
# 517  [[-0.2529297, 0.06640625, -0.31445312, 0.76708...
# 518  [[0.776337890625, -1.4281298828125, 0.64102294...
# 519  [[-0.09094238, 1.5996094, -0.13005066, 1.04711...
# 520  [[-0.20898438, 0.07824707, -0.1550293, 0.69213...
# 521  [[0.15698242, 1.1064453, 0.6452637, -0.4194336...
# 522  [[0.6231079, 0.48828125, -0.6846924, 0.7509765...
# 523  [[0.2109375, 0.20410156, 0.11340332, 1.0283203...
# 524  [[0.24023438, 0.03881836, 0.18017578, 0.09375,...
# 525  [[-0.041992188, 0.0625, 0.0024414062, -0.07421...
# 526  [[0.13671875, 0.19238281, 0.01171875, 0.099121...
# 527                                                  0
# 528  [[0.13476562, 0.045654297, 0.055419922, 0.4042...
# 529  [[-0.04345703, 0.5566406, 0.025924683, -0.1223...
# 530  [[0.026855469, -0.076171875, 0.026977539, 0.13...
# 531  [[0.20983887, 0.40795898, 0.24975586, 0.554687...
# 532  [[-0.021362305, 0.059326172, 0.032714844, 0.12...
# 533  [[0.22998047, 0.4206543, 0.11430359, 0.5515137...
# 534  [[0.13208008, 0.2565918, 0.20385742, 0.2570800...
# 535                                                  0
# 536                                                  0
# 537  [[0.10003662, -0.17541504, 0.11645508, 0.05004...
# 538  [[0.14526367, 0.004638672, 0.18261719, 0.85058...
# 539  [[-0.07397461, 0.12011719, -0.1373291, 0.09509...
#
#                                                aligned  \
# 0           [[water, water], [evaporated, evaporated]]
# 1    [[leaving, let], [water, water], [evaporated, ...
# 2                       [[water, water], [salt, salt]]
# 3                                     [[water, water]]
# 4                                                   []
# 5                                                   []
# 6                                 [[crystal, crystal]]
# 7                                                   []
# 8    [[scratch, scratched], [mineral, mineral], [no...
# 9    [[tool, tool], [scratch, scratched], [could, c...
# 10                 [[topaz, topaz], [hardest, harder]]
# 11   [[none, none], [tool, tool], [could, could], [...
# 12                                        [[rub, rub]]
# 13              [[rub, rubbing], [together, together]]
# 14   [[scratch, scratch], [rub, rub], [see, see], [...
# 15   [[scratch, scratch], [together, together], [se...
# 16                                                  []
# 17                                [[scratch, scratch]]
# 18                 [[scratch, scratch], [leave, leaf]]
# 19   [[leave, leave], [scratch, scratch], [le, le],...
# 20   [[calcite, calcite], [rock, rock], [put, put],...
# 21                                                  []
# 22                                                  []
# 23                                [[calcite, calcite]]
# 24   [[calcite, calcite], [crystal, crystal], [salt...
# 25   [[calcite, calcite], [crystal, crystal], [salt...
# 26                  [[crystal, crystal], [like, like]]
# 27   [[different, different], [crystal, crystal], [...
# 28                                                  []
# 29                                      [[alum, alum]]
# ..                                                 ...
# 510  [[number, number], [tree, tree], [ring, ring],...
# 511                             [[increase, increase]]
# 512     [[light, light], [time, time], [speed, speed]]
# 513                 [[time, minute], [light, lighter]]
# 514     [[speed, speed], [light, light], [time, time]]
# 515  [[stay, staying], [light, light], [increase, i...
# 516  [[fertilizer, fertilizer], [le, le], [mass, ma...
# 517  [[le, le], [scoop, scoop], [scoop, scoop], [gr...
# 518  [[scoop, scoop], [fertilizer, fertilizer], [ma...
# 519  [[scoop, scoop], [fertilizer, fertilizer], [le...
# 520           [[le, le], [travel, go], [block, block]]
# 521      [[second, 2], [block, block], [travel, went]]
# 522  [[distance, distance], [travel, go], [block, b...
# 523  [[second, second], [travel, travel], [10, 10],...
# 524                         [[controlled, controlled]]
# 525                                  [[launch, throw]]
# 526                                                 []
# 527                    [[launch, start], [line, line]]
# 528  [[ball, ball], [ball, ball], [type, kind], [th...
# 529                                     [[ball, ball]]
# 530  [[ball, ball], [different, different], [throwi...
# 531  [[ball, ball], [type, kind], [different, diffe...
# 532  [[throw, throw], [ball, ball], [controlled, co...
# 533                         [[ball, ball], [use, use]]
# 534                                     [[ball, ball]]
# 535                                     [[ball, ball]]
# 536                                                 []
# 537     [[standard, standard], [changing, difference]]
# 538                [[standard, standard], [used, use]]
# 539                             [[standard, standard]]
#
#                                        aligned_demoted
# 0           [[water, water], [evaporated, evaporated]]
# 1    [[leaving, let], [water, water], [evaporated, ...
# 2                       [[water, water], [salt, salt]]
# 3                                     [[water, water]]
# 4                                                   []
# 5                                                   []
# 6                                 [[crystal, crystal]]
# 7                                                   []
# 8    [[scratch, scratched], [mineral, mineral], [no...
# 9    [[tool, tool], [scratch, scratched], [could, c...
# 10                 [[topaz, topaz], [hardest, harder]]
# 11   [[none, none], [tool, tool], [could, could], [...
# 12                                        [[rub, rub]]
# 13              [[rub, rubbing], [together, together]]
# 14   [[scratch, scratch], [rub, rub], [see, see], [...
# 15   [[scratch, scratch], [together, together], [se...
# 16                                                  []
# 17                                [[scratch, scratch]]
# 18                 [[scratch, scratch], [leave, leaf]]
# 19   [[leave, leave], [scratch, scratch], [le, le],...
# 20   [[calcite, calcite], [rock, rock], [put, put],...
# 21                                                  []
# 22                                                  []
# 23                                [[calcite, calcite]]
# 24   [[calcite, calcite], [crystal, crystal], [salt...
# 25   [[calcite, calcite], [crystal, crystal], [salt...
# 26                  [[crystal, crystal], [like, like]]
# 27   [[different, different], [crystal, crystal], [...
# 28                                                  []
# 29                                      [[alum, alum]]
# ..                                                 ...
# 510  [[number, number], [tree, tree], [ring, ring],...
# 511                             [[increase, increase]]
# 512     [[light, light], [time, time], [speed, speed]]
# 513                 [[time, minute], [light, lighter]]
# 514     [[speed, speed], [light, light], [time, time]]
# 515  [[stay, staying], [light, light], [increase, i...
# 516  [[fertilizer, fertilizer], [le, le], [mass, ma...
# 517  [[le, le], [scoop, scoop], [scoop, scoop], [gr...
# 518  [[scoop, scoop], [fertilizer, fertilizer], [ma...
# 519  [[scoop, scoop], [fertilizer, fertilizer], [le...
# 520           [[le, le], [travel, go], [block, block]]
# 521      [[second, 2], [block, block], [travel, went]]
# 522  [[distance, distance], [travel, go], [block, b...
# 523  [[second, second], [travel, travel], [10, 10],...
# 524                         [[controlled, controlled]]
# 525                                  [[launch, throw]]
# 526                                                 []
# 527                    [[launch, start], [line, line]]
# 528  [[ball, ball], [ball, ball], [type, kind], [th...
# 529                                     [[ball, ball]]
# 530  [[ball, ball], [different, different], [throwi...
# 531  [[ball, ball], [type, kind], [different, diffe...
# 532  [[throw, throw], [ball, ball], [controlled, co...
# 533                         [[ball, ball], [use, use]]
# 534                                     [[ball, ball]]
# 535                                     [[ball, ball]]
# 536                                                 []
# 537     [[standard, standard], [changing, difference]]
# 538                [[standard, standard], [used, use]]
# 539                             [[standard, standard]]
#
# [540 rows x 19 columns]

# %%
def cos_similarity(data):
    return 1 - spatial.distance.cosine(data['embed_ref'],data['embed_stud'])

def cos_similarity_demoted(data):
    return 1 - spatial.distance.cosine(data['embed_ref_demoted'],data['embed_stud_demoted'])

def align_ratio(data):
    return (2*len(data['aligned'])) / (len(data['ref_modified'].split()) + len(data['student_modified'].split()))

def align_ratio_demoted(data):
    if (len(data['ref_demoted'].split()) + len(data['student_demoted'].split())) == 0:
        return 0.0
    else:
        return (2*len(data['aligned_demoted'])) / (len(data['ref_demoted'].split()) + len(data['student_demoted'].split()))


df['cos_similarity']=df.apply(cos_similarity, axis=1)
df['cos_similarity_demoted']=df.apply(cos_similarity_demoted, axis=1)
df['align_ratio']=df.apply(align_ratio, axis=1)
df['align_ratio_demoted']=df.apply(align_ratio_demoted, axis=1)
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/scipy/spatial/distance.py:698: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
df
# after this replacce NAN with zero and save it as pickle
# Out:
#      Unnamed: 0                                           question ques_id  \
# 0             0  You used several methods to separate and ident...  EM_45b
# 1             1  You used several methods to separate and ident...  EM_45b
# 2             2  You used several methods to separate and ident...  EM_45b
# 3             3  You used several methods to separate and ident...  EM_45b
# 4             4  You used several methods to separate and ident...  EM_45c
# 5             5  You used several methods to separate and ident...  EM_45c
# 6             6  You used several methods to separate and ident...  EM_45c
# 7             7  You used several methods to separate and ident...  EM_45c
# 8             8  Ms. Teridann, a geologist, made a chart showin...  EM_16b
# 9             9  Ms. Teridann, a geologist, made a chart showin...  EM_16b
# 10           10  Ms. Teridann, a geologist, made a chart showin...  EM_16b
# 11           11  Ms. Teridann, a geologist, made a chart showin...  EM_16b
# 12           12  Georgia found one brown mineral and one black ...  EM_21a
# 13           13  Georgia found one brown mineral and one black ...  EM_21a
# 14           14  Georgia found one brown mineral and one black ...  EM_21a
# 15           15  Georgia found one brown mineral and one black ...  EM_21a
# 16           16  Georgia found one brown mineral and one black ...  EM_21b
# 17           17  Georgia found one brown mineral and one black ...  EM_21b
# 18           18  Georgia found one brown mineral and one black ...  EM_21b
# 19           19  Georgia found one brown mineral and one black ...  EM_21b
# 20           20  If Phil, a geologist, wants to test for calcit...  EM_43b
# 21           21  If Phil, a geologist, wants to test for calcit...  EM_43b
# 22           22  If Phil, a geologist, wants to test for calcit...  EM_43b
# 23           23  If Phil, a geologist, wants to test for calcit...  EM_43b
# 24           24  Describe how you can tell the difference betwe...   EM_46
# 25           25  Describe how you can tell the difference betwe...   EM_46
# 26           26  Describe how you can tell the difference betwe...   EM_46
# 27           27  Describe how you can tell the difference betwe...   EM_46
# 28           28  Emily evaporated a solution and drew a picture...  EM_48b
# 29           29  Emily evaporated a solution and drew a picture...  EM_48b
# ..          ...                                                ...     ...
# 510         510  Explain in one sentence what each graph tells ...   VB_5a
# 511         511  Explain in one sentence what each graph tells ...   VB_5a
# 512         512  Explain in one sentence what each graph tells ...   VB_5b
# 513         513  Explain in one sentence what each graph tells ...   VB_5b
# 514         514  Explain in one sentence what each graph tells ...   VB_5b
# 515         515  Explain in one sentence what each graph tells ...   VB_5b
# 516         516  Describe what the graph tells you about the re...  VB_22c
# 517         517  Describe what the graph tells you about the re...  VB_22c
# 518         518  Describe what the graph tells you about the re...  VB_22c
# 519         519  Describe what the graph tells you about the re...  VB_22c
# 520         520  Don wanted to find out if a battery powered to...   VB_42
# 521         521  Don wanted to find out if a battery powered to...   VB_42
# 522         522  Don wanted to find out if a battery powered to...   VB_42
# 523         523  Don wanted to find out if a battery powered to...   VB_42
# 524         524  3 girls wanted to see who could throw a ball t...  VB_15a
# 525         525  3 girls wanted to see who could throw a ball t...  VB_15a
# 526         526  3 girls wanted to see who could throw a ball t...  VB_15a
# 527         527  3 girls wanted to see who could throw a ball t...  VB_15a
# 528         528  3 girls wanted to see who could throw a ball t...  VB_15b
# 529         529  3 girls wanted to see who could throw a ball t...  VB_15b
# 530         530  3 girls wanted to see who could throw a ball t...  VB_15b
# 531         531  3 girls wanted to see who could throw a ball t...  VB_15b
# 532         532  3 girls wanted to see who could throw a ball t...  VB_15c
# 533         533  3 girls wanted to see who could throw a ball t...  VB_15c
# 534         534  3 girls wanted to see who could throw a ball t...  VB_15c
# 535         535  3 girls wanted to see who could throw a ball t...  VB_15c
# 536         536  When conducting a controlled experiment, why d...   VB_29
# 537         537  When conducting a controlled experiment, why d...   VB_29
# 538         538  When conducting a controlled experiment, why d...   VB_29
# 539         539  When conducting a controlled experiment, why d...   VB_29
#
#                                       reference_answer  \
# 0          The water was evaporated, leaving the salt.
# 1          The water was evaporated, leaving the salt.
# 2          The water was evaporated, leaving the salt.
# 3          The water was evaporated, leaving the salt.
# 4     The crystals were square with Xs on the surface.
# 5     The crystals were square with Xs on the surface.
# 6     The crystals were square with Xs on the surface.
# 7     The crystals were square with Xs on the surface.
# 8    Topaz would be the hardest of the 4 minerals b...
# 9    Topaz would be the hardest of the 4 minerals b...
# 10   Topaz would be the hardest of the 4 minerals b...
# 11   Topaz would be the hardest of the 4 minerals b...
# 12   Rub the minerals together and see which one sc...
# 13   Rub the minerals together and see which one sc...
# 14   Rub the minerals together and see which one sc...
# 15   Rub the minerals together and see which one sc...
# 16   The harder mineral will leave a scratch on the...
# 17   The harder mineral will leave a scratch on the...
# 18   The harder mineral will leave a scratch on the...
# 19   The harder mineral will leave a scratch on the...
# 20   Put acid on a rock. If the acid fizzes, Phil w...
# 21   Put acid on a rock. If the acid fizzes, Phil w...
# 22   Put acid on a rock. If the acid fizzes, Phil w...
# 23   Put acid on a rock. If the acid fizzes, Phil w...
# 24   The crystals have different shapes. Salt cryst...
# 25   The crystals have different shapes. Salt cryst...
# 26   The crystals have different shapes. Salt cryst...
# 27   The crystals have different shapes. Salt cryst...
# 28   The crystals are the same shape as the alum cr...
# 29   The crystals are the same shape as the alum cr...
# ..                                                 ...
# 510  As time increases, the number of tree rings al...
# 511  As time increases, the number of tree rings al...
# 512  As time increases, the speed of light stays th...
# 513  As time increases, the speed of light stays th...
# 514  As time increases, the speed of light stays th...
# 515  As time increases, the speed of light stays th...
# 516  When less than 3 scoops of fertilizer are used...
# 517  When less than 3 scoops of fertilizer are used...
# 518  When less than 3 scoops of fertilizer are used...
# 519  When less than 3 scoops of fertilizer are used...
# 520  The more blocks the truck carries, the less di...
# 521  The more blocks the truck carries, the less di...
# 522  The more blocks the truck carries, the less di...
# 523  The more blocks the truck carries, the less di...
# 524  The launch position (line on the playground) i...
# 525  The launch position (line on the playground) i...
# 526  The launch position (line on the playground) i...
# 527  The launch position (line on the playground) i...
# 528  Different girls are throwing the balls. The gi...
# 529  Different girls are throwing the balls. The gi...
# 530  Different girls are throwing the balls. The gi...
# 531  Different girls are throwing the balls. The gi...
# 532  All variables except the girl need to be held ...
# 533  All variables except the girl need to be held ...
# 534  All variables except the girl need to be held ...
# 535  All variables except the girl need to be held ...
# 536  A standard is used for comparison to determine...
# 537  A standard is used for comparison to determine...
# 538  A standard is used for comparison to determine...
# 539  A standard is used for comparison to determine...
#
#                                         student_answer  \
# 0                             We evaporated the water.
# 1    We poured just the water into another thing an...
# 2    We kept the salt in the vial and put the water...
# 3                               Get all the water out.
# 4                    Well because we broke them apart.
# 5                       By looking very closely at it.
# 6    We know the crystals were salt because we iden...
# 7                         Because I look at the chart.
# 8    Topaz is most like mineral Z because Topaz can...
# 9    Topaz is harder than X, Y, and Z. Because it c...
# 10                       Topaz is harder than X, Y, Z.
# 11   Topaz would be the hardest because none of the...
# 12                She can rub them against each other.
# 13                              Rubbing them together.
# 14   Rub one of the minerals against the other one ...
# 15   Rub them together and see if one scratches the...
# 16                      The one that starts to gather.
# 17                           That it stay the scratch.
# 18                         Which one leaves a scratch.
# 19   The harder one leave a scratch on the less scr...
# 20   He would put vinegar on the rock get the stran...
# 21                                               Move.
# 22              Cube to in test and look for crystals.
# 23                       If it fizzles it has calcite.
# 24   Calcite crystals are flaky and salt crystals w...
# 25   Calcite crystals look different than salt crys...
# 26   The mock rock is smelt like flour but the crys...
# 27   Crystals are already there so calcite will lea...
# 28                         The pictures look the same.
# 29   Because the minerals on the top look just the ...
# ..                                                 ...
# 510  This graph shows that the number of tree rings...
# 511                       They look like it increases.
# 512  How fast the light speeds and how many times i...
# 513  This graph shows that the light was getting li...
# 514      The speed of light does not change over time.
# 515  The light is staying the same and the time is ...
# 516  The more or less of fertilizer about the same ...
# 517  The more you scoop you scoop, the higher, but ...
# 518  The relationship is that they had scoops of fe...
# 519  Too little scoops of fertilizer is too less bu...
# 520  The more blocks the less far it goes the less ...
# 521  When he had 0 blocks it went 5 meters and when...
# 522  The more blocks he adds the more heavier it ge...
# 523  The truck goes slower and slower to travel in ...
# 524        They controlled where they let the ball go.
# 525                   The same spot to throw the ball.
# 526                                    Their strength.
# 527                        They all start in the line.
# 528     What kind of balls and how to throw the balls.
# 529   They did not control the distance the ball went.
# 530  Who got the running start and who did not and ...
# 531  When they are running, standing or stepping. T...
# 532  They all should stand and throw the same ball ...
# 533  They could all go at the same speed and same d...
# 534  They all had to bring the same kind of ball. A...
# 535                            Have the ball the same.
# 536                        In a controlled experiment.
# 537  You need to have a standard so you can tell th...
# 538  You use a standard because you know it will be...
# 539  So when you start with the standard it will he...
#
#                            result  grades_round  \
# 0                         correct             4
# 1                         correct             4
# 2                      irrelevant             1
# 3    partially_correct_incomplete             3
# 4                      irrelevant             1
# 5                      irrelevant             1
# 6                      irrelevant             1
# 7                      irrelevant             1
# 8                         correct             4
# 9                         correct             4
# 10   partially_correct_incomplete             3
# 11                  contradictory             2
# 12   partially_correct_incomplete             3
# 13   partially_correct_incomplete             3
# 14                        correct             4
# 15                        correct             4
# 16                     irrelevant             1
# 17   partially_correct_incomplete             3
# 18   partially_correct_incomplete             3
# 19                        correct             4
# 20   partially_correct_incomplete             3
# 21                     irrelevant             1
# 22                     irrelevant             1
# 23   partially_correct_incomplete             3
# 24   partially_correct_incomplete             3
# 25   partially_correct_incomplete             3
# 26                     irrelevant             1
# 27                     irrelevant             1
# 28   partially_correct_incomplete             3
# 29   partially_correct_incomplete             3
# ..                            ...           ...
# 510                       correct             4
# 511  partially_correct_incomplete             3
# 512                    irrelevant             1
# 513                    irrelevant             1
# 514                       correct             4
# 515                       correct             4
# 516                 contradictory             2
# 517  partially_correct_incomplete             3
# 518                       correct             4
# 519  partially_correct_incomplete             3
# 520                       correct             4
# 521                       correct             4
# 522                       correct             4
# 523  partially_correct_incomplete             3
# 524                    irrelevant             1
# 525  partially_correct_incomplete             3
# 526                    irrelevant             1
# 527  partially_correct_incomplete             3
# 528  partially_correct_incomplete             3
# 529                    irrelevant             1
# 530                       correct             4
# 531                       correct             4
# 532                       correct             4
# 533                       correct             4
# 534  partially_correct_incomplete             3
# 535  partially_correct_incomplete             3
# 536                    irrelevant             1
# 537  partially_correct_incomplete             3
# 538  partially_correct_incomplete             3
# 539                    irrelevant             1
#
#                                       student_modified  \
# 0                                     evaporated water
# 1       poured water another thing let water evaporate
# 2                  kept salt vial put water petri dish
# 3                                            get water
# 4                                     well broke apart
# 5                                      looking closely
# 6                         know crystal salt identified
# 7                                           look chart
# 8    topaz like mineral z topaz can not scratched a...
# 9            topaz harder x z could get scratched tool
# 10                                    topaz harder x z
# 11     topaz would hardest none tool could scratch x z
# 12                                                 rub
# 13                                    rubbing together
# 14                rub one mineral one see mark scratch
# 15                        rub together see one scratch
# 16                                    one start gather
# 17                                        stay scratch
# 18                                    one leaf scratch
# 19         harder one leave scratch le scratch mineral
# 20   would put vinegar rock get strange quiet see c...
# 21                                                move
# 22                              cube test look crystal
# 23                                      fizzle calcite
# 24   calcite crystal flaky salt crystal flaky squar...
# 25         calcite crystal look different salt crystal
# 26                  mock rock smelt like flour crystal
# 27   crystal already calcite leave different crysta...
# 28                                        picture look
# 29                        mineral top look alum bottom
# ..                                                 ...
# 510  graph show number tree ring increasing certain...
# 511                                 look like increase
# 512                      fast light speed many time go
# 513    graph show light getting lighter lighter minute
# 514                            speed light change time
# 515                      light staying time increasing
# 516                                 le fertilizer mass
# 517                 scoop scoop higher get deep le get
# 518  relationship scoop fertilizer numbered 0 one 2...
# 519  little scoop fertilizer le put much weigh le w...
# 520                block le far go le block farther go
# 521  0 block went 5 meter 2 went 3 meter 4 went one...
# 522     block add heavier get heavier slow distance go
# 523            truck go slower slower travel 10 second
# 524                             controlled let ball go
# 525                                    spot throw ball
# 526                                           strength
# 527                                         start line
# 528                               kind ball throw ball
# 529                         control distance ball went
# 530             got running start different ball throw
# 531      running standing stepping different kind ball
# 532             stand throw ball controlled experiment
# 533  could go speed distance get line could use kin...
# 534                             bring kind ball weight
# 535                                               ball
# 536                              controlled experiment
# 537  need standard tell difference experiment tell ...
# 538  use standard know controlled something random ...
# 539          start standard help understand experiment
#
#                                            qn_modified  \
# 0    used several method separate identify substanc...
# 1    used several method separate identify substanc...
# 2    used several method separate identify substanc...
# 3    used several method separate identify substanc...
# 4    used several method separate identify substanc...
# 5    used several method separate identify substanc...
# 6    used several method separate identify substanc...
# 7    used several method separate identify substanc...
# 8    m teridann geologist made chart showing scratc...
# 9    m teridann geologist made chart showing scratc...
# 10   m teridann geologist made chart showing scratc...
# 11   m teridann geologist made chart showing scratc...
# 12   georgia found one brown mineral one black mine...
# 13   georgia found one brown mineral one black mine...
# 14   georgia found one brown mineral one black mine...
# 15   georgia found one brown mineral one black mine...
# 16   georgia found one brown mineral one black mine...
# 17   georgia found one brown mineral one black mine...
# 18   georgia found one brown mineral one black mine...
# 19   georgia found one brown mineral one black mine...
# 20   phil geologist want test calcite field bring a...
# 21   phil geologist want test calcite field bring a...
# 22   phil geologist want test calcite field bring a...
# 23   phil geologist want test calcite field bring a...
# 24   describe tell difference crystal calcite test ...
# 25   describe tell difference crystal calcite test ...
# 26   describe tell difference crystal calcite test ...
# 27   describe tell difference crystal calcite test ...
# 28   emily evaporated solution drew picture crystal...
# 29   emily evaporated solution drew picture crystal...
# ..                                                 ...
# 510  explain one sentence graph tell graph number t...
# 511  explain one sentence graph tell graph number t...
# 512  explain one sentence graph tell graph b speed ...
# 513  explain one sentence graph tell graph b speed ...
# 514  explain one sentence graph tell graph b speed ...
# 515  explain one sentence graph tell graph b speed ...
# 516  describe graph tell relationship number scoop ...
# 517  describe graph tell relationship number scoop ...
# 518  describe graph tell relationship number scoop ...
# 519  describe graph tell relationship number scoop ...
# 520  wanted find battery powered toy truck would al...
# 521  wanted find battery powered toy truck would al...
# 522  wanted find battery powered toy truck would al...
# 523  wanted find battery powered toy truck would al...
# 524  3 girl wanted see could throw ball farthest gi...
# 525  3 girl wanted see could throw ball farthest gi...
# 526  3 girl wanted see could throw ball farthest gi...
# 527  3 girl wanted see could throw ball farthest gi...
# 528  3 girl wanted see could throw ball farthest gi...
# 529  3 girl wanted see could throw ball farthest gi...
# 530  3 girl wanted see could throw ball farthest gi...
# 531  3 girl wanted see could throw ball farthest gi...
# 532  3 girl wanted see could throw ball farthest gi...
# 533  3 girl wanted see could throw ball farthest gi...
# 534  3 girl wanted see could throw ball farthest gi...
# 535  3 girl wanted see could throw ball farthest gi...
# 536      conducting controlled experiment use standard
# 537      conducting controlled experiment use standard
# 538      conducting controlled experiment use standard
# 539      conducting controlled experiment use standard
#
#                                           ref_modified         ...           \
# 0                        water evaporated leaving salt         ...
# 1                        water evaporated leaving salt         ...
# 2                        water evaporated leaving salt         ...
# 3                        water evaporated leaving salt         ...
# 4                             crystal square x surface         ...
# 5                             crystal square x surface         ...
# 6                             crystal square x surface         ...
# 7                             crystal square x surface         ...
# 8    topaz would hardest 4 mineral none tool could ...         ...
# 9    topaz would hardest 4 mineral none tool could ...         ...
# 10   topaz would hardest 4 mineral none tool could ...         ...
# 11   topaz would hardest 4 mineral none tool could ...         ...
# 12                rub mineral together see one scratch         ...
# 13                rub mineral together see one scratch         ...
# 14                rub mineral together see one scratch         ...
# 15                rub mineral together see one scratch         ...
# 16   harder mineral leave scratch le hard mineral b...         ...
# 17   harder mineral leave scratch le hard mineral b...         ...
# 18   harder mineral leave scratch le hard mineral b...         ...
# 19   harder mineral leave scratch le hard mineral b...         ...
# 20   put acid rock acid fizz phil would know rock c...         ...
# 21   put acid rock acid fizz phil would know rock c...         ...
# 22   put acid rock acid fizz phil would know rock c...         ...
# 23   put acid rock acid fizz phil would know rock c...         ...
# 24   crystal different shape salt crystal square li...         ...
# 25   crystal different shape salt crystal square li...         ...
# 26   crystal different shape salt crystal square li...         ...
# 27   crystal different shape salt crystal square li...         ...
# 28                          crystal shape alum crystal         ...
# 29                          crystal shape alum crystal         ...
# ..                                                 ...         ...
# 510       time increase number tree ring also increase         ...
# 511       time increase number tree ring also increase         ...
# 512    time increase speed light stay remains constant         ...
# 513    time increase speed light stay remains constant         ...
# 514    time increase speed light stay remains constant         ...
# 515    time increase speed light stay remains constant         ...
# 516  le 3 scoop fertilizer used fertilizer used gre...         ...
# 517  le 3 scoop fertilizer used fertilizer used gre...         ...
# 518  le 3 scoop fertilizer used fertilizer used gre...         ...
# 519  le 3 scoop fertilizer used fertilizer used gre...         ...
# 520  block truck carry le distance truck travel 10 ...         ...
# 521  block truck carry le distance truck travel 10 ...         ...
# 522  block truck carry le distance truck travel 10 ...         ...
# 523  block truck carry le distance truck travel 10 ...         ...
# 524  launch position line playground variable contr...         ...
# 525  launch position line playground variable contr...         ...
# 526  launch position line playground variable contr...         ...
# 527  launch position line playground variable contr...         ...
# 528  different girl throwing ball girl use differen...         ...
# 529  different girl throwing ball girl use differen...         ...
# 530  different girl throwing ball girl use differen...         ...
# 531  different girl throwing ball girl use differen...         ...
# 532  variable except girl need held constant contro...         ...
# 533  variable except girl need held constant contro...         ...
# 534  variable except girl need held constant contro...         ...
# 535  variable except girl need held constant contro...         ...
# 536  standard used comparison determine changing on...         ...
# 537  standard used comparison determine changing on...         ...
# 538  standard used comparison determine changing on...         ...
# 539  standard used comparison determine changing on...         ...
#
#                                              embed_ref  \
# 0    [[0.06713867, 0.51220703, 0.32043457, -0.32836...
# 1    [[0.06713867, 0.51220703, 0.32043457, -0.32836...
# 2    [[0.06713867, 0.51220703, 0.32043457, -0.32836...
# 3    [[0.06713867, 0.51220703, 0.32043457, -0.32836...
# 4    [[-0.3585205, -0.125, 0.71728516, -0.30647278,...
# 5    [[-0.3585205, -0.125, 0.71728516, -0.30647278,...
# 6    [[-0.3585205, -0.125, 0.71728516, -0.30647278,...
# 7    [[-0.3585205, -0.125, 0.71728516, -0.30647278,...
# 8    [[0.9230957, -0.6287842, 1.4970703, 1.9587402,...
# 9    [[0.9230957, -0.6287842, 1.4970703, 1.9587402,...
# 10   [[0.9230957, -0.6287842, 1.4970703, 1.9587402,...
# 11   [[0.9230957, -0.6287842, 1.4970703, 1.9587402,...
# 12   [[-0.07824707, -0.38409424, 0.31591797, 0.9750...
# 13   [[-0.07824707, -0.38409424, 0.31591797, 0.9750...
# 14   [[-0.07824707, -0.38409424, 0.31591797, 0.9750...
# 15   [[-0.07824707, -0.38409424, 0.31591797, 0.9750...
# 16   [[0.6187134, -0.095825195, 0.52423096, 1.86462...
# 17   [[0.6187134, -0.095825195, 0.52423096, 1.86462...
# 18   [[0.6187134, -0.095825195, 0.52423096, 1.86462...
# 19   [[0.6187134, -0.095825195, 0.52423096, 1.86462...
# 20   [[-0.08331299, 0.7799072, 0.23844147, 0.788203...
# 21   [[-0.08331299, 0.7799072, 0.23844147, 0.788203...
# 22   [[-0.08331299, 0.7799072, 0.23844147, 0.788203...
# 23   [[-0.08331299, 0.7799072, 0.23844147, 0.788203...
# 24   [[-0.4272461, 0.8457031, 0.5647583, 0.8872833,...
# 25   [[-0.4272461, 0.8457031, 0.5647583, 0.8872833,...
# 26   [[-0.4272461, 0.8457031, 0.5647583, 0.8872833,...
# 27   [[-0.4272461, 0.8457031, 0.5647583, 0.8872833,...
# 28   [[0.12792969, 0.095703125, 0.1381836, -0.09188...
# 29   [[0.12792969, 0.095703125, 0.1381836, -0.09188...
# ..                                                 ...
# 510  [[0.24536133, -0.19354248, -0.5960388, 0.39526...
# 511  [[0.24536133, -0.19354248, -0.5960388, 0.39526...
# 512  [[0.38690186, 0.625, 0.01739502, 0.44873047, -...
# 513  [[0.38690186, 0.625, 0.01739502, 0.44873047, -...
# 514  [[0.38690186, 0.625, 0.01739502, 0.44873047, -...
# 515  [[0.38690186, 0.625, 0.01739502, 0.44873047, -...
# 516  [[0.87890625, 3.0974731, 0.51708984, 2.4692383...
# 517  [[0.87890625, 3.0974731, 0.51708984, 2.4692383...
# 518  [[0.87890625, 3.0974731, 0.51708984, 2.4692383...
# 519  [[0.87890625, 3.0974731, 0.51708984, 2.4692383...
# 520  [[0.47630859375, 0.81877685546875, 0.206609497...
# 521  [[0.47630859375, 0.81877685546875, 0.206609497...
# 522  [[0.47630859375, 0.81877685546875, 0.206609497...
# 523  [[0.47630859375, 0.81877685546875, 0.206609497...
# 524  [[-0.032714844, 0.22265625, -0.29559326, 0.197...
# 525  [[-0.032714844, 0.22265625, -0.29559326, 0.197...
# 526  [[-0.032714844, 0.22265625, -0.29559326, 0.197...
# 527  [[-0.032714844, 0.22265625, -0.29559326, 0.197...
# 528  [[1.09729, 0.22117615, 0.5294342, 0.7518921, -...
# 529  [[1.09729, 0.22117615, 0.5294342, 0.7518921, -...
# 530  [[1.09729, 0.22117615, 0.5294342, 0.7518921, -...
# 531  [[1.09729, 0.22117615, 0.5294342, 0.7518921, -...
# 532  [[1.0891113, 0.22525024, 0.17041016, 0.5397339...
# 533  [[1.0891113, 0.22525024, 0.17041016, 0.5397339...
# 534  [[1.0891113, 0.22525024, 0.17041016, 0.5397339...
# 535  [[1.0891113, 0.22525024, 0.17041016, 0.5397339...
# 536  [[-0.008056641, 0.14331055, -0.052001953, 1.07...
# 537  [[-0.008056641, 0.14331055, -0.052001953, 1.07...
# 538  [[-0.008056641, 0.14331055, -0.052001953, 1.07...
# 539  [[-0.008056641, 0.14331055, -0.052001953, 1.07...
#
#                                             embed_stud  \
# 0    [[-0.030761719, 0.18359375, 0.10412598, -0.293...
# 1    [[0.4050293, 0.7039795, 0.47973633, 0.23632812...
# 2    [[-0.5404053, 0.7597656, 1.0896988, 0.17456055...
# 3    [[-0.11816406, 0.046875, -0.17822266, -0.06347...
# 4    [[0.032226562, 0.017578125, -0.2939453, 0.1542...
# 5    [[-0.057617188, 0.2535553, 0.119140625, 0.2019...
# 6    [[-0.21411133, -0.22290039, 0.5083008, 0.13691...
# 7    [[-0.3154297, -0.103515625, -0.41455078, 0.133...
# 8    [[-0.2607422, 0.47216797, 0.8532257, 1.6469727...
# 9    [[0.018066406, 0.09301758, -0.10534668, 0.7578...
# 10   [[-0.37646484, -0.12011719, -0.005126953, 0.49...
# 11   [[0.23168945, -0.22772217, 0.857666, 0.8873291...
# 12   [[0.06201172, -0.048828125, 0.10986328, 0.0639...
# 13   [[-0.1043396, -0.060546875, 0.005126953, 0.344...
# 14   [[0.02722168, -0.3040161, 0.6796875, 1.081543,...
# 15   [[-0.08935547, -0.31573486, 0.1977539, 0.89697...
# 16   [[0.15771484, 0.009521484, 0.06750488, 0.46386...
# 17   [[-0.042541504, -0.0770874, -0.027832031, 0.38...
# 18   [[0.09765625, 0.15093994, 0.26818848, 0.467773...
# 19   [[0.1529541, -0.063964844, 0.49291992, 1.11962...
# 20   [[0.6566162, 0.6447449, -0.41725922, 0.9347534...
# 21   [[-0.061279297, 0.14355469, -0.2109375, 0.0688...
# 22   [[-0.33422852, -0.15039062, 0.31884766, 0.0583...
# 23   [[0.29345703, 0.3154297, -0.27514648, 0.367919...
# 24   [[-0.2154541, -0.10070801, 0.78759766, 0.38659...
# 25   [[-0.20922852, -0.032226562, 0.16125488, 0.220...
# 26   [[0.059326172, 0.22955322, 0.09736633, 0.48994...
# 27   [[0.3234253, -0.436615, 0.13330078, 0.12911987...
# 28   [[-0.07421875, 0.4091797, -0.06982422, 0.02709...
# 29   [[-0.2515869, 0.46289062, 0.3149414, 0.2827148...
# ..                                                 ...
# 510  [[0.5420532, -0.40306473, -0.30267334, 0.37939...
# 511  [[-0.17333984, 0.19433594, -0.13822937, 0.4609...
# 512  [[0.47314453, 0.70983887, 0.45013428, 0.264160...
# 513  [[0.22857666, 0.051757812, -0.5135498, -0.1403...
# 514  [[0.1015625, 0.5649414, 0.32208252, 0.0546875,...
# 515  [[0.083496094, 0.42419434, -0.2662964, 0.14208...
# 516  [[0.16064453, 0.6557617, 0.20117188, 0.1821289...
# 517  [[-0.6044922, 0.057922363, -0.5214844, 0.87207...
# 518  [[0.56125, -0.46981689453125, -0.0005786132812...
# 519  [[-0.076293945, 2.0543518, -0.2980194, 1.29101...
# 520  [[-0.25195312, 0.7852783, 0.7375488, 0.4645996...
# 521  [[0.46826172, 0.9082031, 1.1535645, -0.5073242...
# 522  [[0.60650635, 0.85546875, -0.43684387, 0.53295...
# 523  [[0.6633203125, 0.3834130859375, -0.0035498046...
# 524  [[0.19958496, 0.13366699, 0.18640137, 0.209960...
# 525  [[0.23864746, 0.07104492, 0.09863281, 0.019531...
# 526  [[0.13671875, 0.19238281, 0.01171875, 0.099121...
# 527  [[-0.13208008, 0.16064453, 0.012390137, 0.2182...
# 528  [[0.40112305, 0.08068848, 0.18896484, 0.394531...
# 529  [[0.091674805, 0.6505127, -0.02949524, -0.4309...
# 530  [[0.41271973, 0.26293945, 0.058166504, 0.42950...
# 531  [[0.27319336, 0.5531006, 0.29718018, 0.4412231...
# 532  [[0.46142578, 0.17773438, 0.0009765625, 0.2832...
# 533  [[0.33874512, 0.6365967, 0.41209412, 1.060791,...
# 534  [[0.11779785, 0.28308105, 0.24121094, 0.153564...
# 535  [[-0.014282227, 0.026489258, 0.037353516, -0.1...
# 536  [[0.20214844, 0.10986328, -0.12792969, 0.06542...
# 537  [[0.16693115, 0.014038086, 0.17993164, 0.52954...
# 538  [[0.3894043, 0.061279297, 0.17333984, 1.167968...
# 539  [[-0.007080078, 0.3095703, -0.07385254, 0.5745...
#
#                                      embed_ref_demoted  \
# 0    [[0.2758789, 0.15283203, -0.00036621094, -0.19...
# 1    [[0.2758789, 0.15283203, -0.00036621094, -0.19...
# 2    [[0.2758789, 0.15283203, -0.00036621094, -0.19...
# 3    [[0.2758789, 0.15283203, -0.00036621094, -0.19...
# 4    [[-0.4041748, 0.14453125, 0.64404297, -0.30325...
# 5    [[-0.4041748, 0.14453125, 0.64404297, -0.30325...
# 6    [[-0.4041748, 0.14453125, 0.64404297, -0.30325...
# 7    [[-0.4041748, 0.14453125, 0.64404297, -0.30325...
# 8    [[0.6855469, -0.4970703, 1.0170898, 1.2084961,...
# 9    [[0.6855469, -0.4970703, 1.0170898, 1.2084961,...
# 10   [[0.6855469, -0.4970703, 1.0170898, 1.2084961,...
# 11   [[0.6855469, -0.4970703, 1.0170898, 1.2084961,...
# 12   [[-0.13500977, -0.17022705, 0.041503906, 0.730...
# 13   [[-0.13500977, -0.17022705, 0.041503906, 0.730...
# 14   [[-0.13500977, -0.17022705, 0.041503906, 0.730...
# 15   [[-0.13500977, -0.17022705, 0.041503906, 0.730...
# 16   [[-0.015136719, 0.30810547, 0.39135742, 0.5864...
# 17   [[-0.015136719, 0.30810547, 0.39135742, 0.5864...
# 18   [[-0.015136719, 0.30810547, 0.39135742, 0.5864...
# 19   [[-0.015136719, 0.30810547, 0.39135742, 0.5864...
# 20   [[0.33514404, 0.16027832, -0.046043396, 0.5110...
# 21   [[0.33514404, 0.16027832, -0.046043396, 0.5110...
# 22   [[0.33514404, 0.16027832, -0.046043396, 0.5110...
# 23   [[0.33514404, 0.16027832, -0.046043396, 0.5110...
# 24   [[-0.40771484, 1.2509766, 0.380188, 0.88082886...
# 25   [[-0.40771484, 1.2509766, 0.380188, 0.88082886...
# 26   [[-0.40771484, 1.2509766, 0.380188, 0.88082886...
# 27   [[-0.40771484, 1.2509766, 0.380188, 0.88082886...
# 28                                                   0
# 29                                                   0
# ..                                                 ...
# 510  [[-0.15844727, -0.23406982, -0.3229065, 0.4187...
# 511  [[-0.15844727, -0.23406982, -0.3229065, 0.4187...
# 512  [[0.22528076, -0.033203125, -0.37695312, 0.585...
# 513  [[0.22528076, -0.033203125, -0.37695312, 0.585...
# 514  [[0.22528076, -0.033203125, -0.37695312, 0.585...
# 515  [[0.22528076, -0.033203125, -0.37695312, 0.585...
# 516  [[0.6899414, 0.74560547, 1.3051758, 0.8925781,...
# 517  [[0.6899414, 0.74560547, 1.3051758, 0.8925781,...
# 518  [[0.6899414, 0.74560547, 1.3051758, 0.8925781,...
# 519  [[0.6899414, 0.74560547, 1.3051758, 0.8925781,...
# 520  [[0.04248047, 0.006286621, 0.006378174, 0.0742...
# 521  [[0.04248047, 0.006286621, 0.006378174, 0.0742...
# 522  [[0.04248047, 0.006286621, 0.006378174, 0.0742...
# 523  [[0.04248047, 0.006286621, 0.006378174, 0.0742...
# 524  [[-0.13134766, 0.12695312, -0.36450195, -0.187...
# 525  [[-0.13134766, 0.12695312, -0.36450195, -0.187...
# 526  [[-0.13134766, 0.12695312, -0.36450195, -0.187...
# 527  [[-0.13134766, 0.12695312, -0.36450195, -0.187...
# 528  [[0.70983887, 0.15698242, 0.2613678, 1.187439,...
# 529  [[0.70983887, 0.15698242, 0.2613678, 1.187439,...
# 530  [[0.70983887, 0.15698242, 0.2613678, 1.187439,...
# 531  [[0.70983887, 0.15698242, 0.2613678, 1.187439,...
# 532  [[0.484375, 0.009033203, 0.1352539, 0.6720581,...
# 533  [[0.484375, 0.009033203, 0.1352539, 0.6720581,...
# 534  [[0.484375, 0.009033203, 0.1352539, 0.6720581,...
# 535  [[0.484375, 0.009033203, 0.1352539, 0.6720581,...
# 536  [[0.0949707, 0.064697266, -0.17358398, 0.81150...
# 537  [[0.0949707, 0.064697266, -0.17358398, 0.81150...
# 538  [[0.0949707, 0.064697266, -0.17358398, 0.81150...
# 539  [[0.0949707, 0.064697266, -0.17358398, 0.81150...
#
#                                     embed_stud_demoted  \
# 0    [[0.12060547, 0.046875, -0.012573242, -0.11523...
# 1    [[0.7077637, 0.430542, 0.24633789, 0.59375, -0...
# 2    [[-0.33166504, 0.40039062, 0.768898, 0.3066406...
# 3    [[0.033203125, -0.08984375, -0.29492188, 0.115...
# 4    [[0.032226562, 0.017578125, -0.2939453, 0.1542...
# 5    [[-0.057617188, 0.2535553, 0.119140625, 0.2019...
# 6    [[-0.14746094, -0.05883789, 0.203125, 0.018798...
# 7    [[-0.3154297, -0.103515625, -0.41455078, 0.133...
# 8    [[0.38989258, 0.0063476562, 0.3002472, 0.52661...
# 9    [[0.2680664, -0.21606445, -0.3173828, 0.556640...
# 10   [[0.111328125, -0.15820312, -0.17285156, 0.289...
# 11   [[0.39697266, -0.16723633, 0.54785156, 0.52587...
# 12   [[0.06201172, -0.048828125, 0.10986328, 0.0639...
# 13   [[-0.1043396, -0.060546875, 0.005126953, 0.344...
# 14   [[-0.07519531, 0.055358887, 0.24902344, 0.6713...
# 15   [[-0.13500977, -0.17022705, 0.041503906, 0.730...
# 16   [[0.11206055, 0.1550293, -0.08874512, 0.297851...
# 17   [[-0.042541504, -0.0770874, -0.027832031, 0.38...
# 18   [[0.052001953, 0.29644775, 0.11193848, 0.30175...
# 19   [[-0.015136719, 0.30810547, 0.39135742, 0.5864...
# 20   [[0.6742554, 0.338562, -0.40724945, 0.7792969,...
# 21   [[-0.061279297, 0.14355469, -0.2109375, 0.0688...
# 22   [[-0.19165039, -0.11352539, 0.18310547, 0.1203...
# 23   [[0.39257812, 0.13476562, -0.035888672, 0.3984...
# 24   [[-0.15026855, 0.03503418, 0.67626953, 0.37692...
# 25   [[-0.14404297, 0.103515625, 0.049926758, 0.210...
# 26   [[0.013671875, 0.49908447, 0.024124146, 0.4931...
# 27   [[0.3312378, -0.07821655, 0.22607422, 0.166076...
# 28   [[-0.17089844, 0.1796875, 0.022949219, 0.07421...
# 29   [[-0.366333, 0.19726562, 0.24121094, 0.1953125...
# ..                                                 ...
# 510  [[0.15319824, -0.029529572, -0.07373047, 0.284...
# 511  [[-0.17333984, 0.19433594, -0.13822937, 0.4609...
# 512  [[0.31152344, 0.051635742, 0.055786133, 0.4008...
# 513  [[0.11364746, 0.2919922, -0.6607666, -0.007080...
# 514  [[-0.060058594, -0.09326172, -0.072265625, 0.1...
# 515  [[0.0009765625, 0.06286621, -0.37158203, 0.220...
# 516  [[-0.13476562, 0.28515625, 0.19628906, 0.05615...
# 517  [[-0.2529297, 0.06640625, -0.31445312, 0.76708...
# 518  [[0.776337890625, -1.4281298828125, 0.64102294...
# 519  [[-0.09094238, 1.5996094, -0.13005066, 1.04711...
# 520  [[-0.20898438, 0.07824707, -0.1550293, 0.69213...
# 521  [[0.15698242, 1.1064453, 0.6452637, -0.4194336...
# 522  [[0.6231079, 0.48828125, -0.6846924, 0.7509765...
# 523  [[0.2109375, 0.20410156, 0.11340332, 1.0283203...
# 524  [[0.24023438, 0.03881836, 0.18017578, 0.09375,...
# 525  [[-0.041992188, 0.0625, 0.0024414062, -0.07421...
# 526  [[0.13671875, 0.19238281, 0.01171875, 0.099121...
# 527                                                  0
# 528  [[0.13476562, 0.045654297, 0.055419922, 0.4042...
# 529  [[-0.04345703, 0.5566406, 0.025924683, -0.1223...
# 530  [[0.026855469, -0.076171875, 0.026977539, 0.13...
# 531  [[0.20983887, 0.40795898, 0.24975586, 0.554687...
# 532  [[-0.021362305, 0.059326172, 0.032714844, 0.12...
# 533  [[0.22998047, 0.4206543, 0.11430359, 0.5515137...
# 534  [[0.13208008, 0.2565918, 0.20385742, 0.2570800...
# 535                                                  0
# 536                                                  0
# 537  [[0.10003662, -0.17541504, 0.11645508, 0.05004...
# 538  [[0.14526367, 0.004638672, 0.18261719, 0.85058...
# 539  [[-0.07397461, 0.12011719, -0.1373291, 0.09509...
#
#                                                aligned  \
# 0           [[water, water], [evaporated, evaporated]]
# 1    [[leaving, let], [water, water], [evaporated, ...
# 2                       [[water, water], [salt, salt]]
# 3                                     [[water, water]]
# 4                                                   []
# 5                                                   []
# 6                                 [[crystal, crystal]]
# 7                                                   []
# 8    [[scratch, scratched], [mineral, mineral], [no...
# 9    [[tool, tool], [scratch, scratched], [could, c...
# 10                 [[topaz, topaz], [hardest, harder]]
# 11   [[none, none], [tool, tool], [could, could], [...
# 12                                        [[rub, rub]]
# 13              [[rub, rubbing], [together, together]]
# 14   [[scratch, scratch], [rub, rub], [see, see], [...
# 15   [[scratch, scratch], [together, together], [se...
# 16                                                  []
# 17                                [[scratch, scratch]]
# 18                 [[scratch, scratch], [leave, leaf]]
# 19   [[leave, leave], [scratch, scratch], [le, le],...
# 20   [[calcite, calcite], [rock, rock], [put, put],...
# 21                                                  []
# 22                                                  []
# 23                                [[calcite, calcite]]
# 24   [[calcite, calcite], [crystal, crystal], [salt...
# 25   [[calcite, calcite], [crystal, crystal], [salt...
# 26                  [[crystal, crystal], [like, like]]
# 27   [[different, different], [crystal, crystal], [...
# 28                                                  []
# 29                                      [[alum, alum]]
# ..                                                 ...
# 510  [[number, number], [tree, tree], [ring, ring],...
# 511                             [[increase, increase]]
# 512     [[light, light], [time, time], [speed, speed]]
# 513                 [[time, minute], [light, lighter]]
# 514     [[speed, speed], [light, light], [time, time]]
# 515  [[stay, staying], [light, light], [increase, i...
# 516  [[fertilizer, fertilizer], [le, le], [mass, ma...
# 517  [[le, le], [scoop, scoop], [scoop, scoop], [gr...
# 518  [[scoop, scoop], [fertilizer, fertilizer], [ma...
# 519  [[scoop, scoop], [fertilizer, fertilizer], [le...
# 520           [[le, le], [travel, go], [block, block]]
# 521      [[second, 2], [block, block], [travel, went]]
# 522  [[distance, distance], [travel, go], [block, b...
# 523  [[second, second], [travel, travel], [10, 10],...
# 524                         [[controlled, controlled]]
# 525                                  [[launch, throw]]
# 526                                                 []
# 527                    [[launch, start], [line, line]]
# 528  [[ball, ball], [ball, ball], [type, kind], [th...
# 529                                     [[ball, ball]]
# 530  [[ball, ball], [different, different], [throwi...
# 531  [[ball, ball], [type, kind], [different, diffe...
# 532  [[throw, throw], [ball, ball], [controlled, co...
# 533                         [[ball, ball], [use, use]]
# 534                                     [[ball, ball]]
# 535                                     [[ball, ball]]
# 536                                                 []
# 537     [[standard, standard], [changing, difference]]
# 538                [[standard, standard], [used, use]]
# 539                             [[standard, standard]]
#
#                                        aligned_demoted cos_similarity  \
# 0           [[water, water], [evaporated, evaporated]]       0.839743
# 1    [[leaving, let], [water, water], [evaporated, ...       0.721141
# 2                       [[water, water], [salt, salt]]       0.656509
# 3                                     [[water, water]]       0.600818
# 4                                                   []       0.160882
# 5                                                   []       0.110334
# 6                                 [[crystal, crystal]]       0.483795
# 7                                                   []       0.212979
# 8    [[scratch, scratched], [mineral, mineral], [no...       0.795240
# 9    [[tool, tool], [scratch, scratched], [could, c...       0.717415
# 10                 [[topaz, topaz], [hardest, harder]]       0.533325
# 11   [[none, none], [tool, tool], [could, could], [...       0.836321
# 12                                        [[rub, rub]]       0.678282
# 13              [[rub, rubbing], [together, together]]       0.660661
# 14   [[scratch, scratch], [rub, rub], [see, see], [...       0.910977
# 15   [[scratch, scratch], [together, together], [se...       0.910965
# 16                                                  []       0.259582
# 17                                [[scratch, scratch]]       0.445528
# 18                 [[scratch, scratch], [leave, leaf]]       0.477320
# 19   [[leave, leave], [scratch, scratch], [le, le],...       0.838989
# 20   [[calcite, calcite], [rock, rock], [put, put],...       0.761485
# 21                                                  []       0.109157
# 22                                                  []       0.440765
# 23                                [[calcite, calcite]]       0.567377
# 24   [[calcite, calcite], [crystal, crystal], [salt...       0.830100
# 25   [[calcite, calcite], [crystal, crystal], [salt...       0.867287
# 26                  [[crystal, crystal], [like, like]]       0.681901
# 27   [[different, different], [crystal, crystal], [...       0.817363
# 28                                                  []       0.320119
# 29                                      [[alum, alum]]       0.448282
# ..                                                 ...            ...
# 510  [[number, number], [tree, tree], [ring, ring],...       0.823811
# 511                             [[increase, increase]]       0.567422
# 512     [[light, light], [time, time], [speed, speed]]       0.669825
# 513                 [[time, minute], [light, lighter]]       0.467451
# 514     [[speed, speed], [light, light], [time, time]]       0.727574
# 515  [[stay, staying], [light, light], [increase, i...       0.776938
# 516  [[fertilizer, fertilizer], [le, le], [mass, ma...       0.731760
# 517  [[le, le], [scoop, scoop], [scoop, scoop], [gr...       0.468850
# 518  [[scoop, scoop], [fertilizer, fertilizer], [ma...       0.709247
# 519  [[scoop, scoop], [fertilizer, fertilizer], [le...       0.575185
# 520           [[le, le], [travel, go], [block, block]]       0.605835
# 521      [[second, 2], [block, block], [travel, went]]       0.419493
# 522  [[distance, distance], [travel, go], [block, b...       0.533922
# 523  [[second, second], [travel, travel], [10, 10],...       0.605893
# 524                         [[controlled, controlled]]       0.458824
# 525                                  [[launch, throw]]       0.313878
# 526                                                 []       0.232088
# 527                    [[launch, start], [line, line]]       0.510619
# 528  [[ball, ball], [ball, ball], [type, kind], [th...       0.659156
# 529                                     [[ball, ball]]       0.525681
# 530  [[ball, ball], [different, different], [throwi...       0.709564
# 531  [[ball, ball], [type, kind], [different, diffe...       0.664020
# 532  [[throw, throw], [ball, ball], [controlled, co...       0.673746
# 533                         [[ball, ball], [use, use]]       0.680280
# 534                                     [[ball, ball]]       0.579721
# 535                                     [[ball, ball]]       0.473790
# 536                                                 []       0.388128
# 537     [[standard, standard], [changing, difference]]       0.604625
# 538                [[standard, standard], [used, use]]       0.634441
# 539                             [[standard, standard]]       0.595825
#
#     cos_similarity_demoted align_ratio  align_ratio_demoted
# 0                 0.874477    0.666667             1.333333
# 1                 0.580233    0.545455             0.857143
# 2                 0.230014    0.363636             0.571429
# 3                 0.224198    0.333333             0.666667
# 4                 0.197800    0.000000             0.000000
# 5                 0.072466    0.000000             0.000000
# 6                 0.000121    0.250000             0.500000
# 7                 0.165707    0.000000             0.000000
# 8                 0.575382    0.533333             1.333333
# 9                 0.669236    0.416667             0.909091
# 10                0.425778    0.200000             0.444444
# 11                0.928413    0.560000             1.166667
# 12                0.720454    0.285714             0.400000
# 13                0.732883    0.500000             0.666667
# 14                0.870810    0.769231             1.250000
# 15                1.000000    0.909091             1.250000
# 16                0.303751    0.000000             0.000000
# 17                0.733646    0.133333             0.333333
# 18                0.602897    0.250000             0.666667
# 19                1.000000    0.600000             1.500000
# 20                0.708341    0.526316             0.909091
# 21                0.205055    0.000000             0.000000
# 22                0.348979    0.000000             0.000000
# 23                0.299568    0.166667             0.333333
# 24                0.486244    0.434783             0.714286
# 25                0.535697    0.476190             0.833333
# 26                0.422604    0.190476             0.266667
# 27                0.425808    0.363636             0.571429
# 28                     NaN    0.000000             0.000000
# 29                     NaN    0.222222             0.500000
# ..                     ...         ...                  ...
# 510               0.582153    0.625000             1.428571
# 511               0.633487    0.200000             0.333333
# 512               0.288630    0.461538             0.857143
# 513               0.241689    0.285714             0.444444
# 514               0.363463    0.545455             1.200000
# 515               0.679934    0.727273             1.333333
# 516               0.623461    0.250000             0.600000
# 517               0.480480    0.285714             0.571429
# 518               0.485530    0.400000             0.714286
# 519               0.612866    0.294118             0.500000
# 520               0.331679    0.352941             1.200000
# 521               0.185998    0.272727             0.545455
# 522               0.498368    0.352941             0.857143
# 523               0.231881    0.500000             2.000000
# 524               0.566414    0.200000             0.400000
# 525               0.237611    0.222222             0.500000
# 526               0.205449    0.000000             0.000000
# 527                    NaN    0.500000             1.333333
# 528               0.509978    0.444444             0.800000
# 529               0.229160    0.111111             0.181818
# 530               0.764456    0.400000             0.800000
# 531               0.637076    0.300000             0.461538
# 532               0.174961    0.315789             0.750000
# 533               0.483897    0.166667             0.333333
# 534               0.357210    0.111111             0.200000
# 535                    NaN    0.133333             0.285714
# 536                    NaN    0.000000             0.000000
# 537               0.491157    0.235294             0.285714
# 538               0.461434    0.210526             0.307692
# 539               0.414588    0.142857             0.181818
#
# [540 rows x 23 columns]
