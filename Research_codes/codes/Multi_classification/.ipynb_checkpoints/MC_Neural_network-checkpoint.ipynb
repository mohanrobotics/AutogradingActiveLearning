# %% [markdown]
# # Multiclass Classification NN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl


from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from textblob import Word
from textblob import TextBlob
from nltk import PorterStemmer

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score,accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier


from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

from modAL.models import ActiveLearner,Committee
from modAL.uncertainty import uncertainty_sampling,margin_sampling,entropy_sampling
from modAL.disagreement import vote_entropy_sampling,max_disagreement_sampling,consensus_entropy_sampling
import en_core_web_sm
nlp = en_core_web_sm.load()

# %matplotlib inline

# %%
df = pd.read_pickle("../../dataset/final_dataset/nn_final.pkl")
# df.fillna(-1, inplace=True)
# mms = MinMaxScaler()
# df[['length_ratio', 'aligned_score', 'aligned_score_demo', 'cos_similarity', 'cos_similarity_demo']] = \
# mms.fit_transform(df[['length_ratio', 'aligned_score', 'aligned_score_demo','cos_similarity', 'cos_similarity_demo']])

fig = plt.figure(figsize=(8,6))
df.groupby('grades_round').student_modified.count().plot.bar(ylim=0)
plt.show()
df
# Out:
#                                               question  \
# 0     Give a definition for the term "artificial ne...
# 1     Give a definition for the term "artificial ne...
# 2     Give a definition for the term "artificial ne...
# 3     Give a definition for the term "artificial ne...
# 4     Give a definition for the term "artificial ne...
# 5     Give a definition for the term "artificial ne...
# 6     Give a definition for the term "artificial ne...
# 7     Give a definition for the term "artificial ne...
# 8     Give a definition for the term "artificial ne...
# 9     Give a definition for the term "artificial ne...
# 10    Give a definition for the term "artificial ne...
# 11    Give a definition for the term "artificial ne...
# 12    Give a definition for the term "artificial ne...
# 13    Give a definition for the term "artificial ne...
# 14    Give a definition for the term "artificial ne...
# 15    Give a definition for the term "artificial ne...
# 16    Give a definition for the term "artificial ne...
# 17    Give a definition for the term "artificial ne...
# 18    Give a definition for the term "artificial ne...
# 19    Give a definition for the term "artificial ne...
# 20    Give a definition for the term "artificial ne...
# 21    Give a definition for the term "artificial ne...
# 22    Give a definition for the term "artificial ne...
# 23    Give a definition for the term "artificial ne...
# 24    Give a definition for the term "artificial ne...
# 25    Give a definition for the term "artificial ne...
# 26    Give a definition for the term "artificial ne...
# 27    Give a definition for the term "artificial ne...
# 28    Give a definition for the term "artificial ne...
# 29    Give a definition for the term "artificial ne...
# ..                                                 ...
# 616                 Explain the Bias Variance Dilemma!
# 617                 Explain the Bias Variance Dilemma!
# 618                 Explain the Bias Variance Dilemma!
# 619                 Explain the Bias Variance Dilemma!
# 620                 Explain the Bias Variance Dilemma!
# 621                 Explain the Bias Variance Dilemma!
# 622                 Explain the Bias Variance Dilemma!
# 623                 Explain the Bias Variance Dilemma!
# 624                 Explain the Bias Variance Dilemma!
# 625                 Explain the Bias Variance Dilemma!
# 626                 Explain the Bias Variance Dilemma!
# 627                 Explain the Bias Variance Dilemma!
# 628                 Explain the Bias Variance Dilemma!
# 629                 Explain the Bias Variance Dilemma!
# 630                 Explain the Bias Variance Dilemma!
# 631                 Explain the Bias Variance Dilemma!
# 632                 Explain the Bias Variance Dilemma!
# 633                 Explain the Bias Variance Dilemma!
# 634                 Explain the Bias Variance Dilemma!
# 635                 Explain the Bias Variance Dilemma!
# 636                 Explain the Bias Variance Dilemma!
# 637                 Explain the Bias Variance Dilemma!
# 638                 Explain the Bias Variance Dilemma!
# 639                 Explain the Bias Variance Dilemma!
# 640                 Explain the Bias Variance Dilemma!
# 641                 Explain the Bias Variance Dilemma!
# 642                 Explain the Bias Variance Dilemma!
# 643                 Explain the Bias Variance Dilemma!
# 644                 Explain the Bias Variance Dilemma!
# 645                 Explain the Bias Variance Dilemma!
#
#                                         student_answer  grades_round  \
# 0    An artificial neural network is a massively pa...             2
# 1    Artificial neural network consists of: . Large...             2
# 2    An artificial neural network is a massive dist...             1
# 3    An ANN is a layered graphical model containing...             2
# 4    Artificial Neural Networks are large parallel ...             2
# 5    An articial neural network consists of neurons...             1
# 6    An ANN is a - massivly parallel distibuted Pro...             2
# 7    A ANN is a massively distributed processor. It...             2
# 8    An artificial neural network is defined as a l...             2
# 9    An artificial neural network is a graph of sma...             2
# 10   Artificial neural network is highly parralel p...             1
# 11   It is a massive parallel distributed processor...             2
# 12   ANN is a learning machine which is composed of...             2
# 13   A neural network is a massively parallel distr...             2
# 14   Artificial neural network is a massively paral...             2
# 15   Definition: 1. Artificial neural networks are ...             2
# 16   Artificial neural network is massive parallely...             2
# 17   HERE: Artificial neural network is a massively...             2
# 18   ANN is a learning machine which can perform co...             2
# 19   An artificial neural network is a massively di...             2
# 20   An Artificial Neural Network is a massively pa...             2
# 21   Artificial neural network is massively distrib...             2
# 22   It is a massively parallel distributed process...             2
# 23   Artificial neural network is a massively paral...             1
# 24   Artificial neural network is a **massively par...             2
# 25   Artificial neural network are the network of t...             1
# 26   Artificial neural network is massive parallel ...             2
# 27   An artificial neural network is a highly distr...             1
# 28   A massively distributed processor, consisting ...             1
# 29   An artificial neural network consists of neuro...             2
# ..                                                 ...           ...
# 616  The Bias is defined as the grade of correctnes...             2
# 617  - Bias: the bias is the differnce between the ...             0
# 618  Bias Variance dilemma is coming from the fact ...             0
# 619  It is refers to the problem of tryning to mant...             2
# 620  + One cannot optimize simultaneously the learn...             0
# 621                                                                0
# 622  The Bias Variance Dilemma tells us that the bi...             1
# 623  So in machine learning problem, minimizing the...             2
# 624  High value of bias means netowrk is unable to ...             0
# 625                                                                0
# 626  Bias and variances are the estimation errors. ...             2
# 627                                                                0
# 628  Bias is the difference between the predicted a...             2
# 629  Bias variance dilemma refers to the problem of...             2
# 630                                                                0
# 631  Bias variance dilemma is a process of simultan...             0
# 632  Bias is used to affine transform of $u$. It he...             0
# 633  Bias: How close the estimate is to the true va...             1
# 634  Bias : differnce between the estmated output a...             1
# 635                                                                0
# 636  When adapting the parameters of a network we c...             1
# 637                                                                0
# 638  Ideally bias and variance would be 0 after lea...             1
# 639                                                                0
# 640  Usualy only one of Bias and Variance can be mi...             2
# 641                                                                0
# 642  Bias is an proides an affine transformation. a...             0
# 643  High bias and variance is desirable in input. ...             1
# 644  Bias: Bias means how much the prediction diffe...             1
# 645                                                                0
#
#                                       student_modified  \
# 0    artificial neural network massively parallel d...
# 1    artificial neural network consists largely par...
# 2    artificial neural network massive distributed ...
# 3    ann layered graphical model containing neuron ...
# 4    artificial neural network large parallel proce...
# 5    articial neural network consists neuron neuron...
# 6    ann massivly parallel distibuted processor mad...
# 7    ann massively distributed processor propensity...
# 8    artificial neural network defined learning mac...
# 9    artificial neural network graph small identica...
# 10   artificial neural network highly parralel proc...
# 11   massive parallel distributed processor made sm...
# 12   ann learning machine composed neuron unit comp...
# 13   neural network massively parallel distributed ...
# 14   artificial neural network massively parallel d...
# 15   definition artificial neural network massively...
# 16   artificial neural network massive parallely di...
# 17   artificial neural network massively distribute...
# 18   ann learning machine perform complex parallel ...
# 19   artificial neural network massively distribute...
# 20   artificial neural network massively parallel d...
# 21   artificial neural network massively distribute...
# 22   massively parallel distributed processor consi...
# 23   artificial neural network massively parallel d...
# 24   artificial neural network massively parallel d...
# 25   artificial neural network network unit learn d...
# 26   artificial neural network massive parallel pro...
# 27   artificial neural network highly distributed p...
# 28   massively distributed processor consisting sin...
# 29   artificial neural network consists neuron smal...
# ..                                                 ...
# 616  bias defined grade correctness learning algori...
# 617  bias bias differnce predicted value desired va...
# 618  bias variance dilemma coming fact time network...
# 619  refers problem tryning mantain balance two cau...
# 620  one can not optimize simultaneously learning a...
# 621
# 622  bias variance dilemma tell u bias difference a...
# 623  machine learning problem minimizing two main s...
# 624  high value bias mean netowrk unable learn data...
# 625
# 626  bias variance estimation error bias correspond...
# 627
# 628  bias difference predicted true value variance ...
# 629  bias variance dilemma refers problem minimizin...
# 630
# 631  bias variance dilemma process simultaneously d...
# 632  bias used affine transform u help shift classi...
# 633  bias close estimate true value variance much e...
# 634  bias differnce estmated output actual output v...
# 635
# 636  adapting parameter network either small bias s...
# 637
# 638  ideally bias variance would learning machine h...
# 639
# 640  usualy one bias variance minimized rbfn exampl...
# 641
# 642  bias proides affine transformation treated ext...
# 643  high bias variance desirable input bias varian...
# 644  bias bias mean much prediction differs true va...
# 645
#
#                                             ref_answer  \
# 0    A neural network is a massively parallel distr...
# 1    A neural network is a massively parallel distr...
# 2    A neural network is a massively parallel distr...
# 3    A neural network is a massively parallel distr...
# 4    A neural network is a massively parallel distr...
# 5    A neural network is a massively parallel distr...
# 6    A neural network is a massively parallel distr...
# 7    A neural network is a massively parallel distr...
# 8    A neural network is a massively parallel distr...
# 9    A neural network is a massively parallel distr...
# 10   A neural network is a massively parallel distr...
# 11   A neural network is a massively parallel distr...
# 12   A neural network is a massively parallel distr...
# 13   A neural network is a massively parallel distr...
# 14   A neural network is a massively parallel distr...
# 15   A neural network is a massively parallel distr...
# 16   A neural network is a massively parallel distr...
# 17   A neural network is a massively parallel distr...
# 18   A neural network is a massively parallel distr...
# 19   A neural network is a massively parallel distr...
# 20   A neural network is a massively parallel distr...
# 21   A neural network is a massively parallel distr...
# 22   A neural network is a massively parallel distr...
# 23   A neural network is a massively parallel distr...
# 24   A neural network is a massively parallel distr...
# 25   A neural network is a massively parallel distr...
# 26   A neural network is a massively parallel distr...
# 27   A neural network is a massively parallel distr...
# 28   A neural network is a massively parallel distr...
# 29   A neural network is a massively parallel distr...
# ..                                                 ...
# 616  Bias-variance dilemma is a principle supervise...
# 617  Bias-variance dilemma is a principle supervise...
# 618  Bias-variance dilemma is a principle supervise...
# 619  Bias-variance dilemma is a principle supervise...
# 620  Bias-variance dilemma is a principle supervise...
# 621  Bias-variance dilemma is a principle supervise...
# 622  Bias-variance dilemma is a principle supervise...
# 623  Bias-variance dilemma is a principle supervise...
# 624  Bias-variance dilemma is a principle supervise...
# 625  Bias-variance dilemma is a principle supervise...
# 626  Bias-variance dilemma is a principle supervise...
# 627  Bias-variance dilemma is a principle supervise...
# 628  Bias-variance dilemma is a principle supervise...
# 629  Bias-variance dilemma is a principle supervise...
# 630  Bias-variance dilemma is a principle supervise...
# 631  Bias-variance dilemma is a principle supervise...
# 632  Bias-variance dilemma is a principle supervise...
# 633  Bias-variance dilemma is a principle supervise...
# 634  Bias-variance dilemma is a principle supervise...
# 635  Bias-variance dilemma is a principle supervise...
# 636  Bias-variance dilemma is a principle supervise...
# 637  Bias-variance dilemma is a principle supervise...
# 638  Bias-variance dilemma is a principle supervise...
# 639  Bias-variance dilemma is a principle supervise...
# 640  Bias-variance dilemma is a principle supervise...
# 641  Bias-variance dilemma is a principle supervise...
# 642  Bias-variance dilemma is a principle supervise...
# 643  Bias-variance dilemma is a principle supervise...
# 644  Bias-variance dilemma is a principle supervise...
# 645  Bias-variance dilemma is a principle supervise...
#
#                                            qn_modified  \
# 0    give definition term artificial neural network...
# 1    give definition term artificial neural network...
# 2    give definition term artificial neural network...
# 3    give definition term artificial neural network...
# 4    give definition term artificial neural network...
# 5    give definition term artificial neural network...
# 6    give definition term artificial neural network...
# 7    give definition term artificial neural network...
# 8    give definition term artificial neural network...
# 9    give definition term artificial neural network...
# 10   give definition term artificial neural network...
# 11   give definition term artificial neural network...
# 12   give definition term artificial neural network...
# 13   give definition term artificial neural network...
# 14   give definition term artificial neural network...
# 15   give definition term artificial neural network...
# 16   give definition term artificial neural network...
# 17   give definition term artificial neural network...
# 18   give definition term artificial neural network...
# 19   give definition term artificial neural network...
# 20   give definition term artificial neural network...
# 21   give definition term artificial neural network...
# 22   give definition term artificial neural network...
# 23   give definition term artificial neural network...
# 24   give definition term artificial neural network...
# 25   give definition term artificial neural network...
# 26   give definition term artificial neural network...
# 27   give definition term artificial neural network...
# 28   give definition term artificial neural network...
# 29   give definition term artificial neural network...
# ..                                                 ...
# 616                      explain bias variance dilemma
# 617                      explain bias variance dilemma
# 618                      explain bias variance dilemma
# 619                      explain bias variance dilemma
# 620                      explain bias variance dilemma
# 621                      explain bias variance dilemma
# 622                      explain bias variance dilemma
# 623                      explain bias variance dilemma
# 624                      explain bias variance dilemma
# 625                      explain bias variance dilemma
# 626                      explain bias variance dilemma
# 627                      explain bias variance dilemma
# 628                      explain bias variance dilemma
# 629                      explain bias variance dilemma
# 630                      explain bias variance dilemma
# 631                      explain bias variance dilemma
# 632                      explain bias variance dilemma
# 633                      explain bias variance dilemma
# 634                      explain bias variance dilemma
# 635                      explain bias variance dilemma
# 636                      explain bias variance dilemma
# 637                      explain bias variance dilemma
# 638                      explain bias variance dilemma
# 639                      explain bias variance dilemma
# 640                      explain bias variance dilemma
# 641                      explain bias variance dilemma
# 642                      explain bias variance dilemma
# 643                      explain bias variance dilemma
# 644                      explain bias variance dilemma
# 645                      explain bias variance dilemma
#
#                                           ref_modified  \
# 0    neural network massively parallel distributed ...
# 1    neural network massively parallel distributed ...
# 2    neural network massively parallel distributed ...
# 3    neural network massively parallel distributed ...
# 4    neural network massively parallel distributed ...
# 5    neural network massively parallel distributed ...
# 6    neural network massively parallel distributed ...
# 7    neural network massively parallel distributed ...
# 8    neural network massively parallel distributed ...
# 9    neural network massively parallel distributed ...
# 10   neural network massively parallel distributed ...
# 11   neural network massively parallel distributed ...
# 12   neural network massively parallel distributed ...
# 13   neural network massively parallel distributed ...
# 14   neural network massively parallel distributed ...
# 15   neural network massively parallel distributed ...
# 16   neural network massively parallel distributed ...
# 17   neural network massively parallel distributed ...
# 18   neural network massively parallel distributed ...
# 19   neural network massively parallel distributed ...
# 20   neural network massively parallel distributed ...
# 21   neural network massively parallel distributed ...
# 22   neural network massively parallel distributed ...
# 23   neural network massively parallel distributed ...
# 24   neural network massively parallel distributed ...
# 25   neural network massively parallel distributed ...
# 26   neural network massively parallel distributed ...
# 27   neural network massively parallel distributed ...
# 28   neural network massively parallel distributed ...
# 29   neural network massively parallel distributed ...
# ..                                                 ...
# 616  biasvariance dilemma principle supervised lear...
# 617  biasvariance dilemma principle supervised lear...
# 618  biasvariance dilemma principle supervised lear...
# 619  biasvariance dilemma principle supervised lear...
# 620  biasvariance dilemma principle supervised lear...
# 621  biasvariance dilemma principle supervised lear...
# 622  biasvariance dilemma principle supervised lear...
# 623  biasvariance dilemma principle supervised lear...
# 624  biasvariance dilemma principle supervised lear...
# 625  biasvariance dilemma principle supervised lear...
# 626  biasvariance dilemma principle supervised lear...
# 627  biasvariance dilemma principle supervised lear...
# 628  biasvariance dilemma principle supervised lear...
# 629  biasvariance dilemma principle supervised lear...
# 630  biasvariance dilemma principle supervised lear...
# 631  biasvariance dilemma principle supervised lear...
# 632  biasvariance dilemma principle supervised lear...
# 633  biasvariance dilemma principle supervised lear...
# 634  biasvariance dilemma principle supervised lear...
# 635  biasvariance dilemma principle supervised lear...
# 636  biasvariance dilemma principle supervised lear...
# 637  biasvariance dilemma principle supervised lear...
# 638  biasvariance dilemma principle supervised lear...
# 639  biasvariance dilemma principle supervised lear...
# 640  biasvariance dilemma principle supervised lear...
# 641  biasvariance dilemma principle supervised lear...
# 642  biasvariance dilemma principle supervised lear...
# 643  biasvariance dilemma principle supervised lear...
# 644  biasvariance dilemma principle supervised lear...
# 645  biasvariance dilemma principle supervised lear...
#
#                                        student_demoted  \
# 0    massively parallel distributed processor simpl...
# 1    consists largely parallel distributed processo...
# 2    massive distributed processor consists several...
# 3    ann layered graphical model containing neuron ...
# 4    large parallel processing unit natural ability...
# 5    articial consists neuron neuron several weight...
# 6    ann massivly parallel distibuted processor mad...
# 7    ann massively distributed processor propensity...
# 8    defined learning machine divided layer layer c...
# 9    graph small identical processing unit small un...
# 10   highly parralel processing mathematical model ...
# 11   massive parallel distributed processor made sm...
# 12   ann learning machine composed neuron unit comp...
# 13   massively parallel distributed prcoessor made ...
# 14   massively parallel distributed processor consi...
# 15   massively distributed parallel processor made ...
# 16   massive parallely distributed processor compri...
# 17   massively distributed parallel processor compo...
# 18   ann learning machine perform complex parallel ...
# 19   massively distributed parallel processor made ...
# 20   massively parallel distributed processor inter...
# 21   massively distributed paralled processor conta...
# 22   massively parallel distributed processor consi...
# 23   massively parallel distributed processor made ...
# 24   massively parallel distributed processor synap...
# 25   unit learn data environment store using synapt...
# 26   massive parallel processor made simple process...
# 27   highly distributed processor consists several ...
# 28   massively distributed processor consisting sin...
# 29   consists neuron small computation devicesand s...
# ..                                                 ...
# 616  defined grade correctness learning algorithm u...
# 617  differnce predicted value desired value genera...
# 618  coming fact time network equally great outputi...
# 619  refers problem tryning mantain balance two cau...
# 620  one can not optimize simultaneously learning a...
# 621
# 622  tell u difference actual desired output output...
# 623  machine learning problem minimizing two main s...
# 624  high value mean netowrk unable learn data wher...
# 625
# 626  estimation error corresponds inability learnin...
# 627
# 628  difference predicted true value range several ...
# 629  refers problem minimizing two source error err...
# 630
# 631  process simultaneously decreasing two source e...
# 632  used affine transform u help shift classifier ...
# 633  close estimate true value much estimate vary d...
# 634  differnce estmated output actual output range ...
# 635
# 636  adapting parameter network either small small ...
# 637
# 638  ideally would learning machine however counter...
# 639
# 640  usualy one minimized rbfn example kernel great...
# 641
# 642  proides affine transformation treated extra in...
# 643  high desirable input property input data incre...
# 644  mean much prediction differs true value mean m...
# 645
#
#                                            ref_demoted  length_ratio  \
# 0    massively parallel distributed processor made ...      0.251889
# 1    massively parallel distributed processor made ...      0.232759
# 2    massively parallel distributed processor made ...      0.102828
# 3    massively parallel distributed processor made ...      0.327616
# 4    massively parallel distributed processor made ...      0.286963
# 5    massively parallel distributed processor made ...      0.212831
# 6    massively parallel distributed processor made ...      0.192903
# 7    massively parallel distributed processor made ...      0.207251
# 8    massively parallel distributed processor made ...      0.306093
# 9    massively parallel distributed processor made ...      0.310079
# 10   massively parallel distributed processor made ...      0.201671
# 11   massively parallel distributed processor made ...      0.201671
# 12   massively parallel distributed processor made ...      0.297325
# 13   massively parallel distributed processor made ...      0.255875
# 14   massively parallel distributed processor made ...      0.170583
# 15   massively parallel distributed processor made ...      0.263846
# 16   massively parallel distributed processor made ...      0.221599
# 17   massively parallel distributed processor made ...      0.258266
# 18   massively parallel distributed processor made ...      0.204859
# 19   massively parallel distributed processor made ...      0.290948
# 20   massively parallel distributed processor made ...      0.188120
# 21   massively parallel distributed processor made ...      0.204062
# 22   massively parallel distributed processor made ...      0.206454
# 23   massively parallel distributed processor made ...      0.125148
# 24   massively parallel distributed processor made ...      0.235150
# 25   massively parallel distributed processor made ...      0.163409
# 26   massively parallel distributed processor made ...      0.204859
# 27   massively parallel distributed processor made ...      0.150655
# 28   massively parallel distributed processor made ...      0.109205
# 29   massively parallel distributed processor made ...      0.256672
# ..                                                 ...           ...
# 616  biasvariance principle supervised learning pro...      0.266113
# 617  biasvariance principle supervised learning pro...      0.133057
# 618  biasvariance principle supervised learning pro...      0.170275
# 619  biasvariance principle supervised learning pro...      0.325663
# 620  biasvariance principle supervised learning pro...      0.110725
# 621  biasvariance principle supervised learning pro...      0.000000
# 622  biasvariance principle supervised learning pro...      0.161901
# 623  biasvariance principle supervised learning pro...      0.230755
# 624  biasvariance principle supervised learning pro...      0.109795
# 625  biasvariance principle supervised learning pro...      0.000000
# 626  biasvariance principle supervised learning pro...      0.418709
# 627  biasvariance principle supervised learning pro...      0.000000
# 628  biasvariance principle supervised learning pro...      0.249365
# 629  biasvariance principle supervised learning pro...      0.239130
# 630  biasvariance principle supervised learning pro...      0.000000
# 631  biasvariance principle supervised learning pro...      0.133987
# 632  biasvariance principle supervised learning pro...      0.054897
# 633  biasvariance principle supervised learning pro...      0.131196
# 634  biasvariance principle supervised learning pro...      0.151666
# 635  biasvariance principle supervised learning pro...      0.000000
# 636  biasvariance principle supervised learning pro...      0.192606
# 637  biasvariance principle supervised learning pro...      0.000000
# 638  biasvariance principle supervised learning pro...      0.165623
# 639  biasvariance principle supervised learning pro...      0.000000
# 640  biasvariance principle supervised learning pro...      0.181441
# 641  biasvariance principle supervised learning pro...      0.000000
# 642  biasvariance principle supervised learning pro...      0.065133
# 643  biasvariance principle supervised learning pro...      0.133987
# 644  biasvariance principle supervised learning pro...      0.174927
# 645  biasvariance principle supervised learning pro...      0.000000
#
#                                              embed_ref  \
# 0    [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 1    [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 2    [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 3    [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 4    [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 5    [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 6    [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 7    [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 8    [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 9    [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 10   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 11   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 12   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 13   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 14   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 15   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 16   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 17   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 18   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 19   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 20   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 21   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 22   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 23   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 24   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 25   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 26   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 27   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 28   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# 29   [[1.5640869, 1.7378178, -0.1736145, 2.0961304,...
# ..                                                 ...
# 616  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 617  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 618  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 619  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 620  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 621  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 622  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 623  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 624  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 625  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 626  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 627  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 628  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 629  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 630  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 631  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 632  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 633  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 634  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 635  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 636  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 637  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 638  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 639  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 640  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 641  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 642  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 643  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 644  [[-0.38283203125, 0.6756396484375, -0.51723144...
# 645  [[-0.38283203125, 0.6756396484375, -0.51723144...
#
#                                             embed_stud  \
# 0    [[2.2006836, 0.86382484, 0.27182007, 2.5562744...
# 1    [[1.335439453125, 1.0990445709228516, 0.529989...
# 2    [[0.41577148, -0.37836266, 0.22351074, 0.95300...
# 3    [[2.1478271, 1.4641495, -0.3640442, 0.5910034,...
# 4    [[0.8804833984375, 1.3045060729980469, -0.4420...
# 5    [[0.66605712890625, -0.86836669921875, -1.4553...
# 6    [[0.69897705078125, 0.6726041412353516, 1.2818...
# 7    [[1.5926416015625, 0.03758216857910157, -0.523...
# 8    [[1.00383544921875, 0.034700164794921884, -0.6...
# 9    [[0.64349365, 0.84461784, -0.88964844, 2.92761...
# 10   [[2.329549560546875, -0.7352373504638672, 1.90...
# 11   [[0.140615234375, 0.35929847717285157, -0.5104...
# 12   [[-0.24581909, -0.28298378, 0.510376, 2.47995,...
# 13   [[1.21147705078125, 1.9560086822509763, 0.1161...
# 14   [[0.43408203, 0.50689125, 0.869751, 1.2203064,...
# 15   [[1.3787744140625, 0.9737699127197266, 0.82384...
# 16   [[0.84574462890625, 0.9394889068603516, 1.3022...
# 17   [[1.6464539, 1.2463131, 0.49572754, 1.9798279,...
# 18   [[0.5101123046875, 1.86130859375, -0.356976013...
# 19   [[1.448507080078125, 1.1839444732666016, 0.608...
# 20   [[1.3514404, 0.48797607, -0.39956665, 0.910919...
# 21   [[1.7797753906249998, 0.5790860748291016, -0.8...
# 22   [[2.0133057, -0.36347008, 0.31762695, 1.751251...
# 23   [[0.836792, 0.2891178, 1.114624, 0.9162903, -1...
# 24   [[0.45385742, 0.95043945, -0.6391907, 2.146392...
# 25   [[-0.506357421875, 0.9211671447753906, 0.23937...
# 26   [[1.2305712890625, -0.07772300720214842, 1.224...
# 27   [[0.70666504, -0.38557053, 0.7898865, 1.507904...
# 28   [[0.05663085937500001, -0.5915071868896484, 0....
# 29   [[1.3318994140625, 1.52702880859375, -0.810571...
# ..                                                 ...
# 616  [[-1.7460632, -2.550415, 1.3463745, 4.7440796,...
# 617  [[-0.251962890625, 0.1319482421875, 0.90378356...
# 618  [[1.01555419921875, 0.57707763671875, -1.04207...
# 619  [[-0.02285644531249998, -0.28536865234375, 2.0...
# 620  [[-0.7561035, -0.5913086, 0.97302246, 0.657959...
# 621                                                  0
# 622  [[-0.56781006, -1.0974731, 0.82378006, 2.05393...
# 623  [[-0.839405517578125, -1.7428707885742187, 1.2...
# 624  [[-0.5888672, -0.472229, -0.16881943, 0.834350...
# 625                                                  0
# 626  [[-1.48787353515625, -2.1521115112304687, 0.30...
# 627                                                  0
# 628  [[0.102264404, -0.77227783, -0.56204224, 2.723...
# 629  [[-0.78599853515625, -0.96434326171875, 0.5210...
# 630                                                  0
# 631  [[-0.29833984, -0.6797409, 0.5104675, 0.611328...
# 632  [[-0.327158203125, 0.5330712890625, 0.48521972...
# 633  [[-0.0096588135, -1.12677, 0.8739624, 2.792846...
# 634  [[-0.96813965, -0.47686768, 0.84602356, 2.4096...
# 635                                                  0
# 636  [[-0.11368774414062499, -1.15656494140625, -0....
# 637                                                  0
# 638  [[-0.26983643, -1.2890625, 0.85723877, 1.35144...
# 639                                                  0
# 640  [[0.72490478515625, -0.6902029418945312, -0.19...
# 641                                                  0
# 642  [[-0.488544921875, 0.39548828125, -0.254230957...
# 643  [[-0.9901123, -1.2626343, -0.69189453, 1.68333...
# 644  [[0.43273926, -1.1434326, 1.3979492, 3.0013046...
# 645                                                  0
#
#                                      embed_ref_demoted  \
# 0    [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 1    [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 2    [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 3    [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 4    [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 5    [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 6    [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 7    [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 8    [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 9    [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 10   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 11   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 12   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 13   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 14   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 15   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 16   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 17   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 18   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 19   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 20   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 21   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 22   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 23   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 24   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 25   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 26   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 27   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 28   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# 29   [[1.6300049, 1.5985355, -0.1282959, 1.0488892,...
# ..                                                 ...
# 616  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 617  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 618  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 619  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 620  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 621  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 622  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 623  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 624  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 625  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 626  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 627  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 628  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 629  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 630  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 631  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 632  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 633  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 634  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 635  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 636  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 637  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 638  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 639  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 640  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 641  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 642  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 643  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 644  [[-0.6128125, 1.0052294921875, -0.968403320312...
# 645  [[-0.6128125, 1.0052294921875, -0.968403320312...
#
#                                     embed_stud_demoted  \
# 0    [[2.0412598, 0.49321938, 0.10058594, 1.2648926...
# 1    [[1.1956689453125, 0.7539517974853516, 0.13561...
# 2    [[0.38427734, -0.48944664, 0.17224121, 0.55065...
# 3    [[1.9754639, 1.1296768, -0.6564026, 0.30181885...
# 4    [[0.687978515625, 0.7240617370605469, -0.85735...
# 5    [[0.76102783203125, -1.06660888671875, -1.6119...
# 6    [[0.59875732421875, 0.3972135162353516, 1.1491...
# 7    [[1.492421875, -0.23780845642089843, -0.655771...
# 8    [[0.6730859375, -0.2962934875488281, -0.695642...
# 9    [[0.49041748, 0.3455944, -1.4035645, 1.8238525...
# 10   [[1.956502685546875, -1.4826738739013672, 1.35...
# 11   [[0.008657226562500009, 0.19035316467285157, -...
# 12   [[-0.020111084, -1.0227299, 0.3930664, 2.00158...
# 13   [[1.15959716796875, 1.8164823150634766, -0.009...
# 14   [[0.24645996, 0.028131485, 0.57788086, 0.51074...
# 15   [[1.13646484375, 0.21839881896972657, 0.510122...
# 16   [[0.65812255859375, 0.4607291412353516, 1.0103...
# 17   [[1.5384216, 0.794775, 0.103759766, 1.2219238,...
# 18   [[0.353984375, 1.4936328125, -0.59757659912109...
# 19   [[1.285299072265625, 0.6863858795166016, 0.372...
# 20   [[1.1879883, 0.20794678, -0.5859375, 0.4320678...
# 21   [[1.5604150390625, 0.20677162170410157, -1.180...
# 22   [[1.8571777, -0.73114586, 0.07702637, 1.444030...
# 23   [[0.664917, -0.043157578, 0.9321289, 0.2115783...
# 24   [[0.23498535, 0.58032227, -0.8236084, 0.968811...
# 25   [[-0.63013671875, 0.5050294494628906, -0.09449...
# 26   [[1.0586962890625, -0.4099983978271484, 1.0422...
# 27   [[0.3786621, -1.0855217, 0.36679077, 0.4959716...
# 28   [[0.05663085937500001, -0.5915071868896484, 0....
# 29   [[1.053212890625, 0.79167724609375, -1.0105230...
# ..                                                 ...
# 616  [[-0.8686218, -1.6934814, 0.79559326, 4.78656,...
# 617  [[0.222158203125, 0.4581201171875, 0.642553100...
# 618  [[0.93889404296875, 0.68694091796875, -1.19246...
# 619  [[0.5621044921875, 0.28592041015625, 1.6790478...
# 620  [[-0.46362305, -0.30566406, 0.7894287, 0.67211...
# 621                                                  0
# 622  [[-0.13031006, -0.21173096, 0.27788162, 1.6674...
# 623  [[-0.254444580078125, -1.1715817260742187, 0.8...
# 624  [[-0.29638672, -0.18658447, -0.35241318, 0.848...
# 625                                                  0
# 626  [[-1.09041259765625, -1.7160763549804687, -0.1...
# 627                                                  0
# 628  [[0.90304565, 0.19451904, -1.2632141, 2.390014...
# 629  [[-0.27769775390624996, -0.28319091796874996, ...
# 630                                                  0
# 631  [[-0.375, -0.5698776, 0.3600769, 0.23486328, -...
# 632  [[-0.145517578125, 0.5735986328125, 0.40758300...
# 633  [[0.8677826, -0.26983643, 0.32318115, 2.835327...
# 634  [[-0.3831787, 0.09442139, 0.47883606, 2.437988...
# 635                                                  0
# 636  [[0.763753662109375, -0.29963134765625, -0.575...
# 637                                                  0
# 638  [[0.23846436, -0.60791016, 0.33966064, 1.00329...
# 639                                                  0
# 640  [[1.60234619140625, 0.16673065185546876, -0.74...
# 641                                                  0
# 642  [[-0.306904296875, 0.436015625, -0.33186767578...
# 643  [[-0.48181152, -0.58148193, -1.2094727, 1.3351...
# 644  [[0.6485596, -0.7479248, 1.0639648, 2.639, -1....
# 645                                                  0
#
#                                                aligned  \
# 0    [[neural, neural], [network, network], [massiv...
# 1    [[knowledge, knowledge], [parallel, parallel],...
# 2    [[knowledge, knowledge], [neural, neural], [ne...
# 3    [[resemble, resembling], [neural, neuron], [le...
# 4    [[knowledge, knowledge], [processing, processi...
# 5    [[neural, neural], [network, network], [brain,...
# 6    [[processor, processor], [made, made], [simple...
# 7    [[distributed, distributed], [processor, proce...
# 8    [[neural, neural], [network, network], [brain,...
# 9    [[neural, neural], [network, network], [proces...
# 10   [[neural, neural], [network, network], [networ...
# 11   [[parallel, parallel], [distributed, distribut...
# 12   [[resemble, resembles], [environment, environm...
# 13   [[knowledge, knowledge], [knowledge, knowledge...
# 14   [[neural, neural], [network, network], [massiv...
# 15   [[known, known], [synaptic, synaptic], [weight...
# 16   [[neural, neural], [network, network], [distri...
# 17   [[knowledge, knowledge], [aspect, aspect], [kn...
# 18   [[acquired, acquiring], [environment, environm...
# 19   [[processor, processor], [made, made], [simple...
# 20   [[neural, neural], [network, network], [massiv...
# 21   [[knowledge, knowledge], [simple, simple], [pr...
# 22   [[knowledge, knowledge], [environment, environ...
# 23   [[neural, neural], [network, network], [massiv...
# 24   [[knowledge, knowledge], [neural, neural], [ne...
# 25   [[neural, neural], [network, network], [synapt...
# 26   [[processor, processor], [made, made], [simple...
# 27   [[simple, simple], [processing, processing], [...
# 28   [[processing, processing], [unit, unit], [natu...
# 29   [[weight, weight], [used, used], [store, store...
# ..                                                 ...
# 616  [[high, high], [bias, bias], [high, high], [va...
# 617  [[bias, bias], [bias, bias], [variance, varian...
# 618  [[variance, variance], [arises, coming], [bias...
# 619  [[high, high], [bias, bias], [training, traini...
# 620  [[variance, variance], [data, data], [training...
# 621                                                 []
# 622  [[variance, variance], [low, small], [bias, bi...
# 623  [[learning, learning], [problem, problem], [re...
# 624  [[training, training], [data, data], [bias, bi...
# 625                                                 []
# 626  [[training, training], [data, data], [make, al...
# 627                                                 []
# 628  [[bias, bias], [low, low], [variance, variance...
# 629  [[dilemma, dilemma], [variance, variance], [bi...
# 630                                                 []
# 631  [[supervised, supervised], [learning, learning...
# 632                  [[bias, bias], [make, transform]]
# 633  [[bias, bias], [low, low], [variance, variance...
# 634  [[bias, bias], [variance, variance], [reduces,...
# 635                                                 []
# 636  [[low, low], [variance, variance], [bias, bias...
# 637                                                 []
# 638  [[variance, variance], [bias, bias], [bias, bi...
# 639                                                 []
# 640  [[bias, bias], [low, low], [variance, variance...
# 641                                                 []
# 642                      [[bias, bias], [make, taken]]
# 643  [[high, high], [bias, bias], [data, data], [bi...
# 644  [[bias, mean], [bias, bias], [bias, bias], [va...
# 645                                                 []
#
#                                        aligned_demoted  cos_similarity  \
# 0    [[simple, simple], [processing, processing], [...        0.947867
# 1    [[knowledge, knowledge], [knowledge, knowledge...        0.964398
# 2    [[knowledge, knowledge], [distributed, distrib...        0.854767
# 3    [[environment, environment], [learning, traini...        0.788166
# 4    [[knowledge, knowledge], [processing, processi...        0.894408
# 5    [[parallel, similar], [made, given], [connecti...        0.794897
# 6    [[processor, processor], [made, made], [simple...        0.835716
# 7    [[distributed, distributed], [processor, proce...        0.875301
# 8    [[parallel, similar], [made, given], [learning...        0.806486
# 9    [[processing, processing], [unit, unit], [syna...        0.853033
# 10   [[parallel, parallel], [processing, processing...        0.823909
# 11   [[parallel, parallel], [distributed, distribut...        0.920461
# 12   [[environment, environment], [learning, learns...        0.769191
# 13   [[knowledge, knowledge], [knowledge, knowledge...        0.976718
# 14   [[massively, massively], [parallel, parallel],...        0.927168
# 15   [[known, known], [synaptic, synaptic], [weight...        0.883407
# 16   [[distributed, distributed], [processor, proce...        0.909771
# 17   [[knowledge, knowledge], [aspect, aspect], [kn...        0.970343
# 18   [[acquired, learned], [store, store], [knowled...        0.810302
# 19   [[processor, processor], [made, made], [simple...        0.942812
# 20   [[massively, massively], [parallel, parallel],...        0.915312
# 21   [[knowledge, knowledge], [simple, simple], [pr...        0.949934
# 22   [[knowledge, knowledge], [knowledge, knowledge...        0.883786
# 23   [[massively, massively], [parallel, parallel],...        0.883202
# 24   [[knowledge, knowledge], [knowledge, knowledge...        0.949841
# 25   [[synaptic, synaptic], [weight, weight], [used...        0.859134
# 26   [[processor, processor], [made, made], [simple...        0.918669
# 27   [[simple, simple], [processing, processing], [...        0.841003
# 28   [[processing, processing], [unit, unit], [natu...        0.742950
# 29   [[weight, weight], [used, used], [store, store...        0.839973
# ..                                                 ...             ...
# 616  [[high, high], [low, low], [fit, fit], [model,...        0.851299
# 617                                 [[make, produced]]        0.669321
# 618  [[arises, coming], [data, fact], [high, high],...        0.773152
# 619  [[training, training], [data, data], [data, da...        0.790545
# 620  [[data, data], [high, maximum], [training, lea...        0.730089
# 621                                                 []        0.000000
# 622  [[model, model], [high, larger], [low, small],...        0.809230
# 623  [[learning, learning], [problem, problem], [re...        0.803634
# 624  [[training, training], [data, data], [data, da...        0.793282
# 625                                                 []        0.000000
# 626  [[training, training], [data, data], [make, al...        0.817614
# 627                                                 []        0.000000
# 628  [[high, high], [low, low], [achieve, achieve],...        0.821498
# 629  [[problem, problem], [arises, occurs], [reduce...        0.771097
# 630                                                 []        0.000000
# 631  [[supervised, supervised], [learning, learning...        0.818891
# 632                                [[make, transform]]        0.597484
# 633  [[high, high], [low, low], [training, training...        0.791635
# 634       [[training, training], [reduces, decreased]]        0.710910
# 635                                                 []        0.000000
# 636  [[high, high], [low, low], [reduces, minimized...        0.805754
# 637                                                 []        0.000000
# 638  [[learning, learning], [high, rise], [reduces,...        0.785433
# 639                                                 []        0.000000
# 640  [[high, high], [low, low], [training, training...        0.818816
# 641                                                 []        0.000000
# 642                                    [[make, taken]]        0.583685
# 643  [[high, increased], [data, data], [difficult, ...        0.825904
# 644  [[learning, learning], [reduces, reduced], [we...        0.820242
# 645                                                 []        0.000000
#
#      cos_similarity_demo  aligned_score  aligned_score_demo
# 0               0.933466       0.969697            0.950888
# 1               0.951182       0.883259            0.818713
# 2               0.775333       0.498039            0.465632
# 3               0.735229       0.322950            0.220386
# 4               0.828665       0.585639            0.482094
# 5               0.628488       0.352778            0.182863
# 6               0.822434       0.599354            0.643939
# 7               0.844809       0.646545            0.601010
# 8               0.688594       0.245126            0.184453
# 9               0.759986       0.382458            0.307422
# 10              0.683857       0.306516            0.166370
# 11              0.907509       0.699725            0.669856
# 12              0.685354       0.272942            0.209134
# 13              0.975811       1.000000            0.938897
# 14              0.887153       0.726129            0.662879
# 15              0.798710       0.714719            0.731452
# 16              0.865144       0.776449            0.694215
# 17              0.961347       0.962121            0.919192
# 18              0.807480       0.458994            0.424242
# 19              0.912154       0.832881            0.774411
# 20              0.880091       0.708931            0.678788
# 21              0.941033       0.943968            0.840480
# 22              0.899490       0.824675            0.848485
# 23              0.804967       0.676657            0.591966
# 24              0.907657       0.953898            0.833333
# 25              0.744586       0.589408            0.476190
# 26              0.871280       0.728092            0.655647
# 27              0.713324       0.500303            0.377104
# 28              0.787118       0.543316            0.578512
# 29              0.730435       0.473660            0.347107
# ..                   ...            ...                 ...
# 616             0.828933       0.427609            0.430871
# 617             0.509004       0.149456            0.049331
# 618             0.688905       0.303828            0.249554
# 619             0.749844       0.392703            0.319635
# 620             0.698647       0.265413            0.206948
# 621             0.000000       0.000000            0.000000
# 622             0.670379       0.444056            0.276680
# 623             0.708740       0.397066            0.312966
# 624             0.778547       0.492248            0.345314
# 625             0.000000       0.000000            0.000000
# 626             0.746837       0.459882            0.330579
# 627             0.000000       0.000000            0.000000
# 628             0.683387       0.320707            0.148857
# 629             0.593619       0.352778            0.160091
# 630             0.000000       0.000000            0.000000
# 631             0.725399       0.357999            0.252525
# 632             0.488280       0.098679            0.057330
# 633             0.663849       0.400884            0.192837
# 634             0.579441       0.217839            0.090264
# 635             0.000000       0.000000            0.000000
# 636             0.701863       0.325641            0.207962
# 637             0.000000       0.000000            0.000000
# 638             0.586199       0.403175            0.192837
# 639             0.000000       0.000000            0.000000
# 640             0.736172       0.468511            0.326340
# 641             0.000000       0.000000            0.000000
# 642             0.428050       0.095024            0.058923
# 643             0.670638       0.538788            0.362158
# 644             0.713956       0.323704            0.132576
# 645             0.000000       0.000000            0.000000
#
# [646 rows x 20 columns]

# %% [markdown]
# ## Supervised Learning

# %%
class Supervised_learner():
    def __init__(self,X,Y,model):
        self.X = X
        self.Y = Y
        self.model = model

    def learn(self):
        super_acc = []
        super_f1 = []
        for i in np.linspace(0.05, 0.8, 20):
            X_train,X_test,Y_train,Y_test = train_test_split(self.X,self.Y,test_size = 1 - i)
            model = self.model
            model.fit(X_train, Y_train)
            model_accuracy = model.score(X_test, Y_test)
            super_acc.append(model_accuracy)
            model_pred = model.predict(X_test)
            model_f1 = f1_score(Y_test,model_pred,average ="weighted")
            super_f1.append(model_f1)
        return super_acc, super_f1

# %% [markdown]
# ## Active Learning

# %%
class Active_learner():
    def __init__(self,X,Y,model,data, percentage,query_method):
        self.X = X
        self.Y = Y
        self.short_df = data.copy()
        self.percent = percentage
        self.model = model
        self.query_method = query_method
        
    def learn(self):       
        # seeding
        classes = self.short_df['grades_round'].unique()
        seed_index = []
        for i in classes:
            seed_index.append(self.short_df['grades_round'][self.short_df['grades_round']==i].index[0])
        seed_index

        act_data = self.short_df.copy()
        accuracy_list = []

        # initialising
        train_idx = seed_index
        X_train = self.X[train_idx]
        y_train = self.Y[train_idx]

        # generating the pool
        X_pool = np.delete(self.X, train_idx, axis=0)
        y_pool = np.delete(self.Y, train_idx)

        act_data = act_data.drop(axis=0,index = train_idx)
        act_data.reset_index(drop = True,inplace=True)


        # initializing the active learner

        learner = ActiveLearner(
            estimator = self.model,
            X_training = X_train, y_training=y_train,
            query_strategy=self.query_method
        )

        # pool-based sampling
        n_queries = int(len(X)/(100/self.percent))
        for idx in range(n_queries):
            query_idx, query_instance = learner.query(X_pool)   
            learner.teach(
                X=X_pool[query_idx].reshape(1, -1),
                y=y_pool[query_idx].reshape(1, )
            )

            # remove queried instance from pool
            X_pool = np.delete(X_pool, query_idx, axis=0)
            y_pool = np.delete(y_pool, query_idx)

            act_data = act_data.drop(axis=0,index = query_idx)
            act_data.reset_index(drop=True, inplace=True)

            accuracy_list.append(learner.score(X_pool,y_pool))
#             print('Accuracy after query no. %d: %f' % (idx+1, learner.score(X_pool, y_pool)))
        print("By just labelling ",round(n_queries*100.0/len(X),2),"% of total data accuracy of ", round(learner.score(X_pool, y_pool),3), " % is achieved on the unseen data" )
        model_pred = learner.predict(X_pool)
        model_f1 = f1_score(y_pool,model_pred,average='weighted')
        return accuracy_list,model_f1

# %% [markdown]
# # Active learning Committee

# %%
class Active_learner_committee():
    def __init__(self,X,Y,data, percentage,query_method,learners):
        self.X = X
        self.Y = Y
        self.short_df = data.copy()
        self.percent = percentage
        self.query_method = query_method
        self.learners = learners
        
    def learn(self):       
        

        # seeding
        classes = self.short_df['grades_round'].unique()
        seed_index = []
        for i in classes:
            seed_index.append(self.short_df['grades_round'][self.short_df['grades_round']==i].index[0])
        seed_index

        act_data = self.short_df.copy()
        accuracy_list = []

        # initialising
        train_idx = seed_index
        X_train = self.X[train_idx]
        y_train = self.Y[train_idx]

        # generating the pool
        X_pool = np.delete(self.X, train_idx, axis=0)
        y_pool = np.delete(self.Y, train_idx)

        act_data = act_data.drop(axis=0,index = train_idx)
        act_data.reset_index(drop = True,inplace=True)
        
        initiated_committee = []
        for learner_idx,model in enumerate(self.learners):
            learner = ActiveLearner(
                estimator=model,
                X_training=X_train, y_training=y_train
            )
            initiated_committee.append(learner)
        # Commitee creation
        committee = Committee(
            learner_list= initiated_committee,
            query_strategy=vote_entropy_sampling
        )
        
        committee.teach(X_train,y_train)
        
        # pool-based sampling
        n_queries = int(len(X)/(100/self.percent))
        for idx in range(n_queries):
            query_idx, query_instance = committee.query(X_pool)   
            committee.teach(
                X=X_pool[query_idx].reshape(1, -1),
                y=y_pool[query_idx].reshape(1, )
            )

            # remove queried instance from pool
            X_pool = np.delete(X_pool, query_idx, axis=0)
            y_pool = np.delete(y_pool, query_idx)

            act_data = act_data.drop(axis=0,index = query_idx)
            act_data.reset_index(drop=True, inplace=True)

            accuracy_list.append(accuracy_score(committee.predict(X_pool),y_pool))
            print('Accuracy after query no. %d: %f' % (idx+1, accuracy_score(committee.predict(X_pool),y_pool)))
        print("By just labelling ",round(n_queries*100.0/len(X),2),"% of total data accuracy of ", round(accuracy_score(committee.predict(X_pool),y_pool),3), " % is achieved on the unseen data" )
        model_pred = committee.predict(X_pool)
        model_f1 = f1_score(y_pool,model_pred,average='weighted')
        return accuracy_list,model_f1

# %% [markdown]
# ## Sultan

# %%
# ## Active learner
# X = df[['length_ratio','aligned_score','aligned_score_demo','cos_similarity','cos_similarity_demo']]
# X = np.array(X) 
# Y = df['grades_round'].values

# Percent = 80
# Out:
# ******************************************************************************
# By just labelling  79.98 % of total data accuracy of  0.888  % is achieved on the unseen data
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# By just labelling  79.98 % of total data accuracy of  0.888  % is achieved on the unseen data
# By just labelling  79.98 % of total data accuracy of  0.882  % is achieved on the unseen data
# ******************************************************************************
# By just labelling  79.98 % of total data accuracy of  0.892  % is achieved on the unseen data
# By just labelling  79.98 % of total data accuracy of  0.892  % is achieved on the unseen data
# By just labelling  79.98 % of total data accuracy of  0.872  % is achieved on the unseen data
# ******************************************************************************
# By just labelling  79.98 % of total data accuracy of  0.865  % is achieved on the unseen data
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# By just labelling  79.98 % of total data accuracy of  0.795  % is achieved on the unseen data
# By just labelling  79.98 % of total data accuracy of  0.87  % is achieved on the unseen data
# ******************************************************************************
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# By just labelling  79.98 % of total data accuracy of  0.853  % is achieved on the unseen data
# By just labelling  79.98 % of total data accuracy of  0.851  % is achieved on the unseen data
# By just labelling  79.98 % of total data accuracy of  0.843  % is achieved on the unseen data
# ******************************************************************************
# By just labelling  79.98 % of total data accuracy of  0.841  % is achieved on the unseen data
# By just labelling  79.98 % of total data accuracy of  0.812  % is achieved on the unseen data
# By just labelling  79.98 % of total data accuracy of  0.836  % is achieved on the unseen data
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# supervised learning

iteration_count = 2

## Supervised learner
models = [LogisticRegression(),MultinomialNB(),RandomForestClassifier(n_estimators=100), \
          SVC(kernel='linear' , probability=True),SVC(probability=True)]

dict_accuracy_sl_min = {}
dict_accuracy_sl_avg = {}
dict_accuracy_sl_max = {}
dict_f1_score_sl = {}

for i, model in enumerate(models):
    new_accuracy_list = []
    f1_list = []
    for _ in range(iteration_count):
        sl = Supervised_learner(X,Y,model)
        accuracy,f1score = sl.learn()
        new_accuracy_list.append(accuracy)
        f1_list.append(f1score)
    dict_accuracy_sl_min[i]= np.min(new_accuracy_list,axis = 0)
    dict_accuracy_sl_avg[i]= np.mean(new_accuracy_list,axis = 0)
    dict_accuracy_sl_max[i]= np.max(new_accuracy_list,axis = 0)
    dict_f1_score_sl[i]= np.mean(f1_list,axis=0) 


pkl.dump( dict_accuracy_sl_min, open( "../../results/dict_accuracy_min_nn.pkl", "wb" ) )
pkl.dump( dict_accuracy_sl_max, open( "../../results/dict_accuracy_max_nn.pkl", "wb" ) )
pkl.dump( dict_accuracy_sl_avg, open( "../../results/dict_accuracy_avg_nn.pkl", "wb" ) )
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#plotting
dict_accuracy_al = pkl.load( open("../../results/dict_accuracy_al_nn_"+str(80)+".pkl","rb"))
dict_accuracy_sl_min = pkl.load( open("../../results/dict_accuracy_min_nn.pkl","rb"))
dict_accuracy_sl_max = pkl.load( open("../../results/dict_accuracy_max_nn.pkl","rb"))
dict_accuracy_sl_avg = pkl.load( open("../../results/dict_accuracy_avg_nn.pkl","rb"))

## plotting
fig = plt.figure(figsize=(18,20))
model_title = ["Logistic regression","Naive Bayes","Random Forest","SVC-linear","SVC"]
query_strategy = ["uncertainty_sampling","margin_sampling","entropy_sampling"]
for i in range(0,5):
    ax = fig.add_subplot(3,2,i+1)
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][2]), 20), dict_accuracy_sl_min[i],label = "Supervised learner_min")
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][2]), 20), dict_accuracy_sl_max[i],label = "Supervised learner_max")
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][2]), 20), dict_accuracy_sl_avg[i],label = "Supervised learner_avg")
    for j in range(len(query_strategy)):
        ax.plot(dict_accuracy_al[i][j],label = "Active learner {}".format(query_strategy[j]))
    ax.legend(loc="lower right")
    ax.set_xlabel("Number of queries")
    ax.set_ylabel("Accuracy %")
    ax.set_title(model_title[i])
    ax.grid(color='g', linestyle='-', linewidth=0.2)
    
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-15ef7e807765> in <module>()
#       1 #plotting
# ----> 2 dict_accuracy_al = pkl.load( open("../../results/dict_accuracy_al_nn_"+str(80)+".pkl","rb"))
#       3 dict_accuracy_sl_min = pkl.load( open("../../results/dict_accuracy_min_nn.pkl","rb"))
#       4 dict_accuracy_sl_max = pkl.load( open("../../results/dict_accuracy_max_nn.pkl","rb"))
#       5 dict_accuracy_sl_avg = pkl.load( open("../../results/dict_accuracy_avg_nn.pkl","rb"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../results/dict_accuracy_al_nn_80.pkl'

# %% [markdown]
# ## Bag of Words

# %%
#creating inputs and labels for BOW
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = df['grades_round'].values

Percent = 80

models = [LogisticRegression(),MultinomialNB(),RandomForestClassifier(n_estimators=100),SVC(kernel='linear' , probability=True),SVC(probability=True)]
query_methods = [uncertainty_sampling,margin_sampling,entropy_sampling]
dict_accuracy_al ={}
f1_score_list = {}
for i,model in enumerate(models):
    dict_accuracy_al[i] = []
    f1_score_list[i] = []
    print("******************************************************************************")
    for query_method in query_methods:
        ac = Active_learner(X,Y,model,df, Percent,query_method)
        accuracy_list,f1 = ac.learn()
        dict_accuracy_al[i].append(accuracy_list)
        f1_score_list[i].append(f1_score)
# dict_accuracy_al.to_pickle("../../results/dict_accuracy_al_mohler_"+str(Percent))
pkl.dump( dict_accuracy_al, open( "../../results/dict_accuracy_al_nn_bag_"+str(Percent)+".pkl", "wb" ) )

pkl.dump( f1_score_list, open( "../../results/f1_score_list_al_nn_bag_"+str(Percent)+".pkl", "wb"))
# Out:
# (646, 2540)

# %%
#creating inputs and labels for BOW
CV = CountVectorizer()
student_answer_count_vector = CV.fit_transform(df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = df['grades_round'].values
Percent = 80

# models = [LogisticRegression(),MultinomialNB(),RandomForestClassifier(n_estimators=100),SVC(kernel='linear' , probability=True),SVC(probability=True)]
models = [LogisticRegression(),MultinomialNB(),RandomForestClassifier(n_estimators=100)]
query_methods = [vote_entropy_sampling,max_disagreement_sampling,consensus_entropy_sampling]
dict_accuracy_al = {}
f1_score_list= {}
print("******************************************************************************")
for i,query_method in enumerate(query_methods):
    ac_committee = Active_learner_committee(X,Y,df, Percent,query_method,models)
    accuracy_list,f1 = ac_committee.learn()
    dict_accuracy_al[i].append(accuracy_list)
    f1_score_list[i].append(f1_score)
# dict_accuracy_al.to_pickle("../../results/dict_accuracy_al_mohler_"+str(Percent))
pkl.dump( dict_accuracy_al, open( "../../results/dict_accuracy_al_com_NN_bag_"+str(Percent)+".pkl", "wb" ) )
pkl.dump( f1_score_list, open( "../../results/f1_score_list_al_com_NN_bag_"+str(Percent)+".pkl", "wb" ) )

# %%
# supervised learning
iteration_count = 2

## Supervised learner
models = [LogisticRegression(),MultinomialNB(),RandomForestClassifier(n_estimators=100), \
          SVC(kernel='linear' , probability=True),SVC(probability=True)]

dict_accuracy_sl_min = {}
dict_accuracy_sl_avg = {}
dict_accuracy_sl_max = {}
dict_f1_score_sl = {}

for i, model in enumerate(models):
    new_accuracy_list = []
    f1_list = []
    for _ in range(iteration_count):
        sl = Supervised_learner(X,Y,model)
        accuracy,f1score = sl.learn()
        new_accuracy_list.append(accuracy)
        f1_list.append(f1score)
    dict_accuracy_sl_min[i]= np.min(new_accuracy_list,axis = 0)
    dict_accuracy_sl_avg[i]= np.mean(new_accuracy_list,axis = 0)
    dict_accuracy_sl_max[i]= np.max(new_accuracy_list,axis = 0)
    dict_f1_score_sl[i]= np.mean(f1_list,axis=0) 


pkl.dump( dict_accuracy_sl_min, open( "../../results/dict_accuracy_min_nn_bag.pkl", "wb" ) )
pkl.dump( dict_accuracy_sl_max, open( "../../results/dict_accuracy_max_nn_bag.pkl", "wb" ) )
pkl.dump( dict_accuracy_sl_avg, open( "../../results/dict_accuracy_avg_nn_bag.pkl", "wb" ) )
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#plotting
dict_accuracy_al = pkl.load( open("../../results/dict_accuracy_al_nn_bag_"+str(80)+".pkl","rb"))
dict_accuracy_sl_min = pkl.load( open("../../results/dict_accuracy_min_nn_bag.pkl","rb"))
dict_accuracy_sl_max = pkl.load( open("../../results/dict_accuracy_max_nn_bag.pkl","rb"))
dict_accuracy_sl_avg = pkl.load( open("../../results/dict_accuracy_avg_nn_bag.pkl","rb"))

## plotting
fig = plt.figure(figsize=(18,20))
model_title = ["Logistic regression","Naive Bayes","Random Forest","SVC-linear","SVC"]
query_strategy = ["uncertainty_sampling","margin_sampling","entropy_sampling"]
for i in range(0,5):
    ax = fig.add_subplot(3,2,i+1)
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][2]), 20), dict_accuracy_sl_min[i],label = "Supervised learner_min")
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][2]), 20), dict_accuracy_sl_max[i],label = "Supervised learner_max")
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][2]), 20), dict_accuracy_sl_avg[i],label = "Supervised learner_avg")
    for j in range(len(query_strategy)):
        ax.plot(dict_accuracy_al[i][j],label = "Active learner {}".format(query_strategy[j]))
    ax.legend(loc="lower right")
    ax.set_xlabel("Number of queries")
    ax.set_ylabel("Accuracy %")
    ax.set_title(model_title[i])
    ax.grid(color='g', linestyle='-', linewidth=0.2)
    ax.set_ylim(0,1)

plt.tight_layout()

plt.show()

# %%
#plotting committee
dict_accuracy_al = pkl.load( open("../../results/dict_accuracy_al_com_NN_bag_"+str(80)+".pkl","rb"))
dict_accuracy_sl_min = pkl.load( open("../../results/dict_accuracy_min_nn_bag.pkl","rb"))
dict_accuracy_sl_max = pkl.load( open("../../results/dict_accuracy_max_nn_bag.pkl","rb"))
dict_accuracy_sl_avg = pkl.load( open("../../results/dict_accuracy_avg_nn_bag.pkl","rb"))


## plotting
fig = plt.figure(figsize=(18,20))
# model_title = ["Logistic regression","Naive Bayes","Random Forest","SVC-linear","SVC"]
query_strategy = ["vote_entropy_sampling","max_disagreement_sampling","consensus_entropy_sampling"]
for i in range(0,1):
    ax = fig.add_subplot(1,1,i+1)
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][0]), 20), dict_accuracy_sl_min[i],label = "Supervised learner_min")
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][0]), 20), dict_accuracy_sl_max[i],label = "Supervised learner_max")
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][0]), 20), dict_accuracy_sl_avg[i],label = "Supervised learner_avg")
    for j in range(len(query_strategy)):
        ax.plot(dict_accuracy_al[j][0],label = "Active learner {}".format(query_strategy[j]))
    ax.legend(loc="lower right")
    ax.set_xlabel("Number of queries")
    ax.set_ylabel("Accuracy %")
    ax.set_title("Committee")
    ax.grid(color='g', linestyle='-', linewidth=0.2)
    ax.set_ylim(0,1)
# plt.tight_layout()

plt.show()

# %% [markdown]
# ## Tf-IDf

# %%
#creating inputs and labels for TFidf
Tf = TfidfVectorizer()
student_answer_count_vector = Tf.fit_transform(df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = df['grades_round'].values

Percent = 80

models = [LogisticRegression(),MultinomialNB(),RandomForestClassifier(n_estimators=100),SVC(kernel='linear' , probability=True),SVC(probability=True)]
query_methods = [uncertainty_sampling,margin_sampling,entropy_sampling]
dict_accuracy_al ={}
f1_score_list = {}
for i,model in enumerate(models):
    dict_accuracy_al[i] = []
    f1_score_list[i] = []
    print("******************************************************************************")
    for query_method in query_methods:
        ac = Active_learner(X,Y,model,df, Percent,query_method)
        accuracy_list,f1 = ac.learn()
        dict_accuracy_al[i].append(accuracy_list)
        f1_score_list[i].append(f1_score)
        
        
# dict_accuracy_al.to_pickle("../../results/dict_accuracy_al_mohler_"+str(Percent))
pkl.dump( dict_accuracy_al, open( "../../results/dict_accuracy_al_nn_tfidf_"+str(Percent)+".pkl", "wb" ) )

pkl.dump( f1_score_list, open( "../../results/f1_score_list_al_nn_tfidf_"+str(Percent)+".pkl", "wb" ) )
# Out:
# (646, 2540)

# %%
#creating inputs and labels for TFidf
Tf = TfidfVectorizer()
student_answer_count_vector = Tf.fit_transform(df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = df['grades_round'].values

Percent = 80

# models = [LogisticRegression(),MultinomialNB(),RandomForestClassifier(n_estimators=100),SVC(kernel='linear' , probability=True),SVC(probability=True)]
models = [LogisticRegression(),MultinomialNB(),RandomForestClassifier(n_estimators=100)]
query_methods = [vote_entropy_sampling,max_disagreement_sampling,consensus_entropy_sampling]
dict_accuracy_al = {}
f1_score_list= {}
print("******************************************************************************")
for i,query_method in enumerate(query_methods):
    ac_committee = Active_learner_committee(X,Y,df, Percent,query_method,models)
    accuracy_list,f1 = ac_committee.learn()
    dict_accuracy_al[i].append(accuracy_list)
    f1_score_list[i].append(f1_score)
# dict_accuracy_al.to_pickle("../../results/dict_accuracy_al_mohler_"+str(Percent))
pkl.dump( dict_accuracy_al, open( "../../results/dict_accuracy_al_com_NN_tfidf_"+str(Percent)+".pkl", "wb" ) )
pkl.dump( f1_score_list, open( "../../results/f1_score_list_al_com_NN_tfidf_"+str(Percent)+".pkl", "wb" ) )

# %%
# supervised learning
#creating inputs and labels for TFidf
Tf = TfidfVectorizer()
student_answer_count_vector = Tf.fit_transform(df['student_modified'])
student_answer_count_vector = student_answer_count_vector.toarray()

X = student_answer_count_vector
Y = df['grades_round'].values

iteration_count = 2

## Supervised learner
models = [LogisticRegression(),MultinomialNB(),RandomForestClassifier(n_estimators=100), \
          SVC(kernel='linear' , probability=True),SVC(probability=True)]

dict_accuracy_sl_min = {}
dict_accuracy_sl_avg = {}
dict_accuracy_sl_max = {}
dict_f1_score_sl = {}

for i, model in enumerate(models):
    new_accuracy_list = []
    f1_list = []
    for _ in range(iteration_count):
        sl = Supervised_learner(X,Y,model)
        accuracy,f1score = sl.learn()
        new_accuracy_list.append(accuracy)
        f1_list.append(f1score)
    dict_accuracy_sl_min[i]= np.min(new_accuracy_list,axis = 0)
    dict_accuracy_sl_avg[i]= np.mean(new_accuracy_list,axis = 0)
    dict_accuracy_sl_max[i]= np.max(new_accuracy_list,axis = 0)
    dict_f1_score_sl[i]= np.mean(f1_list,axis=0) 


pkl.dump( dict_accuracy_sl_min, open( "../../results/dict_accuracy_min_nn_tfidf.pkl", "wb" ) )
pkl.dump( dict_accuracy_sl_max, open( "../../results/dict_accuracy_max_nn_tfidf.pkl", "wb" ) )
pkl.dump( dict_accuracy_sl_avg, open( "../../results/dict_accuracy_avg_nn_tfidf.pkl", "wb" ) )
# Out:
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mohandass/anaconda3/envs/maluuba/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#plotting
dict_accuracy_al = pkl.load( open("../../results/dict_accuracy_al_nn_tfidf_"+str(80)+".pkl","rb"))
dict_accuracy_sl_min = pkl.load( open("../../results/dict_accuracy_min_nn_tfidf.pkl","rb"))
dict_accuracy_sl_max = pkl.load( open("../../results/dict_accuracy_max_nn_tfidf.pkl","rb"))
dict_accuracy_sl_avg = pkl.load( open("../../results/dict_accuracy_avg_nn_tfidf.pkl","rb"))

## plotting
fig = plt.figure(figsize=(18,20))
model_title = ["Logistic regression","Naive Bayes","Random Forest","SVC-linear","SVC"]
query_strategy = ["uncertainty_sampling","margin_sampling","entropy_sampling"]
for i in range(0,5):
    ax = fig.add_subplot(3,2,i+1)
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][2]), 20), dict_accuracy_sl_min[i],label = "Supervised learner_min")
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][2]), 20), dict_accuracy_sl_max[i],label = "Supervised learner_max")
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][2]), 20), dict_accuracy_sl_avg[i],label = "Supervised learner_avg")
    for j in range(len(query_strategy)):
        ax.plot(dict_accuracy_al[i][j],label = "Active learner {}".format(query_strategy[j]))
    ax.legend(loc="lower right")
    ax.set_xlabel("Number of queries")
    ax.set_ylabel("Accuracy %")
    ax.set_title(model_title[i])
    ax.grid(color='g', linestyle='-', linewidth=0.2)
    ax.set_ylim(0,1)

plt.tight_layout()

plt.show()

# %%
#plotting committee
dict_accuracy_al = pkl.load( open("../../results/dict_accuracy_al_com_NN_tfidf_"+str(80)+".pkl","rb"))
dict_accuracy_sl_min = pkl.load( open("../../results/dict_accuracy_min_nn_tfidf.pkl","rb"))
dict_accuracy_sl_max = pkl.load( open("../../results/dict_accuracy_max_nn_tfidf.pkl","rb"))
dict_accuracy_sl_avg = pkl.load( open("../../results/dict_accuracy_avg_nn_tfidf.pkl","rb"))


## plotting
fig = plt.figure(figsize=(18,20))
# model_title = ["Logistic regression","Naive Bayes","Random Forest","SVC-linear","SVC"]
query_strategy = ["vote_entropy_sampling","max_disagreement_sampling","consensus_entropy_sampling"]
for i in range(0,1):
    ax = fig.add_subplot(1,1,i+1)
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][0]), 20), dict_accuracy_sl_min[i],label = "Supervised learner_min")
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][0]), 20), dict_accuracy_sl_max[i],label = "Supervised learner_max")
    ax.plot(np.linspace(0, len(dict_accuracy_al[1][0]), 20), dict_accuracy_sl_avg[i],label = "Supervised learner_avg")
    for j in range(len(query_strategy)):
        ax.plot(dict_accuracy_al[j][0],label = "Active learner {}".format(query_strategy[j]))
    ax.legend(loc="lower right")
    ax.set_xlabel("Number of queries")
    ax.set_ylabel("Accuracy %")
    ax.set_title("Committee")
    ax.grid(color='g', linestyle='-', linewidth=0.2)
    ax.set_ylim(0,1)
# plt.tight_layout()

plt.show()
